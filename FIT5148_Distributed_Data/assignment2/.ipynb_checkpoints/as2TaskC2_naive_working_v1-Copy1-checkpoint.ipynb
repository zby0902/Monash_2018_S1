# %% [markdown]
# The processing for stream data can be : db.collection.insertmany() for `fire`, and db.collection.insertone() for `climate`;

# %% [markdown]
# It seems the stream processing function is unable to finish the reference specified in the data model.
# So we just insert in the collections and later set up the reference before we check the records are already there?

# %% [markdown]
# #### We can use tupel-slide window

# %%
import sys
from pyspark import SparkContext
from pyspark.streaming import StreamingContext
import pymongo
from pymongo import MongoClient


def climates_split(record):
    word = record[0]
    count = record[1]
    fields = word.split(',')
    
    client = MongoClient()
    db = client.fit5148_db
    collection = db.climates
    collection.update({"id": fields[0]}, {"$inc": {"count": count}}, upsert=True)
    client.close()
    
def fires_split(record):
    word = record[0]
    count = record[1]
    fields = word.split(',')
    
    client = MongoClient()
    db = client.fit5148_db
    collection = db.fires
    collection.update({"id": fields[0]}, {"$inc": {"count": count}}, upsert=True)
    client.close()
       
def send(record):
    
    client = MongoClient()
    db = client.fit5148_db
    collection = db.climate
    collection.insert_one({"id": record})
    client.close()    
    

    
    
# We add this line to avoid an error : "Cannot run multiple SparkContexts at once". If there is an existing spark context, we will reuse it instead of creating a new context.
sc = SparkContext.getOrCreate()

# If there is no existing spark context, we now create a new context
if (sc is None):
    sc = SparkContext()
ssc = StreamingContext.getActive()
ssc = StreamingContext(sc,1)


host = 'localhost'
stream = ssc.socketTextStream(host,9999)


# Split each stream into records
#fires = fires.flatMap(lambda line: line.split('\n'))
#stream = stream.flatMap(lambda line: line.split('\n'))


# Count each word in each batch
#wordCounts = pairs.reduceByKey(lambda x, y: x + y)

# Output the result
stream.pprint()
ssc.start()
try:
    ssc.awaitTermination(timeout=60)
except KeyboardInterrupt:
    ssc.stop()
    sc.stop()

ssc.stop()
sc.stop()
# Out:
# -------------------------------------------
# Time: 2018-05-20 18:54:17
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:18
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:19
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:21
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:22
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:23
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:24
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:25
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:26
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:27
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:28
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:29
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:31
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:32
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:33
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:34
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:35
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:36
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:37
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:38
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:39
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:40
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:41
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:42
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:43
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:44
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:45
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:46
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:47
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:48
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:49
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:51
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:52
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:53
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:54
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:55
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:56
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:57
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:58
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:54:59
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:55:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:55:01
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:55:02
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:55:03
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:55:04
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:55:05
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:55:06
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:55:07
# -------------------------------------------
#
# -------------------------------------------
# Time: 2018-05-20 18:55:08
# -------------------------------------------

# %%
sc = SparkContext.getOrCreate()

# If there is no existing spark context, we now create a new context
if (sc is None):
    sc = SparkContext()
def f(iterator):
    for x in iterator:
        print(x)

# %%
def f(x): print(x)
a= sc.parallelize([1, 2, 3, 4, 5]).collect()
