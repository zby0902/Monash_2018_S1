# %%
import xml.etree.ElementTree as ET
import re
tree = ET.parse('./topics/ES2002b.topic.xml')

# %%
root = tree.getroot()

# %%
root.tag
# Out:
# '{http://nite.sourceforge.net/}root'

# %%
name_space = {'nite':'http://nite.sourceforge.net/'}

# %%
# The regex used to capture the words segements
p_pattern = r'#id\((\w+\.\w\.\w+)\)\.{2}id\((\w+\.\w\.\w+)\)'
s_pattern = r'#id\((\w+\.\w\.\w+)\)'

# %%
word_segments = []

# %%
a = []
for topic in root.iter('topic'):
    for child in topic.findall('nite:child',name_space):
        a.append(child)

# %%
len(a)
# Out:
# 325

# %%
for topic in root.iter('topic'):
    for child in topic.findall('nite:child',name_space):
        try:
            word_segments.append(list(re.search(p_pattern,child.attrib['href']).groups()))
        except:
            word_segments.append(list(re.search(s_pattern,child.attrib['href']).groups()))

# %%
word_segments
# Out:
# [['ES2002b.B.words0', 'ES2002b.B.words128'],
#  ['ES2002b.D.words0', 'ES2002b.D.words5'],
#  ['ES2002b.C.words0'],
#  ['ES2002b.D.words6', 'ES2002b.D.words13'],
#  ['ES2002b.B.words129', 'ES2002b.B.words294'],
#  ['ES2002b.D.words14', 'ES2002b.D.words17'],
#  ['ES2002b.B.words295', 'ES2002b.B.words321'],
#  ['ES2002b.D.words18', 'ES2002b.D.words37'],
#  ['ES2002b.B.words322', 'ES2002b.B.words347'],
#  ['ES2002b.D.words38', 'ES2002b.D.words44'],
#  ['ES2002b.B.words348', 'ES2002b.B.words373'],
#  ['ES2002b.A.words0', 'ES2002b.A.words8'],
#  ['ES2002b.B.words374', 'ES2002b.B.words449'],
#  ['ES2002b.B.words450', 'ES2002b.B.words464'],
#  ['ES2002b.C.words1', 'ES2002b.C.words5'],
#  ['ES2002b.D.words45', 'ES2002b.D.words46'],
#  ['ES2002b.B.words465', 'ES2002b.B.words468'],
#  ['ES2002b.C.words6', 'ES2002b.C.words22'],
#  ['ES2002b.B.words469', 'ES2002b.B.words481'],
#  ['ES2002b.D.words47'],
#  ['ES2002b.C.words23', 'ES2002b.C.words34'],
#  ['ES2002b.C.words35', 'ES2002b.C.words123'],
#  ['ES2002b.B.words482', 'ES2002b.B.words486'],
#  ['ES2002b.D.words48', 'ES2002b.D.words49'],
#  ['ES2002b.C.words124', 'ES2002b.C.words243'],
#  ['ES2002b.B.words487', 'ES2002b.B.words490'],
#  ['ES2002b.C.words244', 'ES2002b.C.words337'],
#  ['ES2002b.B.words491', 'ES2002b.B.words492'],
#  ['ES2002b.C.words338', 'ES2002b.C.words427'],
#  ['ES2002b.B.words493', 'ES2002b.B.words519'],
#  ['ES2002b.D.words50', 'ES2002b.D.words129'],
#  ['ES2002b.B.words520', 'ES2002b.B.words535'],
#  ['ES2002b.A.words9', 'ES2002b.A.words24'],
#  ['ES2002b.C.words428', 'ES2002b.C.words440'],
#  ['ES2002b.A.words25', 'ES2002b.A.words26'],
#  ['ES2002b.B.words536', 'ES2002b.B.words537'],
#  ['ES2002b.D.words130', 'ES2002b.D.words143'],
#  ['ES2002b.C.words441', 'ES2002b.C.words497'],
#  ['ES2002b.D.words144', 'ES2002b.D.words156'],
#  ['ES2002b.B.words538', 'ES2002b.B.words543'],
#  ['ES2002b.D.words157', 'ES2002b.D.words158'],
#  ['ES2002b.A.words27'],
#  ['ES2002b.D.words159', 'ES2002b.D.words162'],
#  ['ES2002b.B.words544', 'ES2002b.B.words646'],
#  ['ES2002b.D.words163', 'ES2002b.D.words164'],
#  ['ES2002b.A.words28'],
#  ['ES2002b.D.words165', 'ES2002b.D.words170'],
#  ['ES2002b.C.words498', 'ES2002b.C.words553'],
#  ['ES2002b.B.words647', 'ES2002b.B.words663'],
#  ['ES2002b.C.words554', 'ES2002b.C.words585'],
#  ['ES2002b.D.words171', 'ES2002b.D.words184'],
#  ['ES2002b.B.words664', 'ES2002b.B.words703'],
#  ['ES2002b.D.words185', 'ES2002b.D.words189'],
#  ['ES2002b.B.words704', 'ES2002b.B.words751'],
#  ['ES2002b.D.words190', 'ES2002b.D.words275'],
#  ['ES2002b.B.words752', 'ES2002b.B.words755'],
#  ['ES2002b.C.words586', 'ES2002b.C.words591'],
#  ['ES2002b.B.words756', 'ES2002b.B.words778'],
#  ['ES2002b.C.words592', 'ES2002b.C.words627'],
#  ['ES2002b.B.words779', 'ES2002b.B.words828'],
#  ['ES2002b.D.words276', 'ES2002b.D.words279'],
#  ['ES2002b.C.words628', 'ES2002b.C.words647'],
#  ['ES2002b.B.words829', 'ES2002b.B.words833'],
#  ['ES2002b.D.words280', 'ES2002b.D.words462'],
#  ['ES2002b.B.words834', 'ES2002b.B.words839'],
#  ['ES2002b.A.words29'],
#  ['ES2002b.B.words840', 'ES2002b.B.words934'],
#  ['ES2002b.D.words463', 'ES2002b.D.words464'],
#  ['ES2002b.A.words30', 'ES2002b.A.words42'],
#  ['ES2002b.D.words728', 'ES2002b.D.words808'],
#  ['ES2002b.A.words94', 'ES2002b.A.words102'],
#  ['ES2002b.B.words1049', 'ES2002b.B.words1050'],
#  ['ES2002b.D.words809', 'ES2002b.D.words810'],
#  ['ES2002b.B.words1051', 'ES2002b.B.words1052'],
#  ['ES2002b.A.words103', 'ES2002b.A.words106'],
#  ['ES2002b.B.words1053', 'ES2002b.B.words1058'],
#  ['ES2002b.A.words107', 'ES2002b.A.words110'],
#  ['ES2002b.B.words1059', 'ES2002b.B.words1062'],
#  ['ES2002b.D.words811', 'ES2002b.D.words903'],
#  ['ES2002b.B.words935', 'ES2002b.B.words953'],
#  ['ES2002b.D.words465', 'ES2002b.D.words468'],
#  ['ES2002b.A.words43'],
#  ['ES2002b.D.words469', 'ES2002b.D.words470'],
#  ['ES2002b.C.words648', 'ES2002b.C.words655'],
#  ['ES2002b.B.words954', 'ES2002b.B.words957'],
#  ['ES2002b.D.words471', 'ES2002b.D.words485'],
#  ['ES2002b.A.words44', 'ES2002b.A.words47'],
#  ['ES2002b.B.words958', 'ES2002b.B.words963'],
#  ['ES2002b.D.words486', 'ES2002b.D.words496'],
#  ['ES2002b.B.words964', 'ES2002b.B.words965'],
#  ['ES2002b.D.words497', 'ES2002b.D.words532'],
#  ['ES2002b.C.words656', 'ES2002b.C.words660'],
#  ['ES2002b.B.words966', 'ES2002b.B.words981'],
#  ['ES2002b.A.words48'],
#  ['ES2002b.D.words533', 'ES2002b.D.words534'],
#  ['ES2002b.B.words982', 'ES2002b.B.words983'],
#  ['ES2002b.A.words49'],
#  ['ES2002b.D.words535', 'ES2002b.D.words686'],
#  ['ES2002b.B.words984', 'ES2002b.B.words1019'],
#  ['ES2002b.A.words50', 'ES2002b.A.words54'],
#  ['ES2002b.B.words1020', 'ES2002b.B.words1031'],
#  ['ES2002b.D.words687', 'ES2002b.D.words695'],
#  ['ES2002b.A.words55', 'ES2002b.A.words77'],
#  ['ES2002b.D.words696', 'ES2002b.D.words703'],
#  ['ES2002b.B.words1032', 'ES2002b.B.words1033'],
#  ['ES2002b.D.words704', 'ES2002b.D.words705'],
#  ['ES2002b.A.words78', 'ES2002b.A.words79'],
#  ['ES2002b.D.words706', 'ES2002b.D.words715'],
#  ['ES2002b.A.words80', 'ES2002b.A.words85'],
#  ['ES2002b.D.words716', 'ES2002b.D.words719'],
#  ['ES2002b.C.words661', 'ES2002b.C.words672'],
#  ['ES2002b.A.words86', 'ES2002b.A.words87'],
#  ['ES2002b.D.words720', 'ES2002b.D.words721'],
#  ['ES2002b.B.words1034', 'ES2002b.B.words1038'],
#  ['ES2002b.D.words722', 'ES2002b.D.words727'],
#  ['ES2002b.B.words1039', 'ES2002b.B.words1048'],
#  ['ES2002b.A.words88', 'ES2002b.A.words93'],
#  ['ES2002b.D.words904', 'ES2002b.D.words988'],
#  ['ES2002b.B.words1063'],
#  ['ES2002b.A.words111', 'ES2002b.A.words115'],
#  ['ES2002b.D.words989', 'ES2002b.D.words1153'],
#  ['ES2002b.B.words1064', 'ES2002b.B.words1069'],
#  ['ES2002b.D.words1154', 'ES2002b.D.words1345'],
#  ['ES2002b.B.words1070', 'ES2002b.B.words1073'],
#  ['ES2002b.A.words116', 'ES2002b.A.words125'],
#  ['ES2002b.D.words1346', 'ES2002b.D.words1531'],
#  ['ES2002b.B.words1074', 'ES2002b.B.words1094'],
#  ['ES2002b.D.words1532', 'ES2002b.D.words1654'],
#  ['ES2002b.B.words1095', 'ES2002b.B.words1124'],
#  ['ES2002b.D.words1655', 'ES2002b.D.words1749'],
#  ['ES2002b.B.words1125', 'ES2002b.B.words1134'],
#  ['ES2002b.D.words1750', 'ES2002b.D.words1761'],
#  ['ES2002b.B.words1135', 'ES2002b.B.words1212'],
#  ['ES2002b.D.words1762', 'ES2002b.D.words1774'],
#  ['ES2002b.B.words1213', 'ES2002b.B.words1300'],
#  ['ES2002b.D.words1775', 'ES2002b.D.words1789'],
#  ['ES2002b.A.words126', 'ES2002b.A.words162'],
#  ['ES2002b.B.words1301', 'ES2002b.B.words1311'],
#  ['ES2002b.A.words163', 'ES2002b.A.words259'],
#  ['ES2002b.B.words1312', 'ES2002b.B.words1315'],
#  ['ES2002b.D.words1790', 'ES2002b.D.words1791'],
#  ['ES2002b.B.words1316', 'ES2002b.B.words1325'],
#  ['ES2002b.D.words1792', 'ES2002b.D.words1863'],
#  ['ES2002b.A.words260', 'ES2002b.A.words261'],
#  ['ES2002b.B.words1326', 'ES2002b.B.words1345'],
#  ['ES2002b.A.words262', 'ES2002b.A.words263'],
#  ['ES2002b.D.words1864', 'ES2002b.D.words1872'],
#  ['ES2002b.B.words1346', 'ES2002b.B.words1350'],
#  ['ES2002b.C.words673', 'ES2002b.C.words674'],
#  ['ES2002b.B.words1351', 'ES2002b.B.words1374'],
#  ['ES2002b.C.words675', 'ES2002b.C.words701'],
#  ['ES2002b.D.words1873', 'ES2002b.D.words1899'],
#  ['ES2002b.C.words702', 'ES2002b.C.words703'],
#  ['ES2002b.B.words1375', 'ES2002b.B.words1473'],
#  ['ES2002b.D.words1900', 'ES2002b.D.words1911'],
#  ['ES2002b.A.words264', 'ES2002b.A.words305'],
#  ['ES2002b.B.words1474', 'ES2002b.B.words1475'],
#  ['ES2002b.D.words1912', 'ES2002b.D.words1919'],
#  ['ES2002b.B.words1476', 'ES2002b.B.words1506'],
#  ['ES2002b.D.words1920', 'ES2002b.D.words1921'],
#  ['ES2002b.A.words306', 'ES2002b.A.words307'],
#  ['ES2002b.D.words1922', 'ES2002b.D.words1923'],
#  ['ES2002b.A.words308', 'ES2002b.A.words430'],
#  ['ES2002b.D.words1924', 'ES2002b.D.words1925'],
#  ['ES2002b.B.words1507', 'ES2002b.B.words1508'],
#  ['ES2002b.D.words1926', 'ES2002b.D.words1937'],
#  ['ES2002b.B.words1509', 'ES2002b.B.words1510'],
#  ['ES2002b.D.words1938', 'ES2002b.D.words1944'],
#  ['ES2002b.B.words1511', 'ES2002b.B.words1514'],
#  ['ES2002b.D.words1945', 'ES2002b.D.words1946'],
#  ['ES2002b.B.words1515', 'ES2002b.B.words1535'],
#  ['ES2002b.B.words1536', 'ES2002b.B.words1556'],
#  ['ES2002b.A.words431'],
#  ['ES2002b.D.words1947', 'ES2002b.D.words1950'],
#  ['ES2002b.A.words432', 'ES2002b.A.words500'],
#  ['ES2002b.C.words704', 'ES2002b.C.words705'],
#  ['ES2002b.D.words1951', 'ES2002b.D.words1952'],
#  ['ES2002b.B.words1557', 'ES2002b.B.words1562'],
#  ['ES2002b.D.words1953', 'ES2002b.D.words1954'],
#  ['ES2002b.B.words1563', 'ES2002b.B.words1564'],
#  ['ES2002b.D.words1955', 'ES2002b.D.words1971'],
#  ['ES2002b.A.words501', 'ES2002b.A.words609'],
#  ['ES2002b.B.words1565', 'ES2002b.B.words1575'],
#  ['ES2002b.D.words1972', 'ES2002b.D.words1977'],
#  ['ES2002b.B.words1576', 'ES2002b.B.words1577'],
#  ['ES2002b.D.words1978', 'ES2002b.D.words1981'],
#  ['ES2002b.B.words1578', 'ES2002b.B.words1579'],
#  ['ES2002b.D.words1982', 'ES2002b.D.words1984'],
#  ['ES2002b.B.words1580', 'ES2002b.B.words1581'],
#  ['ES2002b.D.words1985', 'ES2002b.D.words1986'],
#  ['ES2002b.B.words1582', 'ES2002b.B.words1674'],
#  ['ES2002b.D.words1987', 'ES2002b.D.words1990'],
#  ['ES2002b.A.words610', 'ES2002b.A.words613'],
#  ['ES2002b.D.words1991', 'ES2002b.D.words2072'],
#  ['ES2002b.B.words1675', 'ES2002b.B.words1681'],
#  ['ES2002b.C.words706', 'ES2002b.C.words748'],
#  ['ES2002b.A.words614'],
#  ['ES2002b.B.words1682', 'ES2002b.B.words1683'],
#  ['ES2002b.D.words2073', 'ES2002b.D.words2082'],
#  ['ES2002b.C.words749'],
#  ['ES2002b.B.words1684', 'ES2002b.B.words1704'],
#  ['ES2002b.C.words750', 'ES2002b.C.words762'],
#  ['ES2002b.A.words615', 'ES2002b.A.words626'],
#  ['ES2002b.B.words1705', 'ES2002b.B.words1713'],
#  ['ES2002b.A.words627', 'ES2002b.A.words857'],
#  ['ES2002b.B.words1714', 'ES2002b.B.words1717'],
#  ['ES2002b.D.words2083', 'ES2002b.D.words2086'],
#  ['ES2002b.A.words858', 'ES2002b.A.words876'],
#  ['ES2002b.D.words2109', 'ES2002b.D.words2159'],
#  ['ES2002b.A.words1345', 'ES2002b.A.words1426'],
#  ['ES2002b.D.words2160', 'ES2002b.D.words2166'],
#  ['ES2002b.B.words1767', 'ES2002b.B.words1768'],
#  ['ES2002b.D.words2167', 'ES2002b.D.words2170'],
#  ['ES2002b.B.words1769', 'ES2002b.B.words1770'],
#  ['ES2002b.D.words2171', 'ES2002b.D.words2173'],
#  ['ES2002b.B.words1771', 'ES2002b.B.words1789'],
#  ['ES2002b.D.words2174', 'ES2002b.D.words2175'],
#  ['ES2002b.B.words1790', 'ES2002b.B.words1791'],
#  ['ES2002b.D.words2176', 'ES2002b.D.words2179'],
#  ['ES2002b.B.words1792', 'ES2002b.B.words1796'],
#  ['ES2002b.A.words1427', 'ES2002b.A.words1491'],
#  ['ES2002b.A.words877', 'ES2002b.A.words1029'],
#  ['ES2002b.B.words1718', 'ES2002b.B.words1723'],
#  ['ES2002b.D.words2087', 'ES2002b.D.words2088'],
#  ['ES2002b.A.words1030', 'ES2002b.A.words1290'],
#  ['ES2002b.B.words1724', 'ES2002b.B.words1725'],
#  ['ES2002b.D.words2089', 'ES2002b.D.words2090'],
#  ['ES2002b.B.words1726', 'ES2002b.B.words1731'],
#  ['ES2002b.D.words2091', 'ES2002b.D.words2096'],
#  ['ES2002b.B.words1732', 'ES2002b.B.words1733'],
#  ['ES2002b.D.words2097', 'ES2002b.D.words2100'],
#  ['ES2002b.B.words1734', 'ES2002b.B.words1758'],
#  ['ES2002b.D.words2101', 'ES2002b.D.words2104'],
#  ['ES2002b.A.words1291', 'ES2002b.A.words1344'],
#  ['ES2002b.D.words2105', 'ES2002b.D.words2106'],
#  ['ES2002b.B.words1759', 'ES2002b.B.words1766'],
#  ['ES2002b.D.words2107', 'ES2002b.D.words2108'],
#  ['ES2002b.A.words1492', 'ES2002b.A.words1547'],
#  ['ES2002b.B.words1797', 'ES2002b.B.words1799'],
#  ['ES2002b.D.words2180', 'ES2002b.D.words2182'],
#  ['ES2002b.B.words1800', 'ES2002b.B.words1896'],
#  ['ES2002b.D.words2183', 'ES2002b.D.words2184'],
#  ['ES2002b.A.words1548', 'ES2002b.A.words1718'],
#  ['ES2002b.B.words1897', 'ES2002b.B.words1902'],
#  ['ES2002b.D.words2185', 'ES2002b.D.words2188'],
#  ['ES2002b.B.words1903', 'ES2002b.B.words1917'],
#  ['ES2002b.D.words2189', 'ES2002b.D.words2192'],
#  ['ES2002b.B.words1918', 'ES2002b.B.words1919'],
#  ['ES2002b.D.words2193', 'ES2002b.D.words2240'],
#  ['ES2002b.A.words1719', 'ES2002b.A.words1751'],
#  ['ES2002b.B.words1920'],
#  ['ES2002b.D.words2241', 'ES2002b.D.words2242'],
#  ['ES2002b.A.words1752'],
#  ['ES2002b.D.words2243', 'ES2002b.D.words2249'],
#  ['ES2002b.B.words1921', 'ES2002b.B.words1953'],
#  ['ES2002b.B.words1954', 'ES2002b.B.words2007'],
#  ['ES2002b.D.words2250'],
#  ['ES2002b.A.words1753', 'ES2002b.A.words1889'],
#  ['ES2002b.B.words2008', 'ES2002b.B.words2011'],
#  ['ES2002b.D.words2251', 'ES2002b.D.words2254'],
#  ['ES2002b.B.words2012', 'ES2002b.B.words2015'],
#  ['ES2002b.D.words2255'],
#  ['ES2002b.B.words2016', 'ES2002b.B.words2023'],
#  ['ES2002b.D.words2256', 'ES2002b.D.words2257'],
#  ['ES2002b.B.words2024', 'ES2002b.B.words2034'],
#  ['ES2002b.B.words2035', 'ES2002b.B.words2138'],
#  ['ES2002b.A.words1890'],
#  ['ES2002b.D.words2258', 'ES2002b.D.words2266'],
#  ['ES2002b.C.words763', 'ES2002b.C.words801'],
#  ['ES2002b.B.words2139', 'ES2002b.B.words2143'],
#  ['ES2002b.C.words802', 'ES2002b.C.words803'],
#  ['ES2002b.D.words2267', 'ES2002b.D.words2288'],
#  ['ES2002b.C.words804', 'ES2002b.C.words826'],
#  ['ES2002b.D.words2289', 'ES2002b.D.words2325'],
#  ['ES2002b.B.words2144', 'ES2002b.B.words2145'],
#  ['ES2002b.A.words1891', 'ES2002b.A.words1894'],
#  ['ES2002b.B.words2146', 'ES2002b.B.words2152'],
#  ['ES2002b.C.words827', 'ES2002b.C.words828'],
#  ['ES2002b.D.words2326', 'ES2002b.D.words2386'],
#  ['ES2002b.B.words2153', 'ES2002b.B.words2155'],
#  ['ES2002b.B.words2455', 'ES2002b.B.words2519'],
#  ['ES2002b.A.words1895', 'ES2002b.A.words2086'],
#  ['ES2002b.B.words2156', 'ES2002b.B.words2157'],
#  ['ES2002b.D.words2387', 'ES2002b.D.words2390'],
#  ['ES2002b.B.words2158', 'ES2002b.B.words2159'],
#  ['ES2002b.D.words2391', 'ES2002b.D.words2394'],
#  ['ES2002b.B.words2160', 'ES2002b.B.words2163'],
#  ['ES2002b.D.words2395', 'ES2002b.D.words2396'],
#  ['ES2002b.B.words2164'],
#  ['ES2002b.D.words2397', 'ES2002b.D.words2414'],
#  ['ES2002b.B.words2165', 'ES2002b.B.words2353'],
#  ['ES2002b.D.words2415', 'ES2002b.D.words2418'],
#  ['ES2002b.A.words2087'],
#  ['ES2002b.D.words2419'],
#  ['ES2002b.A.words2088', 'ES2002b.A.words2093'],
#  ['ES2002b.D.words2420', 'ES2002b.D.words2499'],
#  ['ES2002b.B.words2354', 'ES2002b.B.words2368'],
#  ['ES2002b.A.words2094', 'ES2002b.A.words2095'],
#  ['ES2002b.C.words829', 'ES2002b.C.words846'],
#  ['ES2002b.A.words2096', 'ES2002b.A.words2234'],
#  ['ES2002b.B.words2369', 'ES2002b.B.words2372'],
#  ['ES2002b.D.words2500', 'ES2002b.D.words2503'],
#  ['ES2002b.C.words847', 'ES2002b.C.words848'],
#  ['ES2002b.D.words2504', 'ES2002b.D.words2505'],
#  ['ES2002b.B.words2373', 'ES2002b.B.words2403'],
#  ['ES2002b.D.words2506', 'ES2002b.D.words2507'],
#  ['ES2002b.A.words2235', 'ES2002b.A.words2265'],
#  ['ES2002b.D.words2508', 'ES2002b.D.words2509'],
#  ['ES2002b.B.words2404', 'ES2002b.B.words2409'],
#  ['ES2002b.D.words2510', 'ES2002b.D.words2513'],
#  ['ES2002b.B.words2410', 'ES2002b.B.words2446'],
#  ['ES2002b.A.words2266', 'ES2002b.A.words2267'],
#  ['ES2002b.D.words2514', 'ES2002b.D.words2517'],
#  ['ES2002b.A.words2268', 'ES2002b.A.words2269'],
#  ['ES2002b.D.words2518', 'ES2002b.D.words2521'],
#  ['ES2002b.A.words2270', 'ES2002b.A.words2271'],
#  ['ES2002b.D.words2522', 'ES2002b.D.words2568'],
#  ['ES2002b.A.words2272', 'ES2002b.A.words2346'],
#  ['ES2002b.B.words2447', 'ES2002b.B.words2454'],
#  ['ES2002b.D.words2569', 'ES2002b.D.words2570'],
#  ['ES2002b.A.words2347'],
#  ['ES2002b.D.words2571', 'ES2002b.D.words2574'],
#  ['ES2002b.B.words2520', 'ES2002b.B.words2537'],
#  ['ES2002b.D.words2575', 'ES2002b.D.words2593'],
#  ['ES2002b.C.words849']]

# %%
len(word_segments)
# Out:
# 325

# %% [markdown]
# ### How can we find the boundary of each topic?

# %%
bounds = set()

# %%
for topic in root.findall('topic'):
    try:
        matched = re.search(p_pattern,topic.findall('.//nite:child[last()]',name_space)[-1].attrib['href'])
        bounds.add(matched.groups())
    except:
        matched = re.search(s_pattern,topic.findall('.//nite:child[last()]',name_space)[-1].attrib['href'])
        bounds.add(matched.groups())

# %%
bounds
# Out:
# {('ES2002b.A.words30', 'ES2002b.A.words42'),
#  ('ES2002b.B.words2024', 'ES2002b.B.words2034'),
#  ('ES2002b.B.words2455', 'ES2002b.B.words2519'),
#  ('ES2002b.B.words374', 'ES2002b.B.words449'),
#  ('ES2002b.C.words750', 'ES2002b.C.words762'),
#  ('ES2002b.C.words849',),
#  ('ES2002b.D.words6', 'ES2002b.D.words13')}

# %%
for seg in word_segments:
    if tuple(seg) in bounds:
        seg.append("\n**********")

# %%
#now we know where the topical boundaries are
word_segments
# Out:
# [['ES2002b.B.words0', 'ES2002b.B.words128'],
#  ['ES2002b.D.words0', 'ES2002b.D.words5'],
#  ['ES2002b.C.words0'],
#  ['ES2002b.D.words6', 'ES2002b.D.words13', '\n**********'],
#  ['ES2002b.B.words129', 'ES2002b.B.words294'],
#  ['ES2002b.D.words14', 'ES2002b.D.words17'],
#  ['ES2002b.B.words295', 'ES2002b.B.words321'],
#  ['ES2002b.D.words18', 'ES2002b.D.words37'],
#  ['ES2002b.B.words322', 'ES2002b.B.words347'],
#  ['ES2002b.D.words38', 'ES2002b.D.words44'],
#  ['ES2002b.B.words348', 'ES2002b.B.words373'],
#  ['ES2002b.A.words0', 'ES2002b.A.words8'],
#  ['ES2002b.B.words374', 'ES2002b.B.words449', '\n**********'],
#  ['ES2002b.B.words450', 'ES2002b.B.words464'],
#  ['ES2002b.C.words1', 'ES2002b.C.words5'],
#  ['ES2002b.D.words45', 'ES2002b.D.words46'],
#  ['ES2002b.B.words465', 'ES2002b.B.words468'],
#  ['ES2002b.C.words6', 'ES2002b.C.words22'],
#  ['ES2002b.B.words469', 'ES2002b.B.words481'],
#  ['ES2002b.D.words47'],
#  ['ES2002b.C.words23', 'ES2002b.C.words34'],
#  ['ES2002b.C.words35', 'ES2002b.C.words123'],
#  ['ES2002b.B.words482', 'ES2002b.B.words486'],
#  ['ES2002b.D.words48', 'ES2002b.D.words49'],
#  ['ES2002b.C.words124', 'ES2002b.C.words243'],
#  ['ES2002b.B.words487', 'ES2002b.B.words490'],
#  ['ES2002b.C.words244', 'ES2002b.C.words337'],
#  ['ES2002b.B.words491', 'ES2002b.B.words492'],
#  ['ES2002b.C.words338', 'ES2002b.C.words427'],
#  ['ES2002b.B.words493', 'ES2002b.B.words519'],
#  ['ES2002b.D.words50', 'ES2002b.D.words129'],
#  ['ES2002b.B.words520', 'ES2002b.B.words535'],
#  ['ES2002b.A.words9', 'ES2002b.A.words24'],
#  ['ES2002b.C.words428', 'ES2002b.C.words440'],
#  ['ES2002b.A.words25', 'ES2002b.A.words26'],
#  ['ES2002b.B.words536', 'ES2002b.B.words537'],
#  ['ES2002b.D.words130', 'ES2002b.D.words143'],
#  ['ES2002b.C.words441', 'ES2002b.C.words497'],
#  ['ES2002b.D.words144', 'ES2002b.D.words156'],
#  ['ES2002b.B.words538', 'ES2002b.B.words543'],
#  ['ES2002b.D.words157', 'ES2002b.D.words158'],
#  ['ES2002b.A.words27'],
#  ['ES2002b.D.words159', 'ES2002b.D.words162'],
#  ['ES2002b.B.words544', 'ES2002b.B.words646'],
#  ['ES2002b.D.words163', 'ES2002b.D.words164'],
#  ['ES2002b.A.words28'],
#  ['ES2002b.D.words165', 'ES2002b.D.words170'],
#  ['ES2002b.C.words498', 'ES2002b.C.words553'],
#  ['ES2002b.B.words647', 'ES2002b.B.words663'],
#  ['ES2002b.C.words554', 'ES2002b.C.words585'],
#  ['ES2002b.D.words171', 'ES2002b.D.words184'],
#  ['ES2002b.B.words664', 'ES2002b.B.words703'],
#  ['ES2002b.D.words185', 'ES2002b.D.words189'],
#  ['ES2002b.B.words704', 'ES2002b.B.words751'],
#  ['ES2002b.D.words190', 'ES2002b.D.words275'],
#  ['ES2002b.B.words752', 'ES2002b.B.words755'],
#  ['ES2002b.C.words586', 'ES2002b.C.words591'],
#  ['ES2002b.B.words756', 'ES2002b.B.words778'],
#  ['ES2002b.C.words592', 'ES2002b.C.words627'],
#  ['ES2002b.B.words779', 'ES2002b.B.words828'],
#  ['ES2002b.D.words276', 'ES2002b.D.words279'],
#  ['ES2002b.C.words628', 'ES2002b.C.words647'],
#  ['ES2002b.B.words829', 'ES2002b.B.words833'],
#  ['ES2002b.D.words280', 'ES2002b.D.words462'],
#  ['ES2002b.B.words834', 'ES2002b.B.words839'],
#  ['ES2002b.A.words29'],
#  ['ES2002b.B.words840', 'ES2002b.B.words934'],
#  ['ES2002b.D.words463', 'ES2002b.D.words464'],
#  ['ES2002b.A.words30', 'ES2002b.A.words42', '\n**********'],
#  ['ES2002b.D.words728', 'ES2002b.D.words808'],
#  ['ES2002b.A.words94', 'ES2002b.A.words102'],
#  ['ES2002b.B.words1049', 'ES2002b.B.words1050'],
#  ['ES2002b.D.words809', 'ES2002b.D.words810'],
#  ['ES2002b.B.words1051', 'ES2002b.B.words1052'],
#  ['ES2002b.A.words103', 'ES2002b.A.words106'],
#  ['ES2002b.B.words1053', 'ES2002b.B.words1058'],
#  ['ES2002b.A.words107', 'ES2002b.A.words110'],
#  ['ES2002b.B.words1059', 'ES2002b.B.words1062'],
#  ['ES2002b.D.words811', 'ES2002b.D.words903'],
#  ['ES2002b.B.words935', 'ES2002b.B.words953'],
#  ['ES2002b.D.words465', 'ES2002b.D.words468'],
#  ['ES2002b.A.words43'],
#  ['ES2002b.D.words469', 'ES2002b.D.words470'],
#  ['ES2002b.C.words648', 'ES2002b.C.words655'],
#  ['ES2002b.B.words954', 'ES2002b.B.words957'],
#  ['ES2002b.D.words471', 'ES2002b.D.words485'],
#  ['ES2002b.A.words44', 'ES2002b.A.words47'],
#  ['ES2002b.B.words958', 'ES2002b.B.words963'],
#  ['ES2002b.D.words486', 'ES2002b.D.words496'],
#  ['ES2002b.B.words964', 'ES2002b.B.words965'],
#  ['ES2002b.D.words497', 'ES2002b.D.words532'],
#  ['ES2002b.C.words656', 'ES2002b.C.words660'],
#  ['ES2002b.B.words966', 'ES2002b.B.words981'],
#  ['ES2002b.A.words48'],
#  ['ES2002b.D.words533', 'ES2002b.D.words534'],
#  ['ES2002b.B.words982', 'ES2002b.B.words983'],
#  ['ES2002b.A.words49'],
#  ['ES2002b.D.words535', 'ES2002b.D.words686'],
#  ['ES2002b.B.words984', 'ES2002b.B.words1019'],
#  ['ES2002b.A.words50', 'ES2002b.A.words54'],
#  ['ES2002b.B.words1020', 'ES2002b.B.words1031'],
#  ['ES2002b.D.words687', 'ES2002b.D.words695'],
#  ['ES2002b.A.words55', 'ES2002b.A.words77'],
#  ['ES2002b.D.words696', 'ES2002b.D.words703'],
#  ['ES2002b.B.words1032', 'ES2002b.B.words1033'],
#  ['ES2002b.D.words704', 'ES2002b.D.words705'],
#  ['ES2002b.A.words78', 'ES2002b.A.words79'],
#  ['ES2002b.D.words706', 'ES2002b.D.words715'],
#  ['ES2002b.A.words80', 'ES2002b.A.words85'],
#  ['ES2002b.D.words716', 'ES2002b.D.words719'],
#  ['ES2002b.C.words661', 'ES2002b.C.words672'],
#  ['ES2002b.A.words86', 'ES2002b.A.words87'],
#  ['ES2002b.D.words720', 'ES2002b.D.words721'],
#  ['ES2002b.B.words1034', 'ES2002b.B.words1038'],
#  ['ES2002b.D.words722', 'ES2002b.D.words727'],
#  ['ES2002b.B.words1039', 'ES2002b.B.words1048'],
#  ['ES2002b.A.words88', 'ES2002b.A.words93'],
#  ['ES2002b.D.words904', 'ES2002b.D.words988'],
#  ['ES2002b.B.words1063'],
#  ['ES2002b.A.words111', 'ES2002b.A.words115'],
#  ['ES2002b.D.words989', 'ES2002b.D.words1153'],
#  ['ES2002b.B.words1064', 'ES2002b.B.words1069'],
#  ['ES2002b.D.words1154', 'ES2002b.D.words1345'],
#  ['ES2002b.B.words1070', 'ES2002b.B.words1073'],
#  ['ES2002b.A.words116', 'ES2002b.A.words125'],
#  ['ES2002b.D.words1346', 'ES2002b.D.words1531'],
#  ['ES2002b.B.words1074', 'ES2002b.B.words1094'],
#  ['ES2002b.D.words1532', 'ES2002b.D.words1654'],
#  ['ES2002b.B.words1095', 'ES2002b.B.words1124'],
#  ['ES2002b.D.words1655', 'ES2002b.D.words1749'],
#  ['ES2002b.B.words1125', 'ES2002b.B.words1134'],
#  ['ES2002b.D.words1750', 'ES2002b.D.words1761'],
#  ['ES2002b.B.words1135', 'ES2002b.B.words1212'],
#  ['ES2002b.D.words1762', 'ES2002b.D.words1774'],
#  ['ES2002b.B.words1213', 'ES2002b.B.words1300'],
#  ['ES2002b.D.words1775', 'ES2002b.D.words1789'],
#  ['ES2002b.A.words126', 'ES2002b.A.words162'],
#  ['ES2002b.B.words1301', 'ES2002b.B.words1311'],
#  ['ES2002b.A.words163', 'ES2002b.A.words259'],
#  ['ES2002b.B.words1312', 'ES2002b.B.words1315'],
#  ['ES2002b.D.words1790', 'ES2002b.D.words1791'],
#  ['ES2002b.B.words1316', 'ES2002b.B.words1325'],
#  ['ES2002b.D.words1792', 'ES2002b.D.words1863'],
#  ['ES2002b.A.words260', 'ES2002b.A.words261'],
#  ['ES2002b.B.words1326', 'ES2002b.B.words1345'],
#  ['ES2002b.A.words262', 'ES2002b.A.words263'],
#  ['ES2002b.D.words1864', 'ES2002b.D.words1872'],
#  ['ES2002b.B.words1346', 'ES2002b.B.words1350'],
#  ['ES2002b.C.words673', 'ES2002b.C.words674'],
#  ['ES2002b.B.words1351', 'ES2002b.B.words1374'],
#  ['ES2002b.C.words675', 'ES2002b.C.words701'],
#  ['ES2002b.D.words1873', 'ES2002b.D.words1899'],
#  ['ES2002b.C.words702', 'ES2002b.C.words703'],
#  ['ES2002b.B.words1375', 'ES2002b.B.words1473'],
#  ['ES2002b.D.words1900', 'ES2002b.D.words1911'],
#  ['ES2002b.A.words264', 'ES2002b.A.words305'],
#  ['ES2002b.B.words1474', 'ES2002b.B.words1475'],
#  ['ES2002b.D.words1912', 'ES2002b.D.words1919'],
#  ['ES2002b.B.words1476', 'ES2002b.B.words1506'],
#  ['ES2002b.D.words1920', 'ES2002b.D.words1921'],
#  ['ES2002b.A.words306', 'ES2002b.A.words307'],
#  ['ES2002b.D.words1922', 'ES2002b.D.words1923'],
#  ['ES2002b.A.words308', 'ES2002b.A.words430'],
#  ['ES2002b.D.words1924', 'ES2002b.D.words1925'],
#  ['ES2002b.B.words1507', 'ES2002b.B.words1508'],
#  ['ES2002b.D.words1926', 'ES2002b.D.words1937'],
#  ['ES2002b.B.words1509', 'ES2002b.B.words1510'],
#  ['ES2002b.D.words1938', 'ES2002b.D.words1944'],
#  ['ES2002b.B.words1511', 'ES2002b.B.words1514'],
#  ['ES2002b.D.words1945', 'ES2002b.D.words1946'],
#  ['ES2002b.B.words1515', 'ES2002b.B.words1535'],
#  ['ES2002b.B.words1536', 'ES2002b.B.words1556'],
#  ['ES2002b.A.words431'],
#  ['ES2002b.D.words1947', 'ES2002b.D.words1950'],
#  ['ES2002b.A.words432', 'ES2002b.A.words500'],
#  ['ES2002b.C.words704', 'ES2002b.C.words705'],
#  ['ES2002b.D.words1951', 'ES2002b.D.words1952'],
#  ['ES2002b.B.words1557', 'ES2002b.B.words1562'],
#  ['ES2002b.D.words1953', 'ES2002b.D.words1954'],
#  ['ES2002b.B.words1563', 'ES2002b.B.words1564'],
#  ['ES2002b.D.words1955', 'ES2002b.D.words1971'],
#  ['ES2002b.A.words501', 'ES2002b.A.words609'],
#  ['ES2002b.B.words1565', 'ES2002b.B.words1575'],
#  ['ES2002b.D.words1972', 'ES2002b.D.words1977'],
#  ['ES2002b.B.words1576', 'ES2002b.B.words1577'],
#  ['ES2002b.D.words1978', 'ES2002b.D.words1981'],
#  ['ES2002b.B.words1578', 'ES2002b.B.words1579'],
#  ['ES2002b.D.words1982', 'ES2002b.D.words1984'],
#  ['ES2002b.B.words1580', 'ES2002b.B.words1581'],
#  ['ES2002b.D.words1985', 'ES2002b.D.words1986'],
#  ['ES2002b.B.words1582', 'ES2002b.B.words1674'],
#  ['ES2002b.D.words1987', 'ES2002b.D.words1990'],
#  ['ES2002b.A.words610', 'ES2002b.A.words613'],
#  ['ES2002b.D.words1991', 'ES2002b.D.words2072'],
#  ['ES2002b.B.words1675', 'ES2002b.B.words1681'],
#  ['ES2002b.C.words706', 'ES2002b.C.words748'],
#  ['ES2002b.A.words614'],
#  ['ES2002b.B.words1682', 'ES2002b.B.words1683'],
#  ['ES2002b.D.words2073', 'ES2002b.D.words2082'],
#  ['ES2002b.C.words749'],
#  ['ES2002b.B.words1684', 'ES2002b.B.words1704'],
#  ['ES2002b.C.words750', 'ES2002b.C.words762', '\n**********'],
#  ['ES2002b.A.words615', 'ES2002b.A.words626'],
#  ['ES2002b.B.words1705', 'ES2002b.B.words1713'],
#  ['ES2002b.A.words627', 'ES2002b.A.words857'],
#  ['ES2002b.B.words1714', 'ES2002b.B.words1717'],
#  ['ES2002b.D.words2083', 'ES2002b.D.words2086'],
#  ['ES2002b.A.words858', 'ES2002b.A.words876'],
#  ['ES2002b.D.words2109', 'ES2002b.D.words2159'],
#  ['ES2002b.A.words1345', 'ES2002b.A.words1426'],
#  ['ES2002b.D.words2160', 'ES2002b.D.words2166'],
#  ['ES2002b.B.words1767', 'ES2002b.B.words1768'],
#  ['ES2002b.D.words2167', 'ES2002b.D.words2170'],
#  ['ES2002b.B.words1769', 'ES2002b.B.words1770'],
#  ['ES2002b.D.words2171', 'ES2002b.D.words2173'],
#  ['ES2002b.B.words1771', 'ES2002b.B.words1789'],
#  ['ES2002b.D.words2174', 'ES2002b.D.words2175'],
#  ['ES2002b.B.words1790', 'ES2002b.B.words1791'],
#  ['ES2002b.D.words2176', 'ES2002b.D.words2179'],
#  ['ES2002b.B.words1792', 'ES2002b.B.words1796'],
#  ['ES2002b.A.words1427', 'ES2002b.A.words1491'],
#  ['ES2002b.A.words877', 'ES2002b.A.words1029'],
#  ['ES2002b.B.words1718', 'ES2002b.B.words1723'],
#  ['ES2002b.D.words2087', 'ES2002b.D.words2088'],
#  ['ES2002b.A.words1030', 'ES2002b.A.words1290'],
#  ['ES2002b.B.words1724', 'ES2002b.B.words1725'],
#  ['ES2002b.D.words2089', 'ES2002b.D.words2090'],
#  ['ES2002b.B.words1726', 'ES2002b.B.words1731'],
#  ['ES2002b.D.words2091', 'ES2002b.D.words2096'],
#  ['ES2002b.B.words1732', 'ES2002b.B.words1733'],
#  ['ES2002b.D.words2097', 'ES2002b.D.words2100'],
#  ['ES2002b.B.words1734', 'ES2002b.B.words1758'],
#  ['ES2002b.D.words2101', 'ES2002b.D.words2104'],
#  ['ES2002b.A.words1291', 'ES2002b.A.words1344'],
#  ['ES2002b.D.words2105', 'ES2002b.D.words2106'],
#  ['ES2002b.B.words1759', 'ES2002b.B.words1766'],
#  ['ES2002b.D.words2107', 'ES2002b.D.words2108'],
#  ['ES2002b.A.words1492', 'ES2002b.A.words1547'],
#  ['ES2002b.B.words1797', 'ES2002b.B.words1799'],
#  ['ES2002b.D.words2180', 'ES2002b.D.words2182'],
#  ['ES2002b.B.words1800', 'ES2002b.B.words1896'],
#  ['ES2002b.D.words2183', 'ES2002b.D.words2184'],
#  ['ES2002b.A.words1548', 'ES2002b.A.words1718'],
#  ['ES2002b.B.words1897', 'ES2002b.B.words1902'],
#  ['ES2002b.D.words2185', 'ES2002b.D.words2188'],
#  ['ES2002b.B.words1903', 'ES2002b.B.words1917'],
#  ['ES2002b.D.words2189', 'ES2002b.D.words2192'],
#  ['ES2002b.B.words1918', 'ES2002b.B.words1919'],
#  ['ES2002b.D.words2193', 'ES2002b.D.words2240'],
#  ['ES2002b.A.words1719', 'ES2002b.A.words1751'],
#  ['ES2002b.B.words1920'],
#  ['ES2002b.D.words2241', 'ES2002b.D.words2242'],
#  ['ES2002b.A.words1752'],
#  ['ES2002b.D.words2243', 'ES2002b.D.words2249'],
#  ['ES2002b.B.words1921', 'ES2002b.B.words1953'],
#  ['ES2002b.B.words1954', 'ES2002b.B.words2007'],
#  ['ES2002b.D.words2250'],
#  ['ES2002b.A.words1753', 'ES2002b.A.words1889'],
#  ['ES2002b.B.words2008', 'ES2002b.B.words2011'],
#  ['ES2002b.D.words2251', 'ES2002b.D.words2254'],
#  ['ES2002b.B.words2012', 'ES2002b.B.words2015'],
#  ['ES2002b.D.words2255'],
#  ['ES2002b.B.words2016', 'ES2002b.B.words2023'],
#  ['ES2002b.D.words2256', 'ES2002b.D.words2257'],
#  ['ES2002b.B.words2024', 'ES2002b.B.words2034', '\n**********'],
#  ['ES2002b.B.words2035', 'ES2002b.B.words2138'],
#  ['ES2002b.A.words1890'],
#  ['ES2002b.D.words2258', 'ES2002b.D.words2266'],
#  ['ES2002b.C.words763', 'ES2002b.C.words801'],
#  ['ES2002b.B.words2139', 'ES2002b.B.words2143'],
#  ['ES2002b.C.words802', 'ES2002b.C.words803'],
#  ['ES2002b.D.words2267', 'ES2002b.D.words2288'],
#  ['ES2002b.C.words804', 'ES2002b.C.words826'],
#  ['ES2002b.D.words2289', 'ES2002b.D.words2325'],
#  ['ES2002b.B.words2144', 'ES2002b.B.words2145'],
#  ['ES2002b.A.words1891', 'ES2002b.A.words1894'],
#  ['ES2002b.B.words2146', 'ES2002b.B.words2152'],
#  ['ES2002b.C.words827', 'ES2002b.C.words828'],
#  ['ES2002b.D.words2326', 'ES2002b.D.words2386'],
#  ['ES2002b.B.words2153', 'ES2002b.B.words2155'],
#  ['ES2002b.B.words2455', 'ES2002b.B.words2519', '\n**********'],
#  ['ES2002b.A.words1895', 'ES2002b.A.words2086'],
#  ['ES2002b.B.words2156', 'ES2002b.B.words2157'],
#  ['ES2002b.D.words2387', 'ES2002b.D.words2390'],
#  ['ES2002b.B.words2158', 'ES2002b.B.words2159'],
#  ['ES2002b.D.words2391', 'ES2002b.D.words2394'],
#  ['ES2002b.B.words2160', 'ES2002b.B.words2163'],
#  ['ES2002b.D.words2395', 'ES2002b.D.words2396'],
#  ['ES2002b.B.words2164'],
#  ['ES2002b.D.words2397', 'ES2002b.D.words2414'],
#  ['ES2002b.B.words2165', 'ES2002b.B.words2353'],
#  ['ES2002b.D.words2415', 'ES2002b.D.words2418'],
#  ['ES2002b.A.words2087'],
#  ['ES2002b.D.words2419'],
#  ['ES2002b.A.words2088', 'ES2002b.A.words2093'],
#  ['ES2002b.D.words2420', 'ES2002b.D.words2499'],
#  ['ES2002b.B.words2354', 'ES2002b.B.words2368'],
#  ['ES2002b.A.words2094', 'ES2002b.A.words2095'],
#  ['ES2002b.C.words829', 'ES2002b.C.words846'],
#  ['ES2002b.A.words2096', 'ES2002b.A.words2234'],
#  ['ES2002b.B.words2369', 'ES2002b.B.words2372'],
#  ['ES2002b.D.words2500', 'ES2002b.D.words2503'],
#  ['ES2002b.C.words847', 'ES2002b.C.words848'],
#  ['ES2002b.D.words2504', 'ES2002b.D.words2505'],
#  ['ES2002b.B.words2373', 'ES2002b.B.words2403'],
#  ['ES2002b.D.words2506', 'ES2002b.D.words2507'],
#  ['ES2002b.A.words2235', 'ES2002b.A.words2265'],
#  ['ES2002b.D.words2508', 'ES2002b.D.words2509'],
#  ['ES2002b.B.words2404', 'ES2002b.B.words2409'],
#  ['ES2002b.D.words2510', 'ES2002b.D.words2513'],
#  ['ES2002b.B.words2410', 'ES2002b.B.words2446'],
#  ['ES2002b.A.words2266', 'ES2002b.A.words2267'],
#  ['ES2002b.D.words2514', 'ES2002b.D.words2517'],
#  ['ES2002b.A.words2268', 'ES2002b.A.words2269'],
#  ['ES2002b.D.words2518', 'ES2002b.D.words2521'],
#  ['ES2002b.A.words2270', 'ES2002b.A.words2271'],
#  ['ES2002b.D.words2522', 'ES2002b.D.words2568'],
#  ['ES2002b.A.words2272', 'ES2002b.A.words2346'],
#  ['ES2002b.B.words2447', 'ES2002b.B.words2454'],
#  ['ES2002b.D.words2569', 'ES2002b.D.words2570'],
#  ['ES2002b.A.words2347'],
#  ['ES2002b.D.words2571', 'ES2002b.D.words2574'],
#  ['ES2002b.B.words2520', 'ES2002b.B.words2537'],
#  ['ES2002b.D.words2575', 'ES2002b.D.words2593'],
#  ['ES2002b.C.words849', '\n**********']]
