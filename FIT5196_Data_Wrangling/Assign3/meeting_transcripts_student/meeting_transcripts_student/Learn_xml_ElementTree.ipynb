# %%
import xml.etree.ElementTree as ET
import re
from os import listdir
topic_files = listdir('./topics/')
for file in topic_files:
    file = './topics/' + file
# The regex used to capture the words segements
p_pattern = r'#id\((\w+\.\w\.\w+)\)\.{2}id\((\w+\.\w\.\w+)\)'
s_pattern = r'#id\((\w+\.\w\.\w+)\)'
two_pattern = r'#id\((\w+\.\w\.\w+)(\d+)\)\.{2}id\((\w+\.\w\.\w+?)(\d+)\)'
one_pattern = r'#id\((\w+\.\w\.\w+)(\d+)\)'
name_space = {'nite':'http://nite.sourceforge.net/'}
words_pattern = '(.+?)words'

# %%
def parse_transcript(topic):
    topic_tree = ET.parse(topic)
    topic_root = topic_tree.getroot()
    topic_name = topic_root.attrib['{http://nite.sourceforge.net/}id']
    word_segments = []

    #get word segments without the paragraph bounds
    for topic in topic_root.iter('topic'):
        for child in topic.findall('nite:child',name_space):
            try:
                word_segments.append(list(re.search(p_pattern,child.attrib['href']).groups()))
            except:
                word_segments.append(list(re.search(s_pattern,child.attrib['href']).groups()))
    #get topic bounds
    bounds = set()
    for topic in topic_root.findall('topic'):
        try:
            matched = re.search(p_pattern,topic.findall('.//nite:child[last()]',name_space)[-1].attrib['href'])
            bounds.add(matched.groups())
        except:
            matched = re.search(s_pattern,topic.findall('.//nite:child[last()]',name_space)[-1].attrib['href'])
            bounds.add(matched.groups())        
    #add topical bounds
    for seg in word_segments:
        if tuple(seg) in bounds:
            seg.append("**********")
    #get paragraph bounds
    seg_file_pattern1 = r'\w{7}\.\w\.'
    seg_file_pattern2 = r'\w{6}\.\w\.'
    wseg_with_parapgraph = []
    for seg in word_segments:
        if len(seg) == 1:
            wseg_with_parapgraph.append(seg)
        else:# the length of segment is 2 or 3, 3 means its a topical boundary
            try:
                file_name = re.match(seg_file_pattern1, seg[0]).group(0) + "segments.xml"
            except:
                file_name = re.match(seg_file_pattern2, seg[0]).group(0) + "segments.xml"
            tree =  ET.parse('./segments/'+file_name)
            root = tree.getroot()
            paras = []
            start = False
            for segment in root.findall('.//nite:child', name_space):
                if start:
                    try:
                        paras.append(','.join(re.search(p_pattern, segment.attrib['href']).groups()))
                    except:
                        paras.append(re.search(s_pattern, segment.attrib['href']).group(1))
                if seg[0] in segment.attrib['href']:
                    start = True
                    try:
                        paras.append(','.join(re.search(p_pattern, segment.attrib['href']).groups()))
                    except:
                        paras.append(re.search(s_pattern, segment.attrib['href']).group(1))
                if seg[1] in segment.attrib['href']:
                    break
            if len(paras) == 0:
                paras.append(seg[0] + ',' + seg[1])
            if seg[-1] == '**********':
                paras.append('**********')
            wseg_with_parapgraph.append(paras)
    #start of writing txt process        
    with open('./txt_files/'+ topic_name+'.txt','w') as f:
        for e in wseg_with_parapgraph:
            for s in e:
                if s == '**********':
                    f.write(s + '\n')
                else:   
                    word_file = './words/'+ re.match(words_pattern,s).group() + '.xml'
                    tree = ET.parse(word_file)
                    root = tree.getroot()
                    sentence = s.split(',')
                    if len(sentence) == 1:# even single word sentence will be length of 2 here, 1 means vocal which can be dropped
                        pass
                    else:# length is 2, have start and end word
                        start = sentence[0]
                        end = sentence[1]
                        no_word = 0
                        begin = False
                        for word in root.findall('*'):
                            if begin:
                                if word.text:
                                    no_word += f.write(word.text + ' ') 
                                else:
                                    pass
                            if word.attrib['{http://nite.sourceforge.net/}id'] == start:
                                begin = True
                                if word.text:
                                    no_word = f.write(word.text + ' ') 
                                else:
                                    pass
                            if word.attrib['{http://nite.sourceforge.net/}id'] == end:      
                                if no_word:
                                    f.write('\n')
                                break

# %%
for file in topic_files:
    file = './topics/' + file
    parse_transcript(file)

# %%
if 0:
    print('y')
else:
    print('n')
# Out:
# n

# %% [markdown]
# ### !!! Runing time is excessively long, better reduce iteration to optimize the running efficiency

# %%
#test the parsing process on one transcript
parse_transcript('./topics/ES2002a.topic.xml')

# %%
if None:
    pass
else:
    print('a')
# Out:
# a

# %%
'ES2002a.B.words0,ES2002a.B.words1'.split(',')
# Out:
# ['ES2002a.B.words0', 'ES2002a.B.words1']

# %% [markdown]
# re.match(words_pattern,'ES2002a.B.words0,ES2002a.B.words1').group()

# %%
tree = ET.parse('./words/ES2002a.B.words.xml')
root = tree.getroot()
for word in root.findall('*'):
    if word.attrib['{http://nite.sourceforge.net/}id'] == 'ES2002a.B.words4':
        print(word.text)
# Out:
# None

# %%
# Out:
# ['ES2002a.B.words275']

# %% [markdown]
# ES2002a.B.words0,ES2002a.B.words1

# %%
bounds
# Out:
# {('ES2002d.B.words0', 'ES2002d.B.words170'),
#  ('ES2002d.B.words1612', 'ES2002d.B.words1613'),
#  ('ES2002d.B.words2586', 'ES2002d.B.words2589'),
#  ('ES2002d.B.words2873', 'ES2002d.B.words2885'),
#  ('ES2002d.B.words446', 'ES2002d.B.words473')}

# %%
for seg in word_segments:
    if tuple(seg) in bounds:
        seg.append("**********")

# %%
def a(topic):
    topic_tree = ET.parse(topic)
    topic_root = topic_tree.getroot()
    topic_name = topic_root.attrib['{http://nite.sourceforge.net/}id']
    word_segments = []

    #get word segments without the paragraph bounds
    for topic in topic_root.iter('topic'):
        for child in topic.findall('nite:child',name_space):
            try:
                word_segments.append(list(re.search(p_pattern,child.attrib['href']).groups()))
            except:
                word_segments.append(list(re.search(s_pattern,child.attrib['href']).groups()))
    #get topic bounds
    bounds = set()
    for topic in topic_root.findall('topic'):
        try:
            matched = re.search(p_pattern,topic.findall('.//nite:child[last()]',name_space)[-1].attrib['href'])
            bounds.add(matched.groups())
        except:
            matched = re.search(s_pattern,topic.findall('.//nite:child[last()]',name_space)[-1].attrib['href'])
            bounds.add(matched.groups())        
    #add topical bounds
    for seg in word_segments:
        if tuple(seg) in bounds:
            seg.append("**********")
    #get paragraph bounds
    seg_file_pattern1 = r'\w{7}\.\w\.'
    seg_file_pattern2 = r'\w{6}\.\w\.'
    wseg_with_parapgraph = []
    for seg in word_segments:
        if len(seg) == 1:
            wseg_with_parapgraph.append(seg)
        else:# the length of segment is 2 or 3, 3 means its a topical boundary
            try:
                file_name = re.match(seg_file_pattern1, seg[0]).group(0) + "segments.xml"
            except:
                file_name = re.match(seg_file_pattern2, seg[0]).group(0) + "segments.xml"
            tree =  ET.parse('./segments/'+file_name)
            root = tree.getroot()
            paras = []
            start = False
            for segment in root.findall('.//nite:child', name_space):
                if start:
                    try:
                        paras.append(','.join(re.search(p_pattern, segment.attrib['href']).groups()))
                    except:
                        paras.append(re.search(s_pattern, segment.attrib['href']).group(1))
                if seg[0] in segment.attrib['href']:
                    start = True
                    try:
                        paras.append(','.join(re.search(p_pattern, segment.attrib['href']).groups()))
                    except:
                        paras.append(re.search(s_pattern, segment.attrib['href']).group(1))
                if seg[1] in segment.attrib['href']:
                    break
            if len(paras) == 0:
                paras.append(seg[0] + ',' + seg[1])
            if seg[-1] == '**********':
                paras.append('**********')
            wseg_with_parapgraph.append(paras)
    return wseg_with_parapgraph

# %%
a('./topics/ES2002a.topic.xml')
# Out:
# [['ES2002a.B.words0,ES2002a.B.words1',
#   'ES2002a.B.words2,ES2002a.B.words3',
#   'ES2002a.B.words4,ES2002a.B.words71'],
#  ['ES2002a.D.words0,ES2002a.D.words1', 'ES2002a.D.words2,ES2002a.D.words3'],
#  ['ES2002a.A.words0,ES2002a.A.words12'],
#  ['ES2002a.B.words72,ES2002a.B.words73'],
#  ['ES2002a.D.words4,ES2002a.D.words11'],
#  ['ES2002a.C.words0,ES2002a.C.words7'],
#  ['ES2002a.D.words12,ES2002a.D.words13', '**********'],
#  ['ES2002a.B.words74,ES2002a.B.words109',
#   'ES2002a.B.words110,ES2002a.B.words116',
#   'ES2002a.B.words117,ES2002a.B.words192'],
#  ['ES2002a.A.words13,ES2002a.A.words48'],
#  ['ES2002a.B.words193,ES2002a.B.words194'],
#  ['ES2002a.D.words14,ES2002a.D.words15',
#   'ES2002a.D.words16,ES2002a.D.words23'],
#  ['ES2002a.C.words8,ES2002a.C.words9'],
#  ['ES2002a.D.words24,ES2002a.D.words25'],
#  ['ES2002a.B.words195,ES2002a.B.words268',
#   'ES2002a.B.words269,ES2002a.B.words272',
#   'ES2002a.B.words273,ES2002a.B.words274',
#   'ES2002a.B.words275',
#   'ES2002a.B.words276,ES2002a.B.words279',
#   'ES2002a.B.words280,ES2002a.B.words284',
#   'ES2002a.B.words285',
#   'ES2002a.B.words286,ES2002a.B.words287',
#   'ES2002a.B.words288,ES2002a.B.words325',
#   'ES2002a.B.words326,ES2002a.B.words340',
#   'ES2002a.B.words341,ES2002a.B.words357',
#   'ES2002a.B.words358',
#   'ES2002a.B.words359,ES2002a.B.words364',
#   'ES2002a.B.words365,ES2002a.B.words366',
#   'ES2002a.B.words367,ES2002a.B.words382',
#   'ES2002a.B.words383,ES2002a.B.words415',
#   'ES2002a.B.words416,ES2002a.B.words424',
#   'ES2002a.B.words425,ES2002a.B.words433',
#   'ES2002a.B.words434,ES2002a.B.words436',
#   'ES2002a.B.words437,ES2002a.B.words446',
#   'ES2002a.B.words447',
#   'ES2002a.B.words448,ES2002a.B.words449',
#   'ES2002a.B.words450,ES2002a.B.words499',
#   'ES2002a.B.words500,ES2002a.B.words521',
#   'ES2002a.B.words522,ES2002a.B.words545',
#   'ES2002a.B.words546,ES2002a.B.words583',
#   'ES2002a.B.words584,ES2002a.B.words588',
#   'ES2002a.B.words589,ES2002a.B.words592',
#   'ES2002a.B.words593,ES2002a.B.words610',
#   'ES2002a.B.words611,ES2002a.B.words612',
#   'ES2002a.B.words613,ES2002a.B.words623',
#   'ES2002a.B.words624,ES2002a.B.words636',
#   'ES2002a.B.words637,ES2002a.B.words700',
#   'ES2002a.B.words701,ES2002a.B.words702',
#   'ES2002a.B.words703,ES2002a.B.words705',
#   'ES2002a.B.words706,ES2002a.B.words717',
#   'ES2002a.B.words718,ES2002a.B.words731',
#   'ES2002a.B.words732,ES2002a.B.words747',
#   'ES2002a.B.words748,ES2002a.B.words780',
#   'ES2002a.B.words781,ES2002a.B.words786',
#   'ES2002a.B.words787,ES2002a.B.words789',
#   'ES2002a.B.words790,ES2002a.B.words802',
#   'ES2002a.B.words803,ES2002a.B.words829',
#   'ES2002a.B.words830,ES2002a.B.words835',
#   'ES2002a.B.words836,ES2002a.B.words861',
#   'ES2002a.B.words862,ES2002a.B.words871',
#   'ES2002a.B.words872,ES2002a.B.words890',
#   'ES2002a.B.words891,ES2002a.B.words892',
#   'ES2002a.B.words893,ES2002a.B.words894',
#   'ES2002a.B.words895,ES2002a.B.words911',
#   'ES2002a.B.words912,ES2002a.B.words920',
#   'ES2002a.B.words921,ES2002a.B.words946',
#   'ES2002a.B.words947,ES2002a.B.words975',
#   'ES2002a.B.words976,ES2002a.B.words990',
#   'ES2002a.B.words991,ES2002a.B.words995',
#   'ES2002a.B.words996,ES2002a.B.words1023',
#   'ES2002a.B.words1024',
#   'ES2002a.B.words1025,ES2002a.B.words1050',
#   'ES2002a.B.words1051,ES2002a.B.words1052',
#   'ES2002a.B.words1053,ES2002a.B.words1056',
#   'ES2002a.B.words1057,ES2002a.B.words1058',
#   'ES2002a.B.words1059,ES2002a.B.words1074',
#   'ES2002a.B.words1075,ES2002a.B.words1076',
#   'ES2002a.B.words1077,ES2002a.B.words1112',
#   'ES2002a.B.words1113,ES2002a.B.words1114',
#   'ES2002a.B.words1115,ES2002a.B.words1117',
#   'ES2002a.B.words1118,ES2002a.B.words1159',
#   'ES2002a.B.words1160,ES2002a.B.words1161',
#   'ES2002a.B.words1162,ES2002a.B.words1163',
#   'ES2002a.B.words1164,ES2002a.B.words1228',
#   'ES2002a.B.words1229,ES2002a.B.words1235',
#   'ES2002a.B.words1236,ES2002a.B.words1277',
#   'ES2002a.B.words1278,ES2002a.B.words1283',
#   'ES2002a.B.words1284',
#   'ES2002a.B.words1285,ES2002a.B.words1287',
#   'ES2002a.B.words1288,ES2002a.B.words1292',
#   'ES2002a.B.words1293,ES2002a.B.words1300',
#   'ES2002a.B.words1301,ES2002a.B.words1302',
#   'ES2002a.B.words1303,ES2002a.B.words1316',
#   'ES2002a.B.words1317,ES2002a.B.words1320',
#   'ES2002a.B.words1321,ES2002a.B.words1322',
#   'ES2002a.B.words1323,ES2002a.B.words1324',
#   'ES2002a.B.words1325,ES2002a.B.words1326',
#   'ES2002a.B.words1327,ES2002a.B.words1423',
#   'ES2002a.B.words1424,ES2002a.B.words1457',
#   'ES2002a.B.words1458,ES2002a.B.words1459',
#   'ES2002a.B.words1460,ES2002a.B.words1474',
#   'ES2002a.B.words1475',
#   'ES2002a.B.words1476,ES2002a.B.words1477',
#   'ES2002a.B.words1478,ES2002a.B.words1485',
#   'ES2002a.B.words1486,ES2002a.B.words1502',
#   'ES2002a.B.words1503,ES2002a.B.words1504',
#   'ES2002a.B.words1505,ES2002a.B.words1508',
#   'ES2002a.B.words1509',
#   'ES2002a.B.words1510,ES2002a.B.words1552',
#   'ES2002a.B.words1553,ES2002a.B.words1554',
#   'ES2002a.B.words1555,ES2002a.B.words1556',
#   'ES2002a.B.words1557,ES2002a.B.words1558',
#   'ES2002a.B.words1559,ES2002a.B.words1577',
#   'ES2002a.B.words1578,ES2002a.B.words1580',
#   'ES2002a.B.words1581,ES2002a.B.words1587',
#   '**********'],
#  ['ES2002a.B.words226,ES2002a.B.words268'],
#  ['ES2002a.D.words26,ES2002a.D.words32'],
#  ['ES2002a.B.words269,ES2002a.B.words272'],
#  ['ES2002a.D.words33,ES2002a.D.words36',
#   'ES2002a.D.words37,ES2002a.D.words38',
#   'ES2002a.D.words39,ES2002a.D.words44'],
#  ['ES2002a.B.words273,ES2002a.B.words274'],
#  ['ES2002a.D.words45,ES2002a.D.words54',
#   'ES2002a.D.words55,ES2002a.D.words57',
#   'ES2002a.D.words58',
#   'ES2002a.D.words59',
#   'ES2002a.D.words60,ES2002a.D.words62'],
#  ['ES2002a.B.words275'],
#  ['ES2002a.D.words63,ES2002a.D.words134'],
#  ['ES2002a.B.words276,ES2002a.B.words279'],
#  ['ES2002a.A.words49'],
#  ['ES2002a.B.words280,ES2002a.B.words284'],
#  ['ES2002a.D.words135'],
#  ['ES2002a.C.words10', 'ES2002a.C.words11,ES2002a.C.words20'],
#  ['ES2002a.B.words285'],
#  ['ES2002a.A.words50'],
#  ['ES2002a.C.words21', 'ES2002a.C.words22,ES2002a.C.words47'],
#  ['ES2002a.D.words136'],
#  ['ES2002a.C.words48'],
#  ['ES2002a.B.words286,ES2002a.B.words287'],
#  ['ES2002a.A.words51,ES2002a.A.words52'],
#  ['ES2002a.C.words49'],
#  ['ES2002a.A.words53,ES2002a.A.words58'],
#  ['ES2002a.B.words288,ES2002a.B.words325'],
#  ['ES2002a.A.words59'],
#  ['ES2002a.C.words50'],
#  ['ES2002a.A.words60,ES2002a.A.words61'],
#  ['ES2002a.D.words137,ES2002a.D.words155'],
#  ['ES2002a.B.words326,ES2002a.B.words340'],
#  ['ES2002a.C.words51'],
#  ['ES2002a.B.words341,ES2002a.B.words357'],
#  ['ES2002a.D.words156,ES2002a.D.words157'],
#  ['ES2002a.B.words358'],
#  ['ES2002a.C.words52'],
#  ['ES2002a.A.words62,ES2002a.A.words65'],
#  ['ES2002a.C.words53'],
#  ['ES2002a.B.words359,ES2002a.B.words364'],
#  ['ES2002a.A.words66,ES2002a.A.words67',
#   'ES2002a.A.words68,ES2002a.A.words69',
#   'ES2002a.A.words70,ES2002a.A.words120'],
#  ['ES2002a.B.words365,ES2002a.B.words366'],
#  ['ES2002a.A.words121,ES2002a.A.words143'],
#  ['ES2002a.C.words54'],
#  ['ES2002a.D.words158', 'ES2002a.D.words159,ES2002a.D.words161'],
#  ['ES2002a.A.words144,ES2002a.A.words152'],
#  ['ES2002a.D.words162,ES2002a.D.words163'],
#  ['ES2002a.B.words367,ES2002a.B.words382'],
#  ['ES2002a.D.words164,ES2002a.D.words170'],
#  ['ES2002a.A.words153,ES2002a.A.words162'],
#  ['ES2002a.B.words383,ES2002a.B.words415'],
#  ['ES2002a.D.words171', 'ES2002a.D.words172,ES2002a.D.words173'],
#  ['ES2002a.B.words416,ES2002a.B.words424',
#   'ES2002a.B.words425,ES2002a.B.words433',
#   'ES2002a.B.words434,ES2002a.B.words436'],
#  ['ES2002a.D.words174,ES2002a.D.words182'],
#  ['ES2002a.C.words55'],
#  ['ES2002a.B.words437,ES2002a.B.words446'],
#  ['ES2002a.D.words183', 'ES2002a.D.words184,ES2002a.D.words189'],
#  ['ES2002a.C.words56'],
#  ['ES2002a.A.words163'],
#  ['ES2002a.B.words447', 'ES2002a.B.words448,ES2002a.B.words449'],
#  ['ES2002a.D.words190,ES2002a.D.words194'],
#  ['ES2002a.B.words450,ES2002a.B.words499'],
#  ['ES2002a.D.words195'],
#  ['ES2002a.A.words164'],
#  ['ES2002a.B.words500,ES2002a.B.words521'],
#  ['ES2002a.D.words196'],
#  ['ES2002a.B.words522,ES2002a.B.words545'],
#  ['ES2002a.A.words165'],
#  ['ES2002a.D.words197,ES2002a.D.words209'],
#  ['ES2002a.B.words546,ES2002a.B.words583'],
#  ['ES2002a.D.words210', 'ES2002a.D.words211,ES2002a.D.words212'],
#  ['ES2002a.A.words166,ES2002a.A.words173'],
#  ['ES2002a.B.words584,ES2002a.B.words588'],
#  ['ES2002a.D.words213,ES2002a.D.words231'],
#  ['ES2002a.B.words589,ES2002a.B.words592',
#   'ES2002a.B.words593,ES2002a.B.words610'],
#  ['ES2002a.D.words232'],
#  ['ES2002a.A.words174',
#   'ES2002a.A.words175,ES2002a.A.words176',
#   'ES2002a.A.words177,ES2002a.A.words203',
#   'ES2002a.A.words204,ES2002a.A.words207',
#   'ES2002a.A.words208,ES2002a.A.words209',
#   'ES2002a.A.words210,ES2002a.A.words211',
#   'ES2002a.A.words212,ES2002a.A.words217',
#   'ES2002a.A.words218,ES2002a.A.words253',
#   'ES2002a.A.words254,ES2002a.A.words256',
#   'ES2002a.A.words257,ES2002a.A.words258',
#   'ES2002a.A.words259,ES2002a.A.words260',
#   'ES2002a.A.words261,ES2002a.A.words269',
#   'ES2002a.A.words270,ES2002a.A.words290',
#   'ES2002a.A.words291,ES2002a.A.words298',
#   'ES2002a.A.words299,ES2002a.A.words301',
#   '**********'],
#  ['ES2002a.B.words611,ES2002a.B.words612',
#   'ES2002a.B.words613,ES2002a.B.words623',
#   'ES2002a.B.words624,ES2002a.B.words636',
#   'ES2002a.B.words637,ES2002a.B.words700'],
#  ['ES2002a.D.words233,ES2002a.D.words234',
#   'ES2002a.D.words235,ES2002a.D.words244'],
#  ['ES2002a.B.words701,ES2002a.B.words702'],
#  ['ES2002a.D.words245,ES2002a.D.words256',
#   'ES2002a.D.words257,ES2002a.D.words282'],
#  ['ES2002a.B.words703,ES2002a.B.words705',
#   'ES2002a.B.words706,ES2002a.B.words717'],
#  ['ES2002a.D.words283,ES2002a.D.words293'],
#  ['ES2002a.B.words718,ES2002a.B.words731',
#   'ES2002a.B.words732,ES2002a.B.words747'],
#  ['ES2002a.D.words294,ES2002a.D.words295',
#   'ES2002a.D.words296,ES2002a.D.words297',
#   'ES2002a.D.words298,ES2002a.D.words299',
#   '**********'],
#  ['ES2002a.B.words748,ES2002a.B.words780'],
#  ['ES2002a.D.words300,ES2002a.D.words302'],
#  ['ES2002a.B.words781,ES2002a.B.words786'],
#  ['ES2002a.D.words303,ES2002a.D.words304',
#   'ES2002a.D.words305,ES2002a.D.words306'],
#  ['ES2002a.B.words787,ES2002a.B.words789'],
#  ['ES2002a.D.words307,ES2002a.D.words349'],
#  ['ES2002a.B.words790,ES2002a.B.words802'],
#  ['ES2002a.A.words175,ES2002a.A.words176'],
#  ['ES2002a.B.words803,ES2002a.B.words829'],
#  ['ES2002a.D.words350,ES2002a.D.words351',
#   'ES2002a.D.words352,ES2002a.D.words355',
#   'ES2002a.D.words356,ES2002a.D.words357'],
#  ['ES2002a.A.words177,ES2002a.A.words203'],
#  ['ES2002a.B.words830,ES2002a.B.words835'],
#  ['ES2002a.D.words358,ES2002a.D.words359'],
#  ['ES2002a.A.words204,ES2002a.A.words207'],
#  ['ES2002a.D.words360,ES2002a.D.words380',
#   'ES2002a.D.words381,ES2002a.D.words402'],
#  ['ES2002a.B.words836,ES2002a.B.words861'],
#  ['ES2002a.D.words403,ES2002a.D.words411',
#   'ES2002a.D.words412,ES2002a.D.words413',
#   'ES2002a.D.words414,ES2002a.D.words455'],
#  ['ES2002a.B.words862,ES2002a.B.words871',
#   'ES2002a.B.words872,ES2002a.B.words890'],
#  ['ES2002a.D.words456',
#   'ES2002a.D.words457,ES2002a.D.words458',
#   'ES2002a.D.words459,ES2002a.D.words493'],
#  ['ES2002a.B.words891,ES2002a.B.words892',
#   'ES2002a.B.words893,ES2002a.B.words894'],
#  ['ES2002a.D.words494,ES2002a.D.words525'],
#  ['ES2002a.B.words895,ES2002a.B.words911'],
#  ['ES2002a.D.words526,ES2002a.D.words527'],
#  ['ES2002a.B.words912,ES2002a.B.words920',
#   'ES2002a.B.words921,ES2002a.B.words946'],
#  ['ES2002a.D.words528,ES2002a.D.words529',
#   'ES2002a.D.words530,ES2002a.D.words531',
#   'ES2002a.D.words532,ES2002a.D.words539'],
#  ['ES2002a.B.words947,ES2002a.B.words975'],
#  ['ES2002a.D.words540,ES2002a.D.words541',
#   'ES2002a.D.words542,ES2002a.D.words546'],
#  ['ES2002a.B.words976,ES2002a.B.words990'],
#  ['ES2002a.D.words547,ES2002a.D.words548'],
#  ['ES2002a.B.words991,ES2002a.B.words995',
#   'ES2002a.B.words996,ES2002a.B.words1023'],
#  ['ES2002a.D.words549,ES2002a.D.words562'],
#  ['ES2002a.B.words1024', 'ES2002a.B.words1025,ES2002a.B.words1050'],
#  ['ES2002a.D.words563,ES2002a.D.words565',
#   'ES2002a.D.words566,ES2002a.D.words567'],
#  ['ES2002a.A.words208,ES2002a.A.words209'],
#  ['ES2002a.D.words568,ES2002a.D.words569'],
#  ['ES2002a.B.words1051,ES2002a.B.words1052', '**********'],
#  ['ES2002a.D.words570,ES2002a.D.words624'],
#  ['ES2002a.B.words1053,ES2002a.B.words1056',
#   'ES2002a.B.words1057,ES2002a.B.words1058',
#   'ES2002a.B.words1059,ES2002a.B.words1074'],
#  ['ES2002a.D.words625,ES2002a.D.words695'],
#  ['ES2002a.C.words57,ES2002a.C.words59'],
#  ['ES2002a.A.words210,ES2002a.A.words211'],
#  ['ES2002a.C.words60,ES2002a.C.words63',
#   'ES2002a.C.words64,ES2002a.C.words104'],
#  ['ES2002a.D.words696,ES2002a.D.words697',
#   'ES2002a.D.words698,ES2002a.D.words704',
#   'ES2002a.D.words705,ES2002a.D.words721'],
#  ['ES2002a.B.words1075,ES2002a.B.words1076',
#   'ES2002a.B.words1077,ES2002a.B.words1112'],
#  ['ES2002a.D.words722,ES2002a.D.words729',
#   'ES2002a.D.words730,ES2002a.D.words731',
#   'ES2002a.D.words732,ES2002a.D.words778'],
#  ['ES2002a.B.words1113,ES2002a.B.words1114'],
#  ['ES2002a.D.words779,ES2002a.D.words813'],
#  ['ES2002a.B.words1115,ES2002a.B.words1117',
#   'ES2002a.B.words1118,ES2002a.B.words1159'],
#  ['ES2002a.D.words814,ES2002a.D.words818',
#   'ES2002a.D.words819,ES2002a.D.words880'],
#  ['ES2002a.B.words1160,ES2002a.B.words1161'],
#  ['ES2002a.D.words881', 'ES2002a.D.words882,ES2002a.D.words900'],
#  ['ES2002a.B.words1162,ES2002a.B.words1163'],
#  ['ES2002a.D.words901,ES2002a.D.words902'],
#  ['ES2002a.B.words1164,ES2002a.B.words1228'],
#  ['ES2002a.A.words212,ES2002a.A.words217'],
#  ['ES2002a.B.words1229,ES2002a.B.words1235'],
#  ['ES2002a.D.words903,ES2002a.D.words904'],
#  ['ES2002a.A.words218,ES2002a.A.words253'],
#  ['ES2002a.D.words905,ES2002a.D.words908',
#   'ES2002a.D.words909,ES2002a.D.words912'],
#  ['ES2002a.B.words1236,ES2002a.B.words1277'],
#  ['ES2002a.D.words913,ES2002a.D.words914',
#   'ES2002a.D.words915,ES2002a.D.words916'],
#  ['ES2002a.A.words254,ES2002a.A.words256'],
#  ['ES2002a.D.words917,ES2002a.D.words921',
#   'ES2002a.D.words922,ES2002a.D.words923',
#   'ES2002a.D.words924,ES2002a.D.words1024'],
#  ['ES2002a.B.words1278,ES2002a.B.words1283',
#   'ES2002a.B.words1284',
#   'ES2002a.B.words1285,ES2002a.B.words1287',
#   'ES2002a.B.words1288,ES2002a.B.words1292',
#   'ES2002a.B.words1293,ES2002a.B.words1300'],
#  ['ES2002a.D.words1025,ES2002a.D.words1037'],
#  ['ES2002a.B.words1301,ES2002a.B.words1302',
#   'ES2002a.B.words1303,ES2002a.B.words1316'],
#  ['ES2002a.D.words1038,ES2002a.D.words1101'],
#  ['ES2002a.B.words1317,ES2002a.B.words1320',
#   'ES2002a.B.words1321,ES2002a.B.words1322',
#   'ES2002a.B.words1323,ES2002a.B.words1324',
#   'ES2002a.B.words1325,ES2002a.B.words1326'],
#  ['ES2002a.D.words1102,ES2002a.D.words1106'],
#  ['ES2002a.C.words105,ES2002a.C.words106', '**********'],
#  ['ES2002a.B.words1327,ES2002a.B.words1423'],
#  ['ES2002a.A.words257,ES2002a.A.words258'],
#  ['ES2002a.B.words1424,ES2002a.B.words1457'],
#  ['ES2002a.D.words1107,ES2002a.D.words1108'],
#  ['ES2002a.B.words1458,ES2002a.B.words1459'],
#  ['ES2002a.D.words1109'],
#  ['ES2002a.B.words1460,ES2002a.B.words1474',
#   'ES2002a.B.words1475',
#   'ES2002a.B.words1476,ES2002a.B.words1477',
#   'ES2002a.B.words1478,ES2002a.B.words1485',
#   'ES2002a.B.words1486,ES2002a.B.words1502'],
#  ['ES2002a.D.words1110,ES2002a.D.words1112',
#   'ES2002a.D.words1113',
#   'ES2002a.D.words1114,ES2002a.D.words1153'],
#  ['ES2002a.B.words1503,ES2002a.B.words1504',
#   'ES2002a.B.words1505,ES2002a.B.words1508'],
#  ['ES2002a.A.words259,ES2002a.A.words260'],
#  ['ES2002a.D.words1154', 'ES2002a.D.words1155,ES2002a.D.words1197'],
#  ['ES2002a.B.words1509', 'ES2002a.B.words1510,ES2002a.B.words1552'],
#  ['ES2002a.D.words1198,ES2002a.D.words1203',
#   'ES2002a.D.words1204,ES2002a.D.words1205'],
#  ['ES2002a.A.words261,ES2002a.A.words269'],
#  ['ES2002a.D.words1206,ES2002a.D.words1209'],
#  ['ES2002a.A.words270,ES2002a.A.words290'],
#  ['ES2002a.B.words1553,ES2002a.B.words1554'],
#  ['ES2002a.D.words1210,ES2002a.D.words1211'],
#  ['ES2002a.B.words1555,ES2002a.B.words1556'],
#  ['ES2002a.D.words1212,ES2002a.D.words1213'],
#  ['ES2002a.B.words1557,ES2002a.B.words1558'],
#  ['ES2002a.A.words291,ES2002a.A.words298'],
#  ['ES2002a.B.words1559,ES2002a.B.words1577'],
#  ['ES2002a.D.words1214,ES2002a.D.words1215',
#   'ES2002a.D.words1216,ES2002a.D.words1218',
#   'ES2002a.D.words1219'],
#  ['ES2002a.B.words1578,ES2002a.B.words1580',
#   'ES2002a.B.words1581,ES2002a.B.words1587'],
#  ['ES2002a.D.words1220'],
#  ['ES2002a.A.words299,ES2002a.A.words301', '**********']]

# %%
with open('./test.txt','w') as f:
    a = f.write('1')
    a += f.write('2')
    a += f.write('3')
    print(a)
# Out:
# 3

# %%
#now we know where the topical boundaries are
word_segments
# Out:
# [['ES2002d.B.words0', 'ES2002d.B.words170', '**********'],
#  ['ES2002d.A.words0', 'ES2002d.A.words1'],
#  ['ES2002d.D.words0', 'ES2002d.D.words86'],
#  ['ES2002d.A.words2', 'ES2002d.A.words9'],
#  ['ES2002d.B.words171', 'ES2002d.B.words176'],
#  ['ES2002d.D.words87', 'ES2002d.D.words107'],
#  ['ES2002d.C.words0', 'ES2002d.C.words2'],
#  ['ES2002d.A.words10', 'ES2002d.A.words46'],
#  ['ES2002d.C.words3', 'ES2002d.C.words6'],
#  ['ES2002d.A.words47', 'ES2002d.A.words59'],
#  ['ES2002d.C.words7', 'ES2002d.C.words12'],
#  ['ES2002d.B.words177', 'ES2002d.B.words187'],
#  ['ES2002d.D.words108'],
#  ['ES2002d.A.words60', 'ES2002d.A.words132'],
#  ['ES2002d.C.words13', 'ES2002d.C.words18'],
#  ['ES2002d.B.words188', 'ES2002d.B.words192'],
#  ['ES2002d.C.words19', 'ES2002d.C.words22'],
#  ['ES2002d.A.words133', 'ES2002d.A.words164'],
#  ['ES2002d.C.words23', 'ES2002d.C.words32'],
#  ['ES2002d.B.words193', 'ES2002d.B.words198'],
#  ['ES2002d.A.words165', 'ES2002d.A.words169'],
#  ['ES2002d.C.words33', 'ES2002d.C.words43'],
#  ['ES2002d.B.words199', 'ES2002d.B.words206'],
#  ['ES2002d.A.words170', 'ES2002d.A.words177'],
#  ['ES2002d.D.words109', 'ES2002d.D.words117'],
#  ['ES2002d.B.words207', 'ES2002d.B.words209'],
#  ['ES2002d.A.words178', 'ES2002d.A.words200'],
#  ['ES2002d.B.words210', 'ES2002d.B.words212'],
#  ['ES2002d.A.words201', 'ES2002d.A.words216'],
#  ['ES2002d.C.words44', 'ES2002d.C.words47'],
#  ['ES2002d.A.words217', 'ES2002d.A.words246'],
#  ['ES2002d.B.words213', 'ES2002d.B.words214'],
#  ['ES2002d.C.words48', 'ES2002d.C.words55'],
#  ['ES2002d.B.words215', 'ES2002d.B.words231'],
#  ['ES2002d.D.words118', 'ES2002d.D.words153'],
#  ['ES2002d.B.words232', 'ES2002d.B.words233'],
#  ['ES2002d.C.words56', 'ES2002d.C.words57'],
#  ['ES2002d.A.words247', 'ES2002d.A.words270'],
#  ['ES2002d.C.words58', 'ES2002d.C.words64'],
#  ['ES2002d.A.words271', 'ES2002d.A.words279'],
#  ['ES2002d.B.words234', 'ES2002d.B.words265'],
#  ['ES2002d.C.words65', 'ES2002d.C.words72'],
#  ['ES2002d.A.words280', 'ES2002d.A.words285'],
#  ['ES2002d.C.words73', 'ES2002d.C.words105'],
#  ['ES2002d.B.words266', 'ES2002d.B.words280'],
#  ['ES2002d.C.words106', 'ES2002d.C.words142'],
#  ['ES2002d.D.words154', 'ES2002d.D.words180'],
#  ['ES2002d.C.words143', 'ES2002d.C.words144'],
#  ['ES2002d.D.words181', 'ES2002d.D.words182'],
#  ['ES2002d.B.words281', 'ES2002d.B.words304'],
#  ['ES2002d.D.words183', 'ES2002d.D.words249'],
#  ['ES2002d.A.words286', 'ES2002d.A.words289'],
#  ['ES2002d.B.words305', 'ES2002d.B.words306'],
#  ['ES2002d.A.words290', 'ES2002d.A.words291'],
#  ['ES2002d.B.words307', 'ES2002d.B.words318'],
#  ['ES2002d.C.words145', 'ES2002d.C.words146'],
#  ['ES2002d.A.words292', 'ES2002d.A.words307'],
#  ['ES2002d.D.words250', 'ES2002d.D.words254'],
#  ['ES2002d.B.words319', 'ES2002d.B.words320'],
#  ['ES2002d.C.words147', 'ES2002d.C.words151'],
#  ['ES2002d.A.words308', 'ES2002d.A.words319'],
#  ['ES2002d.C.words152', 'ES2002d.C.words153'],
#  ['ES2002d.D.words255', 'ES2002d.D.words259'],
#  ['ES2002d.B.words321', 'ES2002d.B.words329'],
#  ['ES2002d.A.words320', 'ES2002d.A.words338'],
#  ['ES2002d.D.words260', 'ES2002d.D.words261'],
#  ['ES2002d.C.words154', 'ES2002d.C.words155'],
#  ['ES2002d.D.words262', 'ES2002d.D.words265'],
#  ['ES2002d.B.words330', 'ES2002d.B.words361'],
#  ['ES2002d.A.words339', 'ES2002d.A.words342'],
#  ['ES2002d.C.words156', 'ES2002d.C.words162'],
#  ['ES2002d.D.words266', 'ES2002d.D.words277'],
#  ['ES2002d.B.words362', 'ES2002d.B.words363'],
#  ['ES2002d.D.words278', 'ES2002d.D.words309'],
#  ['ES2002d.B.words364', 'ES2002d.B.words378'],
#  ['ES2002d.C.words163', 'ES2002d.C.words164'],
#  ['ES2002d.D.words310', 'ES2002d.D.words325'],
#  ['ES2002d.B.words379', 'ES2002d.B.words388'],
#  ['ES2002d.D.words326', 'ES2002d.D.words351'],
#  ['ES2002d.B.words389', 'ES2002d.B.words396'],
#  ['ES2002d.D.words352', 'ES2002d.D.words358'],
#  ['ES2002d.A.words343', 'ES2002d.A.words356'],
#  ['ES2002d.B.words397', 'ES2002d.B.words407'],
#  ['ES2002d.A.words357', 'ES2002d.A.words384'],
#  ['ES2002d.C.words165', 'ES2002d.C.words168'],
#  ['ES2002d.B.words408', 'ES2002d.B.words411'],
#  ['ES2002d.C.words169', 'ES2002d.C.words175'],
#  ['ES2002d.A.words385', 'ES2002d.A.words412'],
#  ['ES2002d.B.words412', 'ES2002d.B.words413'],
#  ['ES2002d.C.words176', 'ES2002d.C.words177'],
#  ['ES2002d.B.words414', 'ES2002d.B.words431'],
#  ['ES2002d.C.words178', 'ES2002d.C.words179'],
#  ['ES2002d.A.words413', 'ES2002d.A.words430'],
#  ['ES2002d.D.words359', 'ES2002d.D.words366'],
#  ['ES2002d.A.words431', 'ES2002d.A.words478'],
#  ['ES2002d.B.words432', 'ES2002d.B.words433'],
#  ['ES2002d.C.words180', 'ES2002d.C.words181'],
#  ['ES2002d.B.words434', 'ES2002d.B.words445'],
#  ['ES2002d.C.words182', 'ES2002d.C.words184'],
#  ['ES2002d.A.words479', 'ES2002d.A.words480'],
#  ['ES2002d.B.words446', 'ES2002d.B.words473', '**********'],
#  ['ES2002d.B.words474', 'ES2002d.B.words502'],
#  ['ES2002d.D.words367', 'ES2002d.D.words368'],
#  ['ES2002d.B.words503', 'ES2002d.B.words540'],
#  ['ES2002d.A.words481', 'ES2002d.A.words491'],
#  ['ES2002d.B.words541', 'ES2002d.B.words560'],
#  ['ES2002d.A.words492', 'ES2002d.A.words493'],
#  ['ES2002d.D.words369', 'ES2002d.D.words370'],
#  ['ES2002d.A.words494', 'ES2002d.A.words520'],
#  ['ES2002d.B.words561', 'ES2002d.B.words578'],
#  ['ES2002d.D.words371', 'ES2002d.D.words391'],
#  ['ES2002d.A.words521', 'ES2002d.A.words522'],
#  ['ES2002d.B.words579', 'ES2002d.B.words585'],
#  ['ES2002d.A.words523', 'ES2002d.A.words524'],
#  ['ES2002d.B.words586', 'ES2002d.B.words587'],
#  ['ES2002d.A.words525', 'ES2002d.A.words526'],
#  ['ES2002d.B.words588', 'ES2002d.B.words598'],
#  ['ES2002d.A.words527', 'ES2002d.A.words536'],
#  ['ES2002d.B.words599', 'ES2002d.B.words630'],
#  ['ES2002d.A.words537', 'ES2002d.A.words553'],
#  ['ES2002d.B.words631', 'ES2002d.B.words636'],
#  ['ES2002d.A.words554', 'ES2002d.A.words570'],
#  ['ES2002d.B.words637', 'ES2002d.B.words654'],
#  ['ES2002d.C.words185', 'ES2002d.C.words186'],
#  ['ES2002d.A.words571', 'ES2002d.A.words578'],
#  ['ES2002d.B.words655', 'ES2002d.B.words666'],
#  ['ES2002d.A.words579', 'ES2002d.A.words581'],
#  ['ES2002d.D.words392', 'ES2002d.D.words402'],
#  ['ES2002d.C.words187', 'ES2002d.C.words190'],
#  ['ES2002d.A.words582', 'ES2002d.A.words588'],
#  ['ES2002d.B.words667', 'ES2002d.B.words680'],
#  ['ES2002d.D.words403', 'ES2002d.D.words423'],
#  ['ES2002d.B.words681', 'ES2002d.B.words682'],
#  ['ES2002d.D.words424', 'ES2002d.D.words431'],
#  ['ES2002d.B.words683', 'ES2002d.B.words684'],
#  ['ES2002d.A.words589', 'ES2002d.A.words603'],
#  ['ES2002d.B.words685', 'ES2002d.B.words686'],
#  ['ES2002d.A.words604', 'ES2002d.A.words619'],
#  ['ES2002d.B.words687', 'ES2002d.B.words707'],
#  ['ES2002d.D.words432', 'ES2002d.D.words442'],
#  ['ES2002d.A.words620', 'ES2002d.A.words631'],
#  ['ES2002d.B.words708', 'ES2002d.B.words716'],
#  ['ES2002d.A.words632', 'ES2002d.A.words642'],
#  ['ES2002d.B.words717', 'ES2002d.B.words719'],
#  ['ES2002d.A.words643', 'ES2002d.A.words648'],
#  ['ES2002d.B.words720', 'ES2002d.B.words741'],
#  ['ES2002d.B.words742', 'ES2002d.B.words767'],
#  ['ES2002d.D.words443'],
#  ['ES2002d.A.words649'],
#  ['ES2002d.C.words191', 'ES2002d.C.words205'],
#  ['ES2002d.B.words768', 'ES2002d.B.words810'],
#  ['ES2002d.C.words206', 'ES2002d.C.words220'],
#  ['ES2002d.D.words444', 'ES2002d.D.words461'],
#  ['ES2002d.B.words811', 'ES2002d.B.words812'],
#  ['ES2002d.C.words221', 'ES2002d.C.words226'],
#  ['ES2002d.A.words650', 'ES2002d.A.words687'],
#  ['ES2002d.B.words813', 'ES2002d.B.words821'],
#  ['ES2002d.D.words462', 'ES2002d.D.words465'],
#  ['ES2002d.A.words688', 'ES2002d.A.words747'],
#  ['ES2002d.C.words227', 'ES2002d.C.words228'],
#  ['ES2002d.D.words466', 'ES2002d.D.words471'],
#  ['ES2002d.C.words229', 'ES2002d.C.words232'],
#  ['ES2002d.B.words822', 'ES2002d.B.words824'],
#  ['ES2002d.C.words233', 'ES2002d.C.words236'],
#  ['ES2002d.B.words825', 'ES2002d.B.words838'],
#  ['ES2002d.A.words748', 'ES2002d.A.words759'],
#  ['ES2002d.C.words237', 'ES2002d.C.words238'],
#  ['ES2002d.B.words839', 'ES2002d.B.words846'],
#  ['ES2002d.A.words760', 'ES2002d.A.words764'],
#  ['ES2002d.C.words239', 'ES2002d.C.words240'],
#  ['ES2002d.B.words847', 'ES2002d.B.words848'],
#  ['ES2002d.A.words765', 'ES2002d.A.words772'],
#  ['ES2002d.B.words849', 'ES2002d.B.words878'],
#  ['ES2002d.A.words773', 'ES2002d.A.words781'],
#  ['ES2002d.B.words879', 'ES2002d.B.words881'],
#  ['ES2002d.D.words472', 'ES2002d.D.words487'],
#  ['ES2002d.B.words882', 'ES2002d.B.words883'],
#  ['ES2002d.A.words782', 'ES2002d.A.words796'],
#  ['ES2002d.B.words884', 'ES2002d.B.words887'],
#  ['ES2002d.A.words797', 'ES2002d.A.words820'],
#  ['ES2002d.B.words888', 'ES2002d.B.words908'],
#  ['ES2002d.A.words821', 'ES2002d.A.words857'],
#  ['ES2002d.C.words241', 'ES2002d.C.words242'],
#  ['ES2002d.B.words909', 'ES2002d.B.words910'],
#  ['ES2002d.C.words243', 'ES2002d.C.words244'],
#  ['ES2002d.B.words911', 'ES2002d.B.words922'],
#  ['ES2002d.A.words858', 'ES2002d.A.words885'],
#  ['ES2002d.B.words923', 'ES2002d.B.words924'],
#  ['ES2002d.C.words245'],
#  ['ES2002d.B.words925', 'ES2002d.B.words928'],
#  ['ES2002d.C.words246', 'ES2002d.C.words253'],
#  ['ES2002d.D.words488', 'ES2002d.D.words489'],
#  ['ES2002d.A.words886', 'ES2002d.A.words889'],
#  ['ES2002d.B.words929', 'ES2002d.B.words936'],
#  ['ES2002d.A.words890', 'ES2002d.A.words909'],
#  ['ES2002d.D.words490', 'ES2002d.D.words491'],
#  ['ES2002d.B.words937', 'ES2002d.B.words946'],
#  ['ES2002d.A.words910', 'ES2002d.A.words916'],
#  ['ES2002d.B.words947', 'ES2002d.B.words948'],
#  ['ES2002d.D.words492'],
#  ['ES2002d.A.words917', 'ES2002d.A.words945'],
#  ['ES2002d.B.words949', 'ES2002d.B.words951'],
#  ['ES2002d.C.words254', 'ES2002d.C.words259'],
#  ['ES2002d.B.words952', 'ES2002d.B.words992'],
#  ['ES2002d.C.words260'],
#  ['ES2002d.D.words493', 'ES2002d.D.words497'],
#  ['ES2002d.C.words261', 'ES2002d.C.words276'],
#  ['ES2002d.B.words993', 'ES2002d.B.words997'],
#  ['ES2002d.C.words277', 'ES2002d.C.words282'],
#  ['ES2002d.D.words498', 'ES2002d.D.words509'],
#  ['ES2002d.A.words946', 'ES2002d.A.words947'],
#  ['ES2002d.B.words998', 'ES2002d.B.words1018'],
#  ['ES2002d.D.words510', 'ES2002d.D.words520'],
#  ['ES2002d.B.words1019', 'ES2002d.B.words1082'],
#  ['ES2002d.A.words948'],
#  ['ES2002d.B.words1083', 'ES2002d.B.words1084'],
#  ['ES2002d.C.words283', 'ES2002d.C.words300'],
#  ['ES2002d.A.words949', 'ES2002d.A.words955'],
#  ['ES2002d.D.words521', 'ES2002d.D.words522'],
#  ['ES2002d.C.words301', 'ES2002d.C.words307'],
#  ['ES2002d.A.words956', 'ES2002d.A.words957'],
#  ['ES2002d.D.words523', 'ES2002d.D.words552'],
#  ['ES2002d.C.words308', 'ES2002d.C.words321'],
#  ['ES2002d.A.words958', 'ES2002d.A.words969'],
#  ['ES2002d.D.words553'],
#  ['ES2002d.C.words322', 'ES2002d.C.words334'],
#  ['ES2002d.A.words970', 'ES2002d.A.words1001'],
#  ['ES2002d.C.words335', 'ES2002d.C.words336'],
#  ['ES2002d.B.words1085', 'ES2002d.B.words1107'],
#  ['ES2002d.A.words1002', 'ES2002d.A.words1005'],
#  ['ES2002d.B.words1108', 'ES2002d.B.words1113'],
#  ['ES2002d.C.words337', 'ES2002d.C.words338'],
#  ['ES2002d.B.words1114', 'ES2002d.B.words1132'],
#  ['ES2002d.D.words554', 'ES2002d.D.words559'],
#  ['ES2002d.A.words1006', 'ES2002d.A.words1007'],
#  ['ES2002d.C.words339', 'ES2002d.C.words351'],
#  ['ES2002d.A.words1008', 'ES2002d.A.words1022'],
#  ['ES2002d.C.words352', 'ES2002d.C.words354'],
#  ['ES2002d.D.words560', 'ES2002d.D.words565'],
#  ['ES2002d.B.words1133', 'ES2002d.B.words1160'],
#  ['ES2002d.C.words355', 'ES2002d.C.words365'],
#  ['ES2002d.A.words1023', 'ES2002d.A.words1024'],
#  ['ES2002d.B.words1161', 'ES2002d.B.words1171'],
#  ['ES2002d.C.words366', 'ES2002d.C.words367'],
#  ['ES2002d.B.words1172', 'ES2002d.B.words1206'],
#  ['ES2002d.C.words368', 'ES2002d.C.words448'],
#  ['ES2002d.A.words1025', 'ES2002d.A.words1084'],
#  ['ES2002d.C.words449', 'ES2002d.C.words470'],
#  ['ES2002d.A.words1085', 'ES2002d.A.words1116'],
#  ['ES2002d.C.words471', 'ES2002d.C.words476'],
#  ['ES2002d.D.words566', 'ES2002d.D.words568'],
#  ['ES2002d.C.words477', 'ES2002d.C.words478'],
#  ['ES2002d.B.words1207', 'ES2002d.B.words1209'],
#  ['ES2002d.A.words1117', 'ES2002d.A.words1118'],
#  ['ES2002d.B.words1210', 'ES2002d.B.words1268'],
#  ['ES2002d.C.words479', 'ES2002d.C.words502'],
#  ['ES2002d.B.words1269', 'ES2002d.B.words1278'],
#  ['ES2002d.A.words1119', 'ES2002d.A.words1127'],
#  ['ES2002d.C.words503', 'ES2002d.C.words504'],
#  ['ES2002d.B.words1279', 'ES2002d.B.words1308'],
#  ['ES2002d.C.words505', 'ES2002d.C.words553'],
#  ['ES2002d.B.words1309', 'ES2002d.B.words1315'],
#  ['ES2002d.A.words1128', 'ES2002d.A.words1138'],
#  ['ES2002d.C.words554', 'ES2002d.C.words557'],
#  ['ES2002d.A.words1139', 'ES2002d.A.words1145'],
#  ['ES2002d.C.words558', 'ES2002d.C.words563'],
#  ['ES2002d.A.words1146', 'ES2002d.A.words1164'],
#  ['ES2002d.C.words564', 'ES2002d.C.words580'],
#  ['ES2002d.B.words1316'],
#  ['ES2002d.C.words581', 'ES2002d.C.words602'],
#  ['ES2002d.A.words1165', 'ES2002d.A.words1172'],
#  ['ES2002d.D.words569', 'ES2002d.D.words573'],
#  ['ES2002d.A.words1173', 'ES2002d.A.words1177'],
#  ['ES2002d.D.words574'],
#  ['ES2002d.C.words603', 'ES2002d.C.words691'],
#  ['ES2002d.B.words1317', 'ES2002d.B.words1321'],
#  ['ES2002d.C.words692', 'ES2002d.C.words824'],
#  ['ES2002d.B.words1322', 'ES2002d.B.words1324'],
#  ['ES2002d.C.words825', 'ES2002d.C.words844'],
#  ['ES2002d.B.words1325', 'ES2002d.B.words1326'],
#  ['ES2002d.A.words1178', 'ES2002d.A.words1183'],
#  ['ES2002d.B.words1327', 'ES2002d.B.words1356'],
#  ['ES2002d.D.words575', 'ES2002d.D.words576'],
#  ['ES2002d.C.words845', 'ES2002d.C.words882'],
#  ['ES2002d.B.words1357', 'ES2002d.B.words1360'],
#  ['ES2002d.C.words883', 'ES2002d.C.words885'],
#  ['ES2002d.B.words1361', 'ES2002d.B.words1362'],
#  ['ES2002d.D.words577', 'ES2002d.D.words581'],
#  ['ES2002d.C.words886', 'ES2002d.C.words891'],
#  ['ES2002d.B.words1363', 'ES2002d.B.words1371'],
#  ['ES2002d.C.words892', 'ES2002d.C.words893'],
#  ['ES2002d.A.words1184', 'ES2002d.A.words1189'],
#  ['ES2002d.C.words894', 'ES2002d.C.words900'],
#  ['ES2002d.B.words1372', 'ES2002d.B.words1373'],
#  ['ES2002d.C.words901', 'ES2002d.C.words908'],
#  ['ES2002d.A.words1190', 'ES2002d.A.words1196'],
#  ['ES2002d.C.words909', 'ES2002d.C.words917'],
#  ['ES2002d.B.words1374', 'ES2002d.B.words1386'],
#  ['ES2002d.A.words1197', 'ES2002d.A.words1208'],
#  ['ES2002d.D.words582', 'ES2002d.D.words586'],
#  ['ES2002d.B.words1387', 'ES2002d.B.words1388'],
#  ['ES2002d.C.words918', 'ES2002d.C.words923'],
#  ['ES2002d.D.words587', 'ES2002d.D.words596'],
#  ['ES2002d.C.words924', 'ES2002d.C.words925'],
#  ['ES2002d.A.words1209', 'ES2002d.A.words1213'],
#  ['ES2002d.C.words926', 'ES2002d.C.words943'],
#  ['ES2002d.D.words597'],
#  ['ES2002d.B.words1389'],
#  ['ES2002d.A.words1214'],
#  ['ES2002d.B.words1390', 'ES2002d.B.words1397'],
#  ['ES2002d.C.words944', 'ES2002d.C.words965'],
#  ['ES2002d.B.words1398', 'ES2002d.B.words1399'],
#  ['ES2002d.C.words966', 'ES2002d.C.words968'],
#  ['ES2002d.B.words1400', 'ES2002d.B.words1409'],
#  ['ES2002d.A.words1215', 'ES2002d.A.words1217'],
#  ['ES2002d.D.words598', 'ES2002d.D.words600'],
#  ['ES2002d.A.words1218', 'ES2002d.A.words1234'],
#  ['ES2002d.C.words969', 'ES2002d.C.words972'],
#  ['ES2002d.B.words1410', 'ES2002d.B.words1415'],
#  ['ES2002d.C.words973', 'ES2002d.C.words976'],
#  ['ES2002d.A.words1235'],
#  ['ES2002d.C.words977', 'ES2002d.C.words994'],
#  ['ES2002d.A.words1236', 'ES2002d.A.words1237'],
#  ['ES2002d.B.words1416', 'ES2002d.B.words1420'],
#  ['ES2002d.A.words1238', 'ES2002d.A.words1271'],
#  ['ES2002d.D.words601', 'ES2002d.D.words602'],
#  ['ES2002d.C.words995', 'ES2002d.C.words1000'],
#  ['ES2002d.B.words1421', 'ES2002d.B.words1437'],
#  ['ES2002d.C.words1001', 'ES2002d.C.words1009'],
#  ['ES2002d.A.words1272', 'ES2002d.A.words1295'],
#  ['ES2002d.C.words1010', 'ES2002d.C.words1011'],
#  ['ES2002d.B.words1438', 'ES2002d.B.words1439'],
#  ['ES2002d.C.words1012', 'ES2002d.C.words1017'],
#  ['ES2002d.D.words603'],
#  ['ES2002d.B.words1440', 'ES2002d.B.words1441'],
#  ['ES2002d.C.words1018', 'ES2002d.C.words1033'],
#  ['ES2002d.B.words1442', 'ES2002d.B.words1462'],
#  ['ES2002d.C.words1034', 'ES2002d.C.words1044'],
#  ['ES2002d.D.words604', 'ES2002d.D.words607'],
#  ['ES2002d.A.words1296', 'ES2002d.A.words1300'],
#  ['ES2002d.C.words1045', 'ES2002d.C.words1086'],
#  ['ES2002d.D.words608', 'ES2002d.D.words614'],
#  ['ES2002d.B.words1463', 'ES2002d.B.words1470'],
#  ['ES2002d.D.words615', 'ES2002d.D.words629'],
#  ['ES2002d.B.words1471', 'ES2002d.B.words1476'],
#  ['ES2002d.C.words1087', 'ES2002d.C.words1089'],
#  ['ES2002d.A.words1301', 'ES2002d.A.words1305'],
#  ['ES2002d.C.words1090', 'ES2002d.C.words1105'],
#  ['ES2002d.D.words630', 'ES2002d.D.words649'],
#  ['ES2002d.A.words1306', 'ES2002d.A.words1314'],
#  ['ES2002d.C.words1106', 'ES2002d.C.words1125'],
#  ['ES2002d.A.words1315', 'ES2002d.A.words1316'],
#  ['ES2002d.B.words1477', 'ES2002d.B.words1493'],
#  ['ES2002d.C.words1126', 'ES2002d.C.words1141'],
#  ['ES2002d.D.words650', 'ES2002d.D.words651'],
#  ['ES2002d.C.words1142', 'ES2002d.C.words1163'],
#  ['ES2002d.B.words1494', 'ES2002d.B.words1501'],
#  ['ES2002d.C.words1164', 'ES2002d.C.words1192'],
#  ['ES2002d.B.words1502', 'ES2002d.B.words1505'],
#  ['ES2002d.C.words1193', 'ES2002d.C.words1214'],
#  ['ES2002d.B.words1506', 'ES2002d.B.words1508'],
#  ['ES2002d.C.words1215', 'ES2002d.C.words1228'],
#  ['ES2002d.B.words1509', 'ES2002d.B.words1515'],
#  ['ES2002d.C.words1229', 'ES2002d.C.words1239'],
#  ['ES2002d.B.words1516', 'ES2002d.B.words1528'],
#  ['ES2002d.C.words1240', 'ES2002d.C.words1249'],
#  ['ES2002d.B.words1529', 'ES2002d.B.words1532'],
#  ['ES2002d.C.words1250', 'ES2002d.C.words1265'],
#  ['ES2002d.B.words1533', 'ES2002d.B.words1534'],
#  ['ES2002d.C.words1266', 'ES2002d.C.words1281'],
#  ['ES2002d.D.words652'],
#  ['ES2002d.B.words1535', 'ES2002d.B.words1542'],
#  ['ES2002d.A.words1317', 'ES2002d.A.words1322'],
#  ['ES2002d.C.words1282', 'ES2002d.C.words1283'],
#  ['ES2002d.B.words1543', 'ES2002d.B.words1552'],
#  ['ES2002d.C.words1284', 'ES2002d.C.words1378'],
#  ['ES2002d.B.words1553', 'ES2002d.B.words1556'],
#  ['ES2002d.C.words1379', 'ES2002d.C.words1462'],
#  ['ES2002d.A.words1323', 'ES2002d.A.words1324'],
#  ['ES2002d.B.words1557', 'ES2002d.B.words1558'],
#  ['ES2002d.C.words1463', 'ES2002d.C.words1471'],
#  ['ES2002d.B.words1559', 'ES2002d.B.words1585'],
#  ['ES2002d.C.words1472', 'ES2002d.C.words1491'],
#  ['ES2002d.B.words1586', 'ES2002d.B.words1611'],
#  ['ES2002d.D.words653'],
#  ['ES2002d.C.words1492', 'ES2002d.C.words1496'],
#  ['ES2002d.A.words1325', 'ES2002d.A.words1330'],
#  ['ES2002d.B.words1612', 'ES2002d.B.words1613', '**********'],
#  ['ES2002d.B.words1614', 'ES2002d.B.words1632'],
#  ['ES2002d.A.words1331', 'ES2002d.A.words1355'],
#  ['ES2002d.D.words654'],
#  ['ES2002d.B.words1633', 'ES2002d.B.words1637'],
#  ['ES2002d.D.words655'],
#  ['ES2002d.A.words1356', 'ES2002d.A.words1372'],
#  ['ES2002d.C.words1497', 'ES2002d.C.words1498'],
#  ['ES2002d.A.words1373', 'ES2002d.A.words1380'],
#  ['ES2002d.D.words656', 'ES2002d.D.words660'],
#  ['ES2002d.B.words1638', 'ES2002d.B.words1683'],
#  ['ES2002d.C.words1499'],
#  ['ES2002d.A.words1381'],
#  ['ES2002d.B.words1684'],
#  ['ES2002d.C.words1500', 'ES2002d.C.words1521'],
#  ['ES2002d.B.words1685', 'ES2002d.B.words1694'],
#  ['ES2002d.B.words1695', 'ES2002d.B.words1710'],
#  ['ES2002d.C.words1522', 'ES2002d.C.words1524'],
#  ['ES2002d.B.words1711', 'ES2002d.B.words1720'],
#  ['ES2002d.C.words1525', 'ES2002d.C.words1537'],
#  ['ES2002d.B.words1721', 'ES2002d.B.words1743'],
#  ['ES2002d.C.words1538', 'ES2002d.C.words1673'],
#  ['ES2002d.B.words1744', 'ES2002d.B.words1768'],
#  ['ES2002d.C.words1674', 'ES2002d.C.words1731'],
#  ['ES2002d.B.words1769', 'ES2002d.B.words1791'],
#  ['ES2002d.C.words1732', 'ES2002d.C.words1767'],
#  ['ES2002d.B.words1792', 'ES2002d.B.words1827'],
#  ['ES2002d.C.words1768', 'ES2002d.C.words1844'],
#  ['ES2002d.B.words1828', 'ES2002d.B.words1831'],
#  ['ES2002d.C.words1845', 'ES2002d.C.words1898'],
#  ['ES2002d.B.words1832', 'ES2002d.B.words1833'],
#  ['ES2002d.A.words1382', 'ES2002d.A.words1417'],
#  ['ES2002d.B.words1834', 'ES2002d.B.words1835'],
#  ['ES2002d.C.words1899', 'ES2002d.C.words1904'],
#  ['ES2002d.B.words1836'],
#  ['ES2002d.C.words1905', 'ES2002d.C.words1913'],
#  ['ES2002d.B.words1837', 'ES2002d.B.words1873'],
#  ['ES2002d.C.words1914', 'ES2002d.C.words1915'],
#  ['ES2002d.D.words661', 'ES2002d.D.words702'],
#  ['ES2002d.B.words1874', 'ES2002d.B.words1875'],
#  ['ES2002d.A.words1418', 'ES2002d.A.words1419'],
#  ['ES2002d.C.words1916', 'ES2002d.C.words1917'],
#  ['ES2002d.A.words1420', 'ES2002d.A.words1487'],
#  ['ES2002d.C.words1918', 'ES2002d.C.words1919'],
#  ['ES2002d.B.words1876', 'ES2002d.B.words1877'],
#  ['ES2002d.C.words1920', 'ES2002d.C.words1925'],
#  ['ES2002d.B.words1878', 'ES2002d.B.words1879'],
#  ['ES2002d.C.words1926', 'ES2002d.C.words1930'],
#  ['ES2002d.A.words1488', 'ES2002d.A.words1581'],
#  ['ES2002d.C.words1931', 'ES2002d.C.words1936'],
#  ['ES2002d.B.words1880', 'ES2002d.B.words1881'],
#  ['ES2002d.C.words1937', 'ES2002d.C.words1945'],
#  ['ES2002d.B.words1882', 'ES2002d.B.words1899'],
#  ['ES2002d.A.words1582', 'ES2002d.A.words1617'],
#  ['ES2002d.B.words1900', 'ES2002d.B.words1905'],
#  ['ES2002d.C.words1946', 'ES2002d.C.words1949'],
#  ['ES2002d.B.words1906', 'ES2002d.B.words1907'],
#  ['ES2002d.C.words1950', 'ES2002d.C.words1951'],
#  ['ES2002d.B.words1908', 'ES2002d.B.words1912'],
#  ['ES2002d.B.words1913', 'ES2002d.B.words1917'],
#  ['ES2002d.A.words1618'],
#  ['ES2002d.B.words1918', 'ES2002d.B.words1939'],
#  ['ES2002d.A.words1619'],
#  ['ES2002d.C.words1952', 'ES2002d.C.words1973'],
#  ['ES2002d.B.words1940', 'ES2002d.B.words1955'],
#  ['ES2002d.C.words1974', 'ES2002d.C.words1991'],
#  ['ES2002d.B.words1956', 'ES2002d.B.words1957'],
#  ['ES2002d.C.words1992', 'ES2002d.C.words2042'],
#  ['ES2002d.A.words1620', 'ES2002d.A.words1623'],
#  ['ES2002d.B.words1958', 'ES2002d.B.words1959'],
#  ['ES2002d.C.words2043', 'ES2002d.C.words2125'],
#  ['ES2002d.A.words1624'],
#  ['ES2002d.B.words1960', 'ES2002d.B.words1963'],
#  ['ES2002d.C.words2126', 'ES2002d.C.words2169'],
#  ['ES2002d.B.words1964', 'ES2002d.B.words1973'],
#  ['ES2002d.A.words1625'],
#  ['ES2002d.C.words2170', 'ES2002d.C.words2179'],
#  ['ES2002d.A.words1626', 'ES2002d.A.words1749'],
#  ['ES2002d.C.words2180', 'ES2002d.C.words2195'],
#  ['ES2002d.B.words1974', 'ES2002d.B.words1975'],
#  ['ES2002d.C.words2196', 'ES2002d.C.words2203'],
#  ['ES2002d.B.words1976', 'ES2002d.B.words1977'],
#  ['ES2002d.C.words2204', 'ES2002d.C.words2209'],
#  ['ES2002d.B.words1978', 'ES2002d.B.words1979'],
#  ['ES2002d.C.words2210', 'ES2002d.C.words2217'],
#  ['ES2002d.B.words1980', 'ES2002d.B.words1986'],
#  ['ES2002d.C.words2218', 'ES2002d.C.words2225'],
#  ['ES2002d.D.words703', 'ES2002d.D.words720'],
#  ['ES2002d.C.words2226', 'ES2002d.C.words2227'],
#  ['ES2002d.B.words1987', 'ES2002d.B.words1988'],
#  ['ES2002d.D.words721', 'ES2002d.D.words746'],
#  ['ES2002d.C.words2228', 'ES2002d.C.words2229'],
#  ['ES2002d.B.words1989', 'ES2002d.B.words1990'],
#  ['ES2002d.C.words2230', 'ES2002d.C.words2232'],
#  ['ES2002d.A.words1750', 'ES2002d.A.words1794'],
#  ['ES2002d.C.words2233', 'ES2002d.C.words2235'],
#  ['ES2002d.B.words1991', 'ES2002d.B.words1992'],
#  ['ES2002d.C.words2236'],
#  ['ES2002d.B.words1993', 'ES2002d.B.words2060'],
#  ['ES2002d.C.words2237', 'ES2002d.C.words2238'],
#  ['ES2002d.D.words747', 'ES2002d.D.words750'],
#  ['ES2002d.A.words1795', 'ES2002d.A.words1796'],
#  ['ES2002d.C.words2239', 'ES2002d.C.words2244'],
#  ['ES2002d.A.words1797', 'ES2002d.A.words1798'],
#  ['ES2002d.C.words2245', 'ES2002d.C.words2251'],
#  ['ES2002d.A.words1799', 'ES2002d.A.words1846'],
#  ['ES2002d.C.words2252', 'ES2002d.C.words2259'],
#  ['ES2002d.B.words2061', 'ES2002d.B.words2065'],
#  ['ES2002d.C.words2260', 'ES2002d.C.words2350'],
#  ['ES2002d.B.words2066', 'ES2002d.B.words2067'],
#  ['ES2002d.C.words2351', 'ES2002d.C.words2459'],
#  ['ES2002d.A.words1847', 'ES2002d.A.words1852'],
#  ['ES2002d.B.words2068', 'ES2002d.B.words2075'],
#  ['ES2002d.A.words1853', 'ES2002d.A.words1857'],
#  ['ES2002d.B.words2076', 'ES2002d.B.words2087'],
#  ['ES2002d.B.words2088', 'ES2002d.B.words2127'],
#  ['ES2002d.C.words2460', 'ES2002d.C.words2461'],
#  ['ES2002d.B.words2128', 'ES2002d.B.words2130'],
#  ['ES2002d.C.words2462', 'ES2002d.C.words2548'],
#  ['ES2002d.B.words2131', 'ES2002d.B.words2132'],
#  ['ES2002d.C.words2549', 'ES2002d.C.words2644'],
#  ['ES2002d.B.words2133', 'ES2002d.B.words2142'],
#  ['ES2002d.C.words2645', 'ES2002d.C.words2702'],
#  ['ES2002d.B.words2143', 'ES2002d.B.words2146'],
#  ['ES2002d.C.words2703', 'ES2002d.C.words2717'],
#  ['ES2002d.B.words2147', 'ES2002d.B.words2163'],
#  ['ES2002d.C.words2718', 'ES2002d.C.words2723'],
#  ['ES2002d.A.words1858', 'ES2002d.A.words1930'],
#  ['ES2002d.B.words2164', 'ES2002d.B.words2165'],
#  ['ES2002d.C.words2724', 'ES2002d.C.words2743'],
#  ['ES2002d.B.words2166', 'ES2002d.B.words2167'],
#  ['ES2002d.C.words2744', 'ES2002d.C.words2809'],
#  ['ES2002d.B.words2168', 'ES2002d.B.words2172'],
#  ['ES2002d.A.words1931', 'ES2002d.A.words2015'],
#  ['ES2002d.C.words2810', 'ES2002d.C.words2811'],
#  ['ES2002d.D.words751', 'ES2002d.D.words752'],
#  ['ES2002d.B.words2173', 'ES2002d.B.words2174'],
#  ['ES2002d.C.words2812', 'ES2002d.C.words2813'],
#  ['ES2002d.B.words2175', 'ES2002d.B.words2176'],
#  ['ES2002d.C.words2814', 'ES2002d.C.words2822'],
#  ['ES2002d.B.words2177', 'ES2002d.B.words2178'],
#  ['ES2002d.C.words2823', 'ES2002d.C.words2824'],
#  ['ES2002d.B.words2179', 'ES2002d.B.words2193'],
#  ['ES2002d.A.words2016', 'ES2002d.A.words2022'],
#  ['ES2002d.C.words2825', 'ES2002d.C.words2829'],
#  ['ES2002d.D.words753', 'ES2002d.D.words758'],
#  ['ES2002d.B.words2194', 'ES2002d.B.words2195'],
#  ['ES2002d.C.words2830', 'ES2002d.C.words2834'],
#  ['ES2002d.B.words2196', 'ES2002d.B.words2202'],
#  ['ES2002d.C.words2835', 'ES2002d.C.words2836'],
#  ['ES2002d.A.words2023', 'ES2002d.A.words2059'],
#  ['ES2002d.B.words2203'],
#  ['ES2002d.C.words2837', 'ES2002d.C.words2838'],
#  ['ES2002d.B.words2204', 'ES2002d.B.words2281'],
#  ['ES2002d.C.words2839', 'ES2002d.C.words2851'],
#  ['ES2002d.A.words2060', 'ES2002d.A.words2098'],
#  ['ES2002d.C.words2852', 'ES2002d.C.words2857'],
#  ['ES2002d.B.words2282', 'ES2002d.B.words2285'],
#  ['ES2002d.C.words2858'],
#  ['ES2002d.D.words759'],
#  ['ES2002d.C.words2859', 'ES2002d.C.words2890'],
#  ['ES2002d.B.words2286', 'ES2002d.B.words2287'],
#  ['ES2002d.C.words2891', 'ES2002d.C.words2899'],
#  ['ES2002d.A.words2099', 'ES2002d.A.words2106'],
#  ['ES2002d.C.words2900', 'ES2002d.C.words2906'],
#  ['ES2002d.B.words2288', 'ES2002d.B.words2292'],
#  ['ES2002d.C.words2907', 'ES2002d.C.words2926'],
#  ['ES2002d.D.words760', 'ES2002d.D.words762'],
#  ['ES2002d.A.words2107', 'ES2002d.A.words2142'],
#  ['ES2002d.C.words2927', 'ES2002d.C.words2932'],
#  ['ES2002d.B.words2293', 'ES2002d.B.words2294'],
#  ['ES2002d.C.words2933'],
#  ['ES2002d.B.words2295', 'ES2002d.B.words2306'],
#  ['ES2002d.A.words2143', 'ES2002d.A.words2153'],
#  ['ES2002d.D.words763', 'ES2002d.D.words764'],
#  ['ES2002d.B.words2307', 'ES2002d.B.words2372'],
#  ['ES2002d.C.words2934', 'ES2002d.C.words2939'],
#  ['ES2002d.A.words2154', 'ES2002d.A.words2155'],
#  ['ES2002d.C.words2940', 'ES2002d.C.words2943'],
#  ['ES2002d.B.words2373', 'ES2002d.B.words2418'],
#  ['ES2002d.D.words765', 'ES2002d.D.words771'],
#  ['ES2002d.C.words2944', 'ES2002d.C.words2977'],
#  ['ES2002d.B.words2419', 'ES2002d.B.words2427'],
#  ['ES2002d.C.words2978', 'ES2002d.C.words3028'],
#  ['ES2002d.B.words2428', 'ES2002d.B.words2513'],
#  ['ES2002d.C.words3029', 'ES2002d.C.words3041'],
#  ['ES2002d.B.words2514', 'ES2002d.B.words2585'],
#  ['ES2002d.C.words3042', 'ES2002d.C.words3049'],
#  ['ES2002d.B.words2586', 'ES2002d.B.words2589', '**********'],
#  ['ES2002d.B.words2590', 'ES2002d.B.words2645'],
#  ['ES2002d.D.words772', 'ES2002d.D.words773'],
#  ['ES2002d.C.words3050', 'ES2002d.C.words3054'],
#  ['ES2002d.A.words2156', 'ES2002d.A.words2161'],
#  ['ES2002d.C.words3055', 'ES2002d.C.words3058'],
#  ['ES2002d.D.words774', 'ES2002d.D.words776'],
#  ['ES2002d.A.words2162'],
#  ['ES2002d.B.words2646', 'ES2002d.B.words2661'],
#  ['ES2002d.D.words777', 'ES2002d.D.words785'],
#  ['ES2002d.C.words3059', 'ES2002d.C.words3063'],
#  ['ES2002d.A.words2163'],
#  ['ES2002d.B.words2662', 'ES2002d.B.words2664'],
#  ['ES2002d.D.words786', 'ES2002d.D.words789'],
#  ['ES2002d.C.words3064', 'ES2002d.C.words3065'],
#  ['ES2002d.B.words2665', 'ES2002d.B.words2669'],
#  ['ES2002d.D.words790', 'ES2002d.D.words798'],
#  ['ES2002d.C.words3066', 'ES2002d.C.words3071'],
#  ['ES2002d.A.words2164', 'ES2002d.A.words2172'],
#  ['ES2002d.C.words3072', 'ES2002d.C.words3077'],
#  ['ES2002d.A.words2173', 'ES2002d.A.words2188'],
#  ['ES2002d.B.words2670', 'ES2002d.B.words2700'],
#  ['ES2002d.D.words799'],
#  ['ES2002d.C.words3078', 'ES2002d.C.words3079'],
#  ['ES2002d.A.words2189', 'ES2002d.A.words2192'],
#  ['ES2002d.C.words3080', 'ES2002d.C.words3081'],
#  ['ES2002d.A.words2193', 'ES2002d.A.words2211'],
#  ['ES2002d.C.words3082', 'ES2002d.C.words3083'],
#  ['ES2002d.B.words2701', 'ES2002d.B.words2706'],
#  ['ES2002d.C.words3084', 'ES2002d.C.words3088'],
#  ['ES2002d.B.words2707'],
#  ['ES2002d.A.words2212', 'ES2002d.A.words2227'],
#  ['ES2002d.C.words3089', 'ES2002d.C.words3094'],
#  ['ES2002d.D.words800'],
#  ['ES2002d.B.words2708', 'ES2002d.B.words2739'],
#  ['ES2002d.C.words3095', 'ES2002d.C.words3096'],
#  ['ES2002d.A.words2228', 'ES2002d.A.words2230'],
#  ['ES2002d.C.words3097', 'ES2002d.C.words3100'],
#  ['ES2002d.B.words2740', 'ES2002d.B.words2755'],
#  ['ES2002d.C.words3101', 'ES2002d.C.words3102'],
#  ['ES2002d.A.words2231', 'ES2002d.A.words2335'],
#  ['ES2002d.C.words3103', 'ES2002d.C.words3105'],
#  ['ES2002d.B.words2756', 'ES2002d.B.words2757'],
#  ['ES2002d.C.words3106', 'ES2002d.C.words3109'],
#  ['ES2002d.B.words2758', 'ES2002d.B.words2759'],
#  ['ES2002d.C.words3110', 'ES2002d.C.words3112'],
#  ['ES2002d.B.words2760', 'ES2002d.B.words2764'],
#  ['ES2002d.C.words3113', 'ES2002d.C.words3114'],
#  ['ES2002d.B.words2765', 'ES2002d.B.words2768'],
#  ['ES2002d.C.words3115', 'ES2002d.C.words3121'],
#  ['ES2002d.D.words801', 'ES2002d.D.words809'],
#  ['ES2002d.C.words3122', 'ES2002d.C.words3123'],
#  ['ES2002d.B.words2769', 'ES2002d.B.words2778'],
#  ['ES2002d.C.words3124', 'ES2002d.C.words3134'],
#  ['ES2002d.A.words2336', 'ES2002d.A.words2342'],
#  ['ES2002d.B.words2779', 'ES2002d.B.words2794'],
#  ['ES2002d.D.words810', 'ES2002d.D.words821'],
#  ['ES2002d.A.words2343', 'ES2002d.A.words2359'],
#  ['ES2002d.C.words3135', 'ES2002d.C.words3138'],
#  ['ES2002d.B.words2795', 'ES2002d.B.words2807'],
#  ['ES2002d.A.words2360', 'ES2002d.A.words2393'],
#  ['ES2002d.C.words3139', 'ES2002d.C.words3140'],
#  ['ES2002d.B.words2808', 'ES2002d.B.words2809'],
#  ['ES2002d.C.words3141', 'ES2002d.C.words3145'],
#  ['ES2002d.D.words822'],
#  ['ES2002d.B.words2810'],
#  ['ES2002d.A.words2394', 'ES2002d.A.words2456'],
#  ['ES2002d.C.words3146', 'ES2002d.C.words3148'],
#  ['ES2002d.B.words2811', 'ES2002d.B.words2814'],
#  ['ES2002d.C.words3149', 'ES2002d.C.words3154'],
#  ['ES2002d.D.words823', 'ES2002d.D.words828'],
#  ['ES2002d.C.words3155', 'ES2002d.C.words3156'],
#  ['ES2002d.B.words2815', 'ES2002d.B.words2816'],
#  ['ES2002d.C.words3157', 'ES2002d.C.words3164'],
#  ['ES2002d.B.words2817', 'ES2002d.B.words2821'],
#  ['ES2002d.A.words2457'],
#  ['ES2002d.B.words2822', 'ES2002d.B.words2835'],
#  ['ES2002d.A.words2458', 'ES2002d.A.words2459'],
#  ['ES2002d.B.words2836', 'ES2002d.B.words2851'],
#  ['ES2002d.C.words3165', 'ES2002d.C.words3173'],
#  ['ES2002d.A.words2460', 'ES2002d.A.words2474'],
#  ['ES2002d.B.words2852', 'ES2002d.B.words2853'],
#  ['ES2002d.C.words3174', 'ES2002d.C.words3178'],
#  ['ES2002d.B.words2854', 'ES2002d.B.words2872'],
#  ['ES2002d.C.words3179'],
#  ['ES2002d.A.words2475', 'ES2002d.A.words2481'],
#  ['ES2002d.C.words3180'],
#  ['ES2002d.B.words2873', 'ES2002d.B.words2885', '**********']]

# %% [markdown]
# ### ---- A test of how to capture paragraph boundaries

# %%
tree = ET.parse('./segments/ES2002b.B.segments.xml')
root = tree.getroot()

# %%
para = []
start = False
for segment in root.findall('.//nite:child', name_space):
    if start:
        para.append(re.search(p_pattern, segment.attrib['href']).groups())
    if 'ES2002b.B.words0' in segment.attrib['href']:
        para.append(re.search(p_pattern, segment.attrib['href']).groups())
        start = True
    if 'ES2002b.B.words128' in segment.attrib['href']:
        break

# %%
para
# Out:
# [('ES2002b.B.words0', 'ES2002b.B.words4'),
#  ('ES2002b.B.words5', 'ES2002b.B.words7'),
#  ('ES2002b.B.words8', 'ES2002b.B.words9'),
#  ('ES2002b.B.words10', 'ES2002b.B.words128')]

# %%
'ES2002b.B.words0' in "ES2002b.B.words.xml#id(ES2002b.B.words0)..id(ES2002b.B.words4)"
# Out:
# True

# %% [markdown]
# ### Then we need to figure out paragraph bounds

# %% [markdown]
# ### First we try to get the complete transcript for one topic xml file -- "`ES2002b.topic.xml`"

# %%
seg_file_pattern = r'\w{7}\.\w\.'

# %% [markdown]
# ### Some more complicated situation that we need to be able to  address:
# **1. The start word of a segment from the topic file(`length 2`) is in the interval of segment in segments files, the end word matches the one in the segments file**
#
# **2. Start word matches but the end word falls in the interval**
# 3. Both start word and end word are in the interval
# 4. The segment in segments is single length and match only the start word of a segment in topic file
# 5. The segment in segments is single length and match only the end word of a segment in topic file

# %% [markdown]
# ### It's much easier to deal with the stareting and ending intervals in only numeric mode

# %% [markdown]
#                 try:
#                     paras.append(','.join(re.search(p_pattern, segment.attrib['href']).groups()))
#                 except:
#                     paras.append(re.search(s_pattern, segment.attrib['href']).group(1))

# %%
wseg_with_parapgraph1 = []
for seg in word_segments:
    if len(seg) == 1:
        wseg_with_parapgraph1.append(seg)
    else:# the length of segment is 2 or 3, 3 means its a topical boundary
        file_name = re.match(seg_file_pattern, seg[0]).group(0) + "segments.xml"
        tree =  ET.parse('./segments/'+file_name)
        root = tree.getroot()
        paras = []
        start = False
        for segment in root.findall('.//nite:child', name_space):
            if start:
                try:
                    paras.append(','.join(re.search(p_pattern, segment.attrib['href']).groups()))
                except:
                    paras.append(re.search(s_pattern, segment.attrib['href']).group(1))
            if seg[0] in segment.attrib['href']:
                start = True
                try:
                    paras.append(','.join(re.search(p_pattern, segment.attrib['href']).groups()))
                except:
                    paras.append(re.search(s_pattern, segment.attrib['href']).group(1))
            if seg[1] in segment.attrib['href']:
                break
        if len(paras) == 0:
            paras.append(seg[0] + ',' + seg[1])
        if seg[-1] == '**********':
            paras.append('**********')
        wseg_with_parapgraph1.append(paras)
# Out:
# ['ES2002d.B.words474', 'ES2002d.B.words502']
# {'href': 'ES2002d.B.words.xml#id(ES2002d.B.words490)..id(ES2002d.B.words502)'}
# ['ES2002d.B.words742', 'ES2002d.B.words767']
# {'href': 'ES2002d.B.words.xml#id(ES2002d.B.words720)..id(ES2002d.B.words767)'}
# ['ES2002d.B.words1614', 'ES2002d.B.words1632']
# {'href': 'ES2002d.B.words.xml#id(ES2002d.B.words1612)..id(ES2002d.B.words1632)'}
# ['ES2002d.B.words1695', 'ES2002d.B.words1710']
# {'href': 'ES2002d.B.words.xml#id(ES2002d.B.words1685)..id(ES2002d.B.words1710)'}
# ['ES2002d.B.words1913', 'ES2002d.B.words1917']
# {'href': 'ES2002d.B.words.xml#id(ES2002d.B.words1910)..id(ES2002d.B.words1917)'}
# ['ES2002d.B.words2088', 'ES2002d.B.words2127']
# {'href': 'ES2002d.B.words.xml#id(ES2002d.B.words2076)..id(ES2002d.B.words2127)'}
# ['ES2002d.B.words2590', 'ES2002d.B.words2645']
# {'href': 'ES2002d.B.words.xml#id(ES2002d.B.words2586)..id(ES2002d.B.words2645)'}

# %% [markdown]
# # REVISED VERSION TO DEAL WITH SEGMENTS SPLIT IN TWO SUBTOPICS
# wseg_with_parapgraph = []
# for seg in word_segments:
#     if len(seg) == 1:
#         wseg_with_parapgraph.append(seg)
#     else:# the length of segment is 2 or 3, 3 means its a topical boundary
#         file_name = re.match(seg_file_pattern, seg[0]).group(0) + "segments.xml"
#         tree =  ET.parse('./segments/'+file_name)
#         root = tree.getroot()
#         paras = []
#         #start = False
#         for segment in root.findall('.//nite:child', name_space):
#             #if start:
#                 #try:
#                     #paras.append(','.join(re.search(p_pattern, segment.attrib['href']).groups()))
#                 #except:
#                     #paras.append(re.search(s_pattern, segment.attrib['href']).group(1))
#             if re.search(p_pattern, segment.attrib['href']):#this means the segment has length of 2
#                 if seg[0] >= re.search(p_pattern, segment.attrib['href']).group(1) and seg[1] >= re.search(p_pattern, segment.attrib['href']).group(2):
#                     paras.append(seg[0] + ',' + re.search(p_pattern, segment.attrib['href']).group(2))
#                 if seg[0] >= re.search(p_pattern, segment.attrib['href']).group(1) and seg[1] < re.search(p_pattern, segment.attrib['href']).group(2):
#                     paras.append(seg[0] + ',' + seg[1])
#                 if seg[0] < re.search(p_pattern, segment.attrib['href']).group(1) and seg[1] >= re.search(p_pattern, segment.attrib['href']).group(2):
#         if seg[-1] == '**********':
#             paras.append('**********')
#         if len(paras) == 0:
#             print(seg)
#             print(segment.attrib)
#         wseg_with_parapgraph.append(paras)

# %% [markdown]
#                 start = True
#                 try:
#                     paras.append(re.search(p_pattern, segment.attrib['href']).group(1) + ',' + seg[0])
#                 except:
#                     paras.append(seg[0])
#             try:
#                 if seg[1] <= re.search(p_pattern, segment.attrib['href']).group(2):
#                     break
#             except:
#                 if seg[1] <= re.search(s_pattern, segment.attrib['href']).group(1):
#                     break

# %%
re.match('\w+','abc').group(0)
# Out:
# 'abc'

# %%
wseg_with_parapgraph1
# Out:
# [['ES2002d.B.words0,ES2002d.B.words80',
#   'ES2002d.B.words81,ES2002d.B.words170',
#   '**********'],
#  ['ES2002d.A.words0,ES2002d.A.words1'],
#  ['ES2002d.D.words0,ES2002d.D.words86'],
#  ['ES2002d.A.words2,ES2002d.A.words9'],
#  ['ES2002d.B.words171,ES2002d.B.words172',
#   'ES2002d.B.words173,ES2002d.B.words174',
#   'ES2002d.B.words175,ES2002d.B.words176'],
#  ['ES2002d.D.words87,ES2002d.D.words107'],
#  ['ES2002d.C.words0,ES2002d.C.words2'],
#  ['ES2002d.A.words10,ES2002d.A.words46'],
#  ['ES2002d.C.words3,ES2002d.C.words6'],
#  ['ES2002d.A.words47,ES2002d.A.words59'],
#  ['ES2002d.C.words7,ES2002d.C.words12'],
#  ['ES2002d.B.words177,ES2002d.B.words187'],
#  ['ES2002d.D.words108'],
#  ['ES2002d.A.words60,ES2002d.A.words132'],
#  ['ES2002d.C.words13,ES2002d.C.words14',
#   'ES2002d.C.words15,ES2002d.C.words16',
#   'ES2002d.C.words17,ES2002d.C.words18'],
#  ['ES2002d.B.words188,ES2002d.B.words192'],
#  ['ES2002d.C.words19,ES2002d.C.words22'],
#  ['ES2002d.A.words133,ES2002d.A.words164'],
#  ['ES2002d.C.words23,ES2002d.C.words24',
#   'ES2002d.C.words25,ES2002d.C.words32'],
#  ['ES2002d.B.words193,ES2002d.B.words198'],
#  ['ES2002d.A.words165,ES2002d.A.words169'],
#  ['ES2002d.C.words33,ES2002d.C.words43'],
#  ['ES2002d.B.words199,ES2002d.B.words206'],
#  ['ES2002d.A.words170,ES2002d.A.words177'],
#  ['ES2002d.D.words109,ES2002d.D.words117'],
#  ['ES2002d.B.words207,ES2002d.B.words209'],
#  ['ES2002d.A.words178,ES2002d.A.words200'],
#  ['ES2002d.B.words210', 'ES2002d.B.words211,ES2002d.B.words212'],
#  ['ES2002d.A.words201,ES2002d.A.words216'],
#  ['ES2002d.C.words44,ES2002d.C.words45',
#   'ES2002d.C.words46,ES2002d.C.words47'],
#  ['ES2002d.A.words217,ES2002d.A.words246'],
#  ['ES2002d.B.words213,ES2002d.B.words214'],
#  ['ES2002d.C.words48,ES2002d.C.words50',
#   'ES2002d.C.words51,ES2002d.C.words52',
#   'ES2002d.C.words53,ES2002d.C.words55'],
#  ['ES2002d.B.words215,ES2002d.B.words224',
#   'ES2002d.B.words225,ES2002d.B.words231'],
#  ['ES2002d.D.words118,ES2002d.D.words153'],
#  ['ES2002d.B.words232,ES2002d.B.words233'],
#  ['ES2002d.C.words56,ES2002d.C.words57'],
#  ['ES2002d.A.words247,ES2002d.A.words262',
#   'ES2002d.A.words263,ES2002d.A.words270'],
#  ['ES2002d.C.words58,ES2002d.C.words59',
#   'ES2002d.C.words60,ES2002d.C.words64'],
#  ['ES2002d.A.words271,ES2002d.A.words279'],
#  ['ES2002d.B.words234,ES2002d.B.words243',
#   'ES2002d.B.words244,ES2002d.B.words265'],
#  ['ES2002d.C.words65,ES2002d.C.words70',
#   'ES2002d.C.words71,ES2002d.C.words72'],
#  ['ES2002d.A.words280,ES2002d.A.words283',
#   'ES2002d.A.words284,ES2002d.A.words285'],
#  ['ES2002d.C.words73,ES2002d.C.words105'],
#  ['ES2002d.B.words266,ES2002d.B.words267',
#   'ES2002d.B.words268,ES2002d.B.words280'],
#  ['ES2002d.C.words106,ES2002d.C.words107',
#   'ES2002d.C.words108,ES2002d.C.words142'],
#  ['ES2002d.D.words154,ES2002d.D.words156',
#   'ES2002d.D.words157,ES2002d.D.words180'],
#  ['ES2002d.C.words143,ES2002d.C.words144'],
#  ['ES2002d.D.words181,ES2002d.D.words182'],
#  ['ES2002d.B.words281,ES2002d.B.words304'],
#  ['ES2002d.D.words183,ES2002d.D.words249'],
#  ['ES2002d.A.words286,ES2002d.A.words289'],
#  ['ES2002d.B.words305,ES2002d.B.words306'],
#  ['ES2002d.A.words290,ES2002d.A.words291'],
#  ['ES2002d.B.words307,ES2002d.B.words308',
#   'ES2002d.B.words309,ES2002d.B.words318'],
#  ['ES2002d.C.words145,ES2002d.C.words146'],
#  ['ES2002d.A.words292,ES2002d.A.words307'],
#  ['ES2002d.D.words250,ES2002d.D.words253', 'ES2002d.D.words254'],
#  ['ES2002d.B.words319,ES2002d.B.words320'],
#  ['ES2002d.C.words147,ES2002d.C.words151'],
#  ['ES2002d.A.words308,ES2002d.A.words319'],
#  ['ES2002d.C.words152,ES2002d.C.words153'],
#  ['ES2002d.D.words255,ES2002d.D.words259'],
#  ['ES2002d.B.words321,ES2002d.B.words329'],
#  ['ES2002d.A.words320,ES2002d.A.words338'],
#  ['ES2002d.D.words260,ES2002d.D.words261'],
#  ['ES2002d.C.words154,ES2002d.C.words155'],
#  ['ES2002d.D.words262,ES2002d.D.words265'],
#  ['ES2002d.B.words330,ES2002d.B.words361'],
#  ['ES2002d.A.words339,ES2002d.A.words342'],
#  ['ES2002d.C.words156,ES2002d.C.words157',
#   'ES2002d.C.words158,ES2002d.C.words162'],
#  ['ES2002d.D.words266,ES2002d.D.words277'],
#  ['ES2002d.B.words362,ES2002d.B.words363'],
#  ['ES2002d.D.words278,ES2002d.D.words309'],
#  ['ES2002d.B.words364,ES2002d.B.words368',
#   'ES2002d.B.words369,ES2002d.B.words378'],
#  ['ES2002d.C.words163,ES2002d.C.words164'],
#  ['ES2002d.D.words310,ES2002d.D.words325'],
#  ['ES2002d.B.words379,ES2002d.B.words388'],
#  ['ES2002d.D.words326,ES2002d.D.words328',
#   'ES2002d.D.words329,ES2002d.D.words351'],
#  ['ES2002d.B.words389,ES2002d.B.words396'],
#  ['ES2002d.D.words352,ES2002d.D.words358'],
#  ['ES2002d.A.words343,ES2002d.A.words356'],
#  ['ES2002d.B.words397,ES2002d.B.words398',
#   'ES2002d.B.words399,ES2002d.B.words407'],
#  ['ES2002d.A.words357,ES2002d.A.words358',
#   'ES2002d.A.words359,ES2002d.A.words384'],
#  ['ES2002d.C.words165,ES2002d.C.words168'],
#  ['ES2002d.B.words408,ES2002d.B.words411'],
#  ['ES2002d.C.words169,ES2002d.C.words175'],
#  ['ES2002d.A.words385,ES2002d.A.words386',
#   'ES2002d.A.words387,ES2002d.A.words412'],
#  ['ES2002d.B.words412,ES2002d.B.words413'],
#  ['ES2002d.C.words176,ES2002d.C.words177'],
#  ['ES2002d.B.words414,ES2002d.B.words431'],
#  ['ES2002d.C.words178,ES2002d.C.words179'],
#  ['ES2002d.A.words413,ES2002d.A.words430'],
#  ['ES2002d.D.words359,ES2002d.D.words360',
#   'ES2002d.D.words361,ES2002d.D.words366'],
#  ['ES2002d.A.words431,ES2002d.A.words432',
#   'ES2002d.A.words433,ES2002d.A.words478'],
#  ['ES2002d.B.words432,ES2002d.B.words433'],
#  ['ES2002d.C.words180,ES2002d.C.words181'],
#  ['ES2002d.B.words434,ES2002d.B.words445'],
#  ['ES2002d.C.words182,ES2002d.C.words184'],
#  ['ES2002d.A.words479,ES2002d.A.words480'],
#  ['ES2002d.B.words446,ES2002d.B.words480',
#   'ES2002d.B.words481,ES2002d.B.words489',
#   'ES2002d.B.words490,ES2002d.B.words502',
#   'ES2002d.B.words503,ES2002d.B.words540',
#   'ES2002d.B.words541,ES2002d.B.words560',
#   'ES2002d.B.words561,ES2002d.B.words578',
#   'ES2002d.B.words579,ES2002d.B.words585',
#   'ES2002d.B.words586,ES2002d.B.words587',
#   'ES2002d.B.words588,ES2002d.B.words598',
#   'ES2002d.B.words599,ES2002d.B.words630',
#   'ES2002d.B.words631,ES2002d.B.words636',
#   'ES2002d.B.words637,ES2002d.B.words654',
#   'ES2002d.B.words655,ES2002d.B.words666',
#   'ES2002d.B.words667,ES2002d.B.words680',
#   'ES2002d.B.words681,ES2002d.B.words682',
#   'ES2002d.B.words683,ES2002d.B.words684',
#   'ES2002d.B.words685,ES2002d.B.words686',
#   'ES2002d.B.words687,ES2002d.B.words707',
#   'ES2002d.B.words708,ES2002d.B.words716',
#   'ES2002d.B.words717,ES2002d.B.words719',
#   'ES2002d.B.words720,ES2002d.B.words767',
#   'ES2002d.B.words768,ES2002d.B.words810',
#   'ES2002d.B.words811,ES2002d.B.words812',
#   'ES2002d.B.words813,ES2002d.B.words821',
#   'ES2002d.B.words822,ES2002d.B.words824',
#   'ES2002d.B.words825,ES2002d.B.words838',
#   'ES2002d.B.words839,ES2002d.B.words846',
#   'ES2002d.B.words847,ES2002d.B.words848',
#   'ES2002d.B.words849,ES2002d.B.words878',
#   'ES2002d.B.words879,ES2002d.B.words881',
#   'ES2002d.B.words882,ES2002d.B.words883',
#   'ES2002d.B.words884,ES2002d.B.words887',
#   'ES2002d.B.words888,ES2002d.B.words908',
#   'ES2002d.B.words909,ES2002d.B.words910',
#   'ES2002d.B.words911,ES2002d.B.words922',
#   'ES2002d.B.words923,ES2002d.B.words924',
#   'ES2002d.B.words925,ES2002d.B.words928',
#   'ES2002d.B.words929,ES2002d.B.words936',
#   'ES2002d.B.words937,ES2002d.B.words943',
#   'ES2002d.B.words944,ES2002d.B.words946',
#   'ES2002d.B.words947,ES2002d.B.words948',
#   'ES2002d.B.words949,ES2002d.B.words951',
#   'ES2002d.B.words952,ES2002d.B.words992',
#   'ES2002d.B.words993,ES2002d.B.words997',
#   'ES2002d.B.words998,ES2002d.B.words1003',
#   'ES2002d.B.words1004,ES2002d.B.words1006',
#   'ES2002d.B.words1007,ES2002d.B.words1018',
#   'ES2002d.B.words1019,ES2002d.B.words1082',
#   'ES2002d.B.words1083,ES2002d.B.words1084',
#   'ES2002d.B.words1085,ES2002d.B.words1107',
#   'ES2002d.B.words1108,ES2002d.B.words1113',
#   'ES2002d.B.words1114,ES2002d.B.words1132',
#   'ES2002d.B.words1133,ES2002d.B.words1160',
#   'ES2002d.B.words1161,ES2002d.B.words1169',
#   'ES2002d.B.words1170,ES2002d.B.words1171',
#   'ES2002d.B.words1172,ES2002d.B.words1174',
#   'ES2002d.B.words1175,ES2002d.B.words1206',
#   'ES2002d.B.words1207,ES2002d.B.words1209',
#   'ES2002d.B.words1210,ES2002d.B.words1212',
#   'ES2002d.B.words1213,ES2002d.B.words1232',
#   'ES2002d.B.words1233,ES2002d.B.words1268',
#   'ES2002d.B.words1269,ES2002d.B.words1278',
#   'ES2002d.B.words1279,ES2002d.B.words1308',
#   'ES2002d.B.words1309',
#   'ES2002d.B.words1310,ES2002d.B.words1311',
#   'ES2002d.B.words1312,ES2002d.B.words1313',
#   'ES2002d.B.words1314,ES2002d.B.words1315',
#   'ES2002d.B.words1316',
#   'ES2002d.B.words1317,ES2002d.B.words1321',
#   'ES2002d.B.words1322,ES2002d.B.words1324',
#   'ES2002d.B.words1325,ES2002d.B.words1326',
#   'ES2002d.B.words1327,ES2002d.B.words1356',
#   'ES2002d.B.words1357,ES2002d.B.words1358',
#   'ES2002d.B.words1359,ES2002d.B.words1360',
#   'ES2002d.B.words1361,ES2002d.B.words1362',
#   'ES2002d.B.words1363,ES2002d.B.words1371',
#   'ES2002d.B.words1372,ES2002d.B.words1373',
#   'ES2002d.B.words1374,ES2002d.B.words1386',
#   'ES2002d.B.words1387,ES2002d.B.words1388',
#   'ES2002d.B.words1389',
#   'ES2002d.B.words1390,ES2002d.B.words1397',
#   'ES2002d.B.words1398,ES2002d.B.words1399',
#   'ES2002d.B.words1400,ES2002d.B.words1409',
#   'ES2002d.B.words1410,ES2002d.B.words1415',
#   'ES2002d.B.words1416,ES2002d.B.words1420',
#   'ES2002d.B.words1421,ES2002d.B.words1437',
#   'ES2002d.B.words1438,ES2002d.B.words1439',
#   'ES2002d.B.words1440,ES2002d.B.words1441',
#   'ES2002d.B.words1442,ES2002d.B.words1462',
#   'ES2002d.B.words1463,ES2002d.B.words1470',
#   'ES2002d.B.words1471,ES2002d.B.words1476',
#   'ES2002d.B.words1477,ES2002d.B.words1493',
#   'ES2002d.B.words1494,ES2002d.B.words1501',
#   'ES2002d.B.words1502,ES2002d.B.words1505',
#   'ES2002d.B.words1506,ES2002d.B.words1508',
#   'ES2002d.B.words1509,ES2002d.B.words1515',
#   'ES2002d.B.words1516,ES2002d.B.words1528',
#   'ES2002d.B.words1529,ES2002d.B.words1532',
#   'ES2002d.B.words1533,ES2002d.B.words1534',
#   'ES2002d.B.words1535',
#   'ES2002d.B.words1536,ES2002d.B.words1542',
#   'ES2002d.B.words1543,ES2002d.B.words1552',
#   'ES2002d.B.words1553,ES2002d.B.words1554',
#   'ES2002d.B.words1555,ES2002d.B.words1556',
#   'ES2002d.B.words1557,ES2002d.B.words1558',
#   'ES2002d.B.words1559,ES2002d.B.words1560',
#   'ES2002d.B.words1561,ES2002d.B.words1568',
#   'ES2002d.B.words1569,ES2002d.B.words1585',
#   'ES2002d.B.words1586,ES2002d.B.words1611',
#   'ES2002d.B.words1612,ES2002d.B.words1632',
#   'ES2002d.B.words1633,ES2002d.B.words1637',
#   'ES2002d.B.words1638,ES2002d.B.words1676',
#   'ES2002d.B.words1677,ES2002d.B.words1683',
#   'ES2002d.B.words1684',
#   'ES2002d.B.words1685,ES2002d.B.words1710',
#   'ES2002d.B.words1711,ES2002d.B.words1720',
#   'ES2002d.B.words1721,ES2002d.B.words1743',
#   'ES2002d.B.words1744,ES2002d.B.words1745',
#   'ES2002d.B.words1746,ES2002d.B.words1768',
#   'ES2002d.B.words1769,ES2002d.B.words1791',
#   'ES2002d.B.words1792,ES2002d.B.words1794',
#   'ES2002d.B.words1795,ES2002d.B.words1796',
#   'ES2002d.B.words1797,ES2002d.B.words1827',
#   'ES2002d.B.words1828,ES2002d.B.words1829',
#   'ES2002d.B.words1830,ES2002d.B.words1831',
#   'ES2002d.B.words1832,ES2002d.B.words1833',
#   'ES2002d.B.words1834,ES2002d.B.words1835',
#   'ES2002d.B.words1836',
#   'ES2002d.B.words1837,ES2002d.B.words1873',
#   'ES2002d.B.words1874,ES2002d.B.words1875',
#   'ES2002d.B.words1876,ES2002d.B.words1877',
#   'ES2002d.B.words1878,ES2002d.B.words1879',
#   'ES2002d.B.words1880,ES2002d.B.words1881',
#   'ES2002d.B.words1882,ES2002d.B.words1899',
#   'ES2002d.B.words1900,ES2002d.B.words1905',
#   'ES2002d.B.words1906,ES2002d.B.words1907',
#   'ES2002d.B.words1908,ES2002d.B.words1909',
#   'ES2002d.B.words1910,ES2002d.B.words1917',
#   'ES2002d.B.words1918,ES2002d.B.words1939',
#   'ES2002d.B.words1940,ES2002d.B.words1955',
#   'ES2002d.B.words1956,ES2002d.B.words1957',
#   'ES2002d.B.words1958,ES2002d.B.words1959',
#   'ES2002d.B.words1960,ES2002d.B.words1963',
#   'ES2002d.B.words1964,ES2002d.B.words1973',
#   'ES2002d.B.words1974,ES2002d.B.words1975',
#   'ES2002d.B.words1976,ES2002d.B.words1977',
#   'ES2002d.B.words1978,ES2002d.B.words1979',
#   'ES2002d.B.words1980,ES2002d.B.words1986',
#   'ES2002d.B.words1987,ES2002d.B.words1988',
#   'ES2002d.B.words1989,ES2002d.B.words1990',
#   'ES2002d.B.words1991,ES2002d.B.words1992',
#   'ES2002d.B.words1993,ES2002d.B.words2060',
#   'ES2002d.B.words2061,ES2002d.B.words2065',
#   'ES2002d.B.words2066,ES2002d.B.words2067',
#   'ES2002d.B.words2068,ES2002d.B.words2069',
#   'ES2002d.B.words2070,ES2002d.B.words2071',
#   'ES2002d.B.words2072,ES2002d.B.words2073',
#   'ES2002d.B.words2074,ES2002d.B.words2075',
#   'ES2002d.B.words2076,ES2002d.B.words2127',
#   'ES2002d.B.words2128',
#   'ES2002d.B.words2129,ES2002d.B.words2130',
#   'ES2002d.B.words2131,ES2002d.B.words2132',
#   'ES2002d.B.words2133,ES2002d.B.words2134',
#   'ES2002d.B.words2135,ES2002d.B.words2136',
#   'ES2002d.B.words2137,ES2002d.B.words2142',
#   'ES2002d.B.words2143,ES2002d.B.words2144',
#   'ES2002d.B.words2145,ES2002d.B.words2146',
#   'ES2002d.B.words2147,ES2002d.B.words2163',
#   'ES2002d.B.words2164,ES2002d.B.words2165',
#   'ES2002d.B.words2166,ES2002d.B.words2167',
#   'ES2002d.B.words2168,ES2002d.B.words2169',
#   'ES2002d.B.words2170,ES2002d.B.words2172',
#   'ES2002d.B.words2173,ES2002d.B.words2174',
#   'ES2002d.B.words2175,ES2002d.B.words2176',
#   'ES2002d.B.words2177,ES2002d.B.words2178',
#   'ES2002d.B.words2179,ES2002d.B.words2193',
#   'ES2002d.B.words2194,ES2002d.B.words2195',
#   'ES2002d.B.words2196,ES2002d.B.words2202',
#   'ES2002d.B.words2203',
#   'ES2002d.B.words2204,ES2002d.B.words2205',
#   'ES2002d.B.words2206,ES2002d.B.words2281',
#   'ES2002d.B.words2282,ES2002d.B.words2285',
#   'ES2002d.B.words2286,ES2002d.B.words2287',
#   'ES2002d.B.words2288,ES2002d.B.words2292',
#   'ES2002d.B.words2293,ES2002d.B.words2294',
#   'ES2002d.B.words2295,ES2002d.B.words2306',
#   'ES2002d.B.words2307,ES2002d.B.words2308',
#   'ES2002d.B.words2309,ES2002d.B.words2372',
#   'ES2002d.B.words2373,ES2002d.B.words2418',
#   'ES2002d.B.words2419,ES2002d.B.words2427',
#   'ES2002d.B.words2428',
#   'ES2002d.B.words2429,ES2002d.B.words2430',
#   'ES2002d.B.words2431,ES2002d.B.words2513',
#   'ES2002d.B.words2514,ES2002d.B.words2585',
#   'ES2002d.B.words2586,ES2002d.B.words2645',
#   'ES2002d.B.words2646,ES2002d.B.words2661',
#   'ES2002d.B.words2662,ES2002d.B.words2664',
#   'ES2002d.B.words2665,ES2002d.B.words2669',
#   'ES2002d.B.words2670,ES2002d.B.words2700',
#   'ES2002d.B.words2701,ES2002d.B.words2706',
#   'ES2002d.B.words2707',
#   'ES2002d.B.words2708,ES2002d.B.words2739',
#   'ES2002d.B.words2740',
#   'ES2002d.B.words2741,ES2002d.B.words2755',
#   'ES2002d.B.words2756,ES2002d.B.words2757',
#   'ES2002d.B.words2758,ES2002d.B.words2759',
#   'ES2002d.B.words2760,ES2002d.B.words2761',
#   'ES2002d.B.words2762,ES2002d.B.words2764',
#   'ES2002d.B.words2765,ES2002d.B.words2766',
#   'ES2002d.B.words2767,ES2002d.B.words2768',
#   'ES2002d.B.words2769,ES2002d.B.words2778',
#   'ES2002d.B.words2779,ES2002d.B.words2794',
#   'ES2002d.B.words2795,ES2002d.B.words2807',
#   'ES2002d.B.words2808,ES2002d.B.words2809',
#   'ES2002d.B.words2810',
#   'ES2002d.B.words2811,ES2002d.B.words2812',
#   'ES2002d.B.words2813,ES2002d.B.words2814',
#   'ES2002d.B.words2815,ES2002d.B.words2816',
#   'ES2002d.B.words2817,ES2002d.B.words2818',
#   'ES2002d.B.words2819,ES2002d.B.words2821',
#   'ES2002d.B.words2822,ES2002d.B.words2835',
#   'ES2002d.B.words2836,ES2002d.B.words2841',
#   'ES2002d.B.words2842,ES2002d.B.words2851',
#   'ES2002d.B.words2852,ES2002d.B.words2853',
#   'ES2002d.B.words2854,ES2002d.B.words2872',
#   'ES2002d.B.words2873,ES2002d.B.words2885',
#   '**********'],
#  ['ES2002d.B.words474,ES2002d.B.words502'],
#  ['ES2002d.D.words367,ES2002d.D.words368'],
#  ['ES2002d.B.words503,ES2002d.B.words540'],
#  ['ES2002d.A.words481,ES2002d.A.words483',
#   'ES2002d.A.words484,ES2002d.A.words485',
#   'ES2002d.A.words486,ES2002d.A.words487',
#   'ES2002d.A.words488,ES2002d.A.words491'],
#  ['ES2002d.B.words541,ES2002d.B.words560'],
#  ['ES2002d.A.words492,ES2002d.A.words493'],
#  ['ES2002d.D.words369,ES2002d.D.words370'],
#  ['ES2002d.A.words494,ES2002d.A.words518',
#   'ES2002d.A.words519,ES2002d.A.words520'],
#  ['ES2002d.B.words561,ES2002d.B.words578'],
#  ['ES2002d.D.words371,ES2002d.D.words391'],
#  ['ES2002d.A.words521,ES2002d.A.words522'],
#  ['ES2002d.B.words579,ES2002d.B.words585'],
#  ['ES2002d.A.words523,ES2002d.A.words524'],
#  ['ES2002d.B.words586,ES2002d.B.words587'],
#  ['ES2002d.A.words525,ES2002d.A.words526'],
#  ['ES2002d.B.words588,ES2002d.B.words598'],
#  ['ES2002d.A.words527,ES2002d.A.words536'],
#  ['ES2002d.B.words599,ES2002d.B.words630'],
#  ['ES2002d.A.words537,ES2002d.A.words538',
#   'ES2002d.A.words539,ES2002d.A.words540',
#   'ES2002d.A.words541,ES2002d.A.words553'],
#  ['ES2002d.B.words631,ES2002d.B.words636'],
#  ['ES2002d.A.words554,ES2002d.A.words570'],
#  ['ES2002d.B.words637,ES2002d.B.words654'],
#  ['ES2002d.C.words185,ES2002d.C.words186'],
#  ['ES2002d.A.words571,ES2002d.A.words572',
#   'ES2002d.A.words573,ES2002d.A.words578'],
#  ['ES2002d.B.words655,ES2002d.B.words666'],
#  ['ES2002d.A.words579,ES2002d.A.words581'],
#  ['ES2002d.D.words392,ES2002d.D.words402'],
#  ['ES2002d.C.words187,ES2002d.C.words190'],
#  ['ES2002d.A.words582,ES2002d.A.words588'],
#  ['ES2002d.B.words667,ES2002d.B.words680'],
#  ['ES2002d.D.words403,ES2002d.D.words404',
#   'ES2002d.D.words405,ES2002d.D.words423'],
#  ['ES2002d.B.words681,ES2002d.B.words682'],
#  ['ES2002d.D.words424,ES2002d.D.words431'],
#  ['ES2002d.B.words683,ES2002d.B.words684'],
#  ['ES2002d.A.words589,ES2002d.A.words603'],
#  ['ES2002d.B.words685,ES2002d.B.words686'],
#  ['ES2002d.A.words604,ES2002d.A.words619'],
#  ['ES2002d.B.words687,ES2002d.B.words707'],
#  ['ES2002d.D.words432,ES2002d.D.words442'],
#  ['ES2002d.A.words620,ES2002d.A.words631'],
#  ['ES2002d.B.words708,ES2002d.B.words716'],
#  ['ES2002d.A.words632,ES2002d.A.words642'],
#  ['ES2002d.B.words717,ES2002d.B.words719'],
#  ['ES2002d.A.words643,ES2002d.A.words644',
#   'ES2002d.A.words645,ES2002d.A.words648'],
#  ['ES2002d.B.words720,ES2002d.B.words767',
#   'ES2002d.B.words768,ES2002d.B.words810',
#   'ES2002d.B.words811,ES2002d.B.words812',
#   'ES2002d.B.words813,ES2002d.B.words821',
#   'ES2002d.B.words822,ES2002d.B.words824',
#   'ES2002d.B.words825,ES2002d.B.words838',
#   'ES2002d.B.words839,ES2002d.B.words846',
#   'ES2002d.B.words847,ES2002d.B.words848',
#   'ES2002d.B.words849,ES2002d.B.words878',
#   'ES2002d.B.words879,ES2002d.B.words881',
#   'ES2002d.B.words882,ES2002d.B.words883',
#   'ES2002d.B.words884,ES2002d.B.words887',
#   'ES2002d.B.words888,ES2002d.B.words908',
#   'ES2002d.B.words909,ES2002d.B.words910',
#   'ES2002d.B.words911,ES2002d.B.words922',
#   'ES2002d.B.words923,ES2002d.B.words924',
#   'ES2002d.B.words925,ES2002d.B.words928',
#   'ES2002d.B.words929,ES2002d.B.words936',
#   'ES2002d.B.words937,ES2002d.B.words943',
#   'ES2002d.B.words944,ES2002d.B.words946',
#   'ES2002d.B.words947,ES2002d.B.words948',
#   'ES2002d.B.words949,ES2002d.B.words951',
#   'ES2002d.B.words952,ES2002d.B.words992',
#   'ES2002d.B.words993,ES2002d.B.words997',
#   'ES2002d.B.words998,ES2002d.B.words1003',
#   'ES2002d.B.words1004,ES2002d.B.words1006',
#   'ES2002d.B.words1007,ES2002d.B.words1018',
#   'ES2002d.B.words1019,ES2002d.B.words1082',
#   'ES2002d.B.words1083,ES2002d.B.words1084',
#   'ES2002d.B.words1085,ES2002d.B.words1107',
#   'ES2002d.B.words1108,ES2002d.B.words1113',
#   'ES2002d.B.words1114,ES2002d.B.words1132',
#   'ES2002d.B.words1133,ES2002d.B.words1160',
#   'ES2002d.B.words1161,ES2002d.B.words1169',
#   'ES2002d.B.words1170,ES2002d.B.words1171',
#   'ES2002d.B.words1172,ES2002d.B.words1174',
#   'ES2002d.B.words1175,ES2002d.B.words1206',
#   'ES2002d.B.words1207,ES2002d.B.words1209',
#   'ES2002d.B.words1210,ES2002d.B.words1212',
#   'ES2002d.B.words1213,ES2002d.B.words1232',
#   'ES2002d.B.words1233,ES2002d.B.words1268',
#   'ES2002d.B.words1269,ES2002d.B.words1278',
#   'ES2002d.B.words1279,ES2002d.B.words1308',
#   'ES2002d.B.words1309',
#   'ES2002d.B.words1310,ES2002d.B.words1311',
#   'ES2002d.B.words1312,ES2002d.B.words1313',
#   'ES2002d.B.words1314,ES2002d.B.words1315',
#   'ES2002d.B.words1316',
#   'ES2002d.B.words1317,ES2002d.B.words1321',
#   'ES2002d.B.words1322,ES2002d.B.words1324',
#   'ES2002d.B.words1325,ES2002d.B.words1326',
#   'ES2002d.B.words1327,ES2002d.B.words1356',
#   'ES2002d.B.words1357,ES2002d.B.words1358',
#   'ES2002d.B.words1359,ES2002d.B.words1360',
#   'ES2002d.B.words1361,ES2002d.B.words1362',
#   'ES2002d.B.words1363,ES2002d.B.words1371',
#   'ES2002d.B.words1372,ES2002d.B.words1373',
#   'ES2002d.B.words1374,ES2002d.B.words1386',
#   'ES2002d.B.words1387,ES2002d.B.words1388',
#   'ES2002d.B.words1389',
#   'ES2002d.B.words1390,ES2002d.B.words1397',
#   'ES2002d.B.words1398,ES2002d.B.words1399',
#   'ES2002d.B.words1400,ES2002d.B.words1409',
#   'ES2002d.B.words1410,ES2002d.B.words1415',
#   'ES2002d.B.words1416,ES2002d.B.words1420',
#   'ES2002d.B.words1421,ES2002d.B.words1437',
#   'ES2002d.B.words1438,ES2002d.B.words1439',
#   'ES2002d.B.words1440,ES2002d.B.words1441',
#   'ES2002d.B.words1442,ES2002d.B.words1462',
#   'ES2002d.B.words1463,ES2002d.B.words1470',
#   'ES2002d.B.words1471,ES2002d.B.words1476',
#   'ES2002d.B.words1477,ES2002d.B.words1493',
#   'ES2002d.B.words1494,ES2002d.B.words1501',
#   'ES2002d.B.words1502,ES2002d.B.words1505',
#   'ES2002d.B.words1506,ES2002d.B.words1508',
#   'ES2002d.B.words1509,ES2002d.B.words1515',
#   'ES2002d.B.words1516,ES2002d.B.words1528',
#   'ES2002d.B.words1529,ES2002d.B.words1532',
#   'ES2002d.B.words1533,ES2002d.B.words1534',
#   'ES2002d.B.words1535',
#   'ES2002d.B.words1536,ES2002d.B.words1542',
#   'ES2002d.B.words1543,ES2002d.B.words1552',
#   'ES2002d.B.words1553,ES2002d.B.words1554',
#   'ES2002d.B.words1555,ES2002d.B.words1556',
#   'ES2002d.B.words1557,ES2002d.B.words1558',
#   'ES2002d.B.words1559,ES2002d.B.words1560',
#   'ES2002d.B.words1561,ES2002d.B.words1568',
#   'ES2002d.B.words1569,ES2002d.B.words1585',
#   'ES2002d.B.words1586,ES2002d.B.words1611',
#   'ES2002d.B.words1612,ES2002d.B.words1632',
#   'ES2002d.B.words1633,ES2002d.B.words1637',
#   'ES2002d.B.words1638,ES2002d.B.words1676',
#   'ES2002d.B.words1677,ES2002d.B.words1683',
#   'ES2002d.B.words1684',
#   'ES2002d.B.words1685,ES2002d.B.words1710',
#   'ES2002d.B.words1711,ES2002d.B.words1720',
#   'ES2002d.B.words1721,ES2002d.B.words1743',
#   'ES2002d.B.words1744,ES2002d.B.words1745',
#   'ES2002d.B.words1746,ES2002d.B.words1768',
#   'ES2002d.B.words1769,ES2002d.B.words1791',
#   'ES2002d.B.words1792,ES2002d.B.words1794',
#   'ES2002d.B.words1795,ES2002d.B.words1796',
#   'ES2002d.B.words1797,ES2002d.B.words1827',
#   'ES2002d.B.words1828,ES2002d.B.words1829',
#   'ES2002d.B.words1830,ES2002d.B.words1831',
#   'ES2002d.B.words1832,ES2002d.B.words1833',
#   'ES2002d.B.words1834,ES2002d.B.words1835',
#   'ES2002d.B.words1836',
#   'ES2002d.B.words1837,ES2002d.B.words1873',
#   'ES2002d.B.words1874,ES2002d.B.words1875',
#   'ES2002d.B.words1876,ES2002d.B.words1877',
#   'ES2002d.B.words1878,ES2002d.B.words1879',
#   'ES2002d.B.words1880,ES2002d.B.words1881',
#   'ES2002d.B.words1882,ES2002d.B.words1899',
#   'ES2002d.B.words1900,ES2002d.B.words1905',
#   'ES2002d.B.words1906,ES2002d.B.words1907',
#   'ES2002d.B.words1908,ES2002d.B.words1909',
#   'ES2002d.B.words1910,ES2002d.B.words1917',
#   'ES2002d.B.words1918,ES2002d.B.words1939',
#   'ES2002d.B.words1940,ES2002d.B.words1955',
#   'ES2002d.B.words1956,ES2002d.B.words1957',
#   'ES2002d.B.words1958,ES2002d.B.words1959',
#   'ES2002d.B.words1960,ES2002d.B.words1963',
#   'ES2002d.B.words1964,ES2002d.B.words1973',
#   'ES2002d.B.words1974,ES2002d.B.words1975',
#   'ES2002d.B.words1976,ES2002d.B.words1977',
#   'ES2002d.B.words1978,ES2002d.B.words1979',
#   'ES2002d.B.words1980,ES2002d.B.words1986',
#   'ES2002d.B.words1987,ES2002d.B.words1988',
#   'ES2002d.B.words1989,ES2002d.B.words1990',
#   'ES2002d.B.words1991,ES2002d.B.words1992',
#   'ES2002d.B.words1993,ES2002d.B.words2060',
#   'ES2002d.B.words2061,ES2002d.B.words2065',
#   'ES2002d.B.words2066,ES2002d.B.words2067',
#   'ES2002d.B.words2068,ES2002d.B.words2069',
#   'ES2002d.B.words2070,ES2002d.B.words2071',
#   'ES2002d.B.words2072,ES2002d.B.words2073',
#   'ES2002d.B.words2074,ES2002d.B.words2075',
#   'ES2002d.B.words2076,ES2002d.B.words2127',
#   'ES2002d.B.words2128',
#   'ES2002d.B.words2129,ES2002d.B.words2130',
#   'ES2002d.B.words2131,ES2002d.B.words2132',
#   'ES2002d.B.words2133,ES2002d.B.words2134',
#   'ES2002d.B.words2135,ES2002d.B.words2136',
#   'ES2002d.B.words2137,ES2002d.B.words2142',
#   'ES2002d.B.words2143,ES2002d.B.words2144',
#   'ES2002d.B.words2145,ES2002d.B.words2146',
#   'ES2002d.B.words2147,ES2002d.B.words2163',
#   'ES2002d.B.words2164,ES2002d.B.words2165',
#   'ES2002d.B.words2166,ES2002d.B.words2167',
#   'ES2002d.B.words2168,ES2002d.B.words2169',
#   'ES2002d.B.words2170,ES2002d.B.words2172',
#   'ES2002d.B.words2173,ES2002d.B.words2174',
#   'ES2002d.B.words2175,ES2002d.B.words2176',
#   'ES2002d.B.words2177,ES2002d.B.words2178',
#   'ES2002d.B.words2179,ES2002d.B.words2193',
#   'ES2002d.B.words2194,ES2002d.B.words2195',
#   'ES2002d.B.words2196,ES2002d.B.words2202',
#   'ES2002d.B.words2203',
#   'ES2002d.B.words2204,ES2002d.B.words2205',
#   'ES2002d.B.words2206,ES2002d.B.words2281',
#   'ES2002d.B.words2282,ES2002d.B.words2285',
#   'ES2002d.B.words2286,ES2002d.B.words2287',
#   'ES2002d.B.words2288,ES2002d.B.words2292',
#   'ES2002d.B.words2293,ES2002d.B.words2294',
#   'ES2002d.B.words2295,ES2002d.B.words2306',
#   'ES2002d.B.words2307,ES2002d.B.words2308',
#   'ES2002d.B.words2309,ES2002d.B.words2372',
#   'ES2002d.B.words2373,ES2002d.B.words2418',
#   'ES2002d.B.words2419,ES2002d.B.words2427',
#   'ES2002d.B.words2428',
#   'ES2002d.B.words2429,ES2002d.B.words2430',
#   'ES2002d.B.words2431,ES2002d.B.words2513',
#   'ES2002d.B.words2514,ES2002d.B.words2585',
#   'ES2002d.B.words2586,ES2002d.B.words2645',
#   'ES2002d.B.words2646,ES2002d.B.words2661',
#   'ES2002d.B.words2662,ES2002d.B.words2664',
#   'ES2002d.B.words2665,ES2002d.B.words2669',
#   'ES2002d.B.words2670,ES2002d.B.words2700',
#   'ES2002d.B.words2701,ES2002d.B.words2706',
#   'ES2002d.B.words2707',
#   'ES2002d.B.words2708,ES2002d.B.words2739',
#   'ES2002d.B.words2740',
#   'ES2002d.B.words2741,ES2002d.B.words2755',
#   'ES2002d.B.words2756,ES2002d.B.words2757',
#   'ES2002d.B.words2758,ES2002d.B.words2759',
#   'ES2002d.B.words2760,ES2002d.B.words2761',
#   'ES2002d.B.words2762,ES2002d.B.words2764',
#   'ES2002d.B.words2765,ES2002d.B.words2766',
#   'ES2002d.B.words2767,ES2002d.B.words2768',
#   'ES2002d.B.words2769,ES2002d.B.words2778',
#   'ES2002d.B.words2779,ES2002d.B.words2794',
#   'ES2002d.B.words2795,ES2002d.B.words2807',
#   'ES2002d.B.words2808,ES2002d.B.words2809',
#   'ES2002d.B.words2810',
#   'ES2002d.B.words2811,ES2002d.B.words2812',
#   'ES2002d.B.words2813,ES2002d.B.words2814',
#   'ES2002d.B.words2815,ES2002d.B.words2816',
#   'ES2002d.B.words2817,ES2002d.B.words2818',
#   'ES2002d.B.words2819,ES2002d.B.words2821',
#   'ES2002d.B.words2822,ES2002d.B.words2835',
#   'ES2002d.B.words2836,ES2002d.B.words2841',
#   'ES2002d.B.words2842,ES2002d.B.words2851',
#   'ES2002d.B.words2852,ES2002d.B.words2853',
#   'ES2002d.B.words2854,ES2002d.B.words2872',
#   'ES2002d.B.words2873,ES2002d.B.words2885'],
#  ['ES2002d.B.words742,ES2002d.B.words767'],
#  ['ES2002d.D.words443'],
#  ['ES2002d.A.words649'],
#  ['ES2002d.C.words191,ES2002d.C.words205'],
#  ['ES2002d.B.words768,ES2002d.B.words810'],
#  ['ES2002d.C.words206,ES2002d.C.words211',
#   'ES2002d.C.words212,ES2002d.C.words220'],
#  ['ES2002d.D.words444,ES2002d.D.words461'],
#  ['ES2002d.B.words811,ES2002d.B.words812'],
#  ['ES2002d.C.words221,ES2002d.C.words226'],
#  ['ES2002d.A.words650,ES2002d.A.words687'],
#  ['ES2002d.B.words813,ES2002d.B.words821'],
#  ['ES2002d.D.words462,ES2002d.D.words465'],
#  ['ES2002d.A.words688,ES2002d.A.words747'],
#  ['ES2002d.C.words227,ES2002d.C.words228'],
#  ['ES2002d.D.words466,ES2002d.D.words471'],
#  ['ES2002d.C.words229,ES2002d.C.words230',
#   'ES2002d.C.words231,ES2002d.C.words232'],
#  ['ES2002d.B.words822,ES2002d.B.words824'],
#  ['ES2002d.C.words233,ES2002d.C.words234',
#   'ES2002d.C.words235,ES2002d.C.words236'],
#  ['ES2002d.B.words825,ES2002d.B.words838'],
#  ['ES2002d.A.words748',
#   'ES2002d.A.words749,ES2002d.A.words750',
#   'ES2002d.A.words751,ES2002d.A.words759'],
#  ['ES2002d.C.words237,ES2002d.C.words238'],
#  ['ES2002d.B.words839,ES2002d.B.words846'],
#  ['ES2002d.A.words760,ES2002d.A.words762',
#   'ES2002d.A.words763,ES2002d.A.words764'],
#  ['ES2002d.C.words239,ES2002d.C.words240'],
#  ['ES2002d.B.words847,ES2002d.B.words848'],
#  ['ES2002d.A.words765,ES2002d.A.words772'],
#  ['ES2002d.B.words849,ES2002d.B.words878'],
#  ['ES2002d.A.words773,ES2002d.A.words781'],
#  ['ES2002d.B.words879,ES2002d.B.words881'],
#  ['ES2002d.D.words472,ES2002d.D.words487'],
#  ['ES2002d.B.words882,ES2002d.B.words883'],
#  ['ES2002d.A.words782,ES2002d.A.words796'],
#  ['ES2002d.B.words884,ES2002d.B.words887'],
#  ['ES2002d.A.words797,ES2002d.A.words820'],
#  ['ES2002d.B.words888,ES2002d.B.words908'],
#  ['ES2002d.A.words821,ES2002d.A.words857'],
#  ['ES2002d.C.words241,ES2002d.C.words242'],
#  ['ES2002d.B.words909,ES2002d.B.words910'],
#  ['ES2002d.C.words243,ES2002d.C.words244'],
#  ['ES2002d.B.words911,ES2002d.B.words922'],
#  ['ES2002d.A.words858,ES2002d.A.words885'],
#  ['ES2002d.B.words923,ES2002d.B.words924'],
#  ['ES2002d.C.words245'],
#  ['ES2002d.B.words925,ES2002d.B.words928'],
#  ['ES2002d.C.words246,ES2002d.C.words253'],
#  ['ES2002d.D.words488,ES2002d.D.words489'],
#  ['ES2002d.A.words886,ES2002d.A.words889'],
#  ['ES2002d.B.words929,ES2002d.B.words936'],
#  ['ES2002d.A.words890,ES2002d.A.words909'],
#  ['ES2002d.D.words490,ES2002d.D.words491'],
#  ['ES2002d.B.words937,ES2002d.B.words943',
#   'ES2002d.B.words944,ES2002d.B.words946'],
#  ['ES2002d.A.words910,ES2002d.A.words916'],
#  ['ES2002d.B.words947,ES2002d.B.words948'],
#  ['ES2002d.D.words492'],
#  ['ES2002d.A.words917,ES2002d.A.words945'],
#  ['ES2002d.B.words949,ES2002d.B.words951'],
#  ['ES2002d.C.words254,ES2002d.C.words255',
#   'ES2002d.C.words256,ES2002d.C.words257',
#   'ES2002d.C.words258,ES2002d.C.words259'],
#  ['ES2002d.B.words952,ES2002d.B.words992'],
#  ['ES2002d.C.words260'],
#  ['ES2002d.D.words493,ES2002d.D.words497'],
#  ['ES2002d.C.words261,ES2002d.C.words276'],
#  ['ES2002d.B.words993,ES2002d.B.words997'],
#  ['ES2002d.C.words277,ES2002d.C.words278',
#   'ES2002d.C.words279,ES2002d.C.words282'],
#  ['ES2002d.D.words498,ES2002d.D.words509'],
#  ['ES2002d.A.words946,ES2002d.A.words947'],
#  ['ES2002d.B.words998,ES2002d.B.words1003',
#   'ES2002d.B.words1004,ES2002d.B.words1006',
#   'ES2002d.B.words1007,ES2002d.B.words1018'],
#  ['ES2002d.D.words510,ES2002d.D.words520'],
#  ['ES2002d.B.words1019,ES2002d.B.words1082'],
#  ['ES2002d.A.words948'],
#  ['ES2002d.B.words1083,ES2002d.B.words1084'],
#  ['ES2002d.C.words283,ES2002d.C.words300'],
#  ['ES2002d.A.words949,ES2002d.A.words955'],
#  ['ES2002d.D.words521,ES2002d.D.words522'],
#  ['ES2002d.C.words301,ES2002d.C.words307'],
#  ['ES2002d.A.words956,ES2002d.A.words957'],
#  ['ES2002d.D.words523,ES2002d.D.words552'],
#  ['ES2002d.C.words308,ES2002d.C.words309',
#   'ES2002d.C.words310,ES2002d.C.words321'],
#  ['ES2002d.A.words958,ES2002d.A.words969'],
#  ['ES2002d.D.words553'],
#  ['ES2002d.C.words322,ES2002d.C.words334'],
#  ['ES2002d.A.words970,ES2002d.A.words1001'],
#  ['ES2002d.C.words335,ES2002d.C.words336'],
#  ['ES2002d.B.words1085,ES2002d.B.words1107'],
#  ['ES2002d.A.words1002,ES2002d.A.words1003',
#   'ES2002d.A.words1004,ES2002d.A.words1005'],
#  ['ES2002d.B.words1108,ES2002d.B.words1113'],
#  ['ES2002d.C.words337,ES2002d.C.words338'],
#  ['ES2002d.B.words1114,ES2002d.B.words1132'],
#  ['ES2002d.D.words554,ES2002d.D.words559'],
#  ['ES2002d.A.words1006,ES2002d.A.words1007'],
#  ['ES2002d.C.words339,ES2002d.C.words351'],
#  ['ES2002d.A.words1008,ES2002d.A.words1015',
#   'ES2002d.A.words1016,ES2002d.A.words1022'],
#  ['ES2002d.C.words352,ES2002d.C.words354'],
#  ['ES2002d.D.words560,ES2002d.D.words565'],
#  ['ES2002d.B.words1133,ES2002d.B.words1160'],
#  ['ES2002d.C.words355,ES2002d.C.words365'],
#  ['ES2002d.A.words1023,ES2002d.A.words1024'],
#  ['ES2002d.B.words1161,ES2002d.B.words1169',
#   'ES2002d.B.words1170,ES2002d.B.words1171'],
#  ['ES2002d.C.words366,ES2002d.C.words367'],
#  ['ES2002d.B.words1172,ES2002d.B.words1174',
#   'ES2002d.B.words1175,ES2002d.B.words1206'],
#  ['ES2002d.C.words368,ES2002d.C.words369',
#   'ES2002d.C.words370,ES2002d.C.words448'],
#  ['ES2002d.A.words1025,ES2002d.A.words1084'],
#  ['ES2002d.C.words449,ES2002d.C.words450',
#   'ES2002d.C.words451,ES2002d.C.words454',
#   'ES2002d.C.words455,ES2002d.C.words458',
#   'ES2002d.C.words459,ES2002d.C.words462',
#   'ES2002d.C.words463,ES2002d.C.words470'],
#  ['ES2002d.A.words1085,ES2002d.A.words1116'],
#  ['ES2002d.C.words471,ES2002d.C.words472',
#   'ES2002d.C.words473,ES2002d.C.words474',
#   'ES2002d.C.words475,ES2002d.C.words476'],
#  ['ES2002d.D.words566,ES2002d.D.words568'],
#  ['ES2002d.C.words477,ES2002d.C.words478'],
#  ['ES2002d.B.words1207,ES2002d.B.words1209'],
#  ['ES2002d.A.words1117,ES2002d.A.words1118'],
#  ['ES2002d.B.words1210,ES2002d.B.words1212',
#   'ES2002d.B.words1213,ES2002d.B.words1232',
#   'ES2002d.B.words1233,ES2002d.B.words1268'],
#  ['ES2002d.C.words479,ES2002d.C.words481',
#   'ES2002d.C.words482,ES2002d.C.words489',
#   'ES2002d.C.words490,ES2002d.C.words502'],
#  ['ES2002d.B.words1269,ES2002d.B.words1278'],
#  ['ES2002d.A.words1119,ES2002d.A.words1127'],
#  ['ES2002d.C.words503,ES2002d.C.words504'],
#  ['ES2002d.B.words1279,ES2002d.B.words1308'],
#  ['ES2002d.C.words505,ES2002d.C.words506',
#   'ES2002d.C.words507,ES2002d.C.words508',
#   'ES2002d.C.words509,ES2002d.C.words510',
#   'ES2002d.C.words511,ES2002d.C.words553'],
#  ['ES2002d.B.words1309',
#   'ES2002d.B.words1310,ES2002d.B.words1311',
#   'ES2002d.B.words1312,ES2002d.B.words1313',
#   'ES2002d.B.words1314,ES2002d.B.words1315'],
#  ['ES2002d.A.words1128,ES2002d.A.words1138'],
#  ['ES2002d.C.words554', 'ES2002d.C.words555,ES2002d.C.words557'],
#  ['ES2002d.A.words1139,ES2002d.A.words1145'],
#  ['ES2002d.C.words558,ES2002d.C.words563'],
#  ['ES2002d.A.words1146,ES2002d.A.words1164'],
#  ['ES2002d.C.words564,ES2002d.C.words576',
#   'ES2002d.C.words577,ES2002d.C.words580'],
#  ['ES2002d.B.words1316'],
#  ['ES2002d.C.words581,ES2002d.C.words602'],
#  ['ES2002d.A.words1165,ES2002d.A.words1172'],
#  ['ES2002d.D.words569,ES2002d.D.words570',
#   'ES2002d.D.words571,ES2002d.D.words573'],
#  ['ES2002d.A.words1173,ES2002d.A.words1177'],
#  ['ES2002d.D.words574'],
#  ['ES2002d.C.words603,ES2002d.C.words682',
#   'ES2002d.C.words683,ES2002d.C.words691'],
#  ['ES2002d.B.words1317,ES2002d.B.words1321'],
#  ['ES2002d.C.words692,ES2002d.C.words733',
#   'ES2002d.C.words734,ES2002d.C.words738',
#   'ES2002d.C.words739,ES2002d.C.words824'],
#  ['ES2002d.B.words1322,ES2002d.B.words1324'],
#  ['ES2002d.C.words825,ES2002d.C.words844'],
#  ['ES2002d.B.words1325,ES2002d.B.words1326'],
#  ['ES2002d.A.words1178,ES2002d.A.words1183'],
#  ['ES2002d.B.words1327,ES2002d.B.words1356'],
#  ['ES2002d.D.words575,ES2002d.D.words576'],
#  ['ES2002d.C.words845,ES2002d.C.words846',
#   'ES2002d.C.words847,ES2002d.C.words848',
#   'ES2002d.C.words849,ES2002d.C.words882'],
#  ['ES2002d.B.words1357,ES2002d.B.words1358',
#   'ES2002d.B.words1359,ES2002d.B.words1360'],
#  ['ES2002d.C.words883,ES2002d.C.words885'],
#  ['ES2002d.B.words1361,ES2002d.B.words1362'],
#  ['ES2002d.D.words577,ES2002d.D.words581'],
#  ['ES2002d.C.words886,ES2002d.C.words891'],
#  ['ES2002d.B.words1363,ES2002d.B.words1371'],
#  ['ES2002d.C.words892,ES2002d.C.words893'],
#  ['ES2002d.A.words1184,ES2002d.A.words1189'],
#  ['ES2002d.C.words894,ES2002d.C.words900'],
#  ['ES2002d.B.words1372,ES2002d.B.words1373'],
#  ['ES2002d.C.words901,ES2002d.C.words908'],
#  ['ES2002d.A.words1190,ES2002d.A.words1196'],
#  ['ES2002d.C.words909,ES2002d.C.words917'],
#  ['ES2002d.B.words1374,ES2002d.B.words1386'],
#  ['ES2002d.A.words1197,ES2002d.A.words1208'],
#  ['ES2002d.D.words582,ES2002d.D.words586'],
#  ['ES2002d.B.words1387,ES2002d.B.words1388'],
#  ['ES2002d.C.words918,ES2002d.C.words923'],
#  ['ES2002d.D.words587,ES2002d.D.words596'],
#  ['ES2002d.C.words924,ES2002d.C.words925'],
#  ['ES2002d.A.words1209,ES2002d.A.words1213'],
#  ['ES2002d.C.words926,ES2002d.C.words943'],
#  ['ES2002d.D.words597'],
#  ['ES2002d.B.words1389'],
#  ['ES2002d.A.words1214'],
#  ['ES2002d.B.words1390,ES2002d.B.words1397'],
#  ['ES2002d.C.words944,ES2002d.C.words948',
#   'ES2002d.C.words949,ES2002d.C.words965'],
#  ['ES2002d.B.words1398,ES2002d.B.words1399'],
#  ['ES2002d.C.words966,ES2002d.C.words968'],
#  ['ES2002d.B.words1400,ES2002d.B.words1409'],
#  ['ES2002d.A.words1215,ES2002d.A.words1217'],
#  ['ES2002d.D.words598,ES2002d.D.words600'],
#  ['ES2002d.A.words1218,ES2002d.A.words1234'],
#  ['ES2002d.C.words969,ES2002d.C.words972'],
#  ['ES2002d.B.words1410,ES2002d.B.words1415'],
#  ['ES2002d.C.words973,ES2002d.C.words976'],
#  ['ES2002d.A.words1235'],
#  ['ES2002d.C.words977,ES2002d.C.words994'],
#  ['ES2002d.A.words1236,ES2002d.A.words1237'],
#  ['ES2002d.B.words1416,ES2002d.B.words1420'],
#  ['ES2002d.A.words1238,ES2002d.A.words1271'],
#  ['ES2002d.D.words601,ES2002d.D.words602'],
#  ['ES2002d.C.words995,ES2002d.C.words996',
#   'ES2002d.C.words997,ES2002d.C.words998',
#   'ES2002d.C.words999,ES2002d.C.words1000'],
#  ['ES2002d.B.words1421,ES2002d.B.words1437'],
#  ['ES2002d.C.words1001,ES2002d.C.words1009'],
#  ['ES2002d.A.words1272,ES2002d.A.words1295'],
#  ['ES2002d.C.words1010,ES2002d.C.words1011'],
#  ['ES2002d.B.words1438,ES2002d.B.words1439'],
#  ['ES2002d.C.words1012,ES2002d.C.words1017'],
#  ['ES2002d.D.words603'],
#  ['ES2002d.B.words1440,ES2002d.B.words1441'],
#  ['ES2002d.C.words1018,ES2002d.C.words1019',
#   'ES2002d.C.words1020,ES2002d.C.words1033'],
#  ['ES2002d.B.words1442,ES2002d.B.words1462'],
#  ['ES2002d.C.words1034,ES2002d.C.words1044'],
#  ['ES2002d.D.words604,ES2002d.D.words607'],
#  ['ES2002d.A.words1296,ES2002d.A.words1300'],
#  ['ES2002d.C.words1045,ES2002d.C.words1051',
#   'ES2002d.C.words1052,ES2002d.C.words1086'],
#  ['ES2002d.D.words608,ES2002d.D.words614'],
#  ['ES2002d.B.words1463,ES2002d.B.words1470'],
#  ['ES2002d.D.words615,ES2002d.D.words629'],
#  ['ES2002d.B.words1471,ES2002d.B.words1476'],
#  ['ES2002d.C.words1087,ES2002d.C.words1088', 'ES2002d.C.words1089'],
#  ['ES2002d.A.words1301,ES2002d.A.words1305'],
#  ['ES2002d.C.words1090,ES2002d.C.words1105'],
#  ['ES2002d.D.words630,ES2002d.D.words649'],
#  ['ES2002d.A.words1306,ES2002d.A.words1314'],
#  ['ES2002d.C.words1106,ES2002d.C.words1112',
#   'ES2002d.C.words1113,ES2002d.C.words1125'],
#  ['ES2002d.A.words1315,ES2002d.A.words1316'],
#  ['ES2002d.B.words1477,ES2002d.B.words1493'],
#  ['ES2002d.C.words1126,ES2002d.C.words1141'],
#  ['ES2002d.D.words650,ES2002d.D.words651'],
#  ['ES2002d.C.words1142,ES2002d.C.words1163'],
#  ['ES2002d.B.words1494,ES2002d.B.words1501'],
#  ['ES2002d.C.words1164,ES2002d.C.words1176',
#   'ES2002d.C.words1177,ES2002d.C.words1192'],
#  ['ES2002d.B.words1502,ES2002d.B.words1505'],
#  ['ES2002d.C.words1193,ES2002d.C.words1197',
#   'ES2002d.C.words1198,ES2002d.C.words1207',
#   'ES2002d.C.words1208,ES2002d.C.words1212',
#   'ES2002d.C.words1213,ES2002d.C.words1214'],
#  ['ES2002d.B.words1506,ES2002d.B.words1508'],
#  ['ES2002d.C.words1215,ES2002d.C.words1222',
#   'ES2002d.C.words1223,ES2002d.C.words1224',
#   'ES2002d.C.words1225,ES2002d.C.words1228'],
#  ['ES2002d.B.words1509,ES2002d.B.words1515'],
#  ['ES2002d.C.words1229,ES2002d.C.words1239'],
#  ['ES2002d.B.words1516,ES2002d.B.words1528'],
#  ['ES2002d.C.words1240,ES2002d.C.words1249'],
#  ['ES2002d.B.words1529,ES2002d.B.words1532'],
#  ['ES2002d.C.words1250,ES2002d.C.words1265'],
#  ['ES2002d.B.words1533,ES2002d.B.words1534'],
#  ['ES2002d.C.words1266,ES2002d.C.words1281'],
#  ['ES2002d.D.words652'],
#  ['ES2002d.B.words1535', 'ES2002d.B.words1536,ES2002d.B.words1542'],
#  ['ES2002d.A.words1317,ES2002d.A.words1322'],
#  ['ES2002d.C.words1282,ES2002d.C.words1283'],
#  ['ES2002d.B.words1543,ES2002d.B.words1552'],
#  ['ES2002d.C.words1284,ES2002d.C.words1378'],
#  ['ES2002d.B.words1553,ES2002d.B.words1554',
#   'ES2002d.B.words1555,ES2002d.B.words1556'],
#  ['ES2002d.C.words1379,ES2002d.C.words1462'],
#  ['ES2002d.A.words1323,ES2002d.A.words1324'],
#  ['ES2002d.B.words1557,ES2002d.B.words1558'],
#  ['ES2002d.C.words1463,ES2002d.C.words1471'],
#  ['ES2002d.B.words1559,ES2002d.B.words1560',
#   'ES2002d.B.words1561,ES2002d.B.words1568',
#   'ES2002d.B.words1569,ES2002d.B.words1585'],
#  ['ES2002d.C.words1472,ES2002d.C.words1491'],
#  ['ES2002d.B.words1586,ES2002d.B.words1611'],
#  ['ES2002d.D.words653'],
#  ['ES2002d.C.words1492,ES2002d.C.words1496'],
#  ['ES2002d.A.words1325,ES2002d.A.words1330'],
#  ['ES2002d.B.words1612,ES2002d.B.words1632',
#   'ES2002d.B.words1633,ES2002d.B.words1637',
#   'ES2002d.B.words1638,ES2002d.B.words1676',
#   'ES2002d.B.words1677,ES2002d.B.words1683',
#   'ES2002d.B.words1684',
#   'ES2002d.B.words1685,ES2002d.B.words1710',
#   'ES2002d.B.words1711,ES2002d.B.words1720',
#   'ES2002d.B.words1721,ES2002d.B.words1743',
#   'ES2002d.B.words1744,ES2002d.B.words1745',
#   'ES2002d.B.words1746,ES2002d.B.words1768',
#   'ES2002d.B.words1769,ES2002d.B.words1791',
#   'ES2002d.B.words1792,ES2002d.B.words1794',
#   'ES2002d.B.words1795,ES2002d.B.words1796',
#   'ES2002d.B.words1797,ES2002d.B.words1827',
#   'ES2002d.B.words1828,ES2002d.B.words1829',
#   'ES2002d.B.words1830,ES2002d.B.words1831',
#   'ES2002d.B.words1832,ES2002d.B.words1833',
#   'ES2002d.B.words1834,ES2002d.B.words1835',
#   'ES2002d.B.words1836',
#   'ES2002d.B.words1837,ES2002d.B.words1873',
#   'ES2002d.B.words1874,ES2002d.B.words1875',
#   'ES2002d.B.words1876,ES2002d.B.words1877',
#   'ES2002d.B.words1878,ES2002d.B.words1879',
#   'ES2002d.B.words1880,ES2002d.B.words1881',
#   'ES2002d.B.words1882,ES2002d.B.words1899',
#   'ES2002d.B.words1900,ES2002d.B.words1905',
#   'ES2002d.B.words1906,ES2002d.B.words1907',
#   'ES2002d.B.words1908,ES2002d.B.words1909',
#   'ES2002d.B.words1910,ES2002d.B.words1917',
#   'ES2002d.B.words1918,ES2002d.B.words1939',
#   'ES2002d.B.words1940,ES2002d.B.words1955',
#   'ES2002d.B.words1956,ES2002d.B.words1957',
#   'ES2002d.B.words1958,ES2002d.B.words1959',
#   'ES2002d.B.words1960,ES2002d.B.words1963',
#   'ES2002d.B.words1964,ES2002d.B.words1973',
#   'ES2002d.B.words1974,ES2002d.B.words1975',
#   'ES2002d.B.words1976,ES2002d.B.words1977',
#   'ES2002d.B.words1978,ES2002d.B.words1979',
#   'ES2002d.B.words1980,ES2002d.B.words1986',
#   'ES2002d.B.words1987,ES2002d.B.words1988',
#   'ES2002d.B.words1989,ES2002d.B.words1990',
#   'ES2002d.B.words1991,ES2002d.B.words1992',
#   'ES2002d.B.words1993,ES2002d.B.words2060',
#   'ES2002d.B.words2061,ES2002d.B.words2065',
#   'ES2002d.B.words2066,ES2002d.B.words2067',
#   'ES2002d.B.words2068,ES2002d.B.words2069',
#   'ES2002d.B.words2070,ES2002d.B.words2071',
#   'ES2002d.B.words2072,ES2002d.B.words2073',
#   'ES2002d.B.words2074,ES2002d.B.words2075',
#   'ES2002d.B.words2076,ES2002d.B.words2127',
#   'ES2002d.B.words2128',
#   'ES2002d.B.words2129,ES2002d.B.words2130',
#   'ES2002d.B.words2131,ES2002d.B.words2132',
#   'ES2002d.B.words2133,ES2002d.B.words2134',
#   'ES2002d.B.words2135,ES2002d.B.words2136',
#   'ES2002d.B.words2137,ES2002d.B.words2142',
#   'ES2002d.B.words2143,ES2002d.B.words2144',
#   'ES2002d.B.words2145,ES2002d.B.words2146',
#   'ES2002d.B.words2147,ES2002d.B.words2163',
#   'ES2002d.B.words2164,ES2002d.B.words2165',
#   'ES2002d.B.words2166,ES2002d.B.words2167',
#   'ES2002d.B.words2168,ES2002d.B.words2169',
#   'ES2002d.B.words2170,ES2002d.B.words2172',
#   'ES2002d.B.words2173,ES2002d.B.words2174',
#   'ES2002d.B.words2175,ES2002d.B.words2176',
#   'ES2002d.B.words2177,ES2002d.B.words2178',
#   'ES2002d.B.words2179,ES2002d.B.words2193',
#   'ES2002d.B.words2194,ES2002d.B.words2195',
#   'ES2002d.B.words2196,ES2002d.B.words2202',
#   'ES2002d.B.words2203',
#   'ES2002d.B.words2204,ES2002d.B.words2205',
#   'ES2002d.B.words2206,ES2002d.B.words2281',
#   'ES2002d.B.words2282,ES2002d.B.words2285',
#   'ES2002d.B.words2286,ES2002d.B.words2287',
#   'ES2002d.B.words2288,ES2002d.B.words2292',
#   'ES2002d.B.words2293,ES2002d.B.words2294',
#   'ES2002d.B.words2295,ES2002d.B.words2306',
#   'ES2002d.B.words2307,ES2002d.B.words2308',
#   'ES2002d.B.words2309,ES2002d.B.words2372',
#   'ES2002d.B.words2373,ES2002d.B.words2418',
#   'ES2002d.B.words2419,ES2002d.B.words2427',
#   'ES2002d.B.words2428',
#   'ES2002d.B.words2429,ES2002d.B.words2430',
#   'ES2002d.B.words2431,ES2002d.B.words2513',
#   'ES2002d.B.words2514,ES2002d.B.words2585',
#   'ES2002d.B.words2586,ES2002d.B.words2645',
#   'ES2002d.B.words2646,ES2002d.B.words2661',
#   'ES2002d.B.words2662,ES2002d.B.words2664',
#   'ES2002d.B.words2665,ES2002d.B.words2669',
#   'ES2002d.B.words2670,ES2002d.B.words2700',
#   'ES2002d.B.words2701,ES2002d.B.words2706',
#   'ES2002d.B.words2707',
#   'ES2002d.B.words2708,ES2002d.B.words2739',
#   'ES2002d.B.words2740',
#   'ES2002d.B.words2741,ES2002d.B.words2755',
#   'ES2002d.B.words2756,ES2002d.B.words2757',
#   'ES2002d.B.words2758,ES2002d.B.words2759',
#   'ES2002d.B.words2760,ES2002d.B.words2761',
#   'ES2002d.B.words2762,ES2002d.B.words2764',
#   'ES2002d.B.words2765,ES2002d.B.words2766',
#   'ES2002d.B.words2767,ES2002d.B.words2768',
#   'ES2002d.B.words2769,ES2002d.B.words2778',
#   'ES2002d.B.words2779,ES2002d.B.words2794',
#   'ES2002d.B.words2795,ES2002d.B.words2807',
#   'ES2002d.B.words2808,ES2002d.B.words2809',
#   'ES2002d.B.words2810',
#   'ES2002d.B.words2811,ES2002d.B.words2812',
#   'ES2002d.B.words2813,ES2002d.B.words2814',
#   'ES2002d.B.words2815,ES2002d.B.words2816',
#   'ES2002d.B.words2817,ES2002d.B.words2818',
#   'ES2002d.B.words2819,ES2002d.B.words2821',
#   'ES2002d.B.words2822,ES2002d.B.words2835',
#   'ES2002d.B.words2836,ES2002d.B.words2841',
#   'ES2002d.B.words2842,ES2002d.B.words2851',
#   'ES2002d.B.words2852,ES2002d.B.words2853',
#   'ES2002d.B.words2854,ES2002d.B.words2872',
#   'ES2002d.B.words2873,ES2002d.B.words2885',
#   '**********'],
#  ['ES2002d.B.words1614,ES2002d.B.words1632'],
#  ['ES2002d.A.words1331,ES2002d.A.words1355'],
#  ['ES2002d.D.words654'],
#  ['ES2002d.B.words1633,ES2002d.B.words1637'],
#  ['ES2002d.D.words655'],
#  ['ES2002d.A.words1356,ES2002d.A.words1372'],
#  ['ES2002d.C.words1497,ES2002d.C.words1498'],
#  ['ES2002d.A.words1373,ES2002d.A.words1380'],
#  ['ES2002d.D.words656', 'ES2002d.D.words657,ES2002d.D.words660'],
#  ['ES2002d.B.words1638,ES2002d.B.words1676',
#   'ES2002d.B.words1677,ES2002d.B.words1683'],
#  ['ES2002d.C.words1499'],
#  ['ES2002d.A.words1381'],
#  ['ES2002d.B.words1684'],
#  ['ES2002d.C.words1500,ES2002d.C.words1501',
#   'ES2002d.C.words1502,ES2002d.C.words1521'],
#  ['ES2002d.B.words1685,ES2002d.B.words1710',
#   'ES2002d.B.words1711,ES2002d.B.words1720',
#   'ES2002d.B.words1721,ES2002d.B.words1743',
#   'ES2002d.B.words1744,ES2002d.B.words1745',
#   'ES2002d.B.words1746,ES2002d.B.words1768',
#   'ES2002d.B.words1769,ES2002d.B.words1791',
#   'ES2002d.B.words1792,ES2002d.B.words1794',
#   'ES2002d.B.words1795,ES2002d.B.words1796',
#   'ES2002d.B.words1797,ES2002d.B.words1827',
#   'ES2002d.B.words1828,ES2002d.B.words1829',
#   'ES2002d.B.words1830,ES2002d.B.words1831',
#   'ES2002d.B.words1832,ES2002d.B.words1833',
#   'ES2002d.B.words1834,ES2002d.B.words1835',
#   'ES2002d.B.words1836',
#   'ES2002d.B.words1837,ES2002d.B.words1873',
#   'ES2002d.B.words1874,ES2002d.B.words1875',
#   'ES2002d.B.words1876,ES2002d.B.words1877',
#   'ES2002d.B.words1878,ES2002d.B.words1879',
#   'ES2002d.B.words1880,ES2002d.B.words1881',
#   'ES2002d.B.words1882,ES2002d.B.words1899',
#   'ES2002d.B.words1900,ES2002d.B.words1905',
#   'ES2002d.B.words1906,ES2002d.B.words1907',
#   'ES2002d.B.words1908,ES2002d.B.words1909',
#   'ES2002d.B.words1910,ES2002d.B.words1917',
#   'ES2002d.B.words1918,ES2002d.B.words1939',
#   'ES2002d.B.words1940,ES2002d.B.words1955',
#   'ES2002d.B.words1956,ES2002d.B.words1957',
#   'ES2002d.B.words1958,ES2002d.B.words1959',
#   'ES2002d.B.words1960,ES2002d.B.words1963',
#   'ES2002d.B.words1964,ES2002d.B.words1973',
#   'ES2002d.B.words1974,ES2002d.B.words1975',
#   'ES2002d.B.words1976,ES2002d.B.words1977',
#   'ES2002d.B.words1978,ES2002d.B.words1979',
#   'ES2002d.B.words1980,ES2002d.B.words1986',
#   'ES2002d.B.words1987,ES2002d.B.words1988',
#   'ES2002d.B.words1989,ES2002d.B.words1990',
#   'ES2002d.B.words1991,ES2002d.B.words1992',
#   'ES2002d.B.words1993,ES2002d.B.words2060',
#   'ES2002d.B.words2061,ES2002d.B.words2065',
#   'ES2002d.B.words2066,ES2002d.B.words2067',
#   'ES2002d.B.words2068,ES2002d.B.words2069',
#   'ES2002d.B.words2070,ES2002d.B.words2071',
#   'ES2002d.B.words2072,ES2002d.B.words2073',
#   'ES2002d.B.words2074,ES2002d.B.words2075',
#   'ES2002d.B.words2076,ES2002d.B.words2127',
#   'ES2002d.B.words2128',
#   'ES2002d.B.words2129,ES2002d.B.words2130',
#   'ES2002d.B.words2131,ES2002d.B.words2132',
#   'ES2002d.B.words2133,ES2002d.B.words2134',
#   'ES2002d.B.words2135,ES2002d.B.words2136',
#   'ES2002d.B.words2137,ES2002d.B.words2142',
#   'ES2002d.B.words2143,ES2002d.B.words2144',
#   'ES2002d.B.words2145,ES2002d.B.words2146',
#   'ES2002d.B.words2147,ES2002d.B.words2163',
#   'ES2002d.B.words2164,ES2002d.B.words2165',
#   'ES2002d.B.words2166,ES2002d.B.words2167',
# ...
#  ['ES2002d.A.words1619'],
#  ['ES2002d.C.words1952,ES2002d.C.words1973'],
#  ['ES2002d.B.words1940,ES2002d.B.words1955'],
#  ['ES2002d.C.words1974,ES2002d.C.words1991'],
#  ['ES2002d.B.words1956,ES2002d.B.words1957'],
#  ['ES2002d.C.words1992,ES2002d.C.words2042'],
#  ['ES2002d.A.words1620,ES2002d.A.words1623'],
#  ['ES2002d.B.words1958,ES2002d.B.words1959'],
#  ['ES2002d.C.words2043,ES2002d.C.words2125'],
#  ['ES2002d.A.words1624'],
#  ['ES2002d.B.words1960,ES2002d.B.words1963'],
#  ['ES2002d.C.words2126,ES2002d.C.words2169'],
#  ['ES2002d.B.words1964,ES2002d.B.words1973'],
#  ['ES2002d.A.words1625'],
#  ['ES2002d.C.words2170,ES2002d.C.words2179'],
#  ['ES2002d.A.words1626,ES2002d.A.words1749'],
#  ['ES2002d.C.words2180,ES2002d.C.words2185',
#   'ES2002d.C.words2186,ES2002d.C.words2187',
#   'ES2002d.C.words2188,ES2002d.C.words2191',
#   'ES2002d.C.words2192,ES2002d.C.words2195'],
#  ['ES2002d.B.words1974,ES2002d.B.words1975'],
#  ['ES2002d.C.words2196,ES2002d.C.words2197',
#   'ES2002d.C.words2198,ES2002d.C.words2199',
#   'ES2002d.C.words2200,ES2002d.C.words2203'],
#  ['ES2002d.B.words1976,ES2002d.B.words1977'],
#  ['ES2002d.C.words2204,ES2002d.C.words2207',
#   'ES2002d.C.words2208,ES2002d.C.words2209'],
#  ['ES2002d.B.words1978,ES2002d.B.words1979'],
#  ['ES2002d.C.words2210,ES2002d.C.words2217'],
#  ['ES2002d.B.words1980,ES2002d.B.words1986'],
#  ['ES2002d.C.words2218,ES2002d.C.words2225'],
#  ['ES2002d.D.words703,ES2002d.D.words720'],
#  ['ES2002d.C.words2226,ES2002d.C.words2227'],
#  ['ES2002d.B.words1987,ES2002d.B.words1988'],
#  ['ES2002d.D.words721,ES2002d.D.words746'],
#  ['ES2002d.C.words2228,ES2002d.C.words2229'],
#  ['ES2002d.B.words1989,ES2002d.B.words1990'],
#  ['ES2002d.C.words2230,ES2002d.C.words2232'],
#  ['ES2002d.A.words1750,ES2002d.A.words1794'],
#  ['ES2002d.C.words2233,ES2002d.C.words2235'],
#  ['ES2002d.B.words1991,ES2002d.B.words1992'],
#  ['ES2002d.C.words2236'],
#  ['ES2002d.B.words1993,ES2002d.B.words2060'],
#  ['ES2002d.C.words2237,ES2002d.C.words2238'],
#  ['ES2002d.D.words747,ES2002d.D.words750'],
#  ['ES2002d.A.words1795,ES2002d.A.words1796'],
#  ['ES2002d.C.words2239,ES2002d.C.words2244'],
#  ['ES2002d.A.words1797,ES2002d.A.words1798'],
#  ['ES2002d.C.words2245,ES2002d.C.words2246',
#   'ES2002d.C.words2247,ES2002d.C.words2251'],
#  ['ES2002d.A.words1799,ES2002d.A.words1846'],
#  ['ES2002d.C.words2252,ES2002d.C.words2259'],
#  ['ES2002d.B.words2061,ES2002d.B.words2065'],
#  ['ES2002d.C.words2260,ES2002d.C.words2266',
#   'ES2002d.C.words2267,ES2002d.C.words2350'],
#  ['ES2002d.B.words2066,ES2002d.B.words2067'],
#  ['ES2002d.C.words2351,ES2002d.C.words2459'],
#  ['ES2002d.A.words1847,ES2002d.A.words1852'],
#  ['ES2002d.B.words2068,ES2002d.B.words2069',
#   'ES2002d.B.words2070,ES2002d.B.words2071',
#   'ES2002d.B.words2072,ES2002d.B.words2073',
#   'ES2002d.B.words2074,ES2002d.B.words2075'],
#  ['ES2002d.A.words1853,ES2002d.A.words1857'],
#  ['ES2002d.B.words2076,ES2002d.B.words2127',
#   'ES2002d.B.words2128',
#   'ES2002d.B.words2129,ES2002d.B.words2130',
#   'ES2002d.B.words2131,ES2002d.B.words2132',
#   'ES2002d.B.words2133,ES2002d.B.words2134',
#   'ES2002d.B.words2135,ES2002d.B.words2136',
#   'ES2002d.B.words2137,ES2002d.B.words2142',
#   'ES2002d.B.words2143,ES2002d.B.words2144',
#   'ES2002d.B.words2145,ES2002d.B.words2146',
#   'ES2002d.B.words2147,ES2002d.B.words2163',
#   'ES2002d.B.words2164,ES2002d.B.words2165',
#   'ES2002d.B.words2166,ES2002d.B.words2167',
#   'ES2002d.B.words2168,ES2002d.B.words2169',
#   'ES2002d.B.words2170,ES2002d.B.words2172',
#   'ES2002d.B.words2173,ES2002d.B.words2174',
#   'ES2002d.B.words2175,ES2002d.B.words2176',
#   'ES2002d.B.words2177,ES2002d.B.words2178',
#   'ES2002d.B.words2179,ES2002d.B.words2193',
#   'ES2002d.B.words2194,ES2002d.B.words2195',
#   'ES2002d.B.words2196,ES2002d.B.words2202',
#   'ES2002d.B.words2203',
#   'ES2002d.B.words2204,ES2002d.B.words2205',
#   'ES2002d.B.words2206,ES2002d.B.words2281',
#   'ES2002d.B.words2282,ES2002d.B.words2285',
#   'ES2002d.B.words2286,ES2002d.B.words2287',
#   'ES2002d.B.words2288,ES2002d.B.words2292',
#   'ES2002d.B.words2293,ES2002d.B.words2294',
#   'ES2002d.B.words2295,ES2002d.B.words2306',
#   'ES2002d.B.words2307,ES2002d.B.words2308',
#   'ES2002d.B.words2309,ES2002d.B.words2372',
#   'ES2002d.B.words2373,ES2002d.B.words2418',
#   'ES2002d.B.words2419,ES2002d.B.words2427',
#   'ES2002d.B.words2428',
#   'ES2002d.B.words2429,ES2002d.B.words2430',
#   'ES2002d.B.words2431,ES2002d.B.words2513',
#   'ES2002d.B.words2514,ES2002d.B.words2585',
#   'ES2002d.B.words2586,ES2002d.B.words2645',
#   'ES2002d.B.words2646,ES2002d.B.words2661',
#   'ES2002d.B.words2662,ES2002d.B.words2664',
#   'ES2002d.B.words2665,ES2002d.B.words2669',
#   'ES2002d.B.words2670,ES2002d.B.words2700',
#   'ES2002d.B.words2701,ES2002d.B.words2706',
#   'ES2002d.B.words2707',
#   'ES2002d.B.words2708,ES2002d.B.words2739',
#   'ES2002d.B.words2740',
#   'ES2002d.B.words2741,ES2002d.B.words2755',
#   'ES2002d.B.words2756,ES2002d.B.words2757',
#   'ES2002d.B.words2758,ES2002d.B.words2759',
#   'ES2002d.B.words2760,ES2002d.B.words2761',
#   'ES2002d.B.words2762,ES2002d.B.words2764',
#   'ES2002d.B.words2765,ES2002d.B.words2766',
#   'ES2002d.B.words2767,ES2002d.B.words2768',
#   'ES2002d.B.words2769,ES2002d.B.words2778',
#   'ES2002d.B.words2779,ES2002d.B.words2794',
#   'ES2002d.B.words2795,ES2002d.B.words2807',
#   'ES2002d.B.words2808,ES2002d.B.words2809',
#   'ES2002d.B.words2810',
#   'ES2002d.B.words2811,ES2002d.B.words2812',
#   'ES2002d.B.words2813,ES2002d.B.words2814',
#   'ES2002d.B.words2815,ES2002d.B.words2816',
#   'ES2002d.B.words2817,ES2002d.B.words2818',
#   'ES2002d.B.words2819,ES2002d.B.words2821',
#   'ES2002d.B.words2822,ES2002d.B.words2835',
#   'ES2002d.B.words2836,ES2002d.B.words2841',
#   'ES2002d.B.words2842,ES2002d.B.words2851',
#   'ES2002d.B.words2852,ES2002d.B.words2853',
#   'ES2002d.B.words2854,ES2002d.B.words2872',
#   'ES2002d.B.words2873,ES2002d.B.words2885'],
#  ['ES2002d.B.words2088,ES2002d.B.words2127'],
#  ['ES2002d.C.words2460,ES2002d.C.words2461'],
#  ['ES2002d.B.words2128', 'ES2002d.B.words2129,ES2002d.B.words2130'],
#  ['ES2002d.C.words2462,ES2002d.C.words2548'],
#  ['ES2002d.B.words2131,ES2002d.B.words2132'],
#  ['ES2002d.C.words2549,ES2002d.C.words2644'],
#  ['ES2002d.B.words2133,ES2002d.B.words2134',
#   'ES2002d.B.words2135,ES2002d.B.words2136',
#   'ES2002d.B.words2137,ES2002d.B.words2142'],
#  ['ES2002d.C.words2645,ES2002d.C.words2702'],
#  ['ES2002d.B.words2143,ES2002d.B.words2144',
#   'ES2002d.B.words2145,ES2002d.B.words2146'],
#  ['ES2002d.C.words2703,ES2002d.C.words2717'],
#  ['ES2002d.B.words2147,ES2002d.B.words2163'],
#  ['ES2002d.C.words2718,ES2002d.C.words2723'],
#  ['ES2002d.A.words1858,ES2002d.A.words1930'],
#  ['ES2002d.B.words2164,ES2002d.B.words2165'],
#  ['ES2002d.C.words2724,ES2002d.C.words2727',
#   'ES2002d.C.words2728,ES2002d.C.words2729',
#   'ES2002d.C.words2730,ES2002d.C.words2733',
#   'ES2002d.C.words2734,ES2002d.C.words2735',
#   'ES2002d.C.words2736,ES2002d.C.words2737',
#   'ES2002d.C.words2738,ES2002d.C.words2739',
#   'ES2002d.C.words2740,ES2002d.C.words2743'],
#  ['ES2002d.B.words2166,ES2002d.B.words2167'],
#  ['ES2002d.C.words2744,ES2002d.C.words2809'],
#  ['ES2002d.B.words2168,ES2002d.B.words2169',
#   'ES2002d.B.words2170,ES2002d.B.words2172'],
#  ['ES2002d.A.words1931,ES2002d.A.words2015'],
#  ['ES2002d.C.words2810,ES2002d.C.words2811'],
#  ['ES2002d.D.words751,ES2002d.D.words752'],
#  ['ES2002d.B.words2173,ES2002d.B.words2174'],
#  ['ES2002d.C.words2812,ES2002d.C.words2813'],
#  ['ES2002d.B.words2175,ES2002d.B.words2176'],
#  ['ES2002d.C.words2814,ES2002d.C.words2818',
#   'ES2002d.C.words2819,ES2002d.C.words2820',
#   'ES2002d.C.words2821,ES2002d.C.words2822'],
#  ['ES2002d.B.words2177,ES2002d.B.words2178'],
#  ['ES2002d.C.words2823,ES2002d.C.words2824'],
#  ['ES2002d.B.words2179,ES2002d.B.words2193'],
#  ['ES2002d.A.words2016,ES2002d.A.words2022'],
#  ['ES2002d.C.words2825,ES2002d.C.words2829'],
#  ['ES2002d.D.words753,ES2002d.D.words758'],
#  ['ES2002d.B.words2194,ES2002d.B.words2195'],
#  ['ES2002d.C.words2830,ES2002d.C.words2832',
#   'ES2002d.C.words2833,ES2002d.C.words2834'],
#  ['ES2002d.B.words2196,ES2002d.B.words2202'],
#  ['ES2002d.C.words2835,ES2002d.C.words2836'],
#  ['ES2002d.A.words2023,ES2002d.A.words2059'],
#  ['ES2002d.B.words2203'],
#  ['ES2002d.C.words2837,ES2002d.C.words2838'],
#  ['ES2002d.B.words2204,ES2002d.B.words2205',
#   'ES2002d.B.words2206,ES2002d.B.words2281'],
#  ['ES2002d.C.words2839,ES2002d.C.words2841',
#   'ES2002d.C.words2842,ES2002d.C.words2843',
#   'ES2002d.C.words2844,ES2002d.C.words2845',
#   'ES2002d.C.words2846,ES2002d.C.words2851'],
#  ['ES2002d.A.words2060,ES2002d.A.words2098'],
#  ['ES2002d.C.words2852,ES2002d.C.words2857'],
#  ['ES2002d.B.words2282,ES2002d.B.words2285'],
#  ['ES2002d.C.words2858'],
#  ['ES2002d.D.words759'],
#  ['ES2002d.C.words2859,ES2002d.C.words2890'],
#  ['ES2002d.B.words2286,ES2002d.B.words2287'],
#  ['ES2002d.C.words2891,ES2002d.C.words2899'],
#  ['ES2002d.A.words2099,ES2002d.A.words2106'],
#  ['ES2002d.C.words2900,ES2002d.C.words2906'],
#  ['ES2002d.B.words2288,ES2002d.B.words2292'],
#  ['ES2002d.C.words2907,ES2002d.C.words2926'],
#  ['ES2002d.D.words760,ES2002d.D.words762'],
#  ['ES2002d.A.words2107,ES2002d.A.words2142'],
#  ['ES2002d.C.words2927,ES2002d.C.words2928',
#   'ES2002d.C.words2929,ES2002d.C.words2930',
#   'ES2002d.C.words2931,ES2002d.C.words2932'],
#  ['ES2002d.B.words2293,ES2002d.B.words2294'],
#  ['ES2002d.C.words2933'],
#  ['ES2002d.B.words2295,ES2002d.B.words2306'],
#  ['ES2002d.A.words2143,ES2002d.A.words2153'],
#  ['ES2002d.D.words763,ES2002d.D.words764'],
#  ['ES2002d.B.words2307,ES2002d.B.words2308',
#   'ES2002d.B.words2309,ES2002d.B.words2372'],
#  ['ES2002d.C.words2934,ES2002d.C.words2937',
#   'ES2002d.C.words2938,ES2002d.C.words2939'],
#  ['ES2002d.A.words2154,ES2002d.A.words2155'],
#  ['ES2002d.C.words2940,ES2002d.C.words2941',
#   'ES2002d.C.words2942,ES2002d.C.words2943'],
#  ['ES2002d.B.words2373,ES2002d.B.words2418'],
#  ['ES2002d.D.words765,ES2002d.D.words771'],
#  ['ES2002d.C.words2944,ES2002d.C.words2956',
#   'ES2002d.C.words2957,ES2002d.C.words2977'],
#  ['ES2002d.B.words2419,ES2002d.B.words2427'],
#  ['ES2002d.C.words2978,ES2002d.C.words3028'],
#  ['ES2002d.B.words2428',
#   'ES2002d.B.words2429,ES2002d.B.words2430',
#   'ES2002d.B.words2431,ES2002d.B.words2513'],
#  ['ES2002d.C.words3029,ES2002d.C.words3031',
#   'ES2002d.C.words3032,ES2002d.C.words3035',
#   'ES2002d.C.words3036,ES2002d.C.words3041'],
#  ['ES2002d.B.words2514,ES2002d.B.words2585'],
#  ['ES2002d.C.words3042,ES2002d.C.words3043',
#   'ES2002d.C.words3044,ES2002d.C.words3045',
#   'ES2002d.C.words3046,ES2002d.C.words3047',
#   'ES2002d.C.words3048,ES2002d.C.words3049'],
#  ['ES2002d.B.words2586,ES2002d.B.words2645',
#   'ES2002d.B.words2646,ES2002d.B.words2661',
#   'ES2002d.B.words2662,ES2002d.B.words2664',
#   'ES2002d.B.words2665,ES2002d.B.words2669',
#   'ES2002d.B.words2670,ES2002d.B.words2700',
#   'ES2002d.B.words2701,ES2002d.B.words2706',
#   'ES2002d.B.words2707',
#   'ES2002d.B.words2708,ES2002d.B.words2739',
#   'ES2002d.B.words2740',
#   'ES2002d.B.words2741,ES2002d.B.words2755',
#   'ES2002d.B.words2756,ES2002d.B.words2757',
#   'ES2002d.B.words2758,ES2002d.B.words2759',
#   'ES2002d.B.words2760,ES2002d.B.words2761',
#   'ES2002d.B.words2762,ES2002d.B.words2764',
#   'ES2002d.B.words2765,ES2002d.B.words2766',
#   'ES2002d.B.words2767,ES2002d.B.words2768',
#   'ES2002d.B.words2769,ES2002d.B.words2778',
#   'ES2002d.B.words2779,ES2002d.B.words2794',
#   'ES2002d.B.words2795,ES2002d.B.words2807',
#   'ES2002d.B.words2808,ES2002d.B.words2809',
#   'ES2002d.B.words2810',
#   'ES2002d.B.words2811,ES2002d.B.words2812',
#   'ES2002d.B.words2813,ES2002d.B.words2814',
#   'ES2002d.B.words2815,ES2002d.B.words2816',
#   'ES2002d.B.words2817,ES2002d.B.words2818',
#   'ES2002d.B.words2819,ES2002d.B.words2821',
#   'ES2002d.B.words2822,ES2002d.B.words2835',
#   'ES2002d.B.words2836,ES2002d.B.words2841',
#   'ES2002d.B.words2842,ES2002d.B.words2851',
#   'ES2002d.B.words2852,ES2002d.B.words2853',
#   'ES2002d.B.words2854,ES2002d.B.words2872',
#   'ES2002d.B.words2873,ES2002d.B.words2885',
#   '**********'],
#  ['ES2002d.B.words2590,ES2002d.B.words2645'],
#  ['ES2002d.D.words772', 'ES2002d.D.words773'],
#  ['ES2002d.C.words3050,ES2002d.C.words3054'],
#  ['ES2002d.A.words2156,ES2002d.A.words2161'],
#  ['ES2002d.C.words3055,ES2002d.C.words3058'],
#  ['ES2002d.D.words774,ES2002d.D.words776'],
#  ['ES2002d.A.words2162'],
#  ['ES2002d.B.words2646,ES2002d.B.words2661'],
#  ['ES2002d.D.words777,ES2002d.D.words785'],
#  ['ES2002d.C.words3059,ES2002d.C.words3063'],
#  ['ES2002d.A.words2163'],
#  ['ES2002d.B.words2662,ES2002d.B.words2664'],
#  ['ES2002d.D.words786,ES2002d.D.words789'],
#  ['ES2002d.C.words3064,ES2002d.C.words3065'],
#  ['ES2002d.B.words2665,ES2002d.B.words2669'],
#  ['ES2002d.D.words790,ES2002d.D.words798'],
#  ['ES2002d.C.words3066,ES2002d.C.words3071'],
#  ['ES2002d.A.words2164,ES2002d.A.words2172'],
#  ['ES2002d.C.words3072,ES2002d.C.words3077'],
#  ['ES2002d.A.words2173,ES2002d.A.words2188'],
#  ['ES2002d.B.words2670,ES2002d.B.words2700'],
#  ['ES2002d.D.words799'],
#  ['ES2002d.C.words3078,ES2002d.C.words3079'],
#  ['ES2002d.A.words2189,ES2002d.A.words2192'],
#  ['ES2002d.C.words3080,ES2002d.C.words3081'],
#  ['ES2002d.A.words2193,ES2002d.A.words2211'],
#  ['ES2002d.C.words3082,ES2002d.C.words3083'],
#  ['ES2002d.B.words2701,ES2002d.B.words2706'],
#  ['ES2002d.C.words3084,ES2002d.C.words3088'],
#  ['ES2002d.B.words2707'],
#  ['ES2002d.A.words2212,ES2002d.A.words2227'],
#  ['ES2002d.C.words3089,ES2002d.C.words3094'],
#  ['ES2002d.D.words800'],
#  ['ES2002d.B.words2708,ES2002d.B.words2739'],
#  ['ES2002d.C.words3095,ES2002d.C.words3096'],
#  ['ES2002d.A.words2228,ES2002d.A.words2230'],
#  ['ES2002d.C.words3097,ES2002d.C.words3100'],
#  ['ES2002d.B.words2740', 'ES2002d.B.words2741,ES2002d.B.words2755'],
#  ['ES2002d.C.words3101,ES2002d.C.words3102'],
#  ['ES2002d.A.words2231,ES2002d.A.words2335'],
#  ['ES2002d.C.words3103,ES2002d.C.words3104', 'ES2002d.C.words3105'],
#  ['ES2002d.B.words2756,ES2002d.B.words2757'],
#  ['ES2002d.C.words3106,ES2002d.C.words3107',
#   'ES2002d.C.words3108,ES2002d.C.words3109'],
#  ['ES2002d.B.words2758,ES2002d.B.words2759'],
#  ['ES2002d.C.words3110,ES2002d.C.words3112'],
#  ['ES2002d.B.words2760,ES2002d.B.words2761',
#   'ES2002d.B.words2762,ES2002d.B.words2764'],
#  ['ES2002d.C.words3113,ES2002d.C.words3114'],
#  ['ES2002d.B.words2765,ES2002d.B.words2766',
#   'ES2002d.B.words2767,ES2002d.B.words2768'],
#  ['ES2002d.C.words3115,ES2002d.C.words3121'],
#  ['ES2002d.D.words801,ES2002d.D.words809'],
#  ['ES2002d.C.words3122,ES2002d.C.words3123'],
#  ['ES2002d.B.words2769,ES2002d.B.words2778'],
#  ['ES2002d.C.words3124,ES2002d.C.words3134'],
#  ['ES2002d.A.words2336,ES2002d.A.words2342'],
#  ['ES2002d.B.words2779,ES2002d.B.words2794'],
#  ['ES2002d.D.words810,ES2002d.D.words821'],
#  ['ES2002d.A.words2343,ES2002d.A.words2359'],
#  ['ES2002d.C.words3135,ES2002d.C.words3138'],
#  ['ES2002d.B.words2795,ES2002d.B.words2807'],
#  ['ES2002d.A.words2360,ES2002d.A.words2393'],
#  ['ES2002d.C.words3139,ES2002d.C.words3140'],
#  ['ES2002d.B.words2808,ES2002d.B.words2809'],
#  ['ES2002d.C.words3141,ES2002d.C.words3142',
#   'ES2002d.C.words3143,ES2002d.C.words3145'],
#  ['ES2002d.D.words822'],
#  ['ES2002d.B.words2810'],
#  ['ES2002d.A.words2394', 'ES2002d.A.words2395,ES2002d.A.words2456'],
#  ['ES2002d.C.words3146,ES2002d.C.words3148'],
#  ['ES2002d.B.words2811,ES2002d.B.words2812',
#   'ES2002d.B.words2813,ES2002d.B.words2814'],
#  ['ES2002d.C.words3149,ES2002d.C.words3154'],
#  ['ES2002d.D.words823,ES2002d.D.words828'],
#  ['ES2002d.C.words3155,ES2002d.C.words3156'],
#  ['ES2002d.B.words2815,ES2002d.B.words2816'],
#  ['ES2002d.C.words3157,ES2002d.C.words3162',
#   'ES2002d.C.words3163,ES2002d.C.words3164'],
#  ['ES2002d.B.words2817,ES2002d.B.words2818',
#   'ES2002d.B.words2819,ES2002d.B.words2821'],
#  ['ES2002d.A.words2457'],
#  ['ES2002d.B.words2822,ES2002d.B.words2835'],
#  ['ES2002d.A.words2458,ES2002d.A.words2459'],
#  ['ES2002d.B.words2836,ES2002d.B.words2841',
#   'ES2002d.B.words2842,ES2002d.B.words2851'],
#  ['ES2002d.C.words3165,ES2002d.C.words3173'],
#  ['ES2002d.A.words2460,ES2002d.A.words2474'],
#  ['ES2002d.B.words2852,ES2002d.B.words2853'],
#  ['ES2002d.C.words3174,ES2002d.C.words3178'],
#  ['ES2002d.B.words2854,ES2002d.B.words2872'],
#  ['ES2002d.C.words3179'],
#  ['ES2002d.A.words2475,ES2002d.A.words2481'],
#  ['ES2002d.C.words3180'],
#  ['ES2002d.B.words2873,ES2002d.B.words2885', '**********']]

# %%
with open('./txt_files/'+ topic_name+'.txt','w') as f:
    for e in wseg_with_parapgraph1:
        for s in e:
            f.write(s + '\n')

# %% [markdown]
# ### ------- a break line for automating all files----

# %%
from os import listdir
topic_files = listdir('./topics/')
seg_files = listdir('./segments/')
words_files = listdir('./words/')

# %%
len(listdir('./txt_files/'))
# Out:
# 140

# %%
with open('./test.txt','w') as f:
    for e in [[],'1','2']:
         for s in e:
            f.write(s+'\n')
