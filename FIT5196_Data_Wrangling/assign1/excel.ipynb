# %%
import pandas as pd
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_excel('./basic_indicators.xlsx',skiprows=list(range(5)),names=['x','Country Name']+list(range(22)))

# %%
df = df.dropna(axis=1,how='all');df
# Out:
#                                           Country Name    0    1    2    3  \
# 0                                          Afghanistan   25  177   70   74
# 1                                              Albania  114   40   14   15
# 2                                              Algeria   78   49   25   27
# 3                                              Andorra  179    9    3    3
# 4                                               Angola   17  221   83   88
# 5                                             Anguilla    –    –    –    –
# 6                                  Antigua and Barbuda  133   26    9    9
# 7                                            Argentina  126   29   11   12
# 8                                              Armenia  118   50   13   15
# 9                                            Australia  164    9    4    4
# 10                                             Austria  164   10    4    4
# ...

# %%
df = df.dropna(how='all');df = df[:216];df
# Out:
#                            Country Name    0    1    2    3    4    5    6  \
# 0                           Afghanistan   25  177   70   74   66  120   53
# 1                               Albania  114   40   14   15   12   35   12
# 2                               Algeria   78   49   25   27   24   41   22
# 3                               Andorra  179    9    3    3    3    7    2
# 4                                Angola   17  221   83   88   76  131   55
# 5                              Anguilla    –    –    –    –    –    –    –
# 6                   Antigua and Barbuda  133   26    9    9    8   25    5
# 7                             Argentina  126   29   11   12   10   26   10
# 8                               Armenia  118   50   13   15   12   42   12
# 9                             Australia  164    9    4    4    3    8    3
# 10                              Austria  164   10    4    4    3    8    3
# ...

# %%
df = df.drop(axis=1,columns=[13,15]);df
# Out:
#                            Country Name    0    1    2    3    4    5    6  \
# 0                           Afghanistan   25  177   70   74   66  120   53
# 1                               Albania  114   40   14   15   12   35   12
# 2                               Algeria   78   49   25   27   24   41   22
# 3                               Andorra  179    9    3    3    3    7    2
# 4                                Angola   17  221   83   88   76  131   55
# 5                              Anguilla    –    –    –    –    –    –    –
# 6                   Antigua and Barbuda  133   26    9    9    8   25    5
# 7                             Argentina  126   29   11   12   10   26   10
# 8                               Armenia  118   50   13   15   12   42   12
# 9                             Australia  164    9    4    4    3    8    3
# 10                              Austria  164   10    4    4    3    8    3
# ...

# %%
df = df.drop(labels=203);df
# Out:
#                            Country Name    0    1   2    3   4    5   6     7  \
# 0                           Afghanistan   25  177  70   74  66  120  53    40
# 1                               Albania  114   40  14   15  12   35  12     6
# 2                               Algeria   78   49  25   27  24   41  22    16
# 3                               Andorra  179    9   3    3   3    7   2     1
# 4                                Angola   17  221  83   88  76  131  55    29
# 5                              Anguilla    –    –   –    –   –    –   –     –
# 6                   Antigua and Barbuda  133   26   9    9   8   25   5     4
# 7                             Argentina  126   29  11   12  10   26  10     6
# 8                               Armenia  118   50  13   15  12   42  12     7
# 9                             Australia  164    9   4    4   3    8   3     2
# 10                              Austria  164   10   4    4   3    8   3     2
# ...

# %%
df = df.rename(columns={14:13})

# %%
# Out:
# 0               34656.032
# 1                2926.348
# 2               40606.052
# 3                  77.281
# 4               28813.463
# 5                  14.764
# 6                 100.963
# 7                43847.43
# 8                2924.816
# 9               24125.848
# 10               8712.137
# 11               9725.376
# 12                391.232
# 13               1425.171
# 14              162951.56
# 15                284.996
# 16               9480.042
# 17              11358.379
# 18                366.954
# 19              10872.298
# 20                797.765
# 21              10887.882
# 22               3516.816
# 23                2250.26
# 24             207652.865
# 25                 30.661
# 26                423.196
# 27               7131.494
# 28              18646.433
# 29              10524.117
#               ...
# 185              5662.544
# 186                  34.9
# 187                11.097
# 188             41487.965
# 189             44438.625
# ...

# %%
df.dtypes
# Out:
# Country Name     object
# 0                object
# 1                object
# 2                object
# 3                object
# 4                object
# 5                object
# 6                object
# 7                object
# 8               float64
# 9                object
# 10               object
# 11               object
# 12               object
# 13               object
# dtype: object

# %%
df = df.apply(lambda x : x.apply(lambda elt: str(int(elt)) if isinstance(elt, float) else str(elt)));df

# %%
df = df.apply(lambda x: x.str.replace('–',''),axis=1);df

# %%
df.to_csv('./test_out.csv',index=False)
