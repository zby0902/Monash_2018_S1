# %%
from tabula import read_pdf

# %%
df = read_pdf('./health.pdf')

# %%
df.head()
# Out:
#   Unnamed: 0      Unnamed: 1    Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0        NaN    Use of basic  Use of basic        NaN        NaN        NaN
# 1        NaN  drinking water    sanitation        NaN        NaN        NaN
# 2        NaN    services (%)  services (%)        NaN        NaN        NaN
# 3        NaN             NaN           NaN        NaN        NaN        NaN
# 4  Countries            2015          2015        BCG      DTP1β      DTP3β
#
#       Immunization coverage (%) Unnamed: 7 Unnamed: 8  Unnamed: 9  \
# 0                           NaN        NaN        NaN  Protection
# 1                           NaN        NaN        NaN    at birth
# 2                           NaN        NaN        NaN       (PAB)
# 3                           NaN        NaN        NaN     against
# 4  polio3 MCV1 MCV2^ HepB3 Hib3       rota       PCV3    tetanusλ
#
#              Pneumonia Diarrhoea  Unnamed: 11   Malaria Unnamed: 13
# ...
