# %%
from tabula import read_pdf

# %%
df = read_pdf('./health.pdf')

# %%
df.drop(index=list(range(6)))
# Out:
#                           Unnamed: 0   Unnamed: 1   Unnamed: 2 Unnamed: 3  \
# 6                        Afghanistan     63 89 53     39 56 33         74
# 7                            Albania     91 93 90     98 98 97         99
# 8                            Algeria     93 95 89     87 90 82         99
# 9                            Andorra  100 100 100  100 100 100          –
# 10                            Angola     41 63 23     39 62 21         58
# 11                          Anguilla      98 98 –      97 97 –          –
# 12               Antigua and Barbuda       97 – –       88 – –          –
# 13                         Argentina  100 100 100     95 95 94         92
# 14                           Armenia     99 99 99     92 96 83         99
# 15                         Australia  100 100 100      100 – –          –
# 16                           Austria  100 100 100  100 100 100          –
# 17                        Azerbaijan     84 95 72     89 92 87         98
# ...
