# %%
import tabula

# %%
DF1 = tabula.read_pdf('./health.pdf', pages=1)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-2-449a6a0fc4bf> in <module>()
# ----> 1 DF1 = tabula.read_pdf('./health.pdf', pages=1)
#
# ~/anaconda3/envs/5196/lib/python3.6/site-packages/tabula/wrapper.py in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, **kwargs)
#      73
#      74     try:
# ---> 75         output = subprocess.check_output(args)
#      76     finally:
#      77         if is_url:
#
# ~/anaconda3/envs/5196/lib/python3.6/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     334
#     335     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 336                **kwargs).stdout
#     337
#     338
#
# ~/anaconda3/envs/5196/lib/python3.6/subprocess.py in run(input, timeout, check, *popenargs, **kwargs)
#     416         if check and retcode:
# ...

# %%
DF1
# Out:
#                           Unnamed: 0         Unnamed: 1         Unnamed: 2  \
# 0                                NaN       Use of basic       Use of basic
# 1                                NaN     drinking water         sanitation
# 2                                NaN       services (%)       services (%)
# 3                                NaN                NaN                NaN
# 4                          Countries               2015               2015
# 5                          and areas  total urban rural  total urban rural
# 6                        Afghanistan           63 89 53           39 56 33
# 7                            Albania           91 93 90           98 98 97
# 8                            Algeria           93 95 89           87 90 82
# 9                            Andorra        100 100 100        100 100 100
# 10                            Angola           41 63 23           39 62 21
# ...

# %%
DF2 = tabula.read_pdf('./health.pdf',pages=2);DF2
# Out:
#                           Unnamed: 0         Unnamed: 1         Unnamed: 2  \
# 0                                NaN       Use of basic       Use of basic
# 1                                NaN     drinking water         sanitation
# 2                                NaN       services (%)       services (%)
# 3                                NaN                NaN                NaN
# 4                          Countries               2015               2015
# 5                          and areas  total urban rural  total urban rural
# 6                            Finland        100 100 100           99 99 99
# 7                             France        100 100 100           99 99 99
# 8                              Gabon           88 92 59           41 42 32
# 9                             Gambia           80 88 68           42 46 35
# 10                           Georgia           93 98 87           85 95 73
# ...

# %%
DF3 = tabula.read_pdf('./health.pdf',pages=3);DF3
# Out:
#                          Unnamed: 0         Unnamed: 1         Unnamed: 2  \
# 0                               NaN       Use of basic       Use of basic
# 1                               NaN     drinking water         sanitation
# 2                               NaN       services (%)       services (%)
# 3                               NaN                NaN                NaN
# 4                         Countries               2015               2015
# 5                         and areas  total urban rural  total urban rural
# 6                       Netherlands        100 100 100          98 98 100
# 7                       New Zealand        100 100 100        100 100 100
# 8                         Nicaragua           82 97 61           76 86 63
# 9                             Niger           46 89 36            13 44 6
# 10                          Nigeria           67 82 54           33 39 27
# 11                             Niue             98 – –             97 – –
# ...

# %%
DF4 = tabula.read_pdf('./health.pdf', spreadsheet=True,pages=4);DF4
# Out:
#                          Unnamed: 0  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                            Uganda
# 4                               NaN
# 5              United Arab Emirates
# 6                               NaN
# 7       United Republic of Tanzania
# 8                               NaN
# 9                           Uruguay
# 10                              NaN
# 11                          Vanuatu
# 12                              NaN
# 13                         Viet Nam
# 14                              NaN
# 15                           Zambia
# 16                              NaN
# 17                              NaN
# 18            East Asia and Pacific
# 19                              NaN
# 20  Eastern Europe and Central Asia
# 21                              NaN
# 22      Latin America and Caribbean
# 23                              NaN
# 24                    North America
# ...
