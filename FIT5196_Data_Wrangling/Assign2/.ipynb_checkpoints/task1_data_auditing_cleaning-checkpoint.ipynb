# %% [markdown]
# # FIT5196 Task 1 in Assessment 2
# #### Student Name: Boyu Zhang
# #### Student ID: 28491300
#
# Date: XX/XX/XXXX
#
# Version: 1.0
#
# Environment: Python 3.6 and Jupyter notebook
#
# Libraries used: please include the main libraries you used in your assignment here, e.g.,:
# * pandas (for dataframe, included in Anaconda Python )
# * re (for regular expression, included in Anaconda Python 3.6)
# * numpy (for numpy array, included in Anaconda Python 3.6)

# %% [markdown]
# ## 1.  Import libraries

# %%
# Code to import libraries as you need in this assessment, e.g.,
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ## 2. Load data and exploration

# %%
df1 = pd.read_csv('./Input/dataset1_with_error.csv')

# %%
#overview of the dataset
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25077 entries, 0 to 25076
# Data columns (total 11 columns):
# Id                  25077 non-null int64
# Title               25077 non-null object
# Location            25077 non-null object
# ContractType        25077 non-null object
# ContractTime        25077 non-null object
# Company             21242 non-null object
# Category            25077 non-null object
# Salary per annum    25077 non-null object
# SourceName          25077 non-null object
# OpenDate            25077 non-null object
# CloseDate           25077 non-null object
# dtypes: int64(1), object(10)
# memory usage: 2.1+ MB

# %%
df1.describe(include=['O'])
# Out:
#                                  Title Location   ContractType ContractTime  \
# count                            25077    25077          25077        25077
# unique                           25077      482              3            3
# top     Dialogue Application Developer       UK  not available    permanent
# freq                                 1     3996          19499        16194
#
#               Company Category Salary per annum     SourceName  \
# count           21242    25077            25077          25077
# unique           4879        8             1589             90
# top     UKStaffsearch  IT Jobs            35004  totaljobs.com
# freq              248     7085             1011           5335
#
#                OpenDate        CloseDate
# count             25077            25077
# unique             2203             2400
# top     20130127T150000  20130526T120000
# freq                 27               23

# %%
#number of missing values in each column
df1.isnull().sum()
# Out:
# Id                     0
# Title                  0
# Location               0
# ContractType           0
# ContractTime           0
# Company             3835
# Category               0
# Salary per annum       0
# SourceName             0
# OpenDate               0
# CloseDate              0
# dtype: int64

# %% [markdown]
# ### Highlight of initial investigation
# - There are 9 columns of categorical values, and 2 column of numeric values -- `Id` and `Salary`
# - There are a lot of missing values in the `Company` column
# - There must be issue with the column `Title` since the most frequent value is like "** *Ton**"which is obviously invalid
# - The most frequent value of `Location` is "UK" which suspicious
# - There are potential semantic anomalies :
#     - unique values can have redundance
#     - The violation of two Date
# - There can be sytax anomalies:
#      - inconistent representation of values in the same column
#      - invalid value of categorical values

# %%
#first glance of the dataset
df1.head()
# Out:
#          Id                                              Title   Location  \
# 0  12612628                        Engineering Systems Analyst    Dorking
# 1  12612830                            Stress Engineer Glasgow    Glasgow
# 2  12612844                   Modelling and simulation analyst  Hampshire
# 3  12613049  Engineering Systems Analyst / Mathematical Mod...     Surrey
# 4  12613647         Pioneer, Miser Engineering Systems Analyst     Surrey
#
#     ContractType ContractTime                       Company          Category  \
# 0  not available    permanent  Gregory Martin International  Engineering Jobs
# 1  not available    permanent  Gregory Martin International  Engineering Jobs
# 2  not available    permanent  Gregory Martin International  Engineering Jobs
# 3  not available    permanent  Gregory Martin International  Engineering Jobs
# 4  not available    permanent  Gregory Martin International  Engineering Jobs
#
#   Salary per annum        SourceName         OpenDate        CloseDate
# 0            24996  cv-library.co.uk  20121103T000000  20121203T000000
# 1            30000  cv-library.co.uk  20130108T150000  20130408T150000
# 2            30000  cv-library.co.uk  20130726T150000  20130924T150000
# 3            27504  cv-library.co.uk  20121214T000000  20130314T000000
# 4            24996  cv-library.co.uk  20131025T000000  20131224T000000

# %%
df1.iloc[3].Title
# Out:
# 'Engineering Systems Analyst / Mathematical Modeller'

# %% [markdown]
# ## 3. Identify issues and fix

# %% [markdown]
# ### ID
# For the column `ID` we don't have any constraints other than non-redundance. Thus we only check whether all **IDs** is unique.

# %%
#test if all Id 
df1.Id.unique().shape[0] == df1.shape[0]
# Out:
# True

# %% [markdown]
# ### Title
# - It's reasonable no matter there are redundant tiltles or not.
# - The values should be in valid language

# %%
#test whethere there is redundant titles
df1.Title.unique().shape
# Out:
# (25077,)

# %%
df1.Title.value_counts()
# Out:
# Dialogue Application Developer                                                     1
# Junior Programmer                                                                  1
# Loans Consultant  Times Top 100 Employer                                           1
# Drainage Engineer                                                                  1
# EMC Engineer                                                                       1
# Junior Sales Analyst                                                               1
# Draughtsman  Contract 3months                                                      1
# C Web Developer                                                                    1
# Health Care Assistant (HCA)  Community/ Ward/ Mental Health  Hereford              1
# Care Manager  Plymouth                                                             1
# Dozer Driver                                                                       1
# Mac/PC 1st 2nd line School Technician                                              1
# Information Architect                                                              1
# SharePoint Developer  Growing Consultancy                                          1
# Home Insurance Consultant                                                          1
# Part Time OR Full Time ENTHUSIASTIC Telephone Fundraiser                           1
# Mechanical Design Team Leaders                                                     1
# Synthetic Chemist  Polymers                                                        1
# Senior Software Designer / Developer                                               1
# Home Manager Surrey                                                                1
# Brand Manager, Luxury Travel                                                       1
# Contract Engineers                                                                 1
# Software Developer  (Net, C, C++)  Great Company                                   1
# NVQ Assessor Banking/Financial Services South West Salary to ****kCar Allowance    1
# NEW Account Managers  pound;**** pound;**** ndash; Accrington                      1
# RGN Team Leader, Days, **** per hour                                               1
# Head of Chemistry                                                                  1
# Telemarketing Executive  Central Manchester                                        1
# HDU Nurse Job Manchester                                                           1
# IT Support Apprentice  Buckinghamshire                                             1
#                                                                                   ..
# Estate Agent Junior Sales Negotiator                                               1
# Portfolio & Reporting Manager                                                      1
# Senior Sous Chef – Gastro Aiming for Michelin – MF ****k                           1
# Project Manager  Security Projects                                                 1
# Senior PPC Manager / Insight Specialist  Paid Search Strategy, Data                1
# PPA Teacher Needed  Wembley                                                        1
# Theatre Scrub Nurse / ODP                                                          1
# Quantitative Financial Engineer  Basel ****  Basel III  Risk                       1
# Marketing Graduate Trainee  Manchester City Centre                                 1
# IT Systems Engineer  Windows, Unix, Linux, Exchange, Web Application,              1
# Healthcare Consultant                                                              1
# Chef de Partie  Exciting Berkshire based positions  ****K                          1
# Group Tax Manager  Lloyds Syndicate                                                1
# Data Management Consultant                                                         1
# Life Actuary (Pensions Background)                                                 1
# RGN Staff Nurse  3 X Night Shift  Uxbridge                                         1
# Healthcare Administrator                                                           1
# Vice President, Agency Management                                                  1
# C Software Engineer  WinForms, Web, C, SQL Server  Derby                           1
# Level 3 Qualified Teaching Assistant                                               1
# Senior Superintendent                                                              1
# Assistant Software Developer                                                       1
# Energy Technician                                                                  1
# Area Sales Manager  Southern Territory                                             1
# Automation QA Engineer  Selenium  Ecommerce Leader                                 1
# Sister/ Charge Nurse  Main Theatres                                                1
# Java J****EE Senior Lead Developer                                                 1
# Head Chef Tunbridge Wells  Fantastic Opportunity                                   1
# Software Engineers  Defence and Military                                           1
# Senior HR Advisor  12 month contract                                               1
# Name: Title, Length: 25077, dtype: int64

# %% [markdown]
# - It appears there are values that contain invalid characters in the `Title` column
# - It seems some titles also contains the company name or location which could be improved for clearity of data

# %%
df1[df1.Title=='**** Ton']
# Out:
#              Id     Title Location ContractType ContractTime  \
# 24644  69193100  **** Ton    Rugby    full_time    permanent
#
#                            Company          Category Salary per annum  \
# 24644  Interaction Recruitment plc  Engineering Jobs            13440
#
#         SourceName         OpenDate        CloseDate
# 24644  fish4.co.uk  20130815T120000  20131113T120000

# %%
df1[df1.Title=='Electronics Engineer, Embedded Software, R D, York, ****']
# Out:
#             Id                                              Title  \
# 2987  65102296  Electronics Engineer, Embedded Software, R D, ...
#
#              Location ContractType ContractTime Company          Category  \
# 2987  North Yorkshire    full_time    permanent   Amrec  Engineering Jobs
#
#      Salary per annum             SourceName         OpenDate        CloseDate
# 2987            37500  thecareerengineer.com  20130926T120000  20131225T120000

# %%
df1[df1.Title=='Assistant Manager  South West London Gastro Pub  ****K']
# Out:
#              Id                                              Title Location  \
# 18230  68706648  Assistant Manager  South West London Gastro Pu...   London
#
#         ContractType   ContractTime                Company  \
# 18230  not available  not available  Cherryred Recruitment
#
#                           Category Salary per annum  \
# 18230  Hospitality & Catering Jobs            22500
#
#                            SourceName         OpenDate        CloseDate
# 18230  jobs.catererandhotelkeeper.com  20130702T000000  20130831T000000

# %% [markdown]
# #### Temporary conclusions:
# - After inspecting some records that contains invalid character, there seems no clues how to replace with meaningful values. Thus we think it is better to keep these invalid character, since R****** still tell the length of the word but 'R' will not

# %% [markdown]
# ### Location

# %%
df1[df1.Location == 'UK']
# Out:
#              Id                                              Title Location  \
# 9      22933091  Chef de Partie  Award Winning Dining  Live In ...       UK
# 12     23530231                            Lead Engineers (Stress)       UK
# 13     24104334    Relief Chef de Partie  Croydon, Surrey  Live in       UK
# 26     27739522  Welwyn Chef de Partie does it get any better t...       UK
# 27     27740574       Pastry Chef AL**** ****AA Rosette Restaurant       UK
# 30     29650985  Fine Dining Chefs for rosette restaurants  up ...       UK
# 31     30192171                                      Web Developer       UK
# 39     31989124     Mechanical Engineer  Design and Substantiation       UK
# 42     32233421                      Principle Mechanical Engineer       UK
# 43     32417995  Chef de Partie  Award Winning Fine Dining Rest...       UK
# 44     32621550  Chef De Partie up to ****  Tips Ipswich Outskirts       UK
# 48     33469049                          IT Recruitment Consultant       UK
# 52     34558621    Chef De Partie Norfolk Live In up to ****  Tips       UK
# 54     34558938   Pastry Chef/Baker  artisan bakery  Suffolk Coast       UK
# 55     34790490                                     Java Developer       UK
# 79     41406133                              IT Support Technician       UK
# 80     41783094  Chef de Partie  High Volume Banqueting Departm...       UK
# 81     41879934   Future Leaders Development Programme  Technology       UK
# 85     43196787  Chef de Partie  High Volume Conference Centre ...       UK
# 88     43611718  SALES ENGINEER  MIDLANDS, CAMBRIDGESHIRE, NORT...       UK
# 90     43611886                         PROPERTY BUYER / TELESALES       UK
# 94     44452543  Sous Chef Straight Shifts Bury St Edmunds up t...       UK
# 96     45057486                                            Manager       UK
# 104    46541847  Chef de Partie  Accredited Boutique Hotel  Sha...       UK
# 105    46626508                        Support Worker Job Chepstow       UK
# 106    46626509                     Support Worker Job Abergavenny       UK
# 110    46626537               RGN Registered Nurse Job Southampton       UK
# 118    46626571                    RGN Registered Nurse Job Durham       UK
# 127    46626838               Senior Care Assistant North Tyneside       UK
# 135    46626893        Deputy Nursing Home Manager Job Southampton       UK
# ...         ...                                                ...      ...
# 24998  69219824                             ASD Teaching Assistant       UK
# 24999  69219830                  Primary Teacher South West London       UK
# 25000  69219927  Teacher Assistant in south east London seconda...       UK
# 25002  69219932               Insurance Sales Executive  Dunstable       UK
# 25004  69220056      Credit Risk Modellers  Consultancy Roles  SAS       UK
# 25006  69220200                           Early Years Lead Teacher       UK
# 25007  69220230    LONG TERM ROLES STILL AVAILABLE IN SOUTH LONDON       UK
# 25014  69220916                 Assistant Finance Business Manager       UK
# 25016  69221014  Hospitality / Front Of House NVQ Assessor  Dorset       UK
# 25017  69221053  Windows Systems Administrator / Finance / Secu...       UK
# 25018  69221162     Quant Analysts Required High Earning Potential       UK
# 25025  69221374                                SALES  NEW BUSINESS       UK
# 25026  69221393             Bookkeeper / Accounts Assistant  Music       UK
# 25027  69221532                                Test Engineer (BSR)       UK
# 25029  69221582             Electronics Engineer (Graduate to Snr)       UK
# 25032  69221776                       MultiChannel Finance Manager       UK
# 25035  69224868  Hardware Design Engineer Digital and Analogue ...       UK
# 25036  69225891                      Mechatronics Product Engineer       UK
# 25041  69228388     Jnr Mid, Mobile Games Developer, ****K, London       UK
# 25043  69228449                 Interim Senior Year End Accountant       UK
# 25048  69228674                     RF Design and Customer Support       UK
# 25049  69228685          Technical Sales Engineer  Deburring tools       UK
# 25050  69228842                             Senior Internal Audior       UK
# 25051  69228969  Business Development, P/T F/T, Flexible hours,...       UK
# 25053  69229283                   Design and Applications Engineer       UK
# 25057  69229454                     Education and Training Manager       UK
# 25062  69229778         Junior Drainage Engineer PDS Microdrainage       UK
# 25063  69229815                       Head of Research Development       UK
# 25064  69229843        Performance Test Consultant  SoapUI, LoadUI       UK
# 25066  69229954  Fibre Laser Physicists / Engineers (Graduate t...       UK
#
#         ContractType   ContractTime                             Company  \
# 9      non_specified  non_specified                        Chef Results
# 12     non_specified      permanent        Gregory Martin International
# 13     non_specified  non_specified                  Towngate Personnel
# 26     non_specified  non_specified                     Clear Selection
# 27     non_specified  non_specified                     Clear Selection
# 30     non_specified  non_specified                     Clear Selection
# 31     non_specified      permanent                       Indigo 21 Ltd
# 39     non_specified      permanent        Gregory Martin International
# 42     non_specified      permanent             Rullion Engineering Ltd
# 43     non_specified  non_specified                        Chef Results
# 44     non_specified  non_specified                     Clear Selection
# 48     non_specified      permanent               Code Blue Recruitment
# 52     non_specified  non_specified                     Clear Selection
# 54     non_specified  non_specified                     Clear Selection
# 55     non_specified      permanent                                 NaN
# 79     non_specified      permanent             MatchBox Recruiting Ltd
# 80     non_specified  non_specified                        Chef Results
# 81     non_specified      permanent                                 NaN
# 85     non_specified  non_specified                        Chef Results
# 88     non_specified      permanent                                  OP
# 90     non_specified      permanent                  Serata Search  Ltd
# 94     non_specified  non_specified                     Clear Selection
# 96     non_specified  non_specified                     Clear Selection
# 104    non_specified  non_specified                        Chef Results
# 105        full_time  non_specified                                 NaN
# 106        full_time  non_specified                                 NaN
# 110        full_time  non_specified                                 NaN
# 118        full_time  non_specified                                 NaN
# 127    non_specified  non_specified                                 NaN
# 135        full_time  non_specified                                 NaN
# ...              ...            ...                                 ...
# 24998      full_time      permanent  Teaching Personnel Ltd   London CR
# 24999      full_time      permanent  Teaching Personnel Ltd   London CR
# 25000      full_time      permanent                     Career Teachers
# 25002      full_time      permanent                Additional Resources
# 25004      full_time      permanent             Aspire Data Recruitment
# 25006      full_time      permanent                            Edustaff
# 25007      full_time      permanent                     Career Teachers
# 25014      full_time      permanent             CY Executive Resourcing
# 25016      full_time      permanent                Additional Resources
# 25017      full_time      permanent                           OHO Group
# 25018      full_time      permanent                           OHO Group
# 25025      full_time      permanent                Candidate Source Ltd
# 25026      full_time      permanent               Sauce Recruitment Ltd
# 25027      full_time      permanent                   RLE International
# 25029      full_time      permanent          Enterprise Recruitment Ltd
# 25032      full_time      permanent               Firefly Human Capital
# 25035      full_time      permanent         Teambuilder Recruitment Ltd
# 25036      full_time      permanent                    Forest Personnel
# 25041      full_time      permanent                 Monarch Recruitment
# 25043      full_time      permanent                Finegreen Associates
# 25048      full_time      permanent                European Recruitment
# 25049      full_time      permanent             ETS Technical Selection
# 25050      full_time      permanent                 Hydrogen UK Limited
# 25051      full_time      permanent           Orion Business Management
# 25053      full_time      permanent         Interaction Recruitment plc
# 25057      full_time      permanent              ATOM Education Limited
# 25062      full_time      permanent                       Hays TCE Jobs
# 25063      full_time      permanent                   Hays   North West
# 25064      full_time      permanent                 Monarch Recruitment
# 25066      full_time      permanent                         RE & M  Ltd
#
#                           Category  Salary per annum           SourceName  \
# 9      Hospitality & Catering Jobs             18000          caterer.com
# 12                Engineering Jobs             39504     cv-library.co.uk
# 13     Hospitality & Catering Jobs             17280          caterer.com
# 26     Hospitality & Catering Jobs             18000          caterer.com
# 27     Hospitality & Catering Jobs             18996          caterer.com
# 30     Hospitality & Catering Jobs             24000          caterer.com
# 31                         IT Jobs             35004     cv-library.co.uk
# 39                Engineering Jobs             35004     cv-library.co.uk
# 42                Engineering Jobs             48504     cv-library.co.uk
# 43     Hospitality & Catering Jobs             20496          caterer.com
# 44     Hospitality & Catering Jobs             17004          caterer.com
# 48                         IT Jobs             24996     cv-library.co.uk
# 52     Hospitality & Catering Jobs             17496          caterer.com
# 54     Hospitality & Catering Jobs             21000          caterer.com
# 55                         IT Jobs             33996  theitjobboard.co.uk
# 79                         IT Jobs             23496     cv-library.co.uk
# 80     Hospitality & Catering Jobs             22500          caterer.com
# 81                         IT Jobs             36000  theitjobboard.co.uk
# 85     Hospitality & Catering Jobs             20004          caterer.com
# 88                      Sales Jobs             30996     cv-library.co.uk
# 90                      Sales Jobs             20496     cv-library.co.uk
# 94     Hospitality & Catering Jobs             23004          caterer.com
# 96     Hospitality & Catering Jobs             24996          caterer.com
# 104    Hospitality & Catering Jobs             15996          caterer.com
# 105      Healthcare & Nursing Jobs             12348       careworx.co.uk
# 106      Healthcare & Nursing Jobs             14256       careworx.co.uk
# 110      Healthcare & Nursing Jobs             23040       careworx.co.uk
# 118      Healthcare & Nursing Jobs             27000       careworx.co.uk
# 127      Healthcare & Nursing Jobs             14880       careworx.co.uk
# 135      Healthcare & Nursing Jobs             25440       careworx.co.uk
# ...                            ...               ...                  ...
# 24998                Teaching Jobs             13200          fish4.co.uk
# 24999                Teaching Jobs             28800          fish4.co.uk
# 25000                Teaching Jobs             17400          fish4.co.uk
# 25002                   Sales Jobs             21504          fish4.co.uk
# 25004                      IT Jobs             60000          fish4.co.uk
# 25006                Teaching Jobs             40368          fish4.co.uk
# 25007                Teaching Jobs             32400          fish4.co.uk
# 25014    Accounting & Finance Jobs             54000          fish4.co.uk
# 25016                Teaching Jobs             20004          fish4.co.uk
# 25017                      IT Jobs             52500          fish4.co.uk
# 25018                      IT Jobs             87504          fish4.co.uk
# 25025                   Sales Jobs             18504          fish4.co.uk
# 25026    Accounting & Finance Jobs             24996          fish4.co.uk
# 25027             Engineering Jobs             38496          fish4.co.uk
# 25029             Engineering Jobs             30996          fish4.co.uk
# 25032    Accounting & Finance Jobs             84996          fish4.co.uk
# 25035             Engineering Jobs             33504          fish4.co.uk
# 25036             Engineering Jobs             35004          fish4.co.uk
# 25041                      IT Jobs             27504          fish4.co.uk
# 25043    Accounting & Finance Jobs             90000          fish4.co.uk
# 25048                      IT Jobs             82560          fish4.co.uk
# 25049                      IT Jobs             32496          fish4.co.uk
# 25050    Accounting & Finance Jobs             47496          fish4.co.uk
# 25051    Healthcare & Nursing Jobs             37500          fish4.co.uk
# 25053             Engineering Jobs             39996          fish4.co.uk
# 25057                Teaching Jobs             45996          fish4.co.uk
# 25062             Engineering Jobs             20004          fish4.co.uk
# 25063                      IT Jobs             48504          fish4.co.uk
# 25064                      IT Jobs             15120          fish4.co.uk
# 25066                      IT Jobs             32496          fish4.co.uk
#
#                  OpenDate           CloseDate
# 9     2012-08-14 00:00:00 2012-08-28 00:00:00
# 12    2012-11-13 12:00:00 2013-02-11 12:00:00
# 13    2013-10-29 00:00:00 2013-11-28 00:00:00
# 26    2013-01-06 12:00:00 2013-03-07 12:00:00
# 27    2012-03-20 12:00:00 2012-04-03 12:00:00
# 30    2013-12-05 15:00:00 2014-01-04 15:00:00
# 31    2013-03-05 00:00:00 2013-05-04 00:00:00
# 39    2013-10-18 12:00:00 2013-11-17 12:00:00
# 42    2013-08-16 12:00:00 2013-11-14 12:00:00
# 43    2013-10-16 15:00:00 2013-10-30 15:00:00
# 44    2013-11-25 12:00:00 2013-12-25 12:00:00
# 48    2013-03-23 12:00:00 2013-06-21 12:00:00
# 52    2013-08-03 15:00:00 2013-10-02 15:00:00
# 54    2012-04-16 15:00:00 2012-06-15 15:00:00
# 55    2012-02-03 12:00:00 2012-03-04 12:00:00
# 79    2012-12-10 15:00:00 2013-03-10 15:00:00
# 80    2013-02-20 15:00:00 2013-03-22 15:00:00
# 81    2012-08-15 15:00:00 2012-10-14 15:00:00
# 85    2012-02-03 12:00:00 2012-03-04 12:00:00
# 88    2012-09-19 15:00:00 2012-12-18 15:00:00
# 90    2013-06-07 12:00:00 2013-08-06 12:00:00
# 94    2013-10-01 12:00:00 2013-10-31 12:00:00
# 96    2013-05-27 15:00:00 2013-06-26 15:00:00
# 104   2012-05-17 00:00:00 2012-05-31 00:00:00
# 105   2013-04-07 00:00:00 2013-05-07 00:00:00
# 106   2013-06-14 00:00:00 2013-09-12 00:00:00
# 110   2013-08-24 12:00:00 2013-11-22 12:00:00
# 118   2012-04-07 12:00:00 2012-05-07 12:00:00
# 127   2013-10-21 00:00:00 2013-11-04 00:00:00
# 135   2012-07-30 12:00:00 2012-08-29 12:00:00
# ...                   ...                 ...
# 24998 2012-02-15 12:00:00 2012-03-16 12:00:00
# 24999 2012-08-26 12:00:00 2012-11-24 12:00:00
# 25000 2013-01-09 00:00:00 2013-04-09 00:00:00
# 25002 2013-03-26 12:00:00 2013-06-24 12:00:00
# 25004 2012-04-11 15:00:00 2012-06-10 15:00:00
# 25006 2013-06-06 15:00:00 2013-09-04 15:00:00
# 25007 2013-06-20 00:00:00 2013-08-19 00:00:00
# 25014 2012-07-26 15:00:00 2012-10-24 15:00:00
# 25016 2013-03-29 12:00:00 2013-05-28 12:00:00
# 25017 2012-09-05 12:00:00 2012-10-05 12:00:00
# 25018 2013-06-20 12:00:00 2013-09-18 12:00:00
# 25025 2012-03-25 00:00:00 2012-06-23 00:00:00
# 25026 2012-06-16 15:00:00 2012-09-14 15:00:00
# 25027 2012-06-15 12:00:00 2012-08-14 12:00:00
# 25029 2013-05-23 00:00:00 2013-06-22 00:00:00
# 25032 2013-02-17 15:00:00 2013-03-19 15:00:00
# 25035 2013-01-23 00:00:00 2013-04-23 00:00:00
# 25036 2012-11-30 15:00:00 2013-02-28 15:00:00
# 25041 2012-04-22 12:00:00 2012-06-21 12:00:00
# 25043 2013-05-08 12:00:00 2013-08-06 12:00:00
# 25048 2012-06-05 00:00:00 2012-08-04 00:00:00
# 25049 2013-11-28 15:00:00 2014-01-27 15:00:00
# 25050 2013-07-06 12:00:00 2013-09-04 12:00:00
# 25051 2012-06-17 15:00:00 2012-07-17 15:00:00
# 25053 2012-10-10 00:00:00 2013-01-08 00:00:00
# 25057 2012-08-06 15:00:00 2012-09-05 15:00:00
# 25062 2013-12-07 00:00:00 2014-03-07 00:00:00
# 25063 2012-08-12 00:00:00 2012-11-10 00:00:00
# 25064 2013-06-27 12:00:00 2013-07-27 12:00:00
# 25066 2012-07-09 12:00:00 2012-10-07 12:00:00
#
# [3996 rows x 11 columns]

# %% [markdown]
# Problem of location seems more complicated:
#  - some records has just no detailed `Location` but just "UK"(default filling for none)
#  - some has the location data but it is included in the `Title` value and these record also just have the value of `Location` as "UK"

# %% [markdown]
# #### Solution:
# - If the location is both in `Title` and `Location`, we delete the location in the `Ttile`
# - But for the one with no specigic `Location` we cannot tell where to get this `Location` information

# %%
p = '\s*(\w+)\s*$'
# Out:
# 'Chepstow'

# %% [markdown]
# ### ContractType

# %%
#check unique values of the columns
df1.ContractType.unique()
# Out:
# array(['not available', 'full_time', 'part_time'], dtype=object)

# %% [markdown]
# According to dta dataset description, the 'not available' should be replaced by 'non_specified'

# %%
df1.ContractType.replace('not available','non_specified',inplace=True)

# %% [markdown]
# ### ContractTime

# %%
#check unique values
df1.ContractTime.unique()
# Out:
# array(['permanent', 'not available', 'contract'], dtype=object)

# %%
df1.ContractTime.replace('not available','non_specified',inplace=True)

# %% [markdown]
# ### Company

# %%
df1.Company.value_counts()
# Out:
# UKStaffsearch                                          248
# CVbrowser                                              170
# Randstad                                               169
# JOBG8                                                  159
# Matchtech Group plc.                                   150
# Chef Results                                           137
# Penguin Recruitment                                    134
# Hays                                                   115
# London4Jobs                                            112
# COREcruitment International                            111
# JAM Recruitment Ltd                                    109
# Computer People                                         99
# Clear Selection                                         92
# Monarch Recruitment                                     89
# Towngate Personnel                                      79
# Cherryred Recruitment                                   69
# Senitor Associates                                      67
# Support Services Group                                  62
# Capita Resourcing                                       62
# Modis                                                   62
# Aspire Data Recruitment                                 61
# Adecco                                                  57
# Populus Healthcare                                      55
# Idex Consulting                                         55
# Evolution Recruitment Solutions                         55
# Swiis Healthcare                                        54
# Bee Recruitment London Ltd                              53
# The Placement Group                                     52
# IC Software                                             52
# HCL Permanent                                           51
#                                                       ...
# JP Aero                                                  1
# Arthur Financial                                         1
# CARE QUALITY COMMISSION                                  1
# Hatstand Limited                                         1
# Optimum Appointments                                     1
# Julian Cresswell                                         1
# The Management Recruitment Group                         1
# Apollo solutions                                         1
# Exhausts UK Limited                                      1
# WILTSHIRE COLLEGE                                        1
# Point Professional Recruitment                           1
# RDF                                                      1
# QHotels                                                  1
# Heads Engineering Limited                                1
# Cox  Little Company                                      1
# Henley Computer Services                                 1
# Quadratek                                                1
# Accounting Academy Partnership                           1
# Reilly People                                            1
# Clare Moore                                              1
# JSM Specialist Services ltd                              1
# Rail Ability                                             1
# Priya Services                                           1
# Hybrow                                                   1
# THE MEETINGS RECRUITMENT                                 1
# MGT Training.com                                         1
# Sand Resources. A division of InterQuest Group  Ltd      1
# TotalJobs Group                                          1
# Design Haus UK Ltd                                       1
# KINGS SCIENCE ACADEMY                                    1
# Name: Company, Length: 4879, dtype: int64

# %% [markdown]
# Seems there are some minor irregularities like the inconsitent use of "Limited","Ltd" and "LTD".

# %%
# unify all occurences of Ltd

# %% [markdown]
# ### Company
# It is already discovered before that there is large amount of missing values in the `Company` column

# %%
df1.Company.isna().sum()
# Out:
# 3835

# %% [markdown]
# It seems that it is impossible to fill in the name of these companies, but depends on whether it was just a system error or typo, and also regarding different usage of the dataset, it is better we keep this records.

# %% [markdown]
# ### Category

# %%
df1.Category.value_counts()
# Out:
# IT Jobs                             7085
# Healthcare & Nursing Jobs           4334
# Engineering Jobs                    3458
# Accounting & Finance Jobs           3099
# Sales Jobs                          2609
# Hospitality & Catering Jobs         2124
# Teaching Jobs                       1378
# PR, Advertising & Marketing Jobs     990
# Name: Category, dtype: int64

# %% [markdown]
# - No invalid values and no redundance
# - Also no inconsistent represnetation of same value

# %% [markdown]
# ### Salary

# %%
df1["Salary per annum"].unique()
# Out:
# array(['24996', '30000', '27504', ..., '17K', '18264', '40368'], dtype=object)

# %% [markdown]
# There are inconsiten representations of the salary

# %%
p1 = '^\d+$'

# %%
non_numeric_salary = df1['Salary per annum'].apply(lambda x: False if re.match(p1,x) else True )

# %%
inconsis_salary =df1['Salary per annum'][non_numeric_salary];inconsis_salary.value_counts()
# Out:
# 32K                                        7
# 45K                                        5
# 30871.199999999997 - 34120.8               5
# 38K                                        5
# 33253.799999999996 - 36754.200000000004    5
# 35K                                        5
# 37996.2 - 41995.8                          5
# 26K                                        4
# 19K                                        4
# 40K                                        4
# 30K                                        4
# 23K                                        4
# 28500.0 - 31500.0                          4
# 42750.0 - 47250.0                          4
# 24K                                        4
# 20K                                        4
# 47K                                        4
# 52K                                        3
# 22321.2 - 24670.8                          3
# 27553.8 - 30454.2                          3
# 21K                                        3
# 26128.8 - 28879.2                          3
# 55K                                        3
# 52246.2 - 57745.8                          3
# 23746.199999999997 - 26245.800000000003    3
# 50K                                        3
# 25K                                        3
# 15196.199999999999 - 16795.8               3
# 28K                                        3
# 31K                                        2
#                                           ..
# 13497.599999999999 - 14918.400000000001    1
# 80K                                        1
# 29K                                        1
# 23712.0 - 26208.0                          1
# 40846.2 - 45145.8                          1
# 21819.6 - 24116.4                          1
# 19243.2 - 21268.8                          1
# 66496.2 - 73495.8                          1
# 27816.0 - 30744.0                          1
# 85500.0 - 94500.0                          1
# 24646.8 - 27241.2                          1
# 47503.799999999996 - 52504.200000000004    1
# 61753.799999999996 - 68254.2               1
# 49020.0 - 54180.0                          1
# 17K                                        1
# 18K                                        1
# 21375.0 - 23625.0                          1
# 29446.199999999997 - 32545.800000000003    1
# 48336.0 - 53424.0                          1
# 28021.199999999997 - 30970.800000000003    1
# 39K                                        1
# 42K                                        1
# 14614.8 - 16153.2                          1
# 44175.0 - 48825.0                          1
# 19003.8 - 21004.2                          1
# 15891.599999999999 - 17564.4               1
# 30403.8 - 33604.200000000004               1
# 54K                                        1
# 25171.199999999997 - 27820.800000000003    1
# 60K                                        1
# Name: Salary per annum, Length: 101, dtype: int64

# %% [markdown]
# There seems to have two type of invalid representations:
# 1. "90K"
# 2. "21819.6 - 24116.4"
#
# **For the first one we just transfer the str representation to int.**
#
# **For the second one we pick the mean of the range and round them to the nearest integer.**

# %%
#design the regex patterns
p1 = '(\d+)K'#regex for '90K'
p2 = '(\d+\.\d+)\s*-\s*(\d+\.\d+)'#regex for '3333.222 - 34444.333'
p3 = '^\d+$' # regex for normal representation

# %%
#the method for unifying the values of salaries
def unify_salary(sp):
    r1 = re.match(p1,sp)
    r2 = re.match(p2,sp)
    if r1:
        return r1.group(1) + '000'
    if r2:
        return float(r2.group(1))+float(r2.group(2))/2
    if re.match(p3,sp):
        return sp

# %%
df1['Salary per annum'] = df1['Salary per annum'].apply(unify_salary)

# %%
#for space saving, salary won't be that large, so transfer to int32 is enough
df1['Salary per annum'] = df1['Salary per annum'].astype(int);

# %% [markdown]
# Then we need to check if there are semantic errors in the salary column:
# - one error can be the occurence of error or negative number

# %%
df1.shape[0] - (df1['Salary per annum'] <= 0).sum() == df1.shape[0]
# Out:
# True

# %% [markdown]
# Thia proves there is not zero or negative values in the row of `Salary per annum`

# %% [markdown]
# ### SourceName

# %%
df1.SourceName.value_counts()
# Out:
# totaljobs.com                     5335
# cv-library.co.uk                  4207
# careworx.co.uk                    1777
# cwjobs.co.uk                      1202
# staffnurse.com                    1182
# jobsite.co.uk                     1110
# caterer.com                       1047
# fish4.co.uk                        757
# theitjobboard.co.uk                755
# jobserve.com                       717
# jobs.catererandhotelkeeper.com     640
# planetrecruit.com                  460
# rengineeringjobs.com               363
# salestarget.co.uk                  355
# britishjobsonthe.net               332
# jobs.guardian.co.uk                301
# ukstaffsearch.com                  248
# hays.co.uk                         247
# strike-jobs.co.uk                  221
# technojobs.co.uk                   219
# gojobsearch.co.uk                  187
# justengineers.net                  179
# cvbrowser.com                      170
# cityjobs.com                       159
# jobg8.com                          145
# careerbuilder.com                  137
# jobsineducation.co.uk              129
# jobs.newstatesman.com              115
# thecareerengineer.com              113
# london4jobs.co.uk                  112
#                                   ...
# randstadfp.com                      29
# mediaweekjobs.co.uk                 27
# nurseryworldjobs.co.uk              26
# juniorbroker.com                    23
# jobsincredit.com                    21
# actuaryjobs.co.uk                   21
# simplymarketingjobs.co.uk           20
# OilCareers.com                      17
# emptylemon.co.uk                    16
# jobs.chinwag.com                    14
# jobs.planningresource.co.uk         14
# rcnbulletinjobs.co.uk               13
# ifaonlinejobs.co.uk                 13
# eventjobsearch.co.uk                13
# frontofficebanking.com              11
# renewablescareers.com                8
# legalprospects.com                   8
# wikijob.co.uk                        5
# jobsinsocialwork.co.uk               4
# 3desk.com                            4
# jobs.perl.org                        3
# cardandpaymentjobs.com               2
# scotsman.com                         2
# workthing.com                        2
# jobcareer                            1
# admin@caterer.com                    1
# jobs.gponline.com                    1
# monashstudent                        1
# thegraduate.co.uk                    1
# grb.uk.com                           1
# Name: SourceName, Length: 90, dtype: int64

# %% [markdown]
# Seems no explicit issues.

# %% [markdown]
# ### OpenData and CloseDate
# We assume at the first place that the date form is Y-M-D

# %%
df1.OpenDate.head()
# Out:
# 0    20121103T000000
# 1    20130108T150000
# 2    20130726T150000
# 3    20121214T000000
# 4    20131025T000000
# Name: OpenDate, dtype: object

# %% [markdown]
# The result of above cell proves our assumption, so we can start invetigate whether there are issues in the two columns for date.

# %%
p = '\d{4}(\d{2})(\d{2}).(\d{2})(\d{2})(\d{2})'
def is_valid_date(d):
    month_invalid = int(re.match(p,d).group(1)) > 12 
    day_invalid = int(re.match(p,d).group(2)) > 31 #keep it simple fallacious for the moment, for simplicity just assume each month has 31 days
    hr_invalid = int(re.match(p,d).group(3)) > 23
    min_invalid = int(re.match(p,d).group(4)) > 59
    second_invalid = int(re.match(p,d).group(5)) > 59
    if month_invalid or day_invalid or hr_invalid or min_invalid or second_invalid:
        return d
    else:
        return np.nan
    
invalid_open_date = df1.OpenDate.apply(is_valid_date)
invalid_close_date = df1.CloseDate.apply(is_valid_date)

# %%
#test
print(invalid_open_date.dropna().shape, invalid_close_date.dropna().shape)
# Out:
# (10,) (0,)

# %% [markdown]
# indicates there are 10 invalid date
#
# inspect the invalid values

# %%
invalid_series = invalid_open_date.dropna().values

# %%
df1[df1.OpenDate.isin(invalid_series)]
# Out:
#              Id                                              Title  \
# 1102   51593546                       Community Nurse South London
# 2104   61282006                           Deputy Home Care Manager
# 2839   64796836  Technical Tester  Manual, Automation, Java, SQ...
# 5707   66935867  Technical Sales Manager, Pigments Fillers to S...
# 10881  68257270   Desire a Change?  London  ****K Basic  ****K OTE
# 11948  68350622                  Mechanical Design Engineer (HVAC)
# 15353  68671948                                 Investment Analyst
# 22918  69072305                                     Scheme Actuary
# 23007  69079402                Naval architect/structural engineer
# 23169  69080910  MS (Elec biased) Maintenance Engineer / Superv...
#
#                   Location   ContractType   ContractTime  \
# 1102              The City  non_specified  non_specified
# 2104                Barnet  non_specified  non_specified
# 2839                London  non_specified      permanent
# 5707                    UK  non_specified  non_specified
# 10881    South East London  non_specified  non_specified
# 11948         Gainsborough  non_specified      permanent
# 15353             Cheshire  non_specified      permanent
# 22918            Hampshire  non_specified      permanent
# 23007  Newcastle Upon Tyne  non_specified      permanent
# 23169            Harrogate  non_specified      permanent
#
#                       Company                   Category  Salary per annum  \
# 1102                      NaN  Healthcare & Nursing Jobs             29004
# 2104                      NaN  Healthcare & Nursing Jobs             20004
# 2839                      NaN                    IT Jobs             19500
# 5707   Wallace Hind Selection                 Sales Jobs             45000
# 10881      Zest 2 Recruitment                 Sales Jobs             13500
# 11948                     NaN                    IT Jobs             39996
# 15353         Idex Consulting  Accounting & Finance Jobs             24000
# 22918        Sammons Pensions  Accounting & Finance Jobs             54996
# 23007    Workshop Recruitment           Engineering Jobs             33504
# 23169     Jenrick Engineering           Engineering Jobs             17004
#
#                          SourceName         OpenDate        CloseDate
# 1102                 careworx.co.uk  20131803T120000  20130417T120000
# 2104                 careworx.co.uk  20132606T000000  20130710T000000
# 2839            theitjobboard.co.uk  20122003T150000  20120519T150000
# 5707              salestarget.co.uk  20121512T150000  20130213T150000
# 10881             salestarget.co.uk  20133004T150000  20130530T150000
# 11948              technojobs.co.uk  20131908T000000  20131117T000000
# 15353                 totaljobs.com  20121406T120000  20120912T120000
# 22918  professionalpensionsjobs.com  20131509T000000  20131114T000000
# 23007              cv-library.co.uk  20132901T150000  20130429T150000
# 23169              cv-library.co.uk  20132108T120000  20131119T120000

# %% [markdown]
# It seems though these OpenDates are invalid, but if the month and day get reversed they are all valid date.
#
# Thus we decide to reverse them.

# %%
df1.loc[df1.OpenDate.isin(invalid_series), 'OpenDate'] = df1[df1.OpenDate.isin(invalid_series)]['OpenDate'].apply(lambda s: s[:4] + s[6:8] + s[4:6] + s[8:])

# %%
#transform the string representation of date to type datetime for more flexibility
df1[['OpenDate','CloseDate']] = df1[['OpenDate','CloseDate']].apply(lambda x: pd.to_datetime(x))

# %% [markdown]
# Then we need to check semantic errors, which is that that the OpenDate later than the CloseDate

# %%
df1[df1.OpenDate > df1.CloseDate]
# Out:
# Empty DataFrame
# Columns: [Id, Title, Location, ContractType, ContractTime, Company, Category, Salary per annum, SourceName, OpenDate, CloseDate]
# Index: []

# %% [markdown]
# We propose a solution to this semantic error which is reverse the `OpenDate` and the `CloseDate`

# %%
df1_date = df1[['OpenDate','CloseDate']]

# %%
df1[['OpenDate','CloseDate']] = pd.concat([df1_date.min(axis=1), df1_date.max(axis=1)], axis=1)

# %% [markdown]
# ## 3. Summary
# Give a short summary of your work done above, such as your findings.
