# %% [markdown]
# # Exploratory data analysis: Demos

# %% [markdown]
# In this notebook, we study graphical and non graphical EDA.
# ### Part 1: Non-Graphical EDA:
# #### Measures of centeral location:
#     Mean, Median, Mode
# #### Measures for variability:
#     Range, SD, IQR
# #### Correlation

# %% [markdown]
# We can extract most of the basic statistics using describe() function.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()

# %%
df1=sns.load_dataset("titanic")
df1.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df1.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ### Part2: Graphical EDA:
#     * BarPlot,
#     * Line plot
#     * BoxPlot
#     * Histogram
#     * Scatterplot

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Basic Example:

# %%
import random
random.seed(0)
fig = plt.figure(figsize=(60, 40)) 
N = 100
x = range(N)
y1 = [random.randint(0, 50) for i in x]

# %% [markdown]
# ### 1. Bar Plot

# %%
plt.bar([10, 20, 30], [5, 8, 2])
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ### 2. Histogram

# %%
plt.hist(y1)
# Out:
# (array([  6.,  13.,   6.,  13.,  11.,   7.,  13.,  16.,   4.,  11.]),
#  array([  0.,   5.,  10.,  15.,  20.,  25.,  30.,  35.,  40.,  45.,  50.]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### 3. Boxplot

# %%
y_outliers = y1+[-10]
plt.boxplot([y1,y_outliers])
plt.show()

# %% [markdown]
# ### 4. Line plot

# %%
plt.plot(x,y1,'-');

# %% [markdown]
# ### 5. Scatter plot

# %%
plt.plot(x,y1,'.r');

# %% [markdown]
# ## Example 1: Titanic Data

# %% [markdown]
# Load the dataframe

# %%
import pandas as pd
import numpy as np
import seaborn as sns
df1=sns.load_dataset("titanic")

# %%
df1.count()
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %%
# or plot
import matplotlib.pyplot as plt
# %matplotlib inline

df1['sex'].value_counts().plot( kind='bar');

# %%
df1['embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %% [markdown]
# embarked is 'S', 'C', nan, 'Q'
#
# What do the letters mean. How many missing values are there?
#
# Check the wikipedia page to find out that https://en.wikipedia.org/wiki/RMS_Titanic"Southampton... Additional passengers were picked up at Cherbourg and Queenstown."
#
# So that would seem to be the S, 'Southampton'

# %%
df1['embarked'].value_counts() # notice that 'nan' doesn't count or isn't counted
# Out:
# S    644
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
644 + 168 + 77
# Out:
# 889

# %%
# there are two missing?

# %%
df1['fare'].value_counts()
# Out:
# 8.0500      43
# 13.0000     42
# 7.8958      38
# 7.7500      34
# 26.0000     31
# 10.5000     24
# 7.9250      18
# 7.7750      16
# 26.5500     15
# 0.0000      15
# 7.2292      15
# 7.8542      13
# 8.6625      13
# 7.2500      13
# 7.2250      12
# 16.1000      9
# 9.5000       9
# 24.1500      8
# 15.5000      8
# 56.4958      7
# 52.0000      7
# 14.5000      7
# 14.4542      7
# 69.5500      7
# 7.0500       7
# 31.2750      7
# 46.9000      6
# 30.0000      6
# 7.7958       6
# 39.6875      6
#             ..
# 7.1417       1
# 42.4000      1
# 211.5000     1
# 12.2750      1
# 61.1750      1
# 8.4333       1
# 51.4792      1
# 7.8875       1
# 8.6833       1
# 7.5208       1
# 34.6542      1
# 28.7125      1
# 25.5875      1
# 7.7292       1
# 12.2875      1
# 8.6542       1
# 8.7125       1
# 61.3792      1
# 6.9500       1
# 9.8417       1
# 8.3000       1
# 13.7917      1
# 9.4750       1
# 13.4167      1
# 26.3875      1
# 8.4583       1
# 9.8375       1
# 8.3625       1
# 14.1083      1
# 17.4000      1
# Name: fare, Length: 248, dtype: int64

# %%
# look at fares, seems like a total mess
plt.plot(df1['fare']);

# %%
# that's not quite right, it's showing all ~1300 fares left to right
# try another type of plot, histogram, change bins to get different views 

fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist(df1['fare'], bins = 50, range = (df1['fare'].min(),df1['fare'].max()))
plt.title('Fare distribution')
plt.xlabel('Fare')
plt.ylabel('Count of Passengers')
plt.show()

# %%
df1.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df1.boxplot('fare',by='pclass',sym='k.', figsize=(6, 10))

# %%
# just look at fare
bp = df1.boxplot(column='fare',sym='k.')

# %%
# but there are three 'classes', separate them:
df1.boxplot(column='fare', by = 'pclass',sym='k.', figsize=(8, 8))

# %%
# do similarly with ages
fig = plt.figure()
ax = fig.add_subplot(111)
ax.hist(df1['age'], bins = 10, range = (df1['age'].min(),df1['age'].max()))
plt.title('Age distribution')
plt.xlabel('Age')
plt.ylabel('Count of Passengers')
plt.show()
# Out:
# /home/zby0902/anaconda3/envs/5196/lib/python3.6/site-packages/numpy/lib/function_base.py:229: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= mn)
# /home/zby0902/anaconda3/envs/5196/lib/python3.6/site-packages/numpy/lib/function_base.py:230: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= mx)

# %%
# a multiscatter matrix? Not always useful
from pandas.plotting import scatter_matrix

sm = scatter_matrix(df1, alpha=0.2, figsize=(8, 8), diagonal='kde')

# %%
# just to complete the story... what were some of the factors for survival?


ct = pd.crosstab([df1.pclass, df1.sex], df1.survived.astype(bool))
ct.plot(kind='bar', stacked=True, color=['red','blue'], grid=False)

# %% [markdown]
# ### Plotting non-numerical data

# %%
df1['sex'].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
df1['sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
fig, ax = plt.subplots()
df1['sex'].value_counts().plot(ax=ax, kind='bar')

# %%
df1['embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
fig, ax = plt.subplots()
df1['embarked'].value_counts().plot(ax=ax, kind='bar')

# %%
# note that the something appears to be missing, the 'nan' (it's 'Not A Number', not granny)
# do you want to plot nan anyway?

# %%
sum(df1['embarked'].isnull())
# Out:
# 2

# %%
temp = df1['embarked'].value_counts()

# %%
temp
# Out:
# S    644
# C    168
# Q     77
# Name: embarked, dtype: int64

# %%
temp['S']
# Out:
# 644

# %%
temp['NaN'] = sum(df1['embarked'].isnull())

# %%
fig, ax = plt.subplots()
temp.plot(ax=ax, kind='bar')

# %% [markdown]
# ## Example 2

# %% [markdown]
# ### Exploratory Plotting

# %%
import seaborn as sns
# %matplotlib inline
df1 = pd.read_pickle('df1.p')

# %%
sns.distplot(df1['Age'])
# Out:
# /home/zby0902/anaconda3/envs/5196/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(df1['AQ'].map({'high':1,'low':0}))
# Out:
# /home/zby0902/anaconda3/envs/5196/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
df1.plot(x='Years Educ',y='Age',kind='scatter')

# %%
df1.plot(x='Years Educ',y='Age',kind='scatter',color=df1['AQ'].map({'high':1,'low':0}))

# %%
df1.boxplot('Age',by='Gender')

# %%
import matplotlib
matplotlib.style.use('ggplot')

# %%
df1.boxplot('Age',by='Gender')

# %%
a = 1,2,3
b = 4,5,6

# %%
c = zip(a,b)

# %%
for i in c:
    print(i)
# Out:
# (1, 4)
# (2, 5)
# (3, 6)

# %%
[x+y for x,y in c]
# Out:
# [5, 7, 9]

# %%
def x():
    return 1>2 or 3<4 or 5>1

# %%
from math import pi,acos,sqrt

# %%
from decimal import Decimal

# %%
a = Decimal(1.1)
b= sqrt(a*5)

# %%
b = Decimal(b)

# %%
b
# Out:
# Decimal('2.345207879911714865528438167530111968517303466796875')

# %%
type(b*5)
# Out:
# decimal.Decimal
