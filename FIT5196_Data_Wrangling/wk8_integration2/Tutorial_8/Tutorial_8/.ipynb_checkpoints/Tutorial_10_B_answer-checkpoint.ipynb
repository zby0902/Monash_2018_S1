# %% [markdown]
# # Data Integration with Household heating data

# %% [markdown]
# ##  1. Case study: visualizing Household heating data on the map

# %% [markdown]
# Our aim in this tutorial is to visualize the household heating data for each state in USA on a map. We will discuss how to integrate between three different data sources:
# * a basic map of USA (S1),
# * shapefiles of States (S2),
# * and hourse heating data for those regions (S3).
#
# S3 presents household heating by congressional district. Now, our task is to merge the three data set together and generate a map.

# %% [markdown]
# We start first with setting up the environment.
#
# If you use your own laptop in the tutorial, you will need to install the following Python libraries
# * basemap: conda install basemap
# * shapefile: pip install pyshp
#
# In general, there are a couple of simple options for plotting data on maps, i.e., using latitude and longitude. However, if you want to plot on a country you may have to go for the middle or find an actual location
# (e.g. Austin, Texas, USA rather than just USA). There's also a nice example here:
# http://introtopython.org/visualization_earthquakes.html. Instead of using the coordinate values, we can use
# shapefiles that often come as a set, the minimum is .dbf, shp & .shx
#
# ## 2. Examples on the map plotting
#
# ### 2.1 The use of Basemap
#
# The materials in this section are partially based on those from http://vizclass.csc.ncsu.edu/2011/09/tutorial-geographic-data-on-map-with.html.

# %%
from mpl_toolkits.basemap import Basemap 
import matplotlib.pyplot as plt 
import numpy as np  
# %matplotlib inline

# %% [markdown]
# Let's start with a world map by drawing the countries and the coasts.

# %%
# lon_0 is central longitude of robinson projection. 
# resolution = 'c' means use crude resolution coastlines. 
m = Basemap(projection = 'robin', lon_0 = 0, resolution = 'c') 
# draw coastlines, country boundaries, fill continents. 
m.drawcoastlines(color = '#6D5F47', linewidth = .4) 
m.drawcountries(color = '#6D5F47', linewidth = .4)

# %% [markdown]
# Now, we can further add some color to the map. For example, we can change the background color to light blue so that it indicates the ocean.

# %%
# set a background colour = water
# m.drawmapboundary(fill_color='#85A6D9') # using codes or just names:
m.drawmapboundary(fill_color='lightblue')
# draw coastlines, country boundaries, fill continents. 
m.fillcontinents(color = 'white', lake_color = '#85A6D9') 
m.drawcoastlines(color = '#6D5F47', linewidth = .4) 
m.drawcountries(color = '#6D5F47', linewidth = .4)

# %% [markdown]
# We can also draws the lines of longitude and latitude.

# %%
# draw lat/lon grid lines every 30 degrees. 
m.drawmeridians(np.arange(-180, 180, 30), color='#bbbbbb') 
m.drawparallels(np.arange(-90, 90, 30), color='#bbbbbb')
m.fillcontinents(color = 'white', lake_color = '#85A6D9') 
m.drawcoastlines(color = '#6D5F47', linewidth = .4) 
m.drawcountries(color = '#6D5F47', linewidth = .4)

# %% [markdown]
# Now, assume that we are going to draw a map showing the population information of the cities that are given by their coordinates as follows.
# ```python
# lats = [35.69,37.569,19.433,40.809,18.975,-6.175,-23.55,28.61,34.694,31.2]
# lngs = [139.692,126.977,-99.133,-74.02,72.825,106.828,-46.633,77.23,135.502,121.5]
# populations = [32.45,20.55,20.45,19.75,19.2,18.9,18.85,18.6,17.375,16.65] #millions
# ```
#
# The size of the circle is proportional to the population. If the population is less than 19 million, we will use color blue. There are two ways to do this task. One is as follows:

# %%
def get_marker_color(population):
    # Returns green for small earthquakes, yellow for moderate
    #  earthquakes, and red for significant earthquakes.
    if population < 19:
        return ('bo')
    else:
        return ('ro')

plt.figure(figsize = (12,6)) # make it bigger first

m = Basemap(projection = 'robin', lon_0 = 0, resolution = 'c') 
#set a background colour 
m.drawmapboundary(fill_color = '#85A6D9')
m.fillcontinents(color = 'white', lake_color = '#85A6D9') 
m.drawcoastlines(color = '#6D5F47', linewidth = .4) 
m.drawcountries(color = '#6D5F47', linewidth = .4)
m.drawmeridians(np.arange(-180, 180, 30), color = '#bbbbbb') 
m.drawparallels(np.arange(-90, 90, 30), color = '#bbbbbb')
lats = [35.69,37.569,19.433,40.809,18.975,-6.175,-23.55,28.61,34.694,31.2] 
lngs = [139.692,126.977,-99.133,-74.02,72.825,106.828,-46.633,77.23,135.502,121.5] 
populations = [32.45,20.55,20.45,19.75,19.2,18.9,18.85,18.6,17.375,16.65] #millions

for lng, lat, s in zip(lngs, lats, populations):
    x,y = m(lng, lat)
    colour = get_marker_color(s)
    m.plot(x, y, colour, markersize= s, alpha = 0.25 )
 
plt.show()

# %% [markdown]
# The other is

# %%
plt.figure(figsize = (12,6)) # make it bigger first

m = Basemap(projection = 'robin', lon_0 = 0, resolution = 'c') 
#set a background colour 
m.drawmapboundary(fill_color = '#85A6D9')
m.fillcontinents(color = 'white', lake_color = '#85A6D9') 
m.drawcoastlines(color = '#6D5F47', linewidth = .4) 
m.drawcountries(color = '#6D5F47', linewidth = .4)
m.drawmeridians(np.arange(-180, 180, 30), color = '#bbbbbb') 
m.drawparallels(np.arange(-90, 90, 30), color = '#bbbbbb')

df_3 = pd.DataFrame({'lats':[35.69,37.569,19.433,40.809,18.975,-6.175,-23.55,28.61,34.694,31.2],
                     'lngs':[139.692,126.977,-99.133,-74.02,72.825,106.828,-46.633,77.23,135.502,121.5],
                     'populations':[32.45,20.55,20.45,19.75,19.2,18.9,18.85,18.6,17.375,16.65]},
                    columns=['lats','lngs','populations']
                   )

x,y = m(df_3.lngs.values,df_3.lats.values)

m.scatter(x, y,
          s = df_3['populations'].apply(lambda x: x*x),
          marker = 'o', # symbol 
          color = pd.np.where(df_3['populations'] < 19,'blue','red'),
          alpha = 0.25, # transparency 
          zorder = 2, # plotting order 
         )
plt.title('Big Cities (Population)') 
plt.show()

# %% [markdown]
# ### 2.2 The use of Shapefiles
# Based on http://stackoverflow.com/questions/15968762/shapefile-and-matplotlib-plot-polygon-collection-of-shapefile-coordinates

# %%
import numpy
import matplotlib 
# %matplotlib inline
import shapefile
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection

# %% [markdown]
# The Shapefile format is a popular Geographic Information System vector data format created by Esri. For more information about this format please read the well-written “ESRI Shapefile Technical Description - July 1998” located at http://www.esri.com/library/whitepapers/pdfs/shapefile.pdf.Essentially, Shapefiles encode points, lines, curves, and polygons. This is useful for mapping applications where you need to represent county lines, major highways, lakes, etc.

# %%
sf = shapefile.Reader("world_countries_boundary_file_world_2002") # note, no suffix, all 3 files are used
recs = sf.records()
shapes = sf.shapes()
recs
# Out:
# [['Afghanistan',
#   'AFG',
#   'AF',
#   65209,
#   'Afghanistan',
#   25067407,
#   'Asia',
#   'AFG',
#   'Afghanistan'],
#  ['Albania',
#   'ALB',
#   'AL',
#   2740,
#   'Albania',
#   3153731,
#   'Europe',
#   'ALB',
#   'Albania'],
#  ['Algeria',
#   'DZA',
#   'DZ',
#   238174,
#   'Algeria',
#   32854159,
#   'NorthAfrica',
#   'DZA',
#   'Algeria'],
#  ['Andorra', 'AND', 'AD', 0, 'Andorra', 73483, 'Europe', 'AND', 'Andorra'],
#  ['Angola',
#   'AGO',
#   'AO',
#   124670,
#   'Angola',
#   16095214,
#   'Sub Saharan Africa',
#   'AGO',
#   'Angola'],
#  ['Antarctica',
#   'AQ',
#   'ATA',
#   0,
#   'Antarctica',
#   0,
#   'Antarctica',
#   'ATA',
#   'Antarctica'],
#  ['Antigua and Barbuda',
#   'ATG',
#   'AG',
#   44,
#   'Antigua and Barbuda',
#   83039,
#   'Caribbean',
#   'ATG',
#   'Antigua and Barbuda'],
#  ['Argentina',
#   'ARG',
#   'AR',
#   273669,
#   'Argentina',
#   38747148,
#   'Latin America',
#   'ARG',
#   'Argentina'],
#  ['Armenia', 'ARM', 'AM', 2820, 'Armenia', 3017661, 'Asia', 'ARM', 'Armenia'],
#  ['Australia',
#   'AUS',
#   'AU',
#   768230,
#   'Australia',
#   20310208,
#   'Australia',
#   'AUS',
#   'Australia'],
#  ['Austria',
#   'AUT',
#   'AT',
#   8245,
#   'Austria',
#   8291979,
#   'Europe',
#   'AUT',
#   'Austria'],
#  ['Azerbaijan',
#   'AZE',
#   'AZ',
#   8260,
#   'Azerbaijan',
#   8352021,
#   'Asia',
#   'AZE',
#   'Azerbaijan'],
#  ['Bahamas, The',
#   'BHS',
#   'BS',
#   1001,
#   'Bahamas, The',
#   323295,
#   'Caribbean',
#   'BHS',
#   'Bahamas'],
#  ['Bahrain', 'BHR', 'BH', 71, 'Bahrain', 724788, 'Asia', 'BHR', 'Bahrain'],
#  ['Bangladesh',
#   'BGD',
#   'BD',
#   13017,
#   'Bangladesh',
#   15328112,
#   'Asia',
#   'BGD',
#   'Bangladesh'],
#  ['Barbados',
#   'BRB',
#   'BB',
#   43,
#   'Barbados',
#   291933,
#   'Caribbean',
#   'BRB',
#   'Barbados'],
#  ['Belgium', 'BEL', 'BE', 0, 'Belgium', 10398049, 'Europe', 'BEL', 'Belgium'],
#  ['Belize',
#   'BLZ',
#   'BZ',
#   2281,
#   'Belize',
#   275546,
#   'Latin America',
#   'BLZ',
#   'Belize'],
#  ['Benin',
#   'BEN',
#   'BJ',
#   11062,
#   'Benin',
#   8490301,
#   'Sub Saharan Africa',
#   'BEN',
#   'Benin'],
#  ['Bermuda',
#   'BMU',
#   'BM',
#   5,
#   'Bermuda',
#   64174,
#   'North America',
#   'BMU',
#   'Bermuda'],
#  ['Bhutan', 'BTN', 'BT', 4700, 'Bhutan', 637013, 'Asia', 'BTN', 'Bhutan'],
#  ['Bolivia',
#   'BOL',
#   'BO',
#   108438,
#   'Bolivia',
#   9182015,
#   'Latin America',
#   'BOL',
#   'Bolivia'],
#  ['Bosnia and Herzegovina',
#   'BIH',
#   'BA',
#   5120,
#   'Bosnia and Herzegovina',
#   3915238,
#   'Europe',
#   'BIH',
#   'Bosnia and Herzegovina'],
#  ['Botswana',
#   'BWA',
#   'BW',
#   56673,
#   'Botswana',
#   1835938,
#   'Sub Saharan Africa',
#   'BWA',
#   'Botswana'],
#  ['Brazil',
#   'BRA',
#   'BR',
#   845942,
#   'Brazil',
#   186830759,
#   'Latin America',
#   'BRA',
#   'Brazil'],
#  ['Brunei',
#   'BRN',
#   'BN',
#   527,
#   'Brunei',
#   373831,
#   'Asia',
#   'BRN',
#   'Brunei Darussalam'],
#  ['Bulgaria',
#   'BGR',
#   'BG',
#   11063,
#   'Bulgaria',
#   7744591,
#   'Europe',
#   'BGR',
#   'Bulgaria'],
#  ['Burkina Faso',
#   'BFA',
#   'BF',
#   27360,
#   'Burkina Faso',
#   13933363,
#   'Sub Saharan Africa',
#   'BFA',
#   'Burkina Faso'],
#  ['Burundi',
#   'BDI',
#   'BI',
#   2568,
#   'Burundi',
#   7858791,
#   'Sub Saharan Africa',
#   'BDI',
#   'Burundi'],
#  ['Byelarus',
#   'BLR',
#   'BY',
#   20748,
#   'Byelarus',
#   9795287,
#   'Europe',
#   'BLR',
#   'Belarus'],
#  ['Cambodia',
#   'KHM',
#   'KH',
#   17652,
#   'Cambodia',
#   13955507,
#   'Asia',
#   'KHM',
#   'Cambodia'],
#  ['Cameroon',
#   'CMR',
#   'CM',
#   46540,
#   'Cameroon',
#   17795149,
#   'Sub Saharan Africa',
#   'CMR',
#   'Cameroon'],
#  ['Canada',
#   'CAN',
#   'CA',
#   909351,
#   'Canada',
#   32270507,
#   'North America',
#   'CAN',
#   'Canada'],
#  ['Cape Verde',
#   'CPV',
#   'CV',
#   403,
#   'Cape Verde',
#   506807,
#   'Sub Saharan Africa',
#   'CPV',
#   'Cape Verde'],
#  ['Central African Republic',
#   'CAF',
#   'CF',
#   62298,
#   'Central African Republic',
#   4191429,
#   'Sub Saharan Africa',
#   'CAF',
#   'Central African Republic'],
#  ['Chad',
#   'TCD',
#   'TD',
#   125920,
#   'Chad',
#   10145609,
#   'Sub Saharan Africa',
#   'TCD',
#   'Chad'],
#  ['Chile',
#   'CHL',
#   'CL',
#   74880,
#   'Chile',
#   16295102,
#   'Latin America',
#   'CHL',
#   'Chile'],
#  ['China', 'CHN', 'CN', 932743, 'China', 1312978855, 'Asia', 'CHN', 'China'],
#  ['Colombia',
#   'COL',
#   'CO',
#   103870,
#   'Colombia',
#   4494579,
#   'Latin America',
#   'COL',
#   'Colombia'],
#  ['Comoros',
#   'COM',
#   'KM',
#   223,
#   'Comoros',
#   797902,
#   'Sub Saharan Africa',
#   'COM',
#   'Comoros'],
#  ['Congo',
#   'COG',
#   'CG',
#   34150,
#   'Congo',
#   3609851,
#   'Sub Saharan Africa',
#   'COG',
#   'Congo'],
#  ['Costa Rica',
#   'CRI',
#   'CR',
#   5106,
#   'Costa Rica',
#   4327228,
#   'Latin America',
#   'CRI',
#   'Costa Rica'],
#  ['Croatia', 'HRV', 'HR', 5592, 'Croatia', 455149, 'Europe', 'HRV', 'Croatia'],
#  ['Cuba', 'CUB', 'CU', 10982, 'Cuba', 11259905, 'Caribbean', 'CUB', 'Cuba'],
#  ['Cyprus', 'CYP', 'CY', 924, 'Cyprus', 836321, 'Asia', 'CYP', 'Cyprus'],
#  ['Czech Republic',
#   'CZE',
#   'CZ',
#   7727,
#   'Czech Republic',
#   10191762,
#   'Europe',
#   'CZE',
#   'Czech Republic'],
#  ['Denmark',
#   'DNK',
#   'DK',
#   4243,
#   'Denmark',
#   5416945,
#   'Europe',
#   'DNK',
#   'Denmark'],
#  ['Djibouti',
#   'DJI',
#   'DJ',
#   2318,
#   'Djibouti',
#   804206,
#   'Sub Saharan Africa',
#   'DJI',
#   'Djibouti'],
#  ['Dominica',
#   'DMA',
#   'DM',
#   75,
#   'Dominica',
#   67827,
#   'Caribbean',
#   'DMA',
#   'Dominica'],
#  ['Dominican Republic',
#   'DOM',
#   'DO',
#   4838,
#   'Dominican Republic',
#   9469601,
#   'Caribbean',
#   'DOM',
#   'Dominican Republic'],
#  ['Ecuador',
#   'ECU',
#   'EC',
#   27684,
#   'Ecuador',
#   13060993,
#   'Latin America',
#   'ECU',
#   'Ecuador'],
#  ['Egypt',
#   'EGY',
#   'EG',
#   99545,
#   'Egypt',
#   72849793,
#   'NorthAfrica',
#   'EGY',
#   'Egypt'],
#  ['El Salvador',
#   'SLV',
#   'SV',
#   2072,
#   'El Salvador',
#   6668356,
#   'Latin America',
#   'SLV',
#   'El Salvador'],
#  ['Equatorial Guinea',
#   'GNQ',
#   'GQ',
#   2805,
#   'Equatorial Guinea',
#   484098,
#   'Sub Saharan Africa',
#   'GNQ',
#   'Equatorial Guinea'],
#  ['Eritrea',
#   'ERI',
#   'ER',
#   10100,
#   'Eritrea',
#   4526722,
#   'Sub Saharan Africa',
#   'ERI',
#   'Eritrea'],
#  ['Estonia',
#   'EST',
#   'EE',
#   4239,
#   'Estonia',
#   1344312,
#   'Europe',
#   'EST',
#   'Estonia'],
#  ['Ethiopia',
#   'ETH',
#   'ET',
#   100000,
#   'Ethiopia',
#   78985857,
#   'Sub Saharan Africa',
#   'ETH',
#   'Ethiopia'],
#  ['Falkland Islands (Islas Malvinas)',
#   'FLK',
#   'FK',
#   1217,
#   'Falkland Islands (Islas Malvinas)',
#   2975,
#   'Latin America',
#   'FLK',
#   'Falkland Islands (Malvinas)'],
#  ['Faroe Islands',
#   'FRO',
#   'FO',
#   0,
#   'Faroe Islands',
#   48205,
#   'Europe',
#   'FRO',
#   'Faroe Islands'],
#  ['Fiji', 'FJI', 'FJ', 1827, 'Fiji', 828046, 'Asia', 'FJI', 'Fiji'],
#  ['Finland',
#   'FIN',
#   'FI',
#   30459,
#   'Finland',
#   5246004,
#   'Europe',
#   'FIN',
#   'Finland'],
#  ['France', 'FRA', 'FR', 55010, 'France', 60990544, 'Europe', 'FRA', 'France'],
#  ['French Guiana',
#   'GUF',
#   'GF',
#   8815,
#   'French Guiana',
#   192099,
#   'Latin America',
#   'GUF',
#   'French Guiana'],
#  ['French Polynesia',
#   'PYF',
#   'PF',
#   366,
#   'French Polynesia',
#   255632,
#   'Pacific',
#   'PYF',
#   'French Polynesia'],
#  ['Gabon',
#   'GAB',
#   'GA',
#   25767,
#   'Gabon',
#   1290693,
#   'Sub Saharan Africa',
#   'GAB',
#   'Gabon'],
#  ['Gambia, The',
#   'GMB',
#   'GM',
#   1000,
#   'Gambia, The',
#   1617029,
#   'Sub Saharan Africa',
#   'GMB',
#   'Gambia'],
#  ['Gaza Strip',
#   'PSE',
#   'PS',
#   0,
#   'Gaza Strip',
#   3762005,
#   'Asia',
#   'PSE',
#   'Palestine'],
#  ['Georgia', 'GEO', 'GE', 6949, 'Georgia', 4473409, 'Asia', 'GEO', 'Georgia'],
#  ['Germany',
#   'DEU',
#   'DE',
#   34895,
#   'Germany',
#   82652369,
#   'Europe',
#   'DEU',
#   'Germany'],
#  ['Ghana',
#   'GHA',
#   'GH',
#   22754,
#   'Ghana',
#   2253501,
#   'Sub Saharan Africa',
#   'GHA',
#   'Ghana'],
#  ['Greece', 'GRC', 'GR', 12890, 'Greece', 11099737, 'Europe', 'GRC', 'Greece'],
#  ['Greenland',
#   'GRL',
#   'GL',
#   41045,
#   'Greenland',
#   57475,
#   'North America',
#   'GRL',
#   'Greenland'],
#  ['Grenada',
#   'GRD',
#   'GD',
#   34,
#   'Grenada',
#   105237,
#   'Caribbean',
#   'GRD',
#   'Grenada'],
#  ['Guadeloupe',
#   'GLP',
#   'GP',
#   169,
#   'Guadeloupe',
#   438403,
#   'Caribbean',
#   'GLP',
#   'Guadeloupe'],
#  ['Guatemala',
#   'GTM',
#   'GT',
#   10843,
#   'Guatemala',
#   12709564,
#   'Latin America',
#   'GTM',
#   'Guatemala'],
#  ['Guinea',
#   'GIN',
#   'GN',
#   24572,
#   'Guinea',
#   9002656,
#   'Sub Saharan Africa',
#   'GIN',
#   'Guinea'],
#  ['Guinea-Bissau',
#   'GNB',
#   'GW',
#   2812,
#   'Guinea-Bissau',
#   1596929,
#   'Sub Saharan Africa',
#   'GNB',
#   'Guinea-Bissau'],
#  ['Guyana',
#   'GUY',
#   'GY',
#   19685,
#   'Guyana',
#   739472,
#   'Latin America',
#   'GUY',
#   'Guyana'],
#  ['Haiti', 'HTI', 'HT', 2756, 'Haiti', 9296291, 'Caribbean', 'HTI', 'Haiti'],
#  ['Honduras',
#   'HND',
#   'HN',
#   11189,
#   'Honduras',
#   683411,
#   'Latin America',
#   'HND',
#   'Honduras'],
#  ['Hong Kong',
#   '                                                                                ',
#   '                                                                                ',
#   0,
#   '                                                                                ',
#   0,
#   'Asia',
#   '                                                                                ',
#   '                                                                                '],
#  ['Hungary',
#   'HUN',
#   'HU',
#   9210,
#   'Hungary',
#   10086387,
#   'Europe',
#   'HUN',
#   'Hungary'],
#  ['Iceland',
#   'ISL',
#   'IS',
#   10025,
#   'Iceland',
#   295732,
#   'Europe',
#   'ISL',
#   'Iceland'],
#  ['India', 'IND', 'IN', 297319, 'India', 1134403141, 'Asia', 'IND', 'India'],
#  ['Indonesia',
#   'IDN',
#   'ID',
#   181157,
#   'Indonesia',
#   226063044,
#   'Asia',
#   'IDN',
#   'Indonesia'],
#  ['Iran',
#   'IRN',
#   'IR',
#   163620,
#   'Iran',
#   69420607,
#   'Asia',
#   'IRN',
#   'Iran (Islamic Republic of)'],
#  ['Iraq', 'IRQ', 'IQ', 43737, 'Iraq', 27995984, 'Asia', 'IRQ', 'Iraq'],
#  ['Iraq-Saudi Arabia Neutral Zone',
#   '                                                                                ',
#   '                                                                                ',
#   0,
#   '                                                                                ',
#   0,
#   'Asia',
#   '                                                                                ',
#   '                                                                                '],
#  ['Ireland',
#   'IRL',
#   'IE',
#   6889,
#   'Ireland',
#   4143294,
#   'Europe',
#   'IRL',
#   'Ireland'],
#  ['Isle of Man',
#   'IMY',
#   '                                                                                ',
#   0,
#   'Isle of Man',
#   78357,
#   'Europe',
#   'XIM',
#   'Isle of Man'],
#  ['Israel', 'ISR', 'IL', 2171, 'Israel', 6692037, 'Asia', 'ISR', 'Israel'],
#  ['Italy', 'ITA', 'IT', 29411, 'Italy', 5864636, 'Europe', 'ITA', 'Italy'],
#  ['Ivory Coast',
#   'CIV',
#   'CI',
#   31800,
#   'Ivory Coast',
#   18584701,
#   'Sub Saharan Africa',
#   'CIV',
#   "Cote d'Ivoire"],
#  ['Jamaica',
#   'JAM',
#   'JM',
#   1083,
#   'Jamaica',
#   2682469,
#   'Caribbean',
#   'JAM',
#   'Jamaica'],
#  ['Jan Mayen', 'SJM', 'SJ', 0, 'Jan Mayen', 0, 'Europe', 'SJM', 'Svalbard'],
#  ['Japan', 'JPN', 'JP', 36450, 'Japan', 127896740, 'Asia', 'JPN', 'Japan'],
#  ['Jordan', 'JOR', 'JO', 8824, 'Jordan', 5544066, 'Asia', 'JOR', 'Jordan'],
#  ['Kazakhstan',
#   'KAZ',
#   'KZ',
#   269970,
#   'Kazakhstan',
#   15210609,
#   'Asia',
#   'KAZ',
#   'Kazakhstan'],
#  ['Kenya',
#   'KEN',
#   'KE',
#   56914,
#   'Kenya',
#   35598952,
#   'Sub Saharan Africa',
#   'KEN',
#   'Kenya'],
#  ['Kerguelen',
#   '                                                                                ',
#   '                                                                                ',
#   0,
#   '                                                                                ',
#   0,
#   'Antarctica',
#   '                                                                                ',
#   '                                                                                '],
#  ['Kiribati', 'KIR', 'KI', 73, 'Kiribati', 92003, 'Asia', 'KIR', 'Kiribati'],
#  ['Korea, Peoples Republic of',
#   'PRK',
#   'KP',
#   12041,
#   'Korea, Peoples Republic of',
#   23615611,
#   'Asia',
#   'PRK',
#   "Korea, Democratic People's Republic of"],
#  ['Korea, Republic of',
#   'KOR',
#   'KR',
#   9873,
#   'Korea, Republic of',
#   47869837,
#   'Asia',
#   'KOR',
#   'Korea, Republic of'],
#  ['Kuwait', 'KWT', 'KW', 1782, 'Kuwait', 2700, 'Asia', 'KWT', 'Kuwait'],
#  ['Kyrgyzstan',
#   'KGZ',
#   'KG',
#   19180,
#   'Kyrgyzstan',
#   5203547,
#   'Asia',
#   'KGZ',
#   'Kyrgyzstan'],
#  ['Laos',
#   'LAO',
#   'LA',
#   23080,
#   'Laos',
#   566391,
#   'Asia',
#   'LAO',
#   "Lao People's Democratic Republic"],
#  ['Latvia', 'LVA', 'LV', 6205, 'Latvia', 2301793, 'Europe', 'LVA', 'Latvia'],
#  ['Lebanon', 'LBN', 'LB', 1023, 'Lebanon', 401074, 'Asia', 'LBN', 'Lebanon'],
#  ['Lesotho',
#   'LSO',
#   'LS',
#   3035,
#   'Lesotho',
#   1980831,
#   'Sub Saharan Africa',
#   'LSO',
#   'Lesotho'],
#  ['Liberia',
#   'LBR',
#   'LR',
#   9632,
#   'Liberia',
#   3441796,
#   'Sub Saharan Africa',
#   'LBR',
#   'Liberia'],
#  ['Libya',
#   'LBY',
#   'LY',
#   175954,
#   'Libya',
#   5918217,
#   'NorthAfrica',
#   'LBY',
#   'Libyan Arab Jamahiriya'],
#  ['Liechtenstein',
#   'LIE',
#   'LI',
#   16,
#   'Liechtenstein',
#   34598,
#   'Europe',
#   'LIE',
#   'Liechtenstein'],
#  ['Lithuania',
#   'LTU',
#   'LT',
#   6268,
#   'Lithuania',
#   3425077,
#   'Europe',
#   'LTU',
#   'Lithuania'],
#  ['Luxembourg',
#   'LUX',
#   'LU',
#   0,
#   'Luxembourg',
#   456613,
#   'Europe',
#   'LUX',
#   'Luxembourg'],
#  ['Macau',
#   '                                                                                ',
#   '                                                                                ',
#   0,
#   'Macau',
#   47309,
#   'Asia',
#   'MAC',
#   'Macau'],
#  ['Macedonia',
#   'MKD',
#   'MK',
#   2543,
#   'Macedonia',
#   2033655,
#   'Europe',
#   'MKD',
#   'The former Yugoslav Republic of Macedonia'],
#  ['Madagascar',
#   'MDG',
#   'MG',
#   58154,
#   'Madagascar',
#   18642586,
#   'Sub Saharan Africa',
#   'MDG',
#   'Madagascar'],
#  ['Malawi',
#   'MWI',
#   'MW',
#   9408,
#   'Malawi',
#   13226091,
#   'Sub Saharan Africa',
#   'MWI',
#   'Malawi'],
#  ['Malaysia',
#   'MYS',
#   'MY',
#   32855,
#   'Malaysia',
#   25652985,
#   'Asia',
#   'MYS',
#   'Malaysia'],
#  ['Maldives',
#   'MDV',
#   'MV',
#   30,
#   'Maldives',
#   295297,
#   'Pacific',
#   'MDV',
#   'Maldives'],
#  ['Mali',
#   'MLI',
#   'ML',
#   122019,
#   'Mali',
#   1161109,
#   'Sub Saharan Africa',
#   'MLI',
#   'Mali'],
#  ['Malta', 'MLT', 'MT', 32, 'Malta', 402617, 'Pacific', 'MLT', 'Malta'],
#  ['Martinique',
#   'MTQ',
#   'MQ',
#   106,
#   'Martinique',
#   395896,
#   'Caribbean',
#   'MTQ',
#   'Martinique'],
#  ['Mauritania',
#   'MRT',
#   'MR',
#   102522,
#   'Mauritania',
#   2963105,
#   'Sub Saharan Africa',
#   'MRT',
#   'Mauritania'],
#  ['Mauritius',
#   'MUS',
#   'MU',
#   203,
#   'Mauritius',
#   1241173,
#   'Sub Saharan Africa',
#   'MUS',
#   'Mauritius'],
#  ['Mexico',
#   'MEX',
#   'MX',
#   190869,
#   'Mexico',
#   104266392,
#   'Latin America',
#   'MEX',
#   'Mexico'],
#  ['Moldova',
#   'MDA',
#   'MD',
#   3288,
#   'Moldova',
#   3876661,
#   'Europe',
#   'MDA',
#   'Republic of Moldova'],
#  ['Monaco', 'MCO', 'MC', 0, 'Monaco', 325, 'Europe', 'MCO', 'Monaco'],
#  ['Mongolia',
#   'MNG',
#   'MN',
#   156650,
#   'Mongolia',
#   2580704,
#   'Asia',
#   'MNG',
#   'Mongolia'],
#  ['Montenegro',
#   'MNE',
#   'ME',
#   0,
#   'Montenegro',
#   607969,
#   'Europe',
#   'MNE',
#   'Montenegro'],
#  ['Morocco',
#   'MAR',
#   'MA',
#   44630,
#   'Morocco',
#   30494991,
#   'NorthAfrica',
#   'MAR',
#   'Morocco'],
#  ['Mozambique',
#   'MOZ',
#   'MZ',
#   78409,
#   'Mozambique',
#   20532675,
#   'Sub Saharan Africa',
#   'MOZ',
#   'Mozambique'],
#  ['Myanmar (Burma)',
#   'MMR',
#   'MM',
#   65755,
#   'Myanmar (Burma)',
#   47967266,
#   'Asia',
#   'MMR',
#   'Burma'],
#  ['Namibia',
#   'NAM',
#   'NA',
#   82329,
#   'Namibia',
#   2019677,
#   'Sub Saharan Africa',
#   'NAM',
#   'Namibia'],
#  ['Nepal', 'NPL', 'NP', 14300, 'Nepal', 27093656, 'Asia', 'NPL', 'Nepal'],
#  ['Netherlands',
#   'NLD',
#   'NL',
#   3388,
#   'Netherlands',
#   1632769,
#   'Europe',
#   'NLD',
#   'Netherlands'],
#  ['New Caledonia',
#   'NCL',
#   'NC',
#   1828,
#   'New Caledonia',
#   234185,
#   'Asia',
#   'NCL',
#   'New Caledonia'],
#  ['New Zealand',
#   'NZL',
#   'NZ',
#   26799,
#   'New Zealand',
#   4097112,
#   'Australia',
#   'NZL',
#   'New Zealand'],
#  ['Nicaragua',
#   'NIC',
#   'NI',
#   12140,
#   'Nicaragua',
#   5462539,
#   'Latin America',
#   'NIC',
#   'Nicaragua'],
#  ['Niger',
#   'NER',
#   'NE',
#   126670,
#   'Niger',
#   1326419,
#   'Sub Saharan Africa',
#   'NER',
#   'Niger'],
#  ['Nigeria',
#   'NGA',
#   'NG',
#   91077,
#   'Nigeria',
#   141356083,
#   'Sub Saharan Africa',
#   'NGA',
#   'Nigeria'],
#  ['Northern Mariana Islands',
#   'MNP',
#   'MP',
#   0,
#   'Northern Mariana Islands',
#   80258,
#   'Pacific',
#   'MNP',
#   'Northern Mariana Islands'],
#  ['Norway', 'NOR', 'NO', 30625, 'Norway', 4638836, 'Europe', 'NOR', 'Norway'],
#  ['Oman', 'OMN', 'OM', 30950, 'Oman', 2507042, 'Asia', 'OMN', 'Oman'],
#  ['Pakistan',
#   'PAK',
#   'PK',
#   77088,
#   'Pakistan',
#   158080591,
#   'Asia',
#   'PAK',
#   'Pakistan'],
#  ['Panama',
#   'PAN',
#   'PA',
#   7443,
#   'Panama',
#   3231502,
#   'Latin America',
#   'PAN',
#   'Panama'],
#  ['Papua New Guinea',
#   'PNG',
#   'PG',
#   45286,
#   'Papua New Guinea',
#   6069715,
#   'Asia',
#   'PNG',
#   'Papua New Guinea'],
#  ['Paraguay',
#   'PRY',
#   'PY',
#   39730,
#   'Paraguay',
#   5904342,
#   'Latin America',
#   'PRY',
#   'Paraguay'],
#  ['Peru',
#   'PER',
#   'PE',
#   128000,
#   'Peru',
#   27274266,
#   'Latin America',
#   'PER',
#   'Peru'],
#  ['Philippines',
#   'PHL',
#   'PH',
#   29817,
#   'Philippines',
#   84566163,
#   'Asia',
#   'PHL',
#   'Philippines'],
#  ['Poland', 'POL', 'PL', 30629, 'Poland', 38195558, 'Europe', 'POL', 'Poland'],
#  ['Portugal',
#   'PRT',
#   'PT',
#   9150,
#   'Portugal',
#   10528226,
#   'Europe',
#   'PRT',
#   'Portugal'],
#  ['Puerto Rico',
#   'PRI',
#   'PR',
#   887,
#   'Puerto Rico',
#   3946779,
#   'Caribbean',
#   'PRI',
#   'Puerto Rico'],
#  ['Qatar', 'QAT', 'QA', 1100, 'Qatar', 796186, 'Asia', 'QAT', 'Qatar'],
#  ['Reunion',
#   'REU',
#   'RE',
#   250,
#   'Reunion',
#   785159,
#   'Sub Saharan Africa',
#   'REU',
#   'Reunion'],
#  ['Romania',
#   'ROU',
#   'RO',
#   22987,
#   'Romania',
#   21627557,
#   'Europe',
#   'ROM',
#   'Romania'],
#  ['Russia',
#   'RUS',
#   'RU',
#   1638094,
#   'Russia',
#   143953092,
#   'Europe',
#   'RUS',
#   'Russia'],
#  ['Rwanda',
#   'RWA',
#   'RW',
#   2467,
#   'Rwanda',
#   9233793,
#   'Sub Saharan Africa',
#   'RWA',
#   'Rwanda'],
#  ['San Marino',
#   'SMR',
#   'SM',
#   0,
#   'San Marino',
#   30214,
#   'Europe',
#   'SMR',
#   'San Marino'],
#  ['Sao Tome and Principe',
#   'STP',
#   'ST',
#   96,
#   'Sao Tome and Principe',
#   152622,
#   'Sub Saharan Africa',
#   'STP',
#   'Sao Tome and Principe'],
#  ['Saudi Arabia',
#   'SAU',
#   'SA',
#   214969,
#   'Saudi Arabia',
#   2361236,
#   'Asia',
#   'SAU',
#   'Saudi Arabia'],
#  ['Senegal',
#   'SEN',
#   'SN',
#   19253,
#   'Senegal',
#   1177034,
#   'Sub Saharan Africa',
#   'SEN',
#   'Senegal'],
#  ['Seychelles',
#   'SYC',
#   'SC',
#   46,
#   'Seychelles',
#   85532,
#   'Sub Saharan Africa',
#   'SYC',
#   'Seychelles'],
#  ['Sierra Leone',
#   'SLE',
#   'SL',
#   7162,
#   'Sierra Leone',
#   5586403,
#   'Sub Saharan Africa',
#   'SLE',
#   'Sierra Leone'],
#  ['Singapore',
#   'SGP',
#   'SG',
#   67,
#   'Singapore',
#   4327468,
#   'Pacific',
#   'SGP',
#   'Singapore'],
#  ['Slovakia',
#   'SVK',
#   'SK',
#   4808,
#   'Slovakia',
#   5386995,
#   'Europe',
#   'SVK',
#   'Slovakia'],
#  ['Slovenia',
#   'SVN',
#   'SI',
#   2014,
#   'Slovenia',
#   1999425,
#   'Europe',
#   'SVN',
#   'Slovenia'],
#  ['Solomon Islands',
#   'SLB',
#   'SB',
#   2799,
#   'Solomon Islands',
#   472419,
#   'Asia',
#   'SLB',
#   'Solomon Islands'],
#  ['Somalia',
#   'SOM',
#   'SO',
#   62734,
#   'Somalia',
#   8196395,
#   'Sub Saharan Africa',
#   'SOM',
#   'Somalia'],
#  ['South Africa',
#   'ZAF',
#   'ZA',
#   121447,
#   'South Africa',
#   47938663,
#   'Sub Saharan Africa',
#   'ZAF',
#   'South Africa'],
#  ['Spain', 'ESP', 'ES', 49904, 'Spain', 43397491, 'Europe', 'ESP', 'Spain'],
#  ['Sri Lanka',
#   'LKA',
#   'LK',
#   6463,
#   'Sri Lanka',
#   19120763,
#   'Asia',
#   'LKA',
#   'Sri Lanka'],
#  ['St. Christopher-Nevis',
#   '                                                                                ',
#   '                                                                                ',
#   0,
#   '                                                                                ',
#   0,
#   'Caribbean',
#   '                                                                                ',
#   '                                                                                '],
#  ['St. Lucia',
#   'LCA',
#   'LC',
#   61,
#   'St. Lucia',
#   16124,
#   'Caribbean',
#   'LCA',
#   'Saint Lucia'],
#  ['St. Vincent and the Grenadines',
#   'VCT',
#   'VC',
#   39,
#   'St. Vincent and the Grenadines',
#   119137,
#   'Caribbean',
#   'VCT',
#   'Saint Vincent and the Grenadines'],
#  ['Sudan',
#   'SDN',
#   'SD',
#   237600,
#   'Sudan',
#   36899747,
#   'Sub Saharan Africa',
#   'SDN',
#   'Sudan'],
#  ['Suriname',
#   'SUR',
#   'SR',
#   15600,
#   'Suriname',
#   452468,
#   'Latin America',
#   'SUR',
#   'Suriname'],
#  ['Svalbard',
#   '                                                                                ',
#   '                                                                                ',
#   0,
#   'Svalbard',
#   0,
#   'Europe',
#   'SJM',
#   'Svalbard'],
#  ['Swaziland',
#   'SWZ',
#   'SZ',
#   1720,
#   'Swaziland',
#   1124529,
#   'Sub Saharan Africa',
#   'SWZ',
#   'Swaziland'],
#  ['Sweden', 'SWE', 'SE', 41033, 'Sweden', 9038049, 'Europe', 'SWE', 'Sweden'],
#  ['Switzerland',
#   'CHE',
#   'CH',
#   4000,
#   'Switzerland',
#   7424389,
#   'Europe',
#   'CHE',
#   'Switzerland'],
#  ['Syria',
#   'SYR',
#   'SY',
#   18378,
#   'Syria',
#   18893881,
#   'Asia',
#   'SYR',
#   'Syrian Arab Republic'],
#  ['Taiwan',
#   '                                                                                ',
#   '                                                                                ',
#   0,
#   'Taiwan',
#   0,
#   'Asia',
#   'TWN',
#   'Taiwan'],
#  ['Tajikistan',
#   'TJK',
#   'TJ',
#   13996,
#   'Tajikistan',
#   6550213,
#   'Asia',
#   'TJK',
#   'Tajikistan'],
#  ['Tanzania, United Republic of',
#   'TZA',
#   'TZ',
#   88359,
#   'Tanzania, United Republic of',
#   38477873,
#   'Sub Saharan Africa',
#   'TZA',
#   'United Republic of Tanzania'],
#  ['Thailand',
#   'THA',
#   'TH',
#   51089,
#   'Thailand',
#   63002911,
#   'Asia',
#   'THA',
#   'Thailand'],
#  ['Timor-Leste',
#   'TLS',
#   'TL',
#   1487,
#   'Timor-Leste',
#   1067285,
#   'Asia',
#   'TLD',
#   'Timor-Leste'],
#  ['Togo',
#   'TGO',
#   'TG',
#   5439,
#   'Togo',
#   6238572,
#   'Sub Saharan Africa',
#   'TGO',
#   'Togo'],
#  ['Tonga', 'TON', 'TO', 72, 'Tonga', 99361, 'Pacific', 'TON', 'Tonga'],
#  ['Trinidad and Tobago',
#   'TTO',
#   'TT',
#   513,
#   'Trinidad and Tobago',
#   1323722,
#   'Caribbean',
#   'TTO',
#   'Trinidad and Tobago'],
#  ['Tunisia',
#   'TUN',
#   'TN',
#   15536,
#   'Tunisia',
#   10104685,
#   'NorthAfrica',
#   'TUN',
#   'Tunisia'],
#  ['Turkey', 'TUR', 'TR', 76963, 'Turkey', 72969723, 'Asia', 'TUR', 'Turkey'],
#  ['Turkmenistan',
#   'TKM',
#   'TM',
#   46993,
#   'Turkmenistan',
#   4833266,
#   'Asia',
#   'TKM',
#   'Turkmenistan'],
#  ['Turks and Caicos Islands',
#   'TCA',
#   'TC',
#   0,
#   'Turks and Caicos Islands',
#   24459,
#   'Caribbean',
#   'TCA',
#   'Turks and Caicos Islands'],
#  ['Uganda',
#   'UGA',
#   'UG',
#   19710,
#   'Uganda',
#   28947181,
#   'Sub Saharan Africa',
#   'UGA',
#   'Uganda'],
#  ['Ukraine',
#   'UKR',
#   'UA',
#   57935,
#   'Ukraine',
#   46917544,
#   'Europe',
#   'UKR',
#   'Ukraine'],
#  ['United Arab Emirates',
#   'ARE',
#   'AE',
#   8360,
#   'United Arab Emirates',
#   4104291,
#   'Asia',
#   'ARE',
#   'United Arab Emirates'],
#  ['United Kingdom',
#   'GBR',
#   'GB',
#   24193,
#   'United Kingdom',
#   60244834,
#   'Europe',
#   'GBR',
#   'United Kingdom'],
#  ['United States',
#   'USA',
#   'US',
#   915896,
#   'United States',
#   299846449,
#   'North America',
#   'USA',
#   'United States'],
#  ['Uruguay',
#   'URY',
#   'UY',
#   17502,
#   'Uruguay',
#   3325727,
#   'Latin America',
#   'URY',
#   'Uruguay'],
#  ['Uzbekistan',
#   'UZB',
#   'UZ',
#   42540,
#   'Uzbekistan',
#   26593123,
#   'Asia',
#   'UZB',
#   'Uzbekistan'],
#  ['Vanuatu', 'VUT', 'VU', 1219, 'Vanuatu', 215366, 'Asia', 'VUT', 'Vanuatu'],
#  ['Venezuela',
#   'VEN',
#   'VE',
#   88205,
#   'Venezuela',
#   26725573,
#   'Latin America',
#   'VEN',
#   'Venezuela'],
#  ['Vietnam',
#   'VNM',
#   'VN',
#   32549,
#   'Vietnam',
#   85028643,
#   'Asia',
#   'VNM',
#   'Viet Nam'],
#  ['Western Sahara',
#   'ESH',
#   'EH',
#   0,
#   'Western Sahara',
#   440428,
#   'NorthAfrica',
#   'ESH',
#   'Western Sahara'],
#  ['Western Samoa',
#   'WSM',
#   'WS',
#   283,
#   'Western Samoa',
#   183845,
#   'Pacific',
#   'WSM',
#   'Samoa'],
#  ['Yemen', 'YEM', 'YE', 52797, 'Yemen', 21095679, 'Asia', 'YEM', 'Yemen'],
#  ['Yugoslavia',
#   'SRB',
#   'RS',
#   0,
#   'Yugoslavia',
#   9863026,
#   'Europe',
#   'YUG',
#   'Serbia'],
#  ['Zaire',
#   'COD',
#   'CD',
#   226705,
#   'Zaire',
#   58740547,
#   'Sub Saharan Africa',
#   'ZAR',
#   'Democratic Republic of the Congo'],
#  ['Zambia',
#   'ZMB',
#   'ZM',
#   74339,
#   'Zambia',
#   11478317,
#   'Sub Saharan Africa',
#   'ZMB',
#   'Zambia'],
#  ['Zimbabwe',
#   'ZWE',
#   'ZW',
#   38685,
#   'Zimbabwe',
#   13119679,
#   'Sub Saharan Africa',
#   'ZWE',
#   'Zimbabwe']]

# %% [markdown]
# This is a list of the country name & country code (ISO) in two different formats, in alphabetical order. Then, how many records (countries) are there?

# %%
len(recs), len(shapes)
# Out:
# (211, 211)

# %% [markdown]
# Now, we are going to draw the world map, where each country is highlighted with a different color, and we would like to have USA marked as black and AUS as pink.

# %%
cm = matplotlib.cm.get_cmap('Dark2')

Nshp = len(shapes)
cccol = cm(1.*numpy.arange(Nshp)/Nshp) # one colour for every contry...
# plot
fig = plt.figure(figsize = (12,6))
ax = fig.add_subplot(111)

#Plot each country
for nshp in xrange(Nshp):
    ptchs   = []
    pts     = numpy.array(shapes[nshp].points)
    prt     = shapes[nshp].parts
    par     = list(prt) + [pts.shape[0]]
        
    for pij in xrange(len(prt)):
         ptchs.append(Polygon(pts[par[pij]:par[pij+1]]))
    ax.add_collection(PatchCollection(ptchs,facecolor=cccol[nshp,:],edgecolor='k', linewidths=.1))
    # hack the colour for specific countries, actually alphabetical, need to know ISO code
    if recs[nshp][1] == "USA":
         ax.add_collection(PatchCollection(ptchs,facecolor=[0,0,0,1],edgecolor='k', linewidths=.1))  # black
    if recs[nshp][1] == "AUS":
         ax.add_collection(PatchCollection(ptchs,facecolor = "pink",edgecolor='k', linewidths=.1))  # pink
ax.set_xlim(-180,+180)
ax.set_ylim(-90,90)

plt.show()

# %% [markdown]
# ## 3. Visualizing the house heating data
# There are three shape files provided. Let's have a look on one of them!

# %%
# You can look at the shapefile data, just display the contents as is, at the moment 
# !cat 'gz_2010_us_040_00_500k.dbf' 
inFile = open('gz_2010_us_040_00_500k.dbf' , 'r')
data = inFile.readlines()
inFile.close()
data
# Out:
# ['\x03o\t\x0c4\x00\x00\x00\xc1\x00\xbf\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00GEO_ID\x00\x00\x00\x00\x00C\x00\x00\x00\x00<\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00STATE\x00\x00\x00\x00\x00\x00C\x00\x00\x00\x00\x02\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00NAME\x00\x00\x00\x00\x00\x00\x00C\x00\x00\x00\x00Z\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00LSAD\x00\x00\x00\x00\x00\x00\x00C\x00\x00\x00\x00\x07\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00CENSUSAREA\x00N\x00\x00\x00\x00\x1f\x0f\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\r 0400000US23                                                 23Maine                                                                                                      30842.923000000000000 0400000US25                                                 25Massachusetts                                                                                               7800.058000000000000 0400000US26                                                 26Michigan                                                                                                   56538.901000000000000 0400000US30                                                 30Montana                                                                                                   145545.801000000000000 0400000US32                                                 32Nevada                                                                                                    109781.180000000000000 0400000US34                                                 34New Jersey                                                                                                  7354.220000000000000 0400000US36                                                 36New York                                                                                                   47126.399000000000000 0400000US37                                                 37North Carolina                                                                                             48617.905000000000000 0400000US39                                                 39Ohio                                                                                                       40860.694000000000000 0400000US42                                                 42Pennsylvania                                                                                               44742.703000000000000 0400000US44                                                 44Rhode Island                                                                                                1033.814000000000000 0400000US47                                                 47Tennessee                                                                                                  41234.896000000000000 0400000US48                                                 48Texas                                                                                                     261231.711000000000000 0400000US49                                                 49Utah                                                                                                       82169.620000000000000 0400000US53                                                 53Washington                                                                                                 66455.521000000000000 0400000US55                                                 55Wisconsin                                                                                                  54157.805000000000000 0400000US72                                                 72Puerto Rico                                                                                                 3423.775000000000000 0400000US24                                                 24Maryland                           ...

# %% [markdown]
# ### 3.1 Explore Household heating data as follows:

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('Household heating by Congressional District - 2008.csv')
df.head()
# Out:
#   Congressional District Two-Digit District  Average Household Size  \
# 0              Alabama 1              AL-01                    2.49
# 1              Alabama 2              AL-02                    2.52
# 2              Alabama 3              AL-03                    2.42
# 3              Alabama 4              AL-04                    2.54
# 4              Alabama 5              AL-05                    2.47
#
#    % Housing Units That Are Mobile Homes  \
# 0                                   11.9
# 1                                   17.0
# 2                                   18.6
# 3                                   19.9
# 4                                   10.4
#
#    % Housing Units Built in 2005 or Later  \
# 0                                     4.5
# 1                                     3.9
# 2                                     5.3
# 3                                     2.6
# 4                                     5.9
#
#    % Housing Units Built in 1939 or Earlier  \
# 0                                       4.5
# 1                                       6.2
# 2                                       7.4
# 3                                       7.2
# 4                                       4.8
#
#   % Homes Heated Principally With Gas  \
# 0                                  37
# 1                                34.1
# 2                                  41
# 3                                39.4
# 4                                33.9
#
#   % Homes Heated Principally With Electricity  \
# 0                                        62.1
# 1                                        64.6
# 2                                        56.3
# 3                                        57.3
# 4                                        64.3
#
#   % Homes Heated Principally with Fuel Oil, Kerosene, Etc.
# 0                                                0.1
# 1                                                0.2
# 2                                                0.3
# 3                                                0.7
# 4                                                0.6

# %% [markdown]
# ** Schema Conflict: Different level of aggregation: **
#
# * The shappefiles (S2) are categorised by state, whereas S3 is represented by district. Therefore, we will need schema matching to integrate between both.

# %% [markdown]
# * Also that the Congressional District attribute contains the following values:
#     * Alabama 1
#     * Alabama 2
# etc.
#
#
# However, we want 'state' names instead of 'district' to be able to visualise data for each state on map. Thus, we can do the following:
#
# * Change the shape files so the regions match the data.
#
# * Find files that already match (e.g. Google Fusion Tables)
#
# * Change the data to match the shape regions

# %% [markdown]
# ### 3.2 Take the original Household heating data ('Household heating by Congressional District - 2008.csv') and wrangle the data into a state format.
#
# Create your own CSV file contains state information. You should have a dataset that looks something like this:

# %% [markdown]
# <img src="States.png">
#
#
# Now, load your new CSV file:

# %%
df['States']=df['Congressional District'].str.extract(r'(.*) [(\d)(At)]').str.strip()
print df.States.value_counts()
df[df.States.isnull()]
# Out:
# California        53
# Texas             32
# New York          29
# Florida           25
# Illinois          19
# Pennsylvania      19
# Ohio              18
# Michigan          15
# North Carolina    13
# New Jersey        13
# Georgia           13
# Virginia          11
# Massachusetts     10
# Indiana            9
# Washington         9
# Tennessee          9
# Missouri           9
# Wisconsin          8
# Minnesota          8
# Arizona            8
# Maryland           8
# Louisiana          7
# Alabama            7
# Colorado           7
# Kentucky           6
# South Carolina     6
# Oregon             5
# Iowa               5
# Oklahoma           5
# Connecticut        5
# Mississippi        4
# Arkansas           4
# Kansas             4
# New Mexico         3
# West Virginia      3
# Utah               3
# Nevada             3
# Nebraska           3
# Idaho              2
# New Hampshire      2
# Rhode Island       2
# Hawaii             2
# Maine              2
# Montana            1
# Wyoming            1
# Vermont            1
# North Dakota       1
# Alaska             1
# Delaware           1
# South Dakota       1
# Name: States, dtype: int64
#    Congressional District Two-Digit District  Average Household Size  \
# 86   District of Columbia                NaN                    2.23
#
#     % Housing Units That Are Mobile Homes  \
# 86                                    0.0
#
#     % Housing Units Built in 2005 or Later  \
# 86                                     2.4
#
#     % Housing Units Built in 1939 or Earlier  \
# 86                                      34.0
#
#    % Homes Heated Principally With Gas  \
# 86                                64.6
#
#    % Homes Heated Principally With Electricity  \
# 86                                        30.1
#
#    % Homes Heated Principally with Fuel Oil, Kerosene, Etc. States
# 86                                                3.9          NaN

# %%
df['State']=df['Two-Digit District'].str.extract(r'(.*)-')
print df.State.value_counts()
df[df.State.isnull()]
# Out:
# CA    53
# TX    32
# NY    29
# FL    25
# IL    19
# PA    19
# OH    18
# MI    15
# GA    13
# NJ    13
# NC    13
# VA    11
# MA    10
# TN     9
# MO     9
# IN     9
# WA     9
# MD     8
# AZ     8
# MN     8
# WI     8
# AL     7
# LA     7
# CO     7
# SC     6
# KY     6
# OK     5
# OR     5
# IA     5
# CT     5
# AR     4
# MS     4
# KS     4
# WV     3
# NM     3
# UT     3
# NE     3
# NV     3
# ME     2
# ID     2
# RI     2
# NH     2
# HI     2
# ND     1
# MT     1
# WY     1
# AK     1
# VT     1
# DE     1
# SD     1
# Name: State, dtype: int64
#    Congressional District Two-Digit District  Average Household Size  \
# 86   District of Columbia                NaN                    2.23
#
#     % Housing Units That Are Mobile Homes  \
# 86                                    0.0
#
#     % Housing Units Built in 2005 or Later  \
# 86                                     2.4
#
#     % Housing Units Built in 1939 or Earlier  \
# 86                                      34.0
#
#    % Homes Heated Principally With Gas  \
# 86                                64.6
#
#    % Homes Heated Principally With Electricity  \
# 86                                        30.1
#
#    % Homes Heated Principally with Fuel Oil, Kerosene, Etc. States State
# 86                                                3.9          NaN   NaN

# %%
df[df.States.isnull()]
# Out:
#    Congressional District Two-Digit District  Average Household Size  \
# 86   District of Columbia                NaN                    2.23
#
#     % Housing Units That Are Mobile Homes  \
# 86                                    0.0
#
#     % Housing Units Built in 2005 or Later  \
# 86                                     2.4
#
#     % Housing Units Built in 1939 or Earlier  \
# 86                                      34.0
#
#    % Homes Heated Principally With Gas  \
# 86                                64.6
#
#    % Homes Heated Principally With Electricity  \
# 86                                        30.1
#
#    % Homes Heated Principally with Fuel Oil, Kerosene, Etc. States State
# 86                                                3.9          NaN   NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 436 entries, 0 to 435
# Data columns (total 11 columns):
# Congressional District                                      436 non-null object
# Two-Digit District                                          435 non-null object
# Average Household Size                                      436 non-null float64
# % Housing Units That Are Mobile Homes                       436 non-null float64
# % Housing Units Built in 2005 or Later                      436 non-null float64
# % Housing Units Built in 1939 or Earlier                    436 non-null float64
# % Homes Heated Principally With Gas                         436 non-null object
# % Homes Heated Principally With Electricity                 436 non-null object
# % Homes Heated Principally with Fuel Oil, Kerosene, Etc.    436 non-null object
# States                                                      435 non-null object
# State                                                       435 non-null object
# dtypes: float64(4), object(7)
# memory usage: 37.5+ KB

# %% [markdown]
# ### 3.3  Plot the avergae"Housing Units That Are Mobile Homes" for each state.
#
# ####  List the average value for each state. We will use the average values to generate the color codes

# %%
avergeValue = dict(statedf['% Housing Units That Are Mobile Homes'])
avergeValue
# Out:
# {'Alabama': 14.371428571428575,
#  'Alaska': 4.5999999999999996,
#  'Arizona': 10.375,
#  'Arkansas': 12.425000000000001,
#  'California': 3.692452830188679,
#  'Colorado': 4.5285714285714276,
#  'Connecticut': 0.73999999999999999,
#  'Delaware': 10.199999999999999,
#  'Florida': 9.3279999999999994,
#  'Georgia': 9.9692307692307693,
#  'Hawaii': 0.14999999999999999,
#  'Idaho': 9.25,
#  'Illinois': 2.521052631578947,
#  'Indiana': 5.5444444444444443,
#  'Iowa': 4.1599999999999993,
#  'Kansas': 5.2249999999999996,
#  'Kentucky': 12.700000000000001,
#  'Louisiana': 12.842857142857142,
#  'Maine': 9.0500000000000007,
#  'Maryland': 1.6000000000000001,
#  'Massachusetts': 0.84999999999999998,
#  'Michigan': 5.4000000000000004,
#  'Minnesota': 3.4500000000000002,
#  'Mississippi': 15.074999999999999,
#  'Missouri': 6.5666666666666673,
#  'Montana': 11.800000000000001,
#  'Nebraska': 3.8000000000000003,
#  'Nevada': 6.1333333333333337,
#  'New Hampshire': 5.9500000000000002,
#  'New Jersey': 0.9307692307692309,
#  'New Mexico': 16.533333333333331,
#  'New York': 2.2931034482758617,
#  'North Carolina': 14.353846153846151,
#  'North Dakota': 7.0,
#  'Ohio': 4.0166666666666666,
#  'Oklahoma': 9.0,
#  'Oregon': 8.4800000000000004,
#  'Pennsylvania': 4.1947368421052644,
#  'Rhode Island': 1.05,
#  'South Carolina': 18.433333333333334,
#  'South Dakota': 9.0,
#  'Tennessee': 10.088888888888889,
#  'Texas': 7.4343749999999993,
#  'Utah': 4.333333333333333,
#  'Vermont': 6.9000000000000004,
#  'Virginia': 5.7000000000000002,
#  'Washington': 7.2777777777777777,
#  'West Virginia': 13.966666666666669,
#  'Wisconsin': 3.6875,
#  'Wyoming': 14.0}

# %%
avergeValue['Virginia']
# Out:
# 5.7000000000000002

# %% [markdown]
# ### Now load the map

# %%
from mpl_toolkits.basemap import Basemap

import warnings
warnings.filterwarnings('ignore')

from matplotlib.collections import LineCollection
from matplotlib.colors import rgb2hex

# Lambert Conformal map of lower 48 states.
m = Basemap(llcrnrlon=-119,llcrnrlat=22,
            urcrnrlon=-64, urcrnrlat=49,
            projection='lcc', lat_1=33,lat_2=45,lon_0=-95)

m.drawcoastlines(linewidth=0.25)
m.drawcountries(linewidth=0.25)
m.fillcontinents(color='green',lake_color='aqua')
# draw the edge of the map projection region (the projection limb)
m.drawmapboundary(fill_color='aqua')
# draw lat/lon grid lines every 30 degrees.
m.drawmeridians(np.arange(0,360,30))
m.drawparallels(np.arange(-90,90,30))
plt.show()

# %% [markdown]
# #### How many states in your data (S3)? Does the number of states match with shapefiles (S2)?
#
# Is there something we need to fix before we plot information?

# %%
shp_info = m.readshapefile('gz_2010_us_040_00_500k','states',drawbounds=False)
statenames=[]
for shapedict in m.states_info:
    statename = shapedict['NAME']
    try:
        av = avergeValue[statename]
    except KeyError:
        print statename 
    statenames.append(statename)

np.unique(statenames)
# Out:
# Puerto Rico
# Puerto Rico
# Puerto Rico
# Puerto Rico
# Puerto Rico
# Puerto Rico
# Puerto Rico
# Puerto Rico
# Puerto Rico
# Puerto Rico
# Puerto Rico
# Puerto Rico
# Puerto Rico
# District of Columbia
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri',
#        'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey',
#        'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio',
#        'Oklahoma', 'Oregon', 'Pennsylvania', 'Puerto Rico', 'Rhode Island',
#        'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah',
#        'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin',
#        'Wyoming'],
#       dtype='|S20')

# %% [markdown]
# However, number of states does not match (should be 50 not 52)?
#
# 'District of Columbia' is listed as a state while it is not.
#
# and 'Puerto Rico'?? (some sort of dependency)
#
# (not on the map anyway, neither is Alaska but Python can handle it)

# %% [markdown]
# #### Assign color for each range: Using color map
# We can now cycle through states, color each one.

# %%
import matplotlib.pyplot as plt

colors={}
vmin = 0; vmax = 20 # set range.
cmap = plt.cm.BrBG
for s in statenames:
    if s != 'District of Columbia' and \
       s != "Puerto Rico":
        colors[s] = cmap((avergeValue[s]-vmin)/(vmax-vmin))[:3]
    ## Try to color Alabama with black 
    if s=='Alabama':
        colors[s]=(0,0,0)

colors
# Out:
# {'Alabama': (0, 0, 0),
#  'Alaska': (0.78346789696270669, 0.57585544021530177, 0.26259131103421757),
#  'Arizona': (0.92895040369088844, 0.95317185697808537, 0.94971164936562869),
#  'Arkansas': (0.71487889273356431, 0.89088811995386397, 0.86482122260668992),
#  'California': (0.71764705882352942, 0.47635524798154555, 0.15494040753556326),
#  'Colorado': (0.7785467128027681, 0.56585928489042658, 0.25028835063437127),
#  'Connecticut': (0.40692041522491351,
#   0.23391003460207613,
#   0.026528258362168398),
#  'Delaware': (0.94309880815071134, 0.95655517108804311, 0.95463283352556716),
#  'Florida': (0.96209150326797388, 0.94379084967320259, 0.89542483660130712),
#  'Georgia': (0.96086120722798929, 0.95978469819300272, 0.95693963860053821),
#  'Hawaii': (0.33802383698577471, 0.1933102652825836, 0.020376778162245292),
#  'Idaho': (0.96224529027297201, 0.94179161860822758, 0.88773548635140331),
#  'Illinois': (0.60000000000000009, 0.3656286043829296, 0.074202229911572465),
#  'Indiana': (0.84252210688196838, 0.69580930411380226, 0.41022683583237207),
#  'Iowa': (0.75886197616301421, 0.52587466359092649, 0.20107650903498644),
#  'Kansas': (0.82283737024221448, 0.65582468281430195, 0.36101499423298705),
#  'Kentucky': (0.68212226066897375, 0.87750865051903126, 0.8482122260668975),
#  'Louisiana': (0.66028450595924704, 0.86858900422914287, 0.83713956170703607),
#  'Maine': (0.96270665128796618, 0.93579392541330253, 0.86466743560169168),
#  'Maryland': (0.50165321030372934, 0.2897347174163783, 0.034986543637062668),
#  'Massachusetts': (0.41553248750480587,
#   0.23898500576701268,
#   0.027297193387158785),
#  'Michigan': (0.83760092272202991, 0.68581314878892718, 0.39792387543252583),
#  'Minnesota': (0.69411764705882351, 0.45420991926182236, 0.13879277201076509),
#  'Mississippi': (0.34625144175317202,
#   0.69181084198385245,
#   0.65305651672433696),
#  'Missouri': (0.90103806228373695, 0.80461361014994226, 0.57093425605536319),
#  'Montana': (0.79454056132256845, 0.92103037293348711, 0.90296039984621312),
#  'Nebraska': (0.72549019607843135, 0.48373702422145326, 0.16032295271049596),
#  'Nevada': (0.87981545559400232, 0.76955017301038053, 0.5063437139561705),
#  'New Hampshire': (0.87204921184159934,
#   0.75578623606305251,
#   0.4840445982314493),
#  'New Jersey': (0.42414455978469823,
#   0.24405997693194925,
#   0.028066128412149172),
#  'New Mexico': (0.1518646674356017, 0.53940792003075744, 0.50803537101114959),
#  'New York': (0.57647058823529418, 0.34348327566320647, 0.058054594386774322),
#  'North Carolina': (0.45005767012687453,
#   0.76655132641291834,
#   0.72226066897347185),
#  'North Dakota': (0.91872356785851594,
#   0.83383314109957696,
#   0.62475970780469037),
#  'Ohio': (0.74901960784313726, 0.50588235294117645, 0.17647058823529413),
#  'Oklahoma': (0.96270665128796618, 0.93579392541330253, 0.86466743560169168),
#  'Oregon': (0.96378316032295275, 0.92179930795847753, 0.81084198385236439),
#  'Pennsylvania': (0.75886197616301421,
#   0.52587466359092649,
#   0.20107650903498644),
#  'Rhode Island': (0.44136870434448289,
#   0.25420991926182235,
#   0.029603998462129948),
#  'South Carolina': (0.0030757400999615533,
#   0.36447520184544407,
#   0.32971933871587855),
#  'South Dakota': (0.96270665128796618,
#   0.93579392541330253,
#   0.86466743560169168),
#  'Tennessee': (0.95017301038062285, 0.95824682814302198, 0.95709342560553634),
#  'Texas': (0.93994617454825069, 0.86889657823913879, 0.68935024990388305),
#  'Utah': (0.76870434448289116, 0.54586697424067665, 0.22568242983467895),
#  'Vermont': (0.91518646674356019, 0.82798923490965004, 0.61399461745482498),
#  'Virginia': (0.85236447520184533, 0.71580161476355231, 0.43483275663206444),
#  'Washington': (0.93287197231833907, 0.85720876585928485, 0.66782006920415216),
#  'West Virginia': (0.50742022299115752,
#   0.80615148019992322,
#   0.75963091118800474),
#  'Wisconsin': (0.71764705882352942, 0.47635524798154555, 0.15494040753556326),
#  'Wyoming': (0.49619377162629791, 0.79976931949250318, 0.75301806997308751)}

# %%
for nshape,seg in enumerate(m.states):
    xx,yy = zip(*seg)
    if statenames[nshape] != 'District of Columbia' and \
        statenames[nshape] != "Puerto Rico":
        color = rgb2hex(colors[statenames[nshape]]) 
        plt.fill(xx,yy,color,edgecolor=color)

# %% [markdown]
# #### Draw color map and set figure options:

# %%
plt.figure(figsize=(20,10))
for nshape,seg in enumerate(m.states):
    xx,yy = zip(*seg)
    if statenames[nshape] != 'District of Columbia' and \
        statenames[nshape] != "Puerto Rico":
        color = rgb2hex(colors[statenames[nshape]]) 
        plt.fill(xx,yy,color,edgecolor=color)

# draw meridians and parallels.
m.drawparallels(np.arange(25,65,20), labels=[0,0,0,0], zorder=-1,color="w")
m.drawmeridians(np.arange(-120,-40,20), labels=[0,0,0,0], zorder=-1,color="w")

# set up colorbar:
mm = plt.cm.ScalarMappable(cmap=cmap)
mm.set_array([0,20]) # Replace this with Min and Max values in your data
plt.colorbar(mm, label="Mobile homes",
             ticks=[0,5,10,15,20],# Replace this with your ranges 
             orientation="horizontal", fraction=0.05,
            )

plt.title('Filling State Polygons by Population Density')
plt.gca().axis("off")

plt.show()

# %% [markdown]
# We can see the lighter colours indicate density of mobile homes, looks like they're popular in the South & South East,
#  not so much in the North East (too cold?)
