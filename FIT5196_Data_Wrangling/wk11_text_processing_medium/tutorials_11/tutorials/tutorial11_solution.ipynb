# %% [markdown]
# # Pre-processing XML Patents
#
#
# ## 1. Introduction
# This tutorial focus on preprocessing a set of patents documents stored in XML format and generating the sparse representations for those patents. The final output file should be exactly the same as the one stored in "patents.txt".
#
# In order to finish this task, you should
# 1. Exatract the abstract and claims for each patent from its xml file. Use Beautiful soup
# 2. Tokenise the patents
# 3. Generate 100 bigram collocations
# 4. Re-tokenize the patents with those bigram collocations
# 5. Generate the TF-IDF vectors for those re-tokenized patents
# 6. save the vectors in the form shown in "patents.txt"

# %% [markdown]
# ## 2.  Import libraries
#
# Here we will focus on using the existing packages as possible as we can.

# %%
from bs4 import BeautifulSoup as bsoup
import re
import os
import nltk
from nltk.collocations import *
from itertools import chain
import itertools
from nltk.tokenize import RegexpTokenizer
from nltk.tokenize import MWETokenizer

# %% [markdown]
# ## 3. Exatract Patent's abstract and Claims
#
# The first task is to parse each patent stored in the "xml_files" folder. The information to be extracted includes
# 1. patent document number (doc-number) stored in "publication-reference"
# 2. patent's abstract
# 3. patent's claims
#
# Hint: you can use a dictionary to save patents, where the key is the doc-number, the value is a long string contains both abstracts and all claims.

# %%
xml_file_path = "./xml_files"

# %%
def parsing(t):

    xmlSoup = bsoup(t,"lxml-xml")
    
    pid = xmlSoup.find("publication-reference").find('doc-number').string 
    
    text = ""
    
    #Extract text in "abstract"    
    abt = xmlSoup.find('abstract')
    for p in abt.findAll('p'):
        text = text + p.text + " "
    
    #Extract Claims 
    for tag in xmlSoup.find_all('claim-text'):
        text = text + tag.text
 
    return (pid, text)

# %%
patents_raw = {}
for xfile in os.listdir(xml_file_path): 
    xfile = os.path.join(xml_file_path, xfile)
    if os.path.isfile(xfile) and xfile.endswith('.XML'): 
        (pid, text) = parsing(open(xfile))
        patents_raw[pid] = text

# %% [markdown]
# ## 4. Tokenize the patents
# After finish extract the texts, you now need to tokenize the patents with regular expression tokenizer implemented in NLTK.

# %%
tokenizer = RegexpTokenizer(r'[a-zA-Z]{2,}')

# %%
def tokenizePatent(pid):
    """
        the tokenization function is used to tokenize each patent.
        The one argument is patent_id.
        First, normalize the case.
        Then, use the regular expression tokenizer to tokenize the patent with the specified id
    """
    raw_patent = patents_raw[pid].lower() 
    tokenized_patents = tokenizer.tokenize(raw_patent)
    return (pid, tokenized_patents) # return a tupel of patent_id and a list of tokens

patents_tokenized = dict(tokenizePatent(pid) for pid in patents_raw.keys())

# %%
patents_tokenized
# Out:
# {'07891018': ['knee',
#   'protective',
#   'device',
#   'for',
#   'garments',
#   'comprising',
#   'of',
#   'at',
#   'least',
#   'one',
#   'pocket',
#   'in',
#   'the',
#   'vicinity',
#   'of',
#   'the',
#   'knees',
#   'having',
#   'an',
#   'opening',
#   'for',
#   'receiving',
#   'an',
#   'insert',
#   'for',
#   'protecting',
#   'the',
#   'wearer',
#   'knees',
#   'garment',
#   'for',
#   'an',
#   'infant',
#   'comprising',
#   'infants',
#   'pants',
#   'with',
#   'two',
#   'longitudinally',
#   'extending',
#   'leg',
#   'portions',
#   'pair',
#   'of',
#   'pockets',
#   'sewn',
#   'substantially',
#   'about',
#   'knee',
#   'portion',
#   'of',
#   'each',
#   'one',
#   'of',
#   'said',
#   'leg',
#   'portions',
#   'each',
#   'one',
#   'of',
#   'said',
#   'pair',
#   'of',
#   'pockets',
#   'having',
#   'an',
#   'upper',
#   'lower',
#   'and',
#   'two',
#   'lateral',
#   'sides',
#   'and',
#   'at',
#   'least',
#   'one',
#   'transverse',
#   'pleat',
#   'with',
#   'an',
#   'opening',
#   'extending',
#   'through',
#   'one',
#   'of',
#   'said',
#   'two',
#   'lateral',
#   'sides',
#   'while',
#   'the',
#   'upper',
#   'lower',
#   'and',
#   'other',
#   'one',
#   'of',
#   'the',
#   'two',
#   'lateral',
#   'sides',
#   'are',
#   'stitched',
#   'and',
#   'an',
#   'impact',
#   'absorbing',
#   'insert',
#   'is',
#   'removeably',
#   'insertable',
#   'in',
#   'each',
#   'one',
#   'of',
#   'said',
#   'pair',
#   'of',
#   'pockets',
#   'through',
#   'said',
#   'opening',
#   'wherein',
#   'said',
#   'at',
#   'least',
#   'one',
#   'transverse',
#   'pleat',
#   'provides',
#   'substantially',
#   'expandable',
#   'cavity',
#   'in',
#   'each',
#   'one',
#   'of',
#   'said',
#   'pair',
#   'of',
#   'pockets',
#   'to',
#   'accommodate',
#   'said',
#   'insert',
#   'the',
#   'opening',
#   'is',
#   'smaller',
#   'than',
#   'lateral',
#   'edge',
#   'of',
#   'the',
#   'impact',
#   'absorbing',
#   'insert',
#   'positioned',
#   'within',
#   'the',
#   'infant',
#   'pants',
#   'two',
#   'longitudinally',
#   'extending',
#   'leg',
#   'portions',
#   'pair',
#   'of',
#   'pockets',
#   'sewn',
#   'substantially',
#   'about',
#   'knee',
#   'portion',
#   'of',
#   'each',
#   'one',
#   'of',
#   'said',
#   'leg',
#   'portions',
#   'each',
#   'one',
#   'of',
#   'said',
#   'pair',
#   'of',
#   'pockets',
#   'having',
#   'an',
#   'upper',
#   'lower',
#   'and',
#   'two',
#   'lateral',
#   'sides',
#   'and',
#   'at',
#   'least',
#   'one',
#   'transverse',
#   'pleat',
#   'with',
#   'an',
#   'opening',
#   'extending',
#   'through',
#   'one',
#   'of',
#   'said',
#   'two',
#   'lateral',
#   'sides',
#   'while',
#   'the',
#   'upper',
#   'lower',
#   'and',
#   'other',
#   'one',
#   'of',
#   'the',
#   'two',
#   'lateral',
#   'sides',
#   'are',
#   'stitched',
#   'andan',
#   'impact',
#   'absorbing',
#   'insert',
#   'is',
#   'removeably',
#   'insertable',
#   'in',
#   'each',
#   'one',
#   'of',
#   'said',
#   'pair',
#   'of',
#   'pockets',
#   'through',
#   'said',
#   'opening',
#   'wherein',
#   'said',
#   'at',
#   'least',
#   'one',
#   'transverse',
#   'pleat',
#   'provides',
#   'substantially',
#   'expandable',
#   'cavity',
#   'in',
#   'each',
#   'one',
#   'of',
#   'said',
#   'pair',
#   'of',
#   'pockets',
#   'to',
#   'accommodate',
#   'said',
#   'insert',
#   'the',
#   'opening',
#   'is',
#   'smaller',
#   'than',
#   'lateral',
#   'edge',
#   'of',
#   'the',
#   'impact',
#   'absorbing',
#   'insert',
#   'positioned',
#   'within',
#   'the',
#   'infant',
#   'pants',
#   'garment',
#   'as',
#   'claimed',
#   'in',
#   'claim',
#   'wherein',
#   'said',
#   'pocket',
#   'is',
#   'disposed',
#   'about',
#   'an',
#   'outside',
#   'surface',
#   'of',
#   'one',
#   'of',
#   'said',
#   'leg',
#   'portions',
#   'garment',
#   'as',
#   'claimed',
#   'in',
#   'claim',
#   'wherein',
#   'said',
#   'impact',
#   'absorbing',
#   'insert',
#   'comprises',
#   'neoprene'],
#  '07891019': ['heatable',
#   'garment',
#   'having',
#   'plurality',
#   'of',
#   'layers',
#   'is',
#   'shown',
#   'the',
#   'first',
#   'layer',
#   'is',
#   'an',
#   'outer',
#   'fabric',
#   'layer',
#   'of',
#   'any',
#   'fabric',
#   'which',
#   'is',
#   'lightweight',
#   'durable',
#   'and',
#   'treatable',
#   'and',
#   'may',
#   'also',
#   'be',
#   'air',
#   'impervious',
#   'cooperating',
#   'with',
#   'the',
#   'outer',
#   'fabric',
#   'layer',
#   'is',
#   'an',
#   'envelope',
#   'or',
#   'inflatable',
#   'bladder',
#   'having',
#   'plurality',
#   'of',
#   'interconnected',
#   'chambers',
#   'further',
#   'inner',
#   'layer',
#   'adjacent',
#   'the',
#   'envelope',
#   'or',
#   'bladder',
#   'is',
#   'heat',
#   'producing',
#   'element',
#   'such',
#   'as',
#   'plurality',
#   'of',
#   'imbedded',
#   'heating',
#   'wires',
#   'woven',
#   'into',
#   'supporting',
#   'fabric',
#   'the',
#   'supporting',
#   'fabric',
#   'may',
#   'however',
#   'comprise',
#   'the',
#   'inner',
#   'wall',
#   'of',
#   'the',
#   'inflatable',
#   'envelope',
#   'source',
#   'of',
#   'heat',
#   'energy',
#   'such',
#   'as',
#   'battery',
#   'is',
#   'connected',
#   'to',
#   'the',
#   'heat',
#   'producing',
#   'element',
#   'to',
#   'heat',
#   'the',
#   'inner',
#   'fabric',
#   'liner',
#   'inflation',
#   'of',
#   'the',
#   'inflatable',
#   'bladder',
#   'urges',
#   'the',
#   'heat',
#   'producing',
#   'element',
#   'into',
#   'intimate',
#   'contact',
#   'with',
#   'the',
#   'body',
#   'of',
#   'the',
#   'wearer',
#   'the',
#   'inflatable',
#   'bladder',
#   'also',
#   'form',
#   'fits',
#   'the',
#   'garment',
#   'on',
#   'the',
#   'body',
#   'of',
#   'the',
#   'wearer',
#   'and',
#   'provides',
#   'insulation',
#   'against',
#   'heat',
#   'loss',
#   'an',
#   'article',
#   'of',
#   'clothing',
#   'comprising',
#   'layered',
#   'construction',
#   'fitted',
#   'to',
#   'conform',
#   'to',
#   'predetermined',
#   'portion',
#   'of',
#   'an',
#   'animal',
#   'body',
#   'the',
#   'layered',
#   'construction',
#   'comprising',
#   'an',
#   'outer',
#   'fabric',
#   'layer',
#   'ii',
#   'first',
#   'inner',
#   'layer',
#   'adjacent',
#   'the',
#   'outer',
#   'fabric',
#   'layer',
#   'said',
#   'first',
#   'inner',
#   'layer',
#   'being',
#   'inflatable',
#   'iii',
#   'second',
#   'inner',
#   'layer',
#   'adjacent',
#   'the',
#   'first',
#   'inner',
#   'layer',
#   'the',
#   'second',
#   'inner',
#   'layer',
#   'comprising',
#   'heat',
#   'producing',
#   'element',
#   'and',
#   'wherein',
#   'the',
#   'inflatable',
#   'layer',
#   'when',
#   'inflated',
#   'urges',
#   'the',
#   'heat',
#   'producing',
#   'element',
#   'into',
#   'more',
#   'intimate',
#   'contact',
#   'with',
#   'the',
#   'predetermined',
#   'portion',
#   'of',
#   'the',
#   'animal',
#   'body',
#   'said',
#   'heat',
#   'producing',
#   'element',
#   'includes',
#   'electrical',
#   'resistance',
#   'panels',
#   'in',
#   'electrical',
#   'communication',
#   'with',
#   'an',
#   'electrical',
#   'current',
#   'source',
#   'powering',
#   'the',
#   'electrical',
#   'resistance',
#   'panel',
#   'and',
#   'iv',
#   'an',
#   'innermost',
#   'fabric',
#   'liner',
#   'adapted',
#   'to',
#   'be',
#   'closest',
#   'to',
#   'the',
#   'animal',
#   'body',
#   'when',
#   'the',
#   'article',
#   'is',
#   'being',
#   'worn',
#   'layered',
#   'construction',
#   'fitted',
#   'to',
#   'conform',
#   'to',
#   'predetermined',
#   'portion',
#   'of',
#   'an',
#   'animal',
#   'body',
#   'the',
#   'layered',
#   'construction',
#   'comprising',
#   'an',
#   'outer',
#   'fabric',
#   'layer',
#   'ii',
#   'first',
#   'inner',
#   'layer',
#   'adjacent',
#   'the',
#   'outer',
#   'fabric',
#   'layer',
#   'said',
#   'first',
#   'inner',
#   'layer',
#   'being',
#   'inflatable',
#   'iii',
#   'second',
#   'inner',
#   'layer',
#   'adjacent',
#   'the',
#   'first',
#   'inner',
#   'layer',
#   'the',
#   'second',
#   'inner',
#   'layer',
#   'comprising',
#   'heat',
#   'producing',
#   'element',
#   'and',
#   'wherein',
#   'the',
#   'inflatable',
#   'layer',
#   'when',
#   'inflated',
#   'urges',
#   'the',
#   'heat',
#   'producing',
#   'element',
#   'into',
#   'more',
#   'intimate',
#   'contact',
#   'with',
#   'the',
#   'predetermined',
#   'portion',
#   'of',
#   'the',
#   'animal',
#   'body',
#   'said',
#   'heat',
#   'producing',
#   'element',
#   'includes',
#   'electrical',
#   'resistance',
#   'panels',
#   'in',
#   'electrical',
#   'communication',
#   'with',
#   'an',
#   'electrical',
#   'current',
#   'source',
#   'powering',
#   'the',
#   'electrical',
#   'resistance',
#   'panel',
#   'and',
#   'iv',
#   'an',
#   'innermost',
#   'fabric',
#   'liner',
#   'adapted',
#   'to',
#   'be',
#   'closest',
#   'to',
#   'the',
#   'animal',
#   'body',
#   'when',
#   'the',
#   'article',
#   'is',
#   'being',
#   'worn',
#   'an',
#   'outer',
#   'fabric',
#   'layer',
#   'ii',
#   'first',
#   'inner',
#   'layer',
#   'adjacent',
#   'the',
#   'outer',
#   'fabric',
#   'layer',
#   'said',
#   'first',
#   'inner',
#   'layer',
#   'being',
#   'inflatable',
#   'iii',
#   'second',
#   'inner',
#   'layer',
#   'adjacent',
#   'the',
#   'first',
#   'inner',
#   'layer',
#   'the',
#   'second',
#   'inner',
#   'layer',
#   'comprising',
#   'heat',
#   'producing',
#   'element',
#   'and',
#   'wherein',
#   'the',
#   'inflatable',
#   'layer',
#   'when',
#   'inflated',
#   'urges',
#   'the',
#   'heat',
#   'producing',
#   'element',
#   'into',
#   'more',
#   'intimate',
#   'contact',
#   'with',
#   'the',
#   'predetermined',
#   'portion',
#   'of',
#   'the',
#   'animal',
#   'body',
#   'said',
#   'heat',
#   'producing',
#   'element',
#   'includes',
#   'electrical',
#   'resistance',
#   'panels',
#   'in',
#   'electrical',
#   'communication',
#   'with',
#   'an',
#   'electrical',
#   'current',
#   'source',
#   'powering',
#   'the',
#   'electrical',
#   'resistance',
#   'panel',
#   'andiv',
#   'an',
#   'innermost',
#   'fabric',
#   'liner',
#   'adapted',
#   'to',
#   'be',
#   'closest',
#   'to',
#   'the',
#   'animal',
#   'body',
#   'when',
#   'the',
#   'article',
#   'is',
#   'being',
#   'worn',
#   'the',
#   'article',
#   'of',
#   'clothing',
#   'of',
#   'claim',
#   'wherein',
#   'said',
#   'article',
#   'is',
#   'fitted',
#   'to',
#   'conform',
#   'to',
#   'torso',
#   'of',
#   'the',
#   'animal',
#   'body',
#   'the',
#   'article',
#   'of',
#   'clothing',
#   'of',
#   'claim',
#   'and',
#   'further',
#   'including',
#   'an',
#   'electrical',
#   'lead',
#   'for',
#   'coupling',
#   'the',
#   'electrical',
#   'current',
#   'source',
#   'to',
#   'the',
#   'electrical',
#   'resistance',
#   'panels',
#   'the',
#   'article',
#   'of',
#   'clothing',
#   'of',
#   'claim',
#   'wherein',
#   'the',
#   'article',
#   'is',
#   'vest',
#   'the',
#   'article',
#   'of',
#   'clothing',
#   'of',
#   'claim',
#   'wherein',
#   'the',
#   'article',
#   'is',
#   'jacket',
#   'an',
#   'article',
#   'of',
#   'clothing',
#   'comprising',
#   'layered',
#   'construction',
#   'fitted',
#   'to',
#   'conform',
#   'to',
#   'predetermined',
#   'portion',
#   'of',
#   'an',
#   'animal',
#   'body',
#   'the',
#   'layered',
#   'construction',
#   'comprising',
#   'an',
#   'outer',
#   'air',
#   'impervious',
#   'fabric',
#   'layer',
#   'ii',
#   'an',
#   'inner',
#   'air',
#   'impervious',
#   'layer',
#   'joined',
#   'to',
#   'the',
#   'outer',
#   'layer',
#   'to',
#   'from',
#   'an',
#   'inflatable',
#   'envelope',
#   'and',
#   'iii',
#   'heat',
#   'energy',
#   'producing',
#   'member',
#   'arranged',
#   'adjacent',
#   'the',
#   'inner',
#   'layer',
#   'such',
#   'that',
#   'inflation',
#   'of',
#   'the',
#   'inflatable',
#   'envelope',
#   'urges',
#   'the',
#   'heat',
#   'energy',
#   'producing',
#   'layer',
#   'against',
#   'the',
#   'body',
#   'of',
#   'wearer',
#   'wherein',
#   'the',
#   'heat',
#   'energy',
#   'producing',
#   'member',
#   'is',
#   'an',
#   'electrical',
#   'resistance',
#   'panel',
#   'in',
#   'electrical',
#   'communication',
#   'with',
#   'an',
#   'electrical',
#   'power',
#   'source',
#   'to',
#   'provide',
#   'an',
#   'electrical',
#   'current',
#   'to',
#   'the',
#   'electrical',
#   'resistance',
#   'panel',
#   'layered',
#   'construction',
#   'fitted',
#   'to',
#   'conform',
#   'to',
#   'predetermined',
#   'portion',
#   'of',
#   'an',
#   'animal',
#   'body',
#   'the',
#   'layered',
#   'construction',
#   'comprising',
#   'an',
#   'outer',
#   'air',
#   'impervious',
#   'fabric',
#   'layer',
#   'ii',
#   'an',
#   'inner',
#   'air',
#   'impervious',
#   'layer',
#   'joined',
#   'to',
#   'the',
#   'outer',
#   'layer',
#   'to',
#   'from',
#   'an',
#   'inflatable',
#   'envelope',
#   'and',
#   'iii',
#   'heat',
#   'energy',
#   'producing',
#   'member',
#   'arranged',
#   'adjacent',
#   'the',
#   'inner',
#   'layer',
#   'such',
#   'that',
#   'inflation',
#   'of',
#   'the',
#   'inflatable',
#   'envelope',
#   'urges',
#   'the',
#   'heat',
#   'energy',
#   'producing',
#   'layer',
#   'against',
#   'the',
#   'body',
#   'of',
#   'wearer',
#   'wherein',
#   'the',
#   'heat',
#   'energy',
#   'producing',
#   'member',
#   'is',
#   'an',
#   'electrical',
#   'resistance',
#   'panel',
#   'in',
#   'electrical',
#   'communication',
#   'with',
#   'an',
#   'electrical',
#   'power',
#   'source',
#   'to',
#   'provide',
#   'an',
#   'electrical',
#   'current',
#   'to',
#   'the',
#   'electrical',
#   'resistance',
#   'panel',
#   'an',
#   'outer',
#   'air',
#   'impervious',
#   'fabric',
#   'layer',
#   'ii',
#   'an',
#   'inner',
#   'air',
#   'impervious',
#   'layer',
#   'joined',
#   'to',
#   'the',
#   'outer',
#   'layer',
#   'to',
#   'from',
#   'an',
#   'inflatable',
#   'envelope',
#   'andiii',
#   'heat',
#   'energy',
#   'producing',
#   'member',
#   'arranged',
#   'adjacent',
#   'the',
#   'inner',
#   'layer',
#   'such',
#   'that',
#   'inflation',
#   'of',
#   'the',
#   'inflatable',
#   'envelope',
#   'urges',
#   'the',
#   'heat',
#   'energy',
#   'producing',
#   'layer',
#   'against',
#   'the',
#   'body',
#   'of',
#   'wearer',
#   'wherein',
#   'the',
#   'heat',
#   'energy',
#   'producing',
#   'member',
#   'is',
#   'an',
#   'electrical',
#   'resistance',
#   'panel',
#   'in',
#   'electrical',
#   'communication',
#   'with',
#   'an',
#   'electrical',
#   'power',
#   'source',
#   'to',
#   'provide',
#   'an',
#   'electrical',
#   'current',
#   'to',
#   'the',
#   'electrical',
#   'resistance',
#   'panel',
#   'the',
#   'article',
#   'of',
#   'clothing',
#   'of',
#   'claim',
#   'wherein',
#   'said',
#   'article',
#   'is',
#   'fitted',
#   'to',
#   'conform',
#   'to',
#   'torso',
#   'of',
#   'the',
#   'animal',
#   'body',
#   'the',
#   'article',
#   'of',
#   'clothing',
#   'of',
#   'claim',
#   'and',
#   'further',
#   'including',
#   'means',
#   'for',
#   'connecting',
#   'the',
#   'heat',
#   'producing',
#   'element',
#   'to',
#   'vehicle',
#   'battery',
#   'the',
#   'article',
#   'of',
#   'clothing',
#   'of',
#   'claim',
#   'and',
#   'further',
#   'including',
#   'an',
#   'electrical',
#   'lead',
#   'for',
#   'coupling',
#   'the',
#   'vehicle',
#   'battery',
#   'to',
#   'the',
#   'heat',
#   'producing',
#   'element',
#   'the',
#   'article',
#   'of',
#   'clothing',
#   'of',
#   'claim',
#   'wherein',
#   'the',
#   'article',
#   'is',
#   'vest',
#   'the',
#   'article',
#   'of',
#   'clothing',
#   'of',
#   'claim',
#   'wherein',
#   'the',
#   'article',
#   'is',
#   'jacket',
#   'an',
#   'article',
#   'of',
#   'clothing',
#   'of',
#   'layered',
#   'construction',
#   'fitted',
#   'to',
#   'conform',
#   'to',
#   'predetermined',
#   'portion',
#   'of',
#   'an',
#   'animal',
#   'body',
#   'the',
#   'layered',
#   'construction',
#   'comprising',
#   'an',
#   'outer',
#   'fabric',
#   'layer',
#   'first',
#   'inner',
#   'layer',
#   'adjacent',
#   'the',
#   'outer',
#   'fabric',
#   'layer',
#   'said',
#   'first',
#   'inner',
#   'layer',
#   'being',
#   'inflatable',
#   'second',
#   'inner',
#   'layer',
#   'adjacent',
#   'the',
#   'first',
#   'inner',
#   'layer',
#   'wherein',
#   'said',
#   'second',
#   'inner',
#   'layer',
#   'is',
#   'heatable',
#   'layer',
#   'that',
#   'includes',
#   'electrical',
#   'resistance',
#   'panels',
#   'adapted',
#   'to',
#   'be',
#   'connected',
#   'to',
#   'power',
#   'source',
#   'of',
#   'electrical',
#   'current',
#   'and',
#   'an',
#   'innermost',
#   'fabric',
#   'liner',
#   'adapted',
#   'to',
#   'be',
#   'closest',
#   'to',
#   'the',
#   'animal',
#   'body',
#   'when',
#   'the',
#   'article',
#   'is',
#   'being',
#   'worn',
#   'wherein',
#   'when',
#   'the',
#   'first',
#   'layer',
#   'is',
#   'inflated',
#   ...],
#  '07891020': ['the',
#   'invention',
#   'concerns',
#   'functional',
#   'apparel',
#   'item',
#   'in',
#   'particular',
#   'protective',
#   'apparel',
#   'having',
#   'protective',
#   'function',
#   'against',
#   'biological',
#   'and',
#   'or',
#   'chemical',
#   'toxicant',
#   'or',
#   'noxiant',
#   'materials',
#   'the',
#   'apparel',
#   'item',
#   'being',
#   'equipped',
#   'with',
#   'measuring',
#   'appliance',
#   'capturing',
#   'at',
#   'least',
#   'one',
#   'measurable',
#   'quantity',
#   'and',
#   'adapted',
#   'for',
#   'determining',
#   'the',
#   'serviceability',
#   'of',
#   'the',
#   'apparel',
#   'item',
#   'functional',
#   'nbc',
#   'protective',
#   'apparel',
#   'item',
#   'having',
#   'protective',
#   'function',
#   'against',
#   'biological',
#   'and',
#   'chemical',
#   'toxicant',
#   'or',
#   'noxiant',
#   'materials',
#   'wherein',
#   'the',
#   'garment',
#   'is',
#   'accommodated',
#   'in',
#   'the',
#   'storage',
#   'state',
#   'in',
#   'air',
#   'tight',
#   'depressurized',
#   'packaging',
#   'wherein',
#   'the',
#   'garment',
#   'comprises',
#   'sheetlike',
#   'material',
#   'having',
#   'layered',
#   'construction',
#   'the',
#   'layered',
#   'construction',
#   'comprising',
#   'at',
#   'least',
#   'one',
#   'textile',
#   'sheetlike',
#   'construction',
#   'and',
#   'an',
#   'adsorptive',
#   'or',
#   'adsorbing',
#   'layer',
#   'as',
#   'well',
#   'as',
#   'barrier',
#   'layer',
#   'in',
#   'the',
#   'form',
#   'of',
#   'membrane',
#   'and',
#   'wherein',
#   'the',
#   'garment',
#   'is',
#   'equipped',
#   'with',
#   'measuring',
#   'appliance',
#   'capturing',
#   'the',
#   'storage',
#   'time',
#   'of',
#   'the',
#   'apparel',
#   'item',
#   'via',
#   'at',
#   'least',
#   'one',
#   'measurable',
#   'parameter',
#   'being',
#   'characterized',
#   'for',
#   'the',
#   'storage',
#   'time',
#   'and',
#   'being',
#   'at',
#   'least',
#   'one',
#   'of',
#   'temperature',
#   'pressure',
#   'or',
#   'moisture',
#   'wherein',
#   'the',
#   'measuring',
#   'appliance',
#   'is',
#   'adapted',
#   'for',
#   'determining',
#   'the',
#   'serviceability',
#   'of',
#   'the',
#   'garment',
#   'and',
#   'comprises',
#   'an',
#   'electrical',
#   'or',
#   'electronic',
#   'sensor',
#   'selected',
#   'from',
#   'the',
#   'group',
#   'consisting',
#   'of',
#   'temperature',
#   'sensor',
#   'pressure',
#   'sensor',
#   'and',
#   'moisture',
#   'sensor',
#   'the',
#   'sensor',
#   'transforming',
#   'measurable',
#   'parameter',
#   'into',
#   'an',
#   'electrical',
#   'readable',
#   'correlated',
#   'measurement',
#   'signal',
#   'wherein',
#   'the',
#   'measurable',
#   'parameter',
#   'is',
#   'capturable',
#   'in',
#   'relation',
#   'to',
#   'at',
#   'least',
#   'one',
#   'of',
#   'their',
#   'duration',
#   'intensity',
#   'and',
#   'frequency',
#   'the',
#   'functional',
#   'nbc',
#   'protective',
#   'garment',
#   'according',
#   'to',
#   'claim',
#   'wherein',
#   'the',
#   'sensor',
#   'is',
#   'selected',
#   'from',
#   'the',
#   'group',
#   'consisting',
#   'of',
#   'thermistor',
#   'or',
#   'posistor',
#   'temperature',
#   'sensor',
#   'barometric',
#   'pressure',
#   'sensor',
#   'ceramic',
#   'pressure',
#   'sensor',
#   'and',
#   'silicon',
#   'based',
#   'pressure',
#   'sensor',
#   'and',
#   'moisture',
#   'sensor',
#   'having',
#   'moisture',
#   'content',
#   'dependent',
#   'sensitivity',
#   'or',
#   'conductivity',
#   'the',
#   'functional',
#   'nbc',
#   'protective',
#   'garment',
#   'according',
#   'to',
#   'claim',
#   'wherein',
#   'the',
#   'sensor',
#   'is',
#   'physical',
#   'chemical',
#   'or',
#   'biochemical',
#   'sensor',
#   'the',
#   'sensor',
#   'responding',
#   'to',
#   'the',
#   'capture',
#   'of',
#   'measurable',
#   'parameter',
#   'by',
#   'inducing',
#   'or',
#   'exhibiting',
#   'measurement',
#   'signal',
#   'induced',
#   'by',
#   'physical',
#   'chemical',
#   'or',
#   'biochemical',
#   'reaction',
#   'the',
#   'functional',
#   'nbc',
#   'protective',
#   'garment',
#   'according',
#   'to',
#   'claim',
#   'wherein',
#   'the',
#   'measuring',
#   'appliance',
#   'comprises',
#   'storage',
#   'unit',
#   'for',
#   'electronic',
#   'storage',
#   'of',
#   'measurement',
#   'signal',
#   'correlating',
#   'with',
#   'measurable',
#   'parameter',
#   'the',
#   'storage',
#   'unit',
#   'being',
#   'coupled',
#   'with',
#   'the',
#   'sensor',
#   'electrically',
#   'the',
#   'functional',
#   'nbc',
#   'protective',
#   'garment',
#   'according',
#   'to',
#   'claim',
#   'wherein',
#   'the',
#   'measuring',
#   'appliance',
#   'comprises',
#   'an',
#   'electronic',
#   'circuit',
#   'for',
#   'processing',
#   'measurement',
#   'signal',
#   'correlating',
#   'with',
#   'captured',
#   'measurable',
#   'parameter',
#   'or',
#   'for',
#   'coupling',
#   'the',
#   'sensor',
#   'with',
#   'storage',
#   'unit',
#   'the',
#   'functional',
#   'nbc',
#   'protective',
#   'garment',
#   'according',
#   'to',
#   'claim',
#   'wherein',
#   'the',
#   'electronic',
#   'circuit',
#   'is',
#   'coupled',
#   'with',
#   'at',
#   'least',
#   'one',
#   'of',
#   'sensor',
#   'storage',
#   'unit',
#   'and',
#   'an',
#   'electronic',
#   'circuit',
#   'the',
#   'functional',
#   'nbc',
#   'protective',
#   'garment',
#   'according',
#   'to',
#   'claim',
#   'wherein',
#   'the',
#   'electronic',
#   'circuit',
#   'reads',
#   'out',
#   'processed',
#   'or',
#   'unprocessed',
#   'measurement',
#   'signal',
#   'stored',
#   'in',
#   'storage',
#   'unit',
#   'and',
#   'correlating',
#   'with',
#   'measurable',
#   'parameter',
#   'the',
#   'functional',
#   'nbc',
#   'protective',
#   'garment',
#   'according',
#   'to',
#   'claim',
#   'wherein',
#   'the',
#   'measuring',
#   'appliance',
#   'comprises',
#   'read',
#   'out',
#   'unit',
#   'the',
#   'read',
#   'out',
#   'unit',
#   'being',
#   'electrically',
#   'coupled',
#   'with',
#   'at',
#   'least',
#   'on',
#   'of',
#   'sensor',
#   'storage',
#   'unit',
#   'and',
#   'an',
#   'electronic',
#   'circuit',
#   'wherein',
#   'the',
#   'read',
#   'out',
#   'unit',
#   'provides',
#   'in',
#   'readable',
#   'form',
#   'the',
#   'measurement',
#   'signal',
#   'correlating',
#   'with',
#   'measurable',
#   'parameter',
#   'the',
#   'functional',
#   'nbc',
#   'garment',
#   'item',
#   'according',
#   'to',
#   'claim',
#   'wherein',
#   'the',
#   'measuring',
#   'appliance',
#   'comprises',
#   'an',
#   'energy',
#   'source'],
#  '07891021': ['protective',
#   'garment',
#   'of',
#   'type',
#   'preferably',
#   'conforming',
#   'to',
#   'at',
#   'least',
#   'one',
#   'nfpa',
#   'standard',
#   'and',
#   'worn',
#   'by',
#   'firefighters',
#   'and',
#   'by',
#   'emergency',
#   'rescue',
#   'workers',
#   'has',
#   'body',
#   'which',
#   'has',
#   'two',
#   'sleeve',
#   'mouths',
#   'and',
#   'has',
#   'two',
#   'sleeves',
#   'each',
#   'sleeve',
#   'is',
#   'attached',
#   'to',
#   'the',
#   'body',
#   'by',
#   'being',
#   'sewn',
#   'thereto',
#   'along',
#   'and',
#   'around',
#   'margin',
#   'of',
#   'an',
#   'associated',
#   'one',
#   'of',
#   'the',
#   'sleeve',
#   'mouths',
#   'so',
#   'as',
#   'to',
#   'extend',
#   'in',
#   'forward',
#   'direction',
#   'when',
#   'unstressed',
#   'the',
#   'forward',
#   'direction',
#   'may',
#   'be',
#   'forward',
#   'and',
#   'downward',
#   'direction',
#   'forward',
#   'and',
#   'upward',
#   'direction',
#   'or',
#   'forward',
#   'and',
#   'lateral',
#   'direction',
#   'the',
#   'protective',
#   'garment',
#   'may',
#   'be',
#   'protective',
#   'coat',
#   'protective',
#   'jacket',
#   'protective',
#   'shirt',
#   'or',
#   'suit',
#   'of',
#   'protective',
#   'coveralls',
#   'protective',
#   'garment',
#   'of',
#   'type',
#   'worn',
#   'by',
#   'firefighters',
#   'and',
#   'by',
#   'emergency',
#   'rescue',
#   'workers',
#   'the',
#   'protective',
#   'garment',
#   'having',
#   'body',
#   'which',
#   'has',
#   'two',
#   'sleeve',
#   'mouths',
#   'the',
#   'protective',
#   'garment',
#   'having',
#   'two',
#   'sleeves',
#   'each',
#   'of',
#   'which',
#   'is',
#   'attached',
#   'to',
#   'the',
#   'body',
#   'along',
#   'and',
#   'around',
#   'margin',
#   'of',
#   'an',
#   'associated',
#   'one',
#   'of',
#   'the',
#   'sleeve',
#   'mouths',
#   'majority',
#   'of',
#   'each',
#   'margin',
#   'being',
#   'located',
#   'on',
#   'the',
#   'anterior',
#   'side',
#   'of',
#   'coronal',
#   'plane',
#   'as',
#   'defined',
#   'by',
#   'wearer',
#   'of',
#   'the',
#   'protective',
#   'garment',
#   'with',
#   'the',
#   'garment',
#   'in',
#   'an',
#   'unstressed',
#   'condition',
#   'the',
#   'protective',
#   'garment',
#   'of',
#   'claim',
#   'wherein',
#   'each',
#   'sleeve',
#   'is',
#   'attached',
#   'to',
#   'the',
#   'body',
#   'by',
#   'being',
#   'sewn',
#   'to',
#   'the',
#   'body',
#   'the',
#   'protective',
#   'garment',
#   'of',
#   'claim',
#   'wherein',
#   'the',
#   'protective',
#   'garment',
#   'conforms',
#   'to',
#   'at',
#   'least',
#   'one',
#   'of',
#   'nfpa',
#   'nfpa',
#   'nfpa',
#   'usar',
#   'nfpa',
#   'nfpa',
#   'ems',
#   'nfpa',
#   'hazmat'],
#  '07891023': ['suspender',
#   'set',
#   'and',
#   'peace',
#   'officer',
#   'shirt',
#   'are',
#   'described',
#   'wherein',
#   'the',
#   'suspenders',
#   'for',
#   'the',
#   'duty',
#   'belt',
#   'are',
#   'located',
#   'beneath',
#   'the',
#   'officer',
#   'shirt',
#   'with',
#   'only',
#   'portion',
#   'of',
#   'the',
#   'suspender',
#   'set',
#   'extending',
#   'outwardly',
#   'through',
#   'the',
#   'front',
#   'and',
#   'rear',
#   'of',
#   'the',
#   'shirt',
#   'for',
#   'connection',
#   'to',
#   'the',
#   'duty',
#   'belt',
#   'worn',
#   'by',
#   'the',
#   'officer',
#   'in',
#   'combination',
#   'peace',
#   'officer',
#   'shirt',
#   'having',
#   'front',
#   'back',
#   'sleeves',
#   'and',
#   'tail',
#   'which',
#   'is',
#   'worn',
#   'tucked',
#   'into',
#   'the',
#   'wearer',
#   'pants',
#   'said',
#   'shirt',
#   'having',
#   'an',
#   'inner',
#   'surface',
#   'and',
#   'an',
#   'outer',
#   'surface',
#   'peace',
#   'officer',
#   'duty',
#   'belt',
#   'extending',
#   'around',
#   'the',
#   'officer',
#   'waist',
#   'which',
#   'supports',
#   'heavy',
#   'gear',
#   'suspender',
#   'set',
#   'comprising',
#   'first',
#   'and',
#   'second',
#   'flexible',
#   'strap',
#   'members',
#   'said',
#   'suspender',
#   'set',
#   'intended',
#   'to',
#   'be',
#   'worn',
#   'under',
#   'the',
#   'officer',
#   'shirt',
#   'and',
#   'to',
#   'extend',
#   'over',
#   'the',
#   'officers',
#   'shoulders',
#   'each',
#   'of',
#   'said',
#   'first',
#   'and',
#   'second',
#   'strap',
#   'members',
#   'having',
#   'front',
#   'end',
#   'and',
#   'rear',
#   'end',
#   'first',
#   'buckle',
#   'fastener',
#   'including',
#   'first',
#   'and',
#   'second',
#   'buckle',
#   'fastener',
#   'members',
#   'which',
#   'may',
#   'be',
#   'selectively',
#   'fastened',
#   'together',
#   'said',
#   'first',
#   'buckle',
#   'fastener',
#   'member',
#   'of',
#   'said',
#   'first',
#   'buckle',
#   'fastener',
#   'means',
#   'being',
#   'secured',
#   'to',
#   'said',
#   'front',
#   'end',
#   'of',
#   'said',
#   'first',
#   'strap',
#   'member',
#   'second',
#   'buckle',
#   'fastener',
#   'including',
#   'first',
#   'and',
#   'second',
#   'buckle',
#   'fastener',
#   'members',
#   'which',
#   'may',
#   'be',
#   'selectively',
#   'fastened',
#   'together',
#   'said',
#   'first',
#   'buckle',
#   'fastener',
#   'member',
#   'of',
#   'said',
#   'second',
#   'buckle',
#   'fastener',
#   'being',
#   'secured',
#   'to',
#   'said',
#   'front',
#   'end',
#   'of',
#   'said',
#   'second',
#   'strap',
#   'member',
#   'third',
#   'buckle',
#   'fastener',
#   'including',
#   'first',
#   'and',
#   'second',
#   'buckle',
#   'fastener',
#   'members',
#   'which',
#   'may',
#   'be',
#   'selectively',
#   'fastened',
#   'together',
#   'said',
#   'first',
#   'buckle',
#   'fastener',
#   'member',
#   'of',
#   'said',
#   'third',
#   'buckle',
#   'fastener',
#   'being',
#   'secured',
#   'to',
#   'said',
#   'rear',
#   'end',
#   'of',
#   'said',
#   'first',
#   'strap',
#   'member',
#   'fourth',
#   'buckle',
#   'fastener',
#   'including',
#   'first',
#   'and',
#   'second',
#   'buckle',
#   'fastener',
#   'members',
#   'which',
#   'may',
#   'be',
#   'selectively',
#   'fastened',
#   'together',
#   'said',
#   'first',
#   'buckle',
#   'fastener',
#   'member',
#   'of',
#   'said',
#   'fourth',
#   'buckle',
#   'fastener',
#   'being',
#   'secured',
#   'to',
#   'said',
#   'rear',
#   'end',
#   'of',
#   'said',
#   'second',
#   'strap',
#   'member',
#   'third',
#   'fourth',
#   'fifth',
#   'and',
#   'sixth',
#   'flexible',
#   'strap',
#   'members',
#   'having',
#   'first',
#   'and',
#   'second',
#   'ends',
#   'said',
#   'first',
#   'ends',
#   'of',
#   'said',
#   'third',
#   'fourth',
#   'fifth',
#   'and',
#   'sixth',
#   'strap',
#   'members',
#   'being',
#   'secured',
#   'to',
#   'said',
#   'second',
#   'buckle',
#   'fastener',
#   'members',
#   'of',
#   'said',
#   'first',
#   'second',
#   'third',
#   'and',
#   'fourth',
#   'buckle',
#   'fasteners',
#   'respectively',
#   'by',
#   'hook',
#   'and',
#   'loop',
#   'fasteners',
#   'said',
#   'shirt',
#   'having',
#   'first',
#   'and',
#   'second',
#   'spaced',
#   'apart',
#   'openings',
#   'formed',
#   'in',
#   'said',
#   'front',
#   'thereof',
#   'above',
#   'said',
#   'duty',
#   'belt',
#   'so',
#   'that',
#   'said',
#   'third',
#   'and',
#   'fourth',
#   'strap',
#   'members',
#   'may',
#   'extend',
#   'outwardly',
#   'therethrough',
#   'to',
#   'said',
#   'outer',
#   'surface',
#   'of',
#   'said',
#   'shirt',
#   'said',
#   'shirt',
#   'having',
#   'third',
#   'and',
#   'fourth',
#   'spaced',
#   'apart',
#   'openings',
#   'formed',
#   'in',
#   'said',
#   'back',
#   'thereof',
#   'above',
#   'said',
#   'duty',
#   'belt',
#   'so',
#   'that',
#   'said',
#   'fifth',
#   'and',
#   'sixth',
#   'strap',
#   'members',
#   'may',
#   'extend',
#   'outwardly',
#   'therethrough',
#   'to',
#   'said',
#   'outer',
#   'surface',
#   'of',
#   'said',
#   'shirt',
#   'each',
#   'of',
#   'said',
#   'second',
#   'ends',
#   'of',
#   'said',
#   'third',
#   'fourth',
#   'fifth',
#   'and',
#   'sixth',
#   'strap',
#   'members',
#   'having',
#   'belt',
#   'loop',
#   'thereon',
#   'adapted',
#   'to',
#   'have',
#   'said',
#   'duty',
#   'belt',
#   'extending',
#   'therethrough',
#   'so',
#   'that',
#   'at',
#   'least',
#   'some',
#   'of',
#   'the',
#   'weight',
#   'of',
#   'said',
#   'duty',
#   'belt',
#   'is',
#   'carried',
#   'by',
#   'the',
#   'shoulders',
#   'of',
#   'the',
#   'officer',
#   'peace',
#   'officer',
#   'shirt',
#   'having',
#   'front',
#   'back',
#   'sleeves',
#   'and',
#   'tail',
#   'which',
#   'is',
#   'worn',
#   'tucked',
#   'into',
#   'the',
#   'wearer',
#   'pants',
#   'said',
#   'shirt',
#   'having',
#   'an',
#   'inner',
#   'surface',
#   'and',
#   'an',
#   'outer',
#   'surface',
#   'peace',
#   'officer',
#   'duty',
#   'belt',
#   'extending',
#   'around',
#   'the',
#   'officer',
#   'waist',
#   'which',
#   'supports',
#   'heavy',
#   'gear',
#   'suspender',
#   'set',
#   'comprising',
#   'first',
#   'and',
#   'second',
#   'flexible',
#   'strap',
#   'members',
#   'said',
#   'suspender',
#   'set',
#   'intended',
#   'to',
#   'be',
#   'worn',
#   'under',
#   'the',
#   'officer',
#   'shirt',
#   'and',
#   'to',
#   'extend',
#   'over',
#   'the',
#   'officers',
#   'shoulders',
#   'each',
#   'of',
#   'said',
#   'first',
#   'and',
#   'second',
#   'strap',
#   'members',
#   'having',
#   'front',
#   'end',
#   'and',
#   'rear',
#   'end',
#   'first',
#   'buckle',
#   'fastener',
#   'including',
#   'first',
#   'and',
#   'second',
#   'buckle',
#   'fastener',
#   'members',
#   'which',
#   'may',
#   'be',
#   'selectively',
#   'fastened',
#   'together',
#   'said',
#   'first',
#   'buckle',
#   'fastener',
#   'member',
#   'of',
#   'said',
#   'first',
#   'buckle',
#   'fastener',
#   'means',
#   'being',
#   'secured',
#   'to',
#   'said',
#   'front',
#   'end',
#   'of',
#   'said',
#   'first',
#   'strap',
#   'member',
#   'second',
#   'buckle',
#   'fastener',
#   'including',
#   'first',
#   'and',
#   'second',
#   'buckle',
#   'fastener',
#   'members',
#   'which',
#   'may',
#   'be',
#   'selectively',
#   'fastened',
#   'together',
#   'said',
#   'first',
#   'buckle',
#   'fastener',
#   'member',
#   'of',
#   'said',
#   'second',
#   'buckle',
#   'fastener',
#   'being',
#   'secured',
#   'to',
#   'said',
#   'front',
#   'end',
#   'of',
#   'said',
#   'second',
#   'strap',
#   'member',
#   'third',
#   'buckle',
#   'fastener',
#   'including',
#   'first',
#   'and',
#   'second',
#   'buckle',
#   'fastener',
#   'members',
#   'which',
#   'may',
#   'be',
#   'selectively',
#   'fastened',
#   'together',
#   'said',
#   'first',
#   'buckle',
#   'fastener',
#   'member',
#   'of',
#   'said',
#   'third',
#   'buckle',
#   'fastener',
#   'being',
#   'secured',
#   'to',
#   'said',
#   'rear',
#   'end',
#   'of',
#   'said',
#   'first',
#   'strap',
#   'member',
#   'fourth',
#   'buckle',
#   'fastener',
#   'including',
#   'first',
#   'and',
#   'second',
#   'buckle',
#   'fastener',
#   'members',
#   'which',
#   'may',
#   'be',
#   'selectively',
#   'fastened',
#   'together',
#   'said',
#   'first',
#   'buckle',
#   'fastener',
#   'member',
#   'of',
#   'said',
#   'fourth',
#   'buckle',
#   'fastener',
#   'being',
#   'secured',
#   'to',
#   'said',
#   'rear',
#   'end',
#   'of',
#   'said',
#   'second',
#   'strap',
#   'member',
#   'third',
#   'fourth',
#   'fifth',
#   'and',
#   'sixth',
#   'flexible',
#   'strap',
#   'members',
#   'having',
#   'first',
#   'and',
#   'second',
#   'ends',
#   'said',
#   'first',
#   'ends',
#   'of',
#   'said',
#   'third',
#   'fourth',
#   'fifth',
#   'and',
#   'sixth',
#   'strap',
#   'members',
#   'being',
#   'secured',
#   'to',
#   'said',
#   'second',
#   'buckle',
#   'fastener',
#   'members',
#   'of',
#   'said',
#   'first',
#   'second',
#   'third',
#   'and',
#   'fourth',
#   'buckle',
#   'fasteners',
#   'respectively',
#   'by',
#   'hook',
#   'and',
#   'loop',
#   'fasteners',
#   'said',
#   'shirt',
#   'having',
#   'first',
#   'and',
#   'second',
#   'spaced',
#   'apart',
#   'openings',
#   'formed',
#   'in',
#   'said',
#   'front',
#   'thereof',
#   'above',
#   'said',
#   'duty',
#   'belt',
#   'so',
#   'that',
#   'said',
#   'third',
#   'and',
#   'fourth',
#   'strap',
#   'members',
#   'may',
#   'extend',
#   'outwardly',
#   'therethrough',
#   'to',
#   'said',
#   'outer',
#   'surface',
#   'of',
#   'said',
#   'shirt',
#   'said',
#   'shirt',
#   'having',
#   'third',
#   'and',
#   'fourth',
#   'spaced',
#   'apart',
#   'openings',
#   'formed',
#   'in',
#   'said',
#   'back',
#   'thereof',
#   'above',
#   'said',
#   'duty',
#   'belt',
#   'so',
#   'that',
#   'said',
#   'fifth',
#   'and',
#   'sixth',
#   'strap',
#   'members',
#   'may',
#   'extend',
#   'outwardly',
#   'therethrough',
#   'to',
#   'said',
#   'outer',
#   'surface',
#   'of',
#   'said',
#   'shirt',
#   'each',
#   'of',
#   'said',
#   'second',
#   'ends',
#   'of',
#   'said',
#   'third',
#   'fourth',
#   'fifth',
#   'and',
#   'sixth',
#   'strap',
#   'members',
#   'having',
#   'belt',
#   'loop',
#   'thereon',
#   'adapted',
#   'to',
#   'have',
#   'said',
#   'duty',
#   'belt',
#   'extending',
#   'therethrough',
#   'so',
#   'that',
#   'at',
#   'least',
#   'some',
#   'of',
#   'the',
#   'weight',
#   'of',
#   'said',
#   'duty',
#   'belt',
#   'is',
#   'carried',
#   'by',
#   'the',
#   'shoulders',
#   'of',
#   'the',
#   'officer',
#   'the',
#   'combination',
#   'of',
#   'claim',
#   'wherein',
#   'each',
#   'of',
#   'said',
#   'first',
#   'and',
#   'second',
#   'strap',
#   'members',
#   'are',
#   'length',
#   'adjustable',
#   'the',
#   'combination',
#   'of',
#   'claim',
#   'wherein',
#   'each',
#   'of',
#   'said',
#   'first',
#   'second',
#   'third',
#   'and',
#   'fourth',
#   'buckle',
#   'fasteners',
#   'are',
#   'of',
#   'the',
#   'side',
#   'release',
#   'type',
#   'in',
#   'combination',
#   'peace',
#   'officer',
#   'shirt',
#   'having',
#   'front',
#   'back',
#   'sleeves',
#   'and',
#   'tail',
#   'which',
#   'is',
#   'worn',
#   'tucked',
#   'into',
#   'the',
#   'officer',
#   'pants',
#   'said',
#   'shirt',
#   'having',
#   'an',
#   'inner',
#   'surface',
#   'and',
#   'an',
#   'outer',
#   'surface',
#   'peace',
#   'officer',
#   'duty',
#   'belt',
#   'extending',
#   'around',
#   'the',
#   'officer',
#   'waist',
#   'and',
#   'which',
#   'supports',
#   'heavy',
#   'gear',
#   'suspender',
#   'set',
#   'comprising',
#   'first',
#   'and',
#   'second',
#   'flexible',
#   'strap',
#   'members',
#   'having',
#   'front',
#   'and',
#   'rear',
#   'ends',
#   'said',
#   'suspender',
#   'set',
#   'intended',
#   'to',
#   'be',
#   'worn',
#   'under',
#   'the',
#   'officer',
#   'shirt',
#   'and',
#   'to',
#   'extend',
#   'over',
#   'the',
#   'officer',
#   'shoulders',
#   'first',
#   'buckle',
#   'fastener',
#   'including',
#   'first',
#   'and',
#   'second',
#   'buckle',
#   'fastener',
#   'members',
#   'which',
#   'may',
#   'be',
#   'selectively',
#   'fastened',
#   'together',
#   'said',
#   'first',
#   'buckle',
#   'fastener',
#   'member',
#   'of',
#   'said',
#   'first',
#   'buckle',
#   'fastener',
#   'means',
#   'being',
#   'secured',
#   'to',
#   'said',
#   'front',
#   'end',
#   'of',
#   'said',
#   'first',
#   'strap',
#   'member',
#   'second',
#   'buckle',
#   'fastener',
#   'including',
#   ...],
#  '07891025': ['protective',
#   'device',
#   'for',
#   'eyes',
#   'for',
#   'example',
#   'goggles',
#   'of',
#   'shield',
#   'includes',
#   'double',
#   'lens',
#   'member',
#   'frame',
#   'member',
#   'and',
#   'face',
#   'fixation',
#   'member',
#   'the',
#   'double',
#   'lens',
#   'member',
#   'includes',
#   'front',
#   'lens',
#   'back',
#   'lens',
#   'and',
#   'gasket',
#   'the',
#   'front',
#   'lens',
#   'and',
#   'the',
#   'back',
#   'lens',
#   'are',
#   'made',
#   'of',
#   'polycarbonate',
#   'resins',
#   'polyurethane',
#   'resins',
#   'polyester',
#   'resins',
#   'or',
#   'polyamide',
#   'resins',
#   'the',
#   'front',
#   'lens',
#   'and',
#   'the',
#   'back',
#   'lens',
#   'are',
#   'disposed',
#   'in',
#   'parallel',
#   'with',
#   'the',
#   'gasket',
#   'therebetween',
#   'in',
#   'order',
#   'to',
#   'form',
#   'space',
#   'surrounded',
#   'with',
#   'the',
#   'front',
#   'lens',
#   'the',
#   'back',
#   'lens',
#   'and',
#   'the',
#   'gasket',
#   'this',
#   'device',
#   'is',
#   'excellent',
#   'in',
#   'the',
#   'antifogging',
#   'property',
#   'in',
#   'the',
#   'double',
#   'lens',
#   'protective',
#   'device',
#   'for',
#   'eyes',
#   'comprising',
#   'double',
#   'lens',
#   'member',
#   'frame',
#   'member',
#   'and',
#   'face',
#   'fixation',
#   'member',
#   'wherein',
#   'the',
#   'double',
#   'lens',
#   'member',
#   'includes',
#   'front',
#   'lens',
#   'back',
#   'lens',
#   'and',
#   'gasket',
#   'the',
#   'front',
#   'lens',
#   'and',
#   'the',
#   'back',
#   'lens',
#   'are',
#   'made',
#   'of',
#   'any',
#   'one',
#   'of',
#   'polycarbonate',
#   'resins',
#   'polyurethane',
#   'resins',
#   'polyester',
#   'resins',
#   'and',
#   'polyamide',
#   'resins',
#   'and',
#   'the',
#   'front',
#   'lens',
#   'and',
#   'the',
#   'back',
#   'lens',
#   'are',
#   'disposed',
#   'in',
#   'parallel',
#   'with',
#   'the',
#   'gasket',
#   'therebetween',
#   'to',
#   'form',
#   'space',
#   'surrounded',
#   'with',
#   'the',
#   'front',
#   'lens',
#   'the',
#   'back',
#   'lens',
#   'and',
#   'the',
#   'gasket',
#   'and',
#   'wherein',
#   'the',
#   'gasket',
#   'is',
#   'made',
#   'of',
#   'resin',
#   'with',
#   'thickness',
#   'of',
#   'about',
#   'to',
#   'mm',
#   'and',
#   'width',
#   'of',
#   'about',
#   'to',
#   'mm',
#   'and',
#   'back',
#   'curve',
#   'side',
#   'of',
#   'the',
#   'front',
#   'lens',
#   'and',
#   'front',
#   'curve',
#   'side',
#   'of',
#   'the',
#   'back',
#   'lens',
#   'are',
#   'fixed',
#   'via',
#   'the',
#   'gasket',
#   'with',
#   'binding',
#   'agent',
#   'or',
#   'adhesive',
#   'agent',
#   'the',
#   'double',
#   'lens',
#   'member',
#   'includes',
#   'front',
#   'lens',
#   'back',
#   'lens',
#   'and',
#   'gasket',
#   'the',
#   'front',
#   'lens',
#   'and',
#   'the',
#   'back',
#   'lens',
#   'are',
#   'made',
#   'of',
#   'any',
#   'one',
#   'of',
#   'polycarbonate',
#   'resins',
#   'polyurethane',
#   'resins',
#   'polyester',
#   'resins',
#   'and',
#   'polyamide',
#   'resins',
#   'andthe',
#   'front',
#   'lens',
#   'and',
#   'the',
#   'back',
#   'lens',
#   'are',
#   'disposed',
#   'in',
#   'parallel',
#   'with',
#   'the',
#   'gasket',
#   'therebetween',
#   'to',
#   'form',
#   'space',
#   'surrounded',
#   'with',
#   'the',
#   'front',
#   'lens',
#   'the',
#   'back',
#   'lens',
#   'and',
#   'the',
#   'gasket',
#   'and',
#   'whereinthe',
#   'gasket',
#   'is',
#   'made',
#   'of',
#   'resin',
#   'with',
#   'thickness',
#   'of',
#   'about',
#   'to',
#   'mm',
#   'and',
#   'width',
#   'of',
#   'about',
#   'to',
#   'mm',
#   'and',
#   'back',
#   'curve',
#   'side',
#   'of',
#   'the',
#   'front',
#   'lens',
#   'and',
#   'front',
#   'curve',
#   'side',
#   'of',
#   'the',
#   'back',
#   'lens',
#   'are',
#   'fixed',
#   'via',
#   'the',
#   'gasket',
#   'with',
#   'binding',
#   'agent',
#   'or',
#   'adhesive',
#   'agent',
#   'the',
#   'protective',
#   'device',
#   'for',
#   'eyes',
#   'according',
#   'to',
#   'claim',
#   'wherein',
#   'the',
#   'front',
#   'lens',
#   'has',
#   'any',
#   'one',
#   'of',
#   'an',
#   'aspheric',
#   'shape',
#   'spherical',
#   'shape',
#   'and',
#   'cylindrical',
#   'shape',
#   'and',
#   'is',
#   'made',
#   'thinner',
#   'from',
#   'center',
#   'toward',
#   'lens',
#   'rim',
#   'for',
#   'refraction',
#   'collection',
#   'the',
#   'protective',
#   'device',
#   'for',
#   'eyes',
#   'according',
#   'to',
#   'claim',
#   'wherein',
#   'the',
#   'back',
#   'lens',
#   'is',
#   'made',
#   'from',
#   'any',
#   'one',
#   'of',
#   'lens',
#   'sheet',
#   'and',
#   'molded',
#   'sheet',
#   'with',
#   'thickness',
#   'of',
#   'to',
#   'mm',
#   'and',
#   'has',
#   'any',
#   'one',
#   'of',
#   'an',
#   'aspheric',
#   'shape',
#   'spherical',
#   'shape',
#   'and',
#   'cylindrical',
#   'shape',
#   'approximately',
#   'same',
#   'as',
#   'the',
#   'front',
#   'lens',
#   'the',
#   'protective',
#   'device',
#   'for',
#   'eyes',
#   'according',
#   'to',
#   'claim',
#   'wherein',
#   'the',
#   'front',
#   'lens',
#   'is',
#   'made',
#   'from',
#   'any',
#   'one',
#   'of',
#   'lens',
#   'sheet',
#   'and',
#   'molded',
#   'sheet',
#   'with',
#   'thickness',
#   'of',
#   'to',
#   'mm',
#   'back',
#   'lens',
#   'is',
#   'made',
#   'from',
#   'lens',
#   'sheet',
#   'with',
#   'thickness',
#   'of',
#   'to',
#   'mm',
#   'and',
#   'the',
#   'double',
#   'lens',
#   'member',
#   'has',
#   'cylindrical',
#   'shape',
#   'the',
#   'front',
#   'lens',
#   'is',
#   'made',
#   'from',
#   'any',
#   'one',
#   'of',
#   'lens',
#   'sheet',
#   'and',
#   'molded',
#   'sheet',
#   'with',
#   'thickness',
#   'of',
#   'to',
#   'mm',
#   'back',
#   'lens',
#   'is',
#   'made',
#   'from',
#   'lens',
#   'sheet',
#   'with',
#   'thickness',
#   'of',
#   'to',
#   'mm',
#   'andthe',
#   'double',
#   'lens',
#   'member',
#   'has',
#   'cylindrical',
#   'shape',
#   'the',
#   'protective',
#   'device',
#   'for',
#   'eyes',
#   'according',
#   'to',
#   'claim',
#   'wherein',
#   'back',
#   'curve',
#   'side',
#   'of',
#   'the',
#   'back',
#   'lens',
#   'is',
#   'treated',
#   'with',
#   'an',
#   'antifogging',
#   'agent',
#   'the',
#   'protective',
#   'device',
#   'for',
#   'eyes',
#   'according',
#   'to',
#   'claim',
#   'wherein',
#   'resin',
#   'sheet',
#   'with',
#   'antifogging',
#   'properties',
#   'having',
#   'any',
#   'one',
#   'of',
#   'an',
#   'aspheric',
#   'shape',
#   'spherical',
#   'shape',
#   'and',
#   'cylindrical',
#   'shape',
#   'approximately',
#   'same',
#   'as',
#   'the',
#   'back',
#   'lens',
#   'is',
#   'layered',
#   'on',
#   'back',
#   'curve',
#   'side',
#   'of',
#   'the',
#   'back',
#   'lens',
#   'the',
#   'protective',
#   'device',
#   'for',
#   'eyes',
#   'according',
#   'to',
#   'claim',
#   'wherein',
#   'at',
#   'least',
#   'one',
#   'pressure',
#   'adjusting',
#   'hole',
#   'is',
#   'provided',
#   'at',
#   'the',
#   'back',
#   'lens',
#   'for',
#   'pressure',
#   'adjustment',
#   'of',
#   'the',
#   'space',
#   'surrounded',
#   'with',
#   'the',
#   'front',
#   'lens',
#   'the',
#   'back',
#   'lens',
#   'and',
#   'the',
#   'gasket',
#   'the',
#   'protective',
#   'device',
#   'for',
#   'eyes',
#   'according',
#   'to',
#   'claim',
#   'wherein',
#   'at',
#   'least',
#   'one',
#   'pressure',
#   'adjusting',
#   'hole',
#   'is',
#   'provided',
#   'at',
#   'the',
#   'gasket',
#   'for',
#   'pressure',
#   'adjustment',
#   'of',
#   'the',
#   'space',
#   'surrounded',
#   'with',
#   'the',
#   'front',
#   'lens',
#   'the',
#   'back',
#   'lens',
#   'and',
#   'the',
#   'gasket',
#   'the',
#   'protective',
#   'device',
#   'for',
#   'eyes',
#   'according',
#   'to',
#   'claim',
#   'wherein',
#   'an',
#   'air',
#   'permeable',
#   'gasket',
#   'is',
#   'used',
#   'for',
#   'pressure',
#   'adjustment',
#   'of',
#   'the',
#   'space',
#   'surrounded',
#   'with',
#   'the',
#   'front',
#   'lens',
#   'the',
#   'back',
#   'lens',
#   'and',
#   'the',
#   'gasket',
#   'the',
#   'protective',
#   'device',
#   'for',
#   'eyes',
#   'according',
#   'to',
#   'claim',
#   'wherein',
#   'the',
#   'pressure',
#   'adjusting',
#   'hole',
#   'is',
#   'covered',
#   'with',
#   'breathable',
#   'member',
#   'which',
#   'is',
#   'permeable',
#   'to',
#   'water',
#   'vapor',
#   'but',
#   'impermeable',
#   'to',
#   'water',
#   'the',
#   'protective',
#   'device',
#   'for',
#   'eyes',
#   'according',
#   'to',
#   'claim',
#   'wherein',
#   'the',
#   'pressure',
#   'adjusting',
#   'hole',
#   'is',
#   'covered',
#   'with',
#   'breathable',
#   'member',
#   'which',
#   'is',
#   'permeable',
#   'to',
#   'water',
#   'vapor',
#   'but',
#   'impermeable',
#   'to',
#   'water',
#   'the',
#   'protective',
#   'device',
#   'for',
#   'eyes',
#   'according',
#   'to',
#   'claim',
#   'wherein',
#   'the',
#   'air',
#   'permeable',
#   'gasket',
#   'is',
#   'covered',
#   'with',
#   'breathable',
#   'member',
#   'which',
#   'is',
#   'permeable',
#   'to',
#   'water',
#   'vapor',
#   'but',
#   'impermeable',
#   'to',
#   'water'],
#  '07891026': ['athletic',
#   'apparel',
#   'containing',
#   'protective',
#   'underlayer',
#   'comprising',
#   'molded',
#   'foam',
#   'padding',
#   'that',
#   'are',
#   'shaped',
#   'and',
#   'curved',
#   'to',
#   'match',
#   'the',
#   'anatomical',
#   'regions',
#   'to',
#   'reduce',
#   'the',
#   'bulk',
#   'of',
#   'the',
#   'underlayers',
#   'the',
#   'molded',
#   'foam',
#   'pads',
#   'perforated',
#   'structure',
#   'to',
#   'allow',
#   'for',
#   'increased',
#   'flexibility',
#   'and',
#   'ventilation',
#   'protective',
#   'underlayers',
#   'that',
#   'surround',
#   'regions',
#   'of',
#   'motion',
#   'such',
#   'as',
#   'the',
#   'hip',
#   'joint',
#   'are',
#   'notched',
#   'to',
#   'provide',
#   'articulation',
#   'of',
#   'the',
#   'protective',
#   'underlayer',
#   'that',
#   'will',
#   'improve',
#   'mobility',
#   'of',
#   'the',
#   'athletic',
#   'apparel',
#   'wearer',
#   'protective',
#   'lower',
#   'body',
#   'garment',
#   'comprising',
#   'garment',
#   'fabric',
#   'for',
#   'covering',
#   'portion',
#   'of',
#   'wearer',
#   'body',
#   'and',
#   'hip',
#   'padded',
#   'underlayer',
#   'attached',
#   'to',
#   'said',
#   'fabric',
#   'and',
#   'positioned',
#   'to',
#   'be',
#   'disposed',
#   'over',
#   'wearer',
#   'hip',
#   'joint',
#   'specifically',
#   'wearer',
#   'iliac',
#   'crest',
#   'femoral',
#   'head',
#   'femoral',
#   'neck',
#   'and',
#   'greater',
#   'trochanter',
#   'said',
#   'underlayer',
#   'incorporating',
#   'contoured',
#   'molded',
#   'foam',
#   'pad',
#   'with',
#   'triangular',
#   'notch',
#   'cut',
#   'to',
#   'be',
#   'disposed',
#   'adjacent',
#   'wearer',
#   'axis',
#   'of',
#   'rotation',
#   'of',
#   'the',
#   'hip',
#   'joint',
#   'during',
#   'running',
#   'or',
#   'walking',
#   'point',
#   'of',
#   'said',
#   'triangular',
#   'notch',
#   'cut',
#   'being',
#   'located',
#   'on',
#   'the',
#   'wearer',
#   'axis',
#   'of',
#   'rotation',
#   'of',
#   'the',
#   'hip',
#   'joint',
#   'wherein',
#   'the',
#   'notch',
#   'cut',
#   'extends',
#   'substantially',
#   'from',
#   'the',
#   'wearer',
#   'axis',
#   'of',
#   'rotation',
#   'of',
#   'the',
#   'hip',
#   'joint',
#   'to',
#   'perimeter',
#   'edge',
#   'of',
#   'the',
#   'padded',
#   'underlayer',
#   'garment',
#   'fabric',
#   'for',
#   'covering',
#   'portion',
#   'of',
#   'wearer',
#   'body',
#   'anda',
#   'hip',
#   'padded',
#   'underlayer',
#   'attached',
#   'to',
#   'said',
#   'fabric',
#   'and',
#   'positioned',
#   'to',
#   'be',
#   'disposed',
#   'over',
#   'wearer',
#   'hip',
#   'joint',
#   'specifically',
#   'wearer',
#   'iliac',
#   'crest',
#   'femoral',
#   'head',
#   'femoral',
#   'neck',
#   'and',
#   'greater',
#   'trochanter',
#   'said',
#   'underlayer',
#   'incorporating',
#   'contoured',
#   'molded',
#   'foam',
#   'pad',
#   'with',
#   'triangular',
#   'notch',
#   'cut',
#   'to',
#   'be',
#   'disposed',
#   'adjacent',
#   'wearer',
#   'axis',
#   'of',
#   'rotation',
#   'of',
#   'the',
#   'hip',
#   'joint',
#   'during',
#   'running',
#   'or',
#   'walking',
#   'point',
#   'of',
#   'said',
#   'triangular',
#   'notch',
#   'cut',
#   'being',
#   'located',
#   'on',
#   'the',
#   'wearer',
#   'axis',
#   'of',
#   'rotation',
#   'of',
#   'the',
#   'hip',
#   'joint',
#   'wherein',
#   'the',
#   'notch',
#   'cut',
#   'extends',
#   'substantially',
#   'from',
#   'the',
#   'wearer',
#   'axis',
#   'of',
#   'rotation',
#   'of',
#   'the',
#   'hip',
#   'joint',
#   'to',
#   'perimeter',
#   'edge',
#   'of',
#   'the',
#   'padded',
#   'underlayer',
#   'the',
#   'garment',
#   'of',
#   'claim',
#   'wherein',
#   'said',
#   'foam',
#   'pad',
#   'has',
#   'non',
#   'perforated',
#   'continuous',
#   'region',
#   'surrounding',
#   'perforated',
#   'region',
#   'the',
#   'garment',
#   'of',
#   'claim',
#   'wherein',
#   'said',
#   'perforated',
#   'region',
#   'comprises',
#   'repeating',
#   'grid',
#   'of',
#   'perforations',
#   'the',
#   'garment',
#   'of',
#   'claim',
#   'wherein',
#   'said',
#   'repeating',
#   'grid',
#   'comprises',
#   'interlocking',
#   'hexagonal',
#   'units',
#   'each',
#   'said',
#   'unit',
#   'formed',
#   'by',
#   'triangular',
#   'perforations',
#   'arranged',
#   'around',
#   'center',
#   'point',
#   'to',
#   'form',
#   'ribs',
#   'therebetween',
#   'the',
#   'garment',
#   'of',
#   'claim',
#   'wherein',
#   'said',
#   'repeating',
#   'grid',
#   'comprises',
#   'triangular',
#   'perforations',
#   'the',
#   'garment',
#   'of',
#   'claim',
#   'wherein',
#   'said',
#   'perforations',
#   'are',
#   'in',
#   'the',
#   'shape',
#   'of',
#   'equilateral',
#   'triangles',
#   'protective',
#   'lower',
#   'body',
#   'garment',
#   'comprising',
#   'garment',
#   'fabric',
#   'for',
#   'covering',
#   'portion',
#   'of',
#   'wearer',
#   'body',
#   'hip',
#   'padded',
#   'underlayer',
#   'attached',
#   'to',
#   'said',
#   'fabric',
#   'and',
#   'positioned',
#   'to',
#   'be',
#   'disposed',
#   'over',
#   'wearer',
#   'hip',
#   'joint',
#   'specifically',
#   'wearer',
#   'iliac',
#   'crest',
#   'femoral',
#   'head',
#   'femoral',
#   'neck',
#   'and',
#   'greater',
#   'trochanter',
#   'said',
#   'underlayer',
#   'including',
#   'notch',
#   'cut',
#   'to',
#   'be',
#   'disposed',
#   'adjacent',
#   'wearer',
#   'axis',
#   'of',
#   'rotation',
#   'of',
#   'the',
#   'hip',
#   'joint',
#   'during',
#   'running',
#   'or',
#   'walking',
#   'said',
#   'notch',
#   'cut',
#   'having',
#   'shape',
#   'generally',
#   'bounded',
#   'by',
#   'first',
#   'radius',
#   'of',
#   'circle',
#   'and',
#   'second',
#   'radius',
#   'of',
#   'circle',
#   'the',
#   'circle',
#   'having',
#   'its',
#   'center',
#   'on',
#   'the',
#   'wearer',
#   'axis',
#   'of',
#   'rotation',
#   'of',
#   'the',
#   'hip',
#   'joint',
#   'wherein',
#   'the',
#   'notch',
#   'cut',
#   'extends',
#   'substantially',
#   'from',
#   'the',
#   'wearer',
#   'axis',
#   'of',
#   'rotation',
#   'of',
#   'the',
#   'hip',
#   'joint',
#   'to',
#   'perimeter',
#   'edge',
#   'of',
#   'the',
#   'padded',
#   'underlayer',
#   'coccyx',
#   'padded',
#   'underlayer',
#   'attached',
#   'to',
#   'said',
#   'fabric',
# ...
#   'gear',
#   'teeth',
#   'such',
#   'that',
#   'the',
#   'angular',
#   'rotational',
#   'speed',
#   'of',
#   'the',
#   'second',
#   'spline',
#   'is',
#   'relatively',
#   'slower',
#   'than',
#   'the',
#   'angular',
#   'rotational',
#   'speed',
#   'of',
#   'the',
#   'wave',
#   'generator',
#   'the',
#   'robotic',
#   'harmonic',
#   'flex',
#   'drive',
#   'of',
#   'claim',
#   'wherein',
#   'the',
#   'wave',
#   'generator',
#   'includes',
#   'second',
#   'pair',
#   'of',
#   'rollers',
#   'disposed',
#   'adjacent',
#   'to',
#   'an',
#   'outside',
#   'surface',
#   'of',
#   'the',
#   'first',
#   'spline',
#   'and',
#   'an',
#   'inner',
#   'surface',
#   'of',
#   'the',
#   'second',
#   'spline',
#   'the',
#   'robotic',
#   'harmonic',
#   'flex',
#   'drive',
#   'of',
#   'claim',
#   'including',
#   'motor',
#   'for',
#   'rotating',
#   'the',
#   'wave',
#   'generator',
#   'the',
#   'robotic',
#   'harmonic',
#   'flex',
#   'drive',
#   'of',
#   'claim',
#   'wherein',
#   'the',
#   'inner',
#   'diameter',
#   'gear',
#   'teeth',
#   'and',
#   'the',
#   'outer',
#   'diameter',
#   'gear',
#   'teeth',
#   'are',
#   'disengaged',
#   'along',
#   'minor',
#   'axis',
#   'of',
#   'the',
#   'deformed',
#   'first',
#   'and',
#   'second',
#   'splines',
#   'the',
#   'robotic',
#   'harmonic',
#   'flex',
#   'drive',
#   'of',
#   'claim',
#   'wherein',
#   'the',
#   'first',
#   'spline',
#   'is',
#   'stationary',
#   'robotic',
#   'harmonic',
#   'flex',
#   'drive',
#   'comprising',
#   'first',
#   'generally',
#   'cylindrical',
#   'spline',
#   'having',
#   'inner',
#   'diameter',
#   'gear',
#   'teeth',
#   'second',
#   'generally',
#   'cylindrical',
#   'spline',
#   'concentric',
#   'to',
#   'the',
#   'first',
#   'spline',
#   'and',
#   'having',
#   'outer',
#   'diameter',
#   'gear',
#   'teeth',
#   'and',
#   'wave',
#   'generator',
#   'comprising',
#   'pair',
#   'of',
#   'rollers',
#   'disposed',
#   'adjacent',
#   'to',
#   'an',
#   'outer',
#   'surface',
#   'of',
#   'the',
#   'first',
#   'spline',
#   'and',
#   'an',
#   'inner',
#   'surface',
#   'of',
#   'the',
#   'second',
#   'spline',
#   'wherein',
#   'the',
#   'rollers',
#   'deform',
#   'the',
#   'second',
#   'splines',
#   'into',
#   'ellipse',
#   'whereby',
#   'the',
#   'inner',
#   'diameter',
#   'gear',
#   'teeth',
#   'of',
#   'the',
#   'first',
#   'spline',
#   'engage',
#   'the',
#   'outer',
#   'diameter',
#   'gear',
#   'teeth',
#   'of',
#   'the',
#   'second',
#   'spline',
#   'along',
#   'major',
#   'axis',
#   'of',
#   'the',
#   'deformed',
#   'first',
#   'and',
#   'second',
#   'splines',
#   'first',
#   'generally',
#   'cylindrical',
#   'spline',
#   'having',
#   'inner',
#   'diameter',
#   'gear',
#   'teeth',
#   'second',
#   'generally',
#   'cylindrical',
#   'spline',
#   'concentric',
#   'to',
#   'the',
#   'first',
#   'spline',
#   'and',
#   'having',
#   'outer',
#   'diameter',
#   'gear',
#   'teeth',
#   'anda',
#   'wave',
#   'generator',
#   'comprising',
#   'pair',
#   'of',
#   'rollers',
#   'disposed',
#   'adjacent',
#   'to',
#   'an',
#   'outer',
#   'surface',
#   'of',
#   'the',
#   'first',
#   'spline',
#   'and',
#   'an',
#   'inner',
#   'surface',
#   'of',
#   'the',
#   'second',
#   'spline',
#   'wherein',
#   'the',
#   'rollers',
#   'deform',
#   'the',
#   'second',
#   'splines',
#   'into',
#   'ellipse',
#   'whereby',
#   'the',
#   'inner',
#   'diameter',
#   'gear',
#   'teeth',
#   'of',
#   'the',
#   'first',
#   'spline',
#   'engage',
#   'the',
#   'outer',
#   'diameter',
#   'gear',
#   'teeth',
#   'of',
#   'the',
#   'second',
#   'spline',
#   'along',
#   'major',
#   'axis',
#   'of',
#   'the',
#   'deformed',
#   'first',
#   'and',
#   'second',
#   'splines',
#   'the',
#   'robotic',
#   'harmonic',
#   'flex',
#   'drive',
#   'of',
#   'claim',
#   'wherein',
#   'the',
#   'outer',
#   'diameter',
#   'gear',
#   'teeth',
#   'outnumber',
#   'the',
#   'inner',
#   'diameter',
#   'gear',
#   'teeth',
#   'such',
#   'that',
#   'the',
#   'angular',
#   'rotational',
#   'speed',
#   'of',
#   'the',
#   'second',
#   'spline',
#   'is',
#   'relatively',
#   'slower',
#   'than',
#   'the',
#   'angular',
#   'rotational',
#   'speed',
#   'of',
#   'the',
#   'wave',
#   'generator',
#   'the',
#   'robotic',
#   'harmonic',
#   'flex',
#   'drive',
#   'of',
#   'claim',
#   'wherein',
#   'the',
#   'wave',
#   'generator',
#   'includes',
#   'second',
#   'pair',
#   'of',
#   'rollers',
#   'disposed',
#   'adjacent',
#   'to',
#   'an',
#   'outside',
#   'surface',
#   'of',
#   'the',
#   'first',
#   'spline',
#   'and',
#   'an',
#   'inner',
#   'surface',
#   'of',
#   'the',
#   'second',
#   'spline',
#   'the',
#   'robotic',
#   'harmonic',
#   'flex',
#   'drive',
#   'of',
#   'claim',
#   'including',
#   'motor',
#   'for',
#   'rotating',
#   'the',
#   'wave',
#   'generator',
#   'the',
#   'robotic',
#   'harmonic',
#   'flex',
#   'drive',
#   'of',
#   'claim',
#   'wherein',
#   'the',
#   'inner',
#   'diameter',
#   'gear',
#   'teeth',
#   'and',
#   'the',
#   'outer',
#   'diameter',
#   'gear',
#   'teeth',
#   'are',
#   'disengaged',
#   'along',
#   'minor',
#   'axis',
#   'of',
#   'the',
#   'deformed',
#   'first',
#   'and',
#   'second',
#   'splines',
#   'the',
#   'robotic',
#   'harmonic',
#   'flex',
#   'drive',
#   'of',
#   'claim',
#   'wherein',
#   'the',
#   'first',
#   'spline',
#   'is',
#   'stationary',
#   'robotic',
#   'harmonic',
#   'flex',
#   'drive',
#   'comprising',
#   'first',
#   'generally',
#   'cylindrical',
#   'spline',
#   'having',
#   'inner',
#   'diameter',
#   'gear',
#   'teeth',
#   'second',
#   'generally',
#   'cylindrical',
#   'spline',
#   'concentric',
#   'to',
#   'the',
#   'first',
#   'spline',
#   'and',
#   'having',
#   'outer',
#   'diameter',
#   'gear',
#   'teeth',
#   'and',
#   'wave',
#   'generator',
#   'comprising',
#   'pair',
#   'of',
#   'rollers',
#   'disposed',
#   'adjacent',
#   'to',
#   'an',
#   'outer',
#   'surface',
#   'of',
#   'the',
#   'first',
#   'spline',
#   'and',
#   'an',
#   'inner',
#   'surface',
#   'of',
#   'the',
#   'second',
#   'spline',
#   'wherein',
#   'the',
#   'rollers',
#   'deform',
#   'the',
#   'second',
#   'splines',
#   'into',
#   'ellipse',
#   'whereby',
#   'the',
#   'inner',
#   'diameter',
#   'gear',
#   'teeth',
#   'of',
#   'the',
#   'first',
#   'spline',
#   'engage',
#   'the',
#   'outer',
#   'diameter',
#   'gear',
#   'teeth',
#   'of',
#   'the',
#   'second',
#   'spline',
#   'at',
#   'pair',
#   'of',
#   'diametrically',
#   'opposed',
#   'points',
#   'and',
#   'wherein',
#   'ratio',
#   'of',
#   'outer',
#   'diameter',
#   'gear',
#   'teeth',
#   'to',
#   'inner',
#   'diameter',
#   'gear',
#   'teeth',
#   'determines',
#   'an',
#   'angular',
#   'rotational',
#   'speed',
#   'of',
#   'the',
#   'second',
#   'spline',
#   'relative',
#   'to',
#   'an',
#   'angular',
#   'rotational',
#   'speed',
#   'of',
#   'the',
#   'wave',
#   'generator',
#   'first',
#   'generally',
#   'cylindrical',
#   'spline',
#   'having',
#   'inner',
#   'diameter',
#   'gear',
#   'teeth',
#   'second',
#   'generally',
#   'cylindrical',
#   'spline',
#   'concentric',
#   'to',
#   'the',
#   'first',
#   'spline',
#   'and',
#   'having',
#   'outer',
#   'diameter',
#   'gear',
#   'teeth',
#   'anda',
#   'wave',
#   'generator',
#   'comprising',
#   'pair',
#   'of',
#   'rollers',
#   'disposed',
#   'adjacent',
#   'to',
#   'an',
#   'outer',
#   'surface',
#   'of',
#   'the',
#   'first',
#   'spline',
#   'and',
#   'an',
#   'inner',
#   'surface',
#   'of',
#   'the',
#   'second',
#   'spline',
#   'wherein',
#   'the',
#   'rollers',
#   'deform',
#   'the',
#   'second',
#   'splines',
#   'into',
#   'ellipse',
#   'whereby',
#   'the',
#   'inner',
#   'diameter',
#   'gear',
#   'teeth',
#   'of',
#   'the',
#   'first',
#   'spline',
#   'engage',
#   'the',
#   'outer',
#   'diameter',
#   'gear',
#   'teeth',
#   'of',
#   'the',
#   'second',
#   'spline',
#   'at',
#   'pair',
#   ...],
#  '07891273': ['pliers',
#   'type',
#   'insulation',
#   'stripping',
#   'tool',
#   'includes',
#   'an',
#   'adjusting',
#   'device',
#   'for',
#   'adjusting',
#   'the',
#   'cutting',
#   'profile',
#   'provided',
#   'by',
#   'the',
#   'knife',
#   'edges',
#   'of',
#   'stack',
#   'of',
#   'parallel',
#   'lamellar',
#   'cutting',
#   'blades',
#   'pivotally',
#   'connected',
#   'at',
#   'one',
#   'end',
#   'with',
#   'knife',
#   'holder',
#   'for',
#   'independent',
#   'pivotal',
#   'movement',
#   'about',
#   'first',
#   'pivot',
#   'axis',
#   'parallel',
#   'with',
#   'the',
#   'tool',
#   'handle',
#   'pivot',
#   'axis',
#   'the',
#   'knife',
#   'holder',
#   'is',
#   'connected',
#   'for',
#   'longitudinal',
#   'displacement',
#   'on',
#   'one',
#   'the',
#   'clamping',
#   'jaws',
#   'of',
#   'the',
#   'tool',
#   'handles',
#   'thereby',
#   'to',
#   'remove',
#   'severed',
#   'length',
#   'of',
#   'the',
#   'insulation',
#   'layer',
#   'from',
#   'the',
#   'insulated',
#   'conductor',
#   'knife',
#   'arrangement',
#   'for',
#   'pliers',
#   'type',
#   'insulation',
#   'stripping',
#   'tool',
#   'operable',
#   'to',
#   'strip',
#   'the',
#   'outer',
#   'insulation',
#   'layer',
#   'from',
#   'an',
#   'insulated',
#   'conductor',
#   'said',
#   'stripping',
#   'tool',
#   'including',
#   'pair',
#   'of',
#   'pivotally',
#   'connected',
#   'handles',
#   'having',
#   'adjacent',
#   'clamping',
#   'jaw',
#   'portions',
#   'comprising',
#   'knife',
#   'holder',
#   'means',
#   'including',
#   'pair',
#   'of',
#   'opposed',
#   'generally',
#   'parallel',
#   'knife',
#   'holders',
#   'respectively',
#   'connected',
#   'with',
#   'said',
#   'stripping',
#   'tool',
#   'jaw',
#   'portions',
#   'for',
#   'initial',
#   'displacement',
#   'by',
#   'said',
#   'jaw',
#   'portions',
#   'between',
#   'separated',
#   'disengaged',
#   'position',
#   'and',
#   'an',
#   'adjacent',
#   'insulation',
#   'cutting',
#   'position',
#   'and',
#   'for',
#   'subsequent',
#   'longitudinal',
#   'displacement',
#   'relative',
#   'to',
#   'said',
#   'jaw',
#   'portions',
#   'from',
#   'said',
#   'insulation',
#   'cutting',
#   'position',
#   'toward',
#   'an',
#   'insulation',
#   'stripping',
#   'position',
#   'pair',
#   'of',
#   'opposed',
#   'knives',
#   'respectively',
#   'carried',
#   'by',
#   'said',
#   'knife',
#   'holders',
#   'and',
#   'extending',
#   'toward',
#   'each',
#   'other',
#   'from',
#   'the',
#   'adjacent',
#   'surfaces',
#   'of',
#   'said',
#   'knife',
#   'holders',
#   'at',
#   'least',
#   'one',
#   'of',
#   'said',
#   'knives',
#   'comprising',
#   'stack',
#   'of',
#   'parallel',
#   'lamellar',
#   'cutting',
#   'blades',
#   'each',
#   'connected',
#   'for',
#   'independent',
#   'pivotal',
#   'displacement',
#   'relative',
#   'to',
#   'the',
#   'associated',
#   'knife',
#   'holder',
#   'said',
#   'cutting',
#   'blades',
#   'having',
#   'knife',
#   'edges',
#   'arranged',
#   'to',
#   'define',
#   'first',
#   'cutting',
#   'profile',
#   'said',
#   'lamellar',
#   'cutting',
#   'blades',
#   'being',
#   'connected',
#   'with',
#   'the',
#   'associated',
#   'knife',
#   'holder',
#   'for',
#   'pivotal',
#   'displacement',
#   'about',
#   'first',
#   'pivot',
#   'axis',
#   'parallel',
#   'with',
#   'the',
#   'tool',
#   'handle',
#   'pivot',
#   'axis',
#   'and',
#   'blade',
#   'adjustment',
#   'mechanism',
#   'for',
#   'adjusting',
#   'the',
#   'positions',
#   'of',
#   'said',
#   'cutting',
#   'blades',
#   'relative',
#   'to',
#   'the',
#   'associated',
#   'knife',
#   'holder',
#   'to',
#   'define',
#   'second',
#   'cutting',
#   'profile',
#   'corresponding',
#   'with',
#   'the',
#   'cross',
#   'sectional',
#   'configuration',
#   'of',
#   'the',
#   'insulated',
#   'conductor',
#   'said',
#   'blade',
#   'adjustment',
#   'mechanism',
#   'including',
#   'generally',
#   'cylindrical',
#   'blade',
#   'support',
#   'member',
#   'mounted',
#   'for',
#   'rotation',
#   'about',
#   'an',
#   'axis',
#   'parallel',
#   'with',
#   'said',
#   'first',
#   'pivot',
#   'axis',
#   'said',
#   'support',
#   'members',
#   'having',
#   'circumferential',
#   'surface',
#   'arranged',
#   'to',
#   'support',
#   'said',
#   'cutting',
#   'blades',
#   'said',
#   'blade',
#   'support',
#   'member',
#   'circumferential',
#   'surface',
#   'including',
#   'plurality',
#   'of',
#   'support',
#   'segments',
#   'for',
#   'defining',
#   'different',
#   'cutting',
#   'profiles',
#   'respectively',
#   'knife',
#   'holder',
#   'means',
#   'including',
#   'pair',
#   'of',
#   'opposed',
#   'generally',
#   'parallel',
#   'knife',
#   'holders',
#   'respectively',
#   'connected',
#   'with',
#   'said',
#   'stripping',
#   'tool',
#   'jaw',
#   'portions',
#   'for',
#   'initial',
#   'displacement',
#   'by',
#   'said',
#   'jaw',
#   'portions',
#   'between',
#   'separated',
#   'disengaged',
#   'position',
#   'and',
#   'an',
#   'adjacent',
#   'insulation',
#   'cutting',
#   'position',
#   'and',
#   'for',
#   'subsequent',
#   'longitudinal',
#   'displacement',
#   'relative',
#   'to',
#   'said',
#   'jaw',
#   'portions',
#   'from',
#   'said',
#   'insulation',
#   'cutting',
#   'position',
#   'toward',
#   'an',
#   'insulation',
#   'stripping',
#   'position',
#   'pair',
#   'of',
#   'opposed',
#   'knives',
#   'respectively',
#   'carried',
#   'by',
#   'said',
#   'knife',
#   'holders',
#   'and',
#   'extending',
#   'toward',
#   'each',
#   'other',
#   'from',
#   'the',
#   'adjacent',
#   'surfaces',
#   'of',
#   'said',
#   'knife',
#   'holders',
#   'at',
#   'least',
#   'one',
#   'of',
#   'said',
#   'knives',
#   'comprising',
#   'stack',
#   'of',
#   'parallel',
#   'lamellar',
#   'cutting',
#   'blades',
#   'each',
#   'connected',
#   'for',
#   'independent',
#   'pivotal',
#   'displacement',
#   'relative',
#   'to',
#   'the',
#   'associated',
#   'knife',
#   'holder',
#   'said',
#   'cutting',
#   'blades',
#   'having',
#   'knife',
#   'edges',
#   'arranged',
#   'to',
#   'define',
#   'first',
#   'cutting',
#   'profile',
#   'said',
#   'lamellar',
#   'cutting',
#   'blades',
#   'being',
#   'connected',
#   'with',
#   'the',
#   'associated',
#   'knife',
#   'holder',
#   'for',
#   'pivotal',
#   'displacement',
#   'about',
#   'first',
#   'pivot',
#   'axis',
#   'parallel',
#   'with',
#   'the',
#   'tool',
#   'handle',
#   'pivot',
#   'axis',
#   'and',
#   'blade',
#   'adjustment',
#   'mechanism',
#   'for',
#   'adjusting',
#   'the',
#   'positions',
#   'of',
#   'said',
#   'cutting',
#   'blades',
#   'relative',
#   'to',
#   'the',
#   'associated',
#   'knife',
#   'holder',
#   'to',
#   'define',
#   'second',
#   'cutting',
#   'profile',
#   'corresponding',
#   'with',
#   'the',
#   'cross',
#   'sectional',
#   'configuration',
#   'of',
#   'the',
#   'insulated',
#   'conductor',
#   'said',
#   'blade',
#   'adjustment',
#   'mechanism',
#   'including',
#   'generally',
#   'cylindrical',
#   'blade',
#   'support',
#   'member',
#   'mounted',
#   'for',
#   'rotation',
#   'about',
#   'an',
#   'axis',
#   'parallel',
#   'with',
#   'said',
#   'first',
#   'pivot',
#   'axis',
#   'said',
#   'support',
#   'members',
#   'having',
#   'circumferential',
#   'surface',
#   'arranged',
#   'to',
#   'support',
#   'said',
#   'cutting',
#   'blades',
#   'said',
#   'blade',
#   'support',
#   'member',
#   'circumferential',
#   'surface',
#   'including',
#   'plurality',
#   'of',
#   'support',
#   'segments',
#   'for',
#   'defining',
#   'different',
#   'cutting',
#   'profiles',
#   'respectively',
#   'knife',
#   'arrangement',
#   'as',
#   'defined',
#   'in',
#   'claim',
#   'wherein',
#   'one',
#   'of',
#   'said',
#   'support',
#   'segments',
#   'is',
#   'planar',
#   'thereby',
#   'to',
#   'produce',
#   'linear',
#   'arrangement',
#   'of',
#   'the',
#   'cutting',
#   'edges',
#   'of',
#   'said',
#   'cutting',
#   'blades',
#   'knife',
#   'arrangement',
#   'as',
#   'defined',
#   'in',
#   'claim',
#   'wherein',
#   'one',
#   'of',
#   'said',
#   'support',
#   'segments',
#   'is',
#   'concave',
#   'thereby',
#   'to',
#   'produce',
#   'concave',
#   'arrangement',
#   'of',
#   'the',
#   'cutting',
#   'edges',
#   'of',
#   'said',
#   'cutting',
#   'blades',
#   'knife',
#   'arrangement',
#   'as',
#   'defined',
#   'in',
#   'claim',
#   'wherein',
#   'one',
#   'of',
#   'said',
#   'support',
#   'segments',
#   'includes',
#   'angular',
#   'walls',
#   'thereby',
#   'causing',
#   'said',
#   'cutting',
#   'blade',
#   'edges',
#   'to',
#   'define',
#   'an',
#   'angular',
#   'profile',
#   'knife',
#   'arrangement',
#   'as',
#   'defined',
#   'in',
#   'claim',
#   'wherein',
#   'said',
#   'cylindrical',
#   'blade',
#   'support',
#   'member',
#   'has',
#   'an',
#   'end',
#   'surface',
#   'that',
#   'contains',
#   'slit',
#   'for',
#   'receiving',
#   'the',
#   'tip',
#   'of',
#   'an',
#   'adjusting',
#   'screwdriver',
#   'knife',
#   'arrangement',
#   'as',
#   'defined',
#   'in',
#   'claim',
#   'wherein',
#   'said',
#   'cutting',
#   'blades',
#   'include',
#   'corresponding',
#   'flat',
#   'surfaces',
#   'arranged',
#   'for',
#   'engagement',
#   'with',
#   'the',
#   'circumferential',
#   'surface',
#   'of',
#   'said',
#   'blade',
#   'support',
#   'member',
#   'knife',
#   'arrangement',
#   'as',
#   'defined',
#   'in',
#   'claim',
#   'wherein',
#   'said',
#   'cylindrical',
#   'blade',
#   'support',
#   'member',
#   'includes',
#   'circular',
#   'end',
#   'flange',
#   'portions',
#   'rotatably',
#   'and',
#   'removably',
#   'mounted',
#   'in',
#   'corresponding',
#   'side',
#   'wall',
#   'bores',
#   'contained',
#   'in',
#   'the',
#   'knife',
#   'holder',
#   'thereby',
#   'to',
#   'permit',
#   'the',
#   'substitution',
#   'of',
#   'different',
#   'blade',
#   'support',
#   'members',
#   'to',
#   'produce',
#   'different',
#   'cutting',
#   'profiles']}

# %% [markdown]
# ## 5.  Generate the 100 bigram collocations
# The next task is go generate the bigram collocations, given the tokenized patents.
#
# The first step is to concatenate all the tokenized patents using the chain.frome_iterable function. The returned list
# by the function contains a list of all the words seprated by while space.

# %%
all_words = list(chain.from_iterable(patents_tokenized.values()))

# %% [markdown]
# The second step is to generate the 100 bigram cllocations. The functions you need include
# * BigramAssocMeasures()
# * BigramCollocationFinder.from_words()
# * apply_freq_filter(20)
# * apply_word_filter(lambda w: len(w) < 3)
# * nbest(bigram_measures.pmi, 100)
#
# Please do not change the parameters given in the last three function. More information about generating collocation with NLTK can be found http://www.nltk.org/howto/collocations.html.

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
bigram_finder = nltk.collocations.BigramCollocationFinder.from_words(all_words)
bigram_finder.apply_freq_filter(20)
bigram_finder.apply_word_filter(lambda w: len(w) < 3)# or w.lower() in ignored_words)
top_100_bigrams = bigram_finder.nbest(bigram_measures.pmi, 100) # Top-100 bigrams
top_100_bigrams
# Out:
# [('harmonic', 'flex'),
#  ('centrifugally', 'balanced'),
#  ('robotic', 'harmonic'),
#  ('expandable', 'chuck'),
#  ('group', 'consisting'),
#  ('charge', 'consistent'),
#  ('walk', 'behind'),
#  ('improperly', 'swapped'),
#  ('saw', 'resonator'),
#  ('behind', 'mowing'),
#  ('jute', 'fibers'),
#  ('actuator', 'flag'),
#  ('elastic', 'band'),
#  ('lead', 'frames'),
#  ('drain', 'vent'),
#  ('fresh', 'food'),
#  ('high', 'humidity'),
#  ('paper', 'particles'),
#  ('fringe', 'maker'),
#  ('ultrasonic', 'test'),
#  ('foot', 'pedal'),
#  ('elastomeric', 'mat'),
#  ('capacitor', 'devices'),
#  ('loaded', 'bag'),
#  ('hammermilled', 'straw'),
#  ('flash', 'tank'),
#  ('tank', 'receiver'),
#  ('hip', 'joint'),
#  ('does', 'not'),
#  ('duty', 'belt'),
#  ('drier', 'solid'),
#  ('solid', 'phase'),
#  ('removable', 'joining'),
#  ('cooler', 'box'),
#  ('not', 'exceed'),
#  ('cross', 'sectional'),
#  ('case', 'packer'),
#  ('vacuum', 'electronic'),
#  ('driver', 'pulley'),
#  ('mowing', 'machine'),
#  ('fastened', 'together'),
#  ('storage', 'capacity'),
#  ('bus', 'bars'),
#  ('provide', 'circulating'),
#  ('set', 'forth'),
#  ('force', 'translation'),
#  ('lock', 'guard'),
#  ('relatively', 'drier'),
#  ('outwardly', 'protruding'),
#  ('hand', 'crank'),
#  ('well', 'plug'),
#  ('coil', 'wires'),
#  ('threaded', 'stud'),
#  ('condemned', 'condition'),
#  ('living', 'hinge'),
#  ('ending', 'point'),
#  ('magazine', 'well'),
#  ('spaced', 'apart'),
#  ('test', 'probe'),
#  ('incline', 'angle'),
#  ('retainer', 'tab'),
#  ('liquid', 'dielectric'),
#  ('shift', 'drum'),
#  ('wringing', 'tube'),
#  ('flex', 'drive'),
#  ('timing', 'pulley'),
#  ('starting', 'point'),
#  ('relatively', 'wet'),
#  ('shift', 'spindle'),
#  ('bus', 'bar'),
#  ('moisture', 'removal'),
#  ('photoreceptor', 'substrate'),
#  ('cat', 'oxygen'),
#  ('fuel', 'ratio'),
#  ('elongate', 'strength'),
#  ('securing', 'connector'),
#  ('notch', 'cut'),
#  ('time', 'period'),
#  ('directly', 'opposite'),
#  ('both', 'sides'),
#  ('less', 'than'),
#  ('multi', 'sensing'),
#  ('selectively', 'fastened'),
#  ('post', 'cat'),
#  ('catalytic', 'converter'),
#  ('joining', 'means'),
#  ('sectional', 'shape'),
#  ('winding', 'arms'),
#  ('mainspring', 'pulley'),
#  ('clamping', 'face'),
#  ('active', 'state'),
#  ('about', 'percent'),
#  ('sixth', 'strap'),
#  ('shutter', 'panel'),
#  ('composite', 'rods'),
#  ('upright', 'post'),
#  ('food', 'compartment'),
#  ('pivotally', 'coupled'),
#  ('determining', 'whether'),
#  ('arm', 'rests')]

# %% [markdown]
# ## 6. Re-tokenize the patents again.
#
# Task in Section 4 takenise the patents with only unigrams. Now, we introduce 100 collcations. we need to make sure those collocations are not split into two individual words. The tokenizer that you need is <a href="http://www.nltk.org/api/nltk.tokenize.html">MWEtokenizer</a>.

# %%
mwetokenizer = MWETokenizer(top_100_bigrams)
colloc_patents =  dict((pid, mwetokenizer.tokenize(patent)) for pid,patent in patents_tokenized.items())
all_words_colloc = list(chain.from_iterable(colloc_patents.values()))
colloc_voc = list(set(all_words_colloc))
print(len(colloc_voc))
# Out:
# 3372

# %% [markdown]
# You can check the difference between th output of MWEtokenizer and RegexpTokenizer by <font size=3>adpating</font> the following code:

# %%
for pid in patents_tokenized.keys():
    diff = set(colloc_patents[pid])-set(patents_tokenized[pid])
    if len(diff) != 0:
        print (pid, diff)
# Out:
# 07891039 {'wringing_tube'}
# 07891030 {'arm_rests'}
# 07891170 {'post_cat', 'catalytic_converter', 'storage_capacity'}
# 07891114 {'solid_phase', 'relatively_drier', 'high_humidity', 'relatively_wet', 'about_percent'}
# 07891206 {'both_sides'}
# 07891136 {'spaced_apart'}
# 07891032 {'starting_point', 'removable_joining', 'ending_point', 'group_consisting'}
# 07891273 {'cross_sectional'}
# 07891104 {'clamping_face'}
# 07891239 {'cross_sectional', 'set_forth'}
# 07891063 {'fringe_maker', 'winding_arms', 'hand_crank', 'group_consisting'}
# 07891141 {'cross_sectional'}
# 07891070 {'composite_rods', 'elongate_strength'}
# 07891158 {'case_packer', 'less_than'}
# 07891234 {'multi_sensing', 'does_not', 'determining_whether', 'condemned_condition'}
# 07891146 {'outwardly_protruding', 'directly_opposite', 'cross_sectional', 'shutter_panel'}
# 07891115 {'moisture_removal', 'less_than'}
# 07891177 {'improperly_swapped'}
# 07891026 {'notch_cut', 'hip_joint'}
# 07891161 {'mowing_machine', 'walk_behind'}
# 07891178 {'centrifugally_balanced'}
# 07891029 {'living_hinge'}
# 07891067 {'elastic_band'}
# 07891219 {'retainer_tab', 'securing_connector', 'spaced_apart', 'lock_guard'}
# 07891169 {'does_not', 'catalytic_converter', 'storage_capacity', 'less_than', 'determining_whether'}
# 07891249 {'pivotally_coupled', 'incline_angle'}
# 07891188 {'group_consisting'}
# 07891055 {'spaced_apart'}
# 07891260 {'elastomeric_mat', 'force_translation'}
# 07891173 {'catalytic_converter', 'fuel_ratio', 'active_state'}
# 07891271 {'foot_pedal'}
# 07891163 {'cross_sectional'}
# 07891242 {'liquid_dielectric'}
# 07891082 {'coil_wires'}
# 07891123 {'does_not', 'group_consisting'}
# 07891027 {'drain_vent'}
# 07891038 {'less_than'}
# 07891036 {'walk_behind'}
# 07891087 {'both_sides', 'bus_bars', 'capacitor_devices', 'bus_bar', 'lead_frames'}
# 07891248 {'test_probe', 'ultrasonic_test'}
# 07891133 {'jute_fibers', 'paper_particles', 'group_consisting', 'hammermilled_straw', 'less_than', 'about_percent'}
# 07891023 {'sixth_strap', 'spaced_apart', 'selectively_fastened', 'duty_belt'}
# 07891044 {'does_not', 'pivotally_coupled'}
# 07891262 {'both_sides', 'spaced_apart', 'shift_drum', 'shift_spindle'}
# 07891037 {'spaced_apart', 'does_not'}
# 07891041 {'does_not'}
# 07891116 {'set_forth'}
# 07891198 {'less_than', 'time_period', 'fresh_food'}
# 07891020 {'group_consisting'}
# 07891259 {'set_forth'}
# 07891252 {'saw_resonator', 'less_than'}
# 07891033 {'less_than'}
# 07891053 {'spaced_apart'}
# 07891183 {'driver_pulley', 'mainspring_pulley', 'timing_pulley'}
# 07891078 {'vacuum_electronic', 'determining_whether', 'group_consisting'}
# 07891201 {'provide_circulating', 'charge_consistent', 'flash_tank'}
# 07891084 {'threaded_stud'}
# 07891139 {'does_not', 'less_than'}
# 07891060 {'spaced_apart'}
# 07891268 {'both_sides', 'does_not'}
# 07891152 {'both_sides', 'spaced_apart', 'upright_post'}
# 07891162 {'cross_sectional'}
# 07891272 {'flex_drive', 'robotic_harmonic'}
# 07891203 {'determining_whether', 'does_not', 'cooler_box'}
# 07891111 {'spaced_apart', 'actuator_flag'}
# 07891159 {'loaded_bag', 'less_than'}
# 07891076 {'expandable_chuck', 'photoreceptor_substrate'}
# 07891129 {'magazine_well'}

# %% [markdown]
# ## 7. Generate the TF-IDF vectors for all the patents.
# Please refer to
# * http://scikit-learn.org/stable/modules/feature_extraction.html
# * http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html

# %%
pids = []
patent_words = []
for pid, tokens in colloc_patents.items():
    pids.append(pid)
    txt = ' '.join(tokens)
    patent_words.append(txt)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(input = 'content', analyzer = 'word')
tfidf_vectors = tfidf_vectorizer.fit_transform(patent_words)
tfidf_vectors.shape
# Out:
# (100, 3372)

# %% [markdown]
# ## 8. Save the TF-IDF vector into the specified format
# Hint: you can use
# * the <a href="https://docs.scipy.org/doc/scipy-0.14.0/reference/generated/scipy.sparse.csc_matrix.tocoo.html">tocoo()</a> function
# * itertools.zip_longest()

# %%
save_file = open("patent_student.txt", 'w')

# %%
vocab = tfidf_vectorizer.get_feature_names()
#########please write the missing code below#######
cx = tfidf_vectors.tocoo() # return the coordinate representation of a sparse matrix
for i,j,v in itertools.zip_longest(cx.row, cx.col, cx.data):
    save_file.write(pids[i] + ',' + vocab[j] + ',' + str(v) + '\n')

# %%
save_file.close()
