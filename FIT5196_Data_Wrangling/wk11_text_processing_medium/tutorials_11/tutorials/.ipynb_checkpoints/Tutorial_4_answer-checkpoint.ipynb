# %% [markdown]
# # Tutorial 4: Convert text into sparse form
# The aim of this tutorial is to learn how to convert unstructured text into a spare or structured form. The text data that you are going to process contains 16 clinical reports, each of which is stored in the following format
#  <img src="pic_1.png" height="500" width="700">
# where sentences are separated by an empty line, and a sequence of 10 asterisks ("*") is used to indicate segment boundaries. Your task is to convert the text files into a proper format so that text segmentation algorithms can take the preprocessed text as input.
#
# The preprocessing task is to generate the following files:
# * <b>clinical_voc.txt</b> contains the vocabulary generated from the 16 clinical reports. It should look like
# <img src="pic_2.png" height="100" width="300">
# * <b>clinical.txt</b> contains the preprocessed clinical reports. Each line contains a file name, a sentence index, a word index and its TF-IDF score.
# The file you are going to generate should look like
# <img src="pic_3.png" height="100" width="300">
# the word index is the index of the word in the vocabulary, and the real value is the TF-IDF score of the word in the sentence.
# * <b>clinical_boundaries.txt</b> contains the segmentation of each clinical reports.
# <img src="pic_4.png" height="300" width="500">
# where each line starts with the name of the clinical report, followed by a binary vector. "1" indicates there is a boundary after the current sentence, "0" otherwise.
#
# The sample output files are provided, which are
# * <b>clinical_voc_sample.txt</b>
# * <b>clinical_sample.txt</b>
# * <b>clinical_boundaries_sample.txt</b>
#
# Your task is to write your own Python code to produce exactly the same files.
#
# In order to generate the three files, you are going to think about how to put some of the techniques covered in week 3 together. For example, we need
# * Word tokenization
# * Case Normalization
# * Stopword removal
#
# and other techniques from lecture materials in week 4. Please finish the following tasks in this tutorial.
#
# Note that for demonstration purpose, we have split the code into difference chunks in difference cells.

# %%
import os
import nltk

# %%
text_file_folder = "./data"

# %% [markdown]
# ## Task 1: Read the data files
#
# The first task is to read the 16 clinical reports stored in the folder <font color="red">"./data"</font>. The file extension used is ".ref". The actual task contains:
# for each file,
# 1. make sure the file's extension is ".ref"
# 2. read all the sentences, and store them in list. The sentence order does matter. The blank lines between sentences should be removed.
# 3. read the segmentation boundaries. You should record where the boundaries are in terms of sentence indexes. For example, if there is a boundary after the 10th, 20th, 30th and 40th sentences, you should generate a list that looks like [9, 19, 29, 39].
#
# In terms of data structure, you can use two dictionaries to store sentences and boundaries separately. For both dictionaries, the key must be the same, e.g., the name of each clinical report so that we can easily match the pre-processed report with the corresponding boundaries.
#
# You can also use one dictionary, where keys are the report file names, values are a pair of sentence list and boundary list. the following code implement the idea of using one dictionary. Please fill in the missing code.

# %%
sents_dict = {}
for root, subFolders, files in os.walk(text_file_folder):
    for file_name in files: # for each files in ./data
        file_path  = os.path.join(root, file_name)
        # mark sure the file extension is "ref". We try to excldue files such as
        # ".DS_Store" in MacOS.   
        if file_path.endswith('ref'):
            file_reader = open(file_path)
            i = 0 # count the total number of sentences in each file
            sents = []
            bds = []
            for line in file_reader.readlines():
            #########please write the missing code below#######
                line = line.strip();
                if line != '': # exclude the empty lines 
                    if line != "**********":
                        sents.append(line)
                        i = i + 1
                    # Lines only contain "**********" indicate segment boundaries.
                    # For text segmentation task, we need to record where the boundaries locate 
                    # in the text 
                    elif line == "**********": 
                        bds.append(i-1)
            ######################################################
            sents_dict[file_name] = (sents, bds)

# %% [markdown]
# It is always a good idea to check the output of your code, i.e., a sanity check. For example, print the list of sentences of "000.ref" and the list of boundaries generated about, and manually check them again the original text file "000.ref".

# %%
sents_dict['000.ref'][0]
# Out:
# ['Physical diagnosis had its origins in Grecian medicine',
#  'Clinical medicine flourished before the Greeks  especially in Egypt  Crete  and Babylonia  and undoubtedly the Greeks were influenced by these earlier physicians',
#  'But writings from these countries did not become part of the mainstream of Western civilization  as did those of the Greeks',
#  'Table contains two quotations that illustrate the level of medicine practiced by the Greeks',
#  'They took a careful history and practiced direct auscultation',
#  'They were masters of observation  their descriptions of patients could fit modern texts without much change',
#  'Greek medicine flourished early',
#  'Homer in the Iliad ca  b c',
#  'described  wounds and used  anatomic terms',
#  'Hippocrates ca  b c',
#  'lived during the Golden Age of Greece',
#  'His contemporaries included Plato  Socrates  Aeschylus  Sophocles  Euripides  Aristophanes  and Pericles',
#  'Medicine became in his hands an art  a science  a profession Major',
#  'The Hippocratic writings are probably a collection from a number of individuals  including the master  from the period during which he was the dominant medical figure',
#  'They were collected after the death of Hippocrates and stored in Alexandria',
#  'From there  they were disseminated to all parts of the civilized world',
#  'The surviving collection contains  clinical cases  the likes of which are not encountered again for  years',
#  'These cases demonstrate a high level of medicine that included a careful history  inspection  palpation  direct auscultation  and examination of the sputum and urine',
#  'An enduring contribution of the Hippocratic school was the conviction that disease is natural and not divine',
#  'Consider the remarks about epilepsy  It is thus with regard to the disease called Sacred  It appears to me to be no wise more divine nor more sacred than other diseases  but has a natural cause from which it originates like other affections Delp and Manning',
#  'This was a major conceptual leap',
#  'Natural phenomena can be studied and their course predicted',
#  'This concept was a necessary prerequisite to the development of physical diagnosis',
#  'The Greeks did not develop an accurate knowledge of human anatomy and pathology',
#  'Dissection of human bodies did not occur except for a brief time at Alexandria in the third century b c',
#  'The Greeks had no concept of nosology',
#  'They felt that disease was caused by an imbalance of the four humors of the body  blood  yellow bile  black bile  and phlegm',
#  'Developments on these three frontsanatomy  pathology  and the nosology of diseasedid not begin to occur until the thirteenth century',
#  'The next great Greek physician after Hippocrates was Galen caa d who was born in Pergamum',
#  'He spent most of his professional life in Rome  becoming physician to the Emperor Marcus Aurelius',
#  'He was a prolific author',
#  'Many of his works have been lost  the surviving ones fill twenty two volumes',
#  'He studied and wrote extensively about anatomy based upon pigs and monkeys',
#  'He was the first experimental physiologist',
#  'He supplemented his findings by speculation',
#  'His written work was accepted as the ultimate truth until the time of Vesalius',
#  'This enshrinement of knowledge  much of which was incorrect  hampered medical progress for the next  years',
#  'Andreas Vesalius founded modern anatomy with the publication of De Humanis Corporis Fabrica On the Structure of the Human Body in June',
#  'His book was based upon personal dissection of human bodies',
#  'This represented a remarkable departure from the zoological anatomy of Galen',
#  'The accomplishments of Vesalius were possible because of the resumption of the dissection of human bodies that began in the thirteenth century',
#  'Human dissection was rare before the thirteenth century',
#  'The Egyptians knew the body organs  but only after extracting them through tiny incisions made for the purposes of embalming',
#  'There is continuing controversy about human dissection during the Hippocratic period',
#  'A knowledge of anatomy  except the skeleton  is scanty in the Corpus Hippocraticum',
#  'The consensus is that human dissection was not practiced during the Hippocratic period  either because of reverence for the human body or belief in a life after death that required an intact body',
#  'Dissection for the purpose of acquiring a knowledge of the human body probably originated in Alexandria  Egypt  in the fourth century b c    years after Hippocrates',
#  'Herophilus studied the nervous system and gastrointestinal tract  describing the cerebrum  cerebellum  meninges  fourth ventricle of the brain  duodenum  and the eye',
#  'He counted the pulse with a water clock  and analyzed the rate and rhythm',
#  'Erasistratus ca   b c',
#  'described the aortic and pulmonic valves and the chordae tendineae of the heart',
#  'He clearly saw that the heart was a pump  although he had the direction of circulation backward',
#  'The practice of human dissection in antiquity was confined largely to Alexandria',
#  'Some dissection apparently occurred in Rome until the second century a d   but it must have been sparse',
#  'Galen a d',
#  'said Alexandria  where he had studied  was the only place where anatomy could be learned',
#  'There is no good evidence that Galen himself practiced human dissection',
#  'Human dissection began again in the thirteenth century in Bologna  one of the great medieval universities  and has continued uninterrupted through the present time',
#  'Several occurrences during the early thirteenth century set the stage for the lifting of the taboo against disturbing the human body',
#  'Emperor Frederic II issued an imperial decree in  authorizing the performance of public anatomes on the bodies of executed criminals for teaching purposes',
#  'Legend has it that Frederick II also had the stomachs of two of his subjects opened in order to determine if digestion was enhanced by exercise or by rest',
#  'Another sign of the relaxation of the concept of the sanctity of the human body during the thirteenth century was the practice of dismembering the bodies of the Crusaders and boiling the parts so that the bones could be returned to their families in Europe for burial',
#  'A more specific reason for the resumption of human dissection probably had to do with the legal scholars at the University of Bologna  which was famous for its law school',
#  'The scholars were concerned to know the causes of deaths for legal reasons',
#  'Mondino of Bologna ca   was the predecessor of Vesalius in the founding of anatomy',
#  'In  he wrote his Anothomia  the first text exclusively on anatomy',
#  'It was based on his own dissection of humans',
#  'This book was published at Padua in  and went through  separate editions and translations',
#  'It was an unillustrated manual or handbook of dissection and not a formal anatomic text',
#  'His method was to begin with the abdominal viscera  then go to the chest and neck',
#  'The book ends with the opening of the skull',
#  'The manual was a student favorite and was widely used',
#  "Mondino's anatomic work was continued by his students  and dissection became more popular",
#  'A public dissection occurred at Padua in',
#  'Public dissections were decreed at the University of Montpelier in   at Venice in   and at Florence in',
#  'In Padua an anatomic theater was erected in',
#  'These events set the stage for Vesalius in the sixteenth century',
#  'Vesalius was born in Brussels in    the son of a Flemish family that had been in medicine for many generations',
#  'He was said to be interested in anatomy even as a youth  dissecting mice  rats  dogs  and cats',
#  'He studied anatomy in Paris under Sylvius  a famous scholar who declared Galen was infallible',
#  'In  he went to Padua  where he received his medical degree',
#  'For the next  years he worked prodigiously as professor of medicine and surgery  breaking tradition by personally performing all the dissections',
#  'At the end of these  years  he published his Fabrica',
#  'He was',
#  "The Fabrica was sumptuously illustrated by Titian's pupil Jan Kalkar  who was the first to attain what Choulant calls the true anatomic norm  that is  a picture at once scientifically exact and artistically beautiful  summing up  as in a composite photograph  the innumerable peculiarities and minor variations in structures encountered in dissection",
#  'The splendid wood cuts representing majestic skeletons and flagged figures  dwarfing a background of landscape  set the fashion for over a century and were copied and imitated by a long line of anatomic illustrators',
#  'Garrison    p',
#  'Vesalius provided the accurate anatomic base upon which physical diagnosis could be built',
#  'In the words of Major   p',
#  'Few men in medical history have dominated their subject or their epoch as did Andreas Vesalius',
#  'The history of anatomy is divided into three periods  the pre Vesalian Period  the Vesalian Period  and the post Vesalian Perioda tribute to the genius of this great anatomist',
#  'Nosology is the branch of medicine that deals with the concept  definition  classification  and nomenclature of disease',
#  'The historic development of nosology was fundamental to the evolution of diagnosis',
#  'A concept essential to modern medicine is that a particular disease can cause manifestations that can be quite different from one individual to another',
#  'The definition of what constitutes a disease began with Thomas Sydenham in seventeenth century England',
#  'Sydenham   was born at Wynford Eagle in Dorset',
#  'He obtained his bachelor of medicine from Oxford in',
#  "He was a captain in the cavalry during Oliver Cromwell's campaign in Scotland against Charles II",
#  'When the Restoration came in  and Charles II became king  Sydenham had no political future and he had no resource other than a serious devotion to the practice of medicine  an event with important benefits to all succeeding generations of physicians Harvey',
#  'He began practicing medicine in London in   after having a lot of trouble passing the examination of the Royal College of Physicians',
#  "The London of Sydenham's day was notable for the occurrence of one murderous epidemic after another Faber",
#  'An epidemic of an acute infectious disease such as smallpox or cholera  which struck thousands suddenly and left just as swiftly  provided the ideal setting for the development of modern nosologic concepts  a great many previously healthy individuals were suddenly afflicted by what was clearly the same illness  which at the same time varied in its manifestations from one person to another',
#  'An idea of the magnitude of these epidemics can be gotten from population estimates  in  the plague killed about   of   inhabitants',
#  'The plague stopped by   but in that year smallpox killed   cholera   phthisis   and only  died of old age Faber',
#  'These figures  although of questionable exactness  nevertheless depict accurately the effects of these diseases',
#  'In contrast to his contemporaries  Sydenham thought it was possible  albeit difficult  to construct an accurate picture of each disease',
#  'And  in truth  it is my opinion that the principal reason of our yet being destitute of an accurate history of diseases  proceeds from a general supposition that diseases are no more than the confused and irregular operations of disordered and debilitated nature  and consequently that it is a fruitless labor to endeavor to give a just description of them',
#  'The symptoms observed by Socrates in his illness may generally be applied to any other person afflicted with the same disease  in the same manner as the general marks of plants justly run through the same plants of every kind',
#  'Thus  for instance  whoever describes a violet exactly as to its colour  taste  smell  form  and other properties  will find the description agrees in most particulars  with all the violets in the universe',
#  'Faber    pp',
#  'Sydenham laid down four principles that he felt to be important Faber',
#  'All diseases should be classified in species  just as botanists do plants',
#  'Hypotheses and philosophical speculations should be eschewed in favor of an objective description of each disease  described with the same accuracy as when an artist paints a portrait',
#  'The manifestations that are constant in each patient with a particular disease should be distinguished from other phenomena that could be due to the age  constitution  or treatment of the patient',
#  'The season of the year in which the disease occurs should be noted because some diseases follow the season as surely as many birds and plants',
#  "Sydenham's first book was on fever  Methodus Curandi Febres",
#  'His most prominent work is Tractatus de Podagra et Hydrope',
#  'In it he separated gout from which he suffered from the entities that had been called rheumatism',
#  'Sydenham stressed personal independent observation',
#  'He first gave clinical observation its place of honor as a scientific methodone which for those who cultivate it effectively is still today a basic asset of the complete physician Harvey    p',
#  'The next physician interested in the classification of diseases was Sauvages',
#  'In  he published a book in which he grouped diseases in classes  orders  and genera  just as the biologists were doing with plants and animals',
#  'This book came to the attention of Linnaeus  who published his Systema Naturae in',
#  'The two men carried on a lifelong correspondence',
#  'Sauvages published his principal work in   Nosologia methodica sistens moborum classes  genera et species',
#  'He described  diseases  divided into  classes and  orders',
#  'In the preface he discussed principles for classifying disease  choosing symptoms as the basis for his scheme',
#  'This led to many difficulties  given the nature of medical knowledge at the time',
#  'There were  kinds of angina   types of asthma   species of dysphagia   different species of anorexia  etc',
#  'This work had much influence upon contemporary medicine  detailed nosologies following his system appeared in various countries',
#  'These nosologies  however  did not appreciably influence the practice of medicine',
#  'The differences between the nosologists of the eighteenth century and Sydenham is that they merely catalogued and arranged symptoms  while he characterized diseases',
#  'Sydenham delineated each disease by its manifestations and clinical course',
#  'Succeeding nosologists classified symptoms',
#  'The distinction between symptom and disease was not appreciated',
#  'The next advance was the development of the discipline of pathologic anatomy by Morgagni  which is described below',
#  'Morgagni established the concept of whole organs being diseased',
#  'Philippe Pinel of Paris published his Nosologie philosophique in',
#  'This book stressed the importance of arriving at the typical picture of a disease  ignoring the varying picture in each individual patient',
#  'He characterized  diseases and divided them into classes  orders  genera  and species',
#  'He grouped diseases that involved a particular tissue together  such as all diseases of the mucous membranes',
#  'This was an entirely new concept',
#  'Previous authors had arranged disorders according to anatomic location  heart  lungs  etc',
#  'Bichat expanded upon this idea and showed how disease of each type of tissue could give rise to two different kinds of symptoms',
#  'One group of symptoms is dependent upon the particular tissue involved  and the other group is caused by dysfunction of the affected organ',
#  'Laennec  who was greatly influenced by Bichat  produced a revolution in nosography with the publication of his book on auscultation see below',
#  'Laennec wove symptoms  signs  and pathologic findings into a series of classic diseases  many of which he was the first to describe  emphysema  bronchiectasis  pneumothorax',
#  'His great achievement was to take many different conditions grouped under the name phthisis and show that they were all different stages of one disease  tuberculosis',
#  'He demonstrated that the process usually begins in the apex of the lung  and that various anatomical changes may be demonstrated by means of stethoscopy  and finally he conceived and described tuberculosis of the lungs as a special disease differing from all other disease processes Faber',
#  'Modern nosology begins with Laennec',
#  'Morbid anatomy had its origins alongside descriptive anatomy',
#  'The first known forensic autopsy was done in  in Bologna  which is also where Mondino started descriptive anatomy Klemperer',
#  'The body of an individual named Azzolino was examined because the authorities felt his death was suspicious',
#  'Visceral congestion was found  and the authorities investigated no further',
#  'The great descriptive anatomists of the time all were quite interested in morbid anatomy',
#  'The bodies of executed criminals were dissected for teaching purposes anatomia publica  and the bodies of individuals who died of disease were also examined anatomia privata',
#  'Vesalius inquired carefully into the history of the bodies he dissected  and planned to publish his records  but apparently they were lost or destroyed',
#  'Many of the great physicians and anatomists of the s and early s strongly advocated autopsies as a means of furthering clinical medicine',
#  'Johannes Schenck von Grafenberg   collected pathologic reports of preceding years  as well as his own experiences  into seven volumes',
#  'His book had a classified index and a collection of aphorisms designed to arouse interest in pathology',
#  'Wilhelm Fabry von Hilden  a physician in Bern  wrote a book in which he called attention to what had been learned from autopsies',
#  'He noted Germany was behind France and Italy in medicine because fewer autopsies were performed in Germany',
#  'The public apparently was willing to support autopsies  and  in fact  often requested that they be done on relatives in order to determine the cause of death',
#  'The situation in the British colonies of North America mirrored that of Europe',
#  'Cotton Mather in Boston described congenital rectal atresia in an autopsy done on his own son',
#  'In Copenhagen  Bartholin was given permission by the authorities to perform autopsies on patients who died in the public hospitals',
#  'Bartholin gave in detail methods by which permission for autopsies could be obtained as well as other techniques for gaining the information  looking through a previously existing surgical incision  inspecting bodies while they were being embalmed',
#  'He recommended that deception could be used  but he advocated caution and tact Klemperer',
#  "Theophil Bonetus   was Morgagni's predecessor as the founder of pathologic anatomy",
#  'He was a physician who gave up practice in Geneva at the age of  because of deafness  and spent the rest of his life writing medical books',
#  'He collected  cases and published in  the Sepulchretum',
#  'The full title reads as follows  Repository of anatomy practiced on corpses deceased of disease  which reports the histories and observations of all alterations of the human body and reveals the hidden causes',
#  'Indeed  anatomy deserves to be called the foundation of real pathology and of proper treatment of disease  even the inspiration of old and recent medicine',
#  'The book was designed to contain each recognizable disease known up to that time  with a description of the clinical features followed by the autopsy findings',
#  'This book was highly influential and gave great impetus to pathologic anatomy',
#  'Lancisi of Rome made important contributions to pathology with the publication of De Subitaneis Mortibus in',
#  'His book contained autopsies on the cases of sudden death in Rome in',
#  'The stimulus for his work was the panic of the Roman populace over the large number of sudden deaths in that year',
#  'The clinical and anatomic descriptions are detailed  with every effort made to correlate the two',
#  'The observations were precisefor example  exact measurements of body organs were given',
#  'The causes of unexpected death included cerebral hemorrhage and hypertrophied hearts  valvular vegetations were described clearly',
#  "Lancisi's book illustrates the trend toward making clinicoanatomic correlations",
#  'Hermann Boerhaave   of Leyden was largely responsible for correlating autopsy results with what was found at the bedside',
#  'He was one of the great consulting clinicians of his timehis reputation extended even to China  and he was regularly consulted by emperors',
#  'Students from all of Europe sought his teaching and in turn became the leading physicians of the eighteenth century',
#  'Bedside teaching of clinical medicine had begun at Padua  and was brought to Leyden by Heurnius',
#  'Boerhaave made bedside teaching an art form',
#  'He was given two wards in an old hospital for the purpose of teaching students  one with six beds for men and the other with six beds for women',
#  'On twelve beds half the physicians of Europe were trained',
#  'Sigerist',
#  'Boerhaave made daily rounds with his students  reviewing the history  inspecting the patient  examining the urine',
#  'The patient was not examined to any extent  since percussion and auscultation had not been discovered',
#  'Boerhaave made his students attend the autopsy on each patient who died',
#  'He felt postmortem examinations were essential  In spite of the most detailed description of all disease phenomena one does not know anything of the cause until one has opened the body',
#  'He continues in his introduction to one of his books to say he will try to give an accurate picture of his observations in order that in subsequent similar cases the disease can be diagnosed early and cured',
#  'Giovanni Battista Morgagni established pathology as it is known today with the publication of his monumental work De sedibus et causis morborum The Seats and Causes of Diseases in',
#  'Morgagni was born in  and received his medical degree from Bologna',
#  'In   on the recommendation of Lancisi  he was appointed professor of anatomy at Padua  filling the chair held previously by Vesalius',
#  'He became a popular teacher  with many foreign students coming to Padua just to attend his lectures',
#  'His fame as a scholar and pathologist was such that Samuel Johnson  upon being asked by Boswell if he believed the tale that a scorpion surrounded by a ring of fire will withdraw to the center and commit suicide  answered  I will believe it if the autopsy was performed by Dr',
#  'Morgagni Klemperer',
#  "He started out to write De sedibus in order to update Bonet's Sepulchretum  correct it  and add to it his own material",
#  'His book',
#  'remains one of the imperishable books of medical literature',
#  'Many authors previously had recorded the results of autopsy findings in an attempt to explain the cause of death',
#  'But here  for the first time we find a vast array of pathological findings  well arranged and indexed  each preceded by a minute history of the disease  the symptoms present  the treatment employed  and finally a discussion of the relationship between the clinical picture and the autopsy findings',
#  "Morgagni's knowledge of the literature of the subject is apparent on every page  where he discusses previous articles on the subject and meticulously gives each author due credit for his own observations",
#  'He often begins with Aristotle and reviews the entire literature down to his own time',
#  'The number of pathological states described by Morgagni  many of them for the first time  is enormous',
#  'He described syphilitic aneurysms  acute yellow atrophy of the liver  pneumonia with consolidation of the lungs  meningitis due to acute otitis  hyperostosis frontalis  cancer of the stomach',
#  'Major    p',
#  'De sedibus was published when Morgagni was   it was the fruit of  years of devoted work',
#  'As Virchow said  he introduced the anatomical concept into medicine',
#  'His work profoundly influenced the next century of medicine',
#  'Modern physical diagnosis began with the discovery of percussion by Leopold Auenbrugger in  and its popularization by Jean Corvisart in',
#  "The concept of anatomic localization of disease in the living patient originated with the discovery of percussion  was given powerful impetus by Laennec's stethoscope in   and became firmly entrenched with the discovery of x rays by R\xc3\xb6ntgen in",
#  'Before Auenbrugger  physicians could not discover the location of internal disease during the life of the patient',
#  'Diagnostic methods  as illustrated by Boerhaave  were confined to the history  inspection at the bedside  taking the pulse  and scrutinizing the excretions of the patient',
#  'The stage for the in vivo autopsy was set by the contributions of Vesalius and Sydenham',
#  'Clinical knowledge had grown by slow accretion over the centuries since Galen by the efforts of the Arabs  by Boerhaave and his students  and by other great clinicians',
#  'The beginnings of modern physiology had occurred with the demonstration of the circulation by William Harvey',
#  'Morgagni had established pathologic anatomy and correlated autopsy findings with the clinical history',
#  "But Morgagni's contributions had little value in the face of the inability of the physician to ascertain the state of diseased organs inside the patient during life",
#  'Auenbrugger conferred this ability upon the physician  he opened up the world of the ear as a clinical instrument',
#  'Clinical observation  though never blind  had been deaf',
#  'Leopold Auenbrugger   was born in Graz  the son of an innkeeper',
#  'Legend has it that his discovery of percussion was based upon observing his father tap wine casks in order to ascertain the amount of wine present in the cask',
#  'He studied medicine in Vienna under van Swieten  whom he revered',
#  "Gerhard van Swieten was Boerhaave's favorite student  and brought the latter's insistence upon bedside teaching and the importance of the autopsy to Vienna  creating what was known as the Old Vienna School",
#  'Upon graduation  Auenbrugger became physician to the Spanish Hospital in Vienna',
#  'Although initially founded as the hospital for citizens of Spain  Italy  and Holland  at the time of Auenbrugger it was mostly a hospital for soldiers',
#  'The discovery of percussion occurred during his years at this hospital',
#  'Auenbrugger published his New Invention by Means of Percussing the Human Thorax for Detecting Signs of Obscure Disease of the Interior of the Chest in',
#  "This  page book was based upon seven years' experience with working out the principles of percussion at the Spanish Hospital",
#  "The book was published on New Year's Eve",
#  'It begins as follows',
#  'I here present the reader with a new sign which I have discovered for detecting diseases of the chest',
#  'This consists in percussion of the human thorax  whereby  according to the character of the particular sounds thence elicited  an opinion is formed of the internal state of that cavity',
#  "In making public my discoveries respecting this matter  I have been actuated neither by an itch for writing  nor a fondness for speculation  but by the desire of submitting to my brethren the fruits of seven years' observation and reflection",
#  'Keele    p',
#  "Auenbrugger recommended that percussion be carried out with the physician's hand gloved with unpolished leather or that the patient's chest be covered by a tight fitting shirt",
#  'The patient was struck with the points of the extended fingers held close together',
#  'This is known as direct  or immediate  percussion',
#  'The normal note resembles the stifled sound of a drum covered with a thick woolen cloth or other envelope',
#  'If a sonorous region of the chest appears  on percussion  entirely destitute of the natural soundsthat is  if it yields only a sound like that of a fleshy limb when struckdisease exists in that region',
#  'He injected fluid into the chests of cadavers and studied the percussion notes produced',
#  'He percussed during inspiration  during expiration  and at the end of a full inspiration',
#  'He distinguished four percussion notes Jarcho    normal  tympanitic  dullness  and flatness',
#  'The percussion notes associated with various thoracic diseases were outlined',
#  'He also listed diseases that could not be discovered by percussion',
#  'He described cardiac dullness to percussion  thereby outlining the position of the heart in the chest',
#  "Auenbrugger's book received unfavorable and even hostile reviews",
#  'It was apparently little noticed until Maximilian Stoll became the leader of the Old Vienna School and used percussion in the clinics',
#  "One of Stoll's pupils  Josef Eyerel  wrote a paper on percussion that by chance was noticed by the French clinician Corvisart  who was stimulated to obtain a copy of Inventum Novum",
#  "Jean Nicolas Corvisart   was France's greatest clinician during his time",
#  'He was born in the small village of Dricourt in Champagne',
#  'He received his degree in Paris in',
#  'He was a hard worker and inspiring teacher  and by  he was professor of practical medicine in the Coll\xc3\xa8ge de France  the highest teaching honor in France',
#  'He was deeply interested in diseases of the heart  publishing in  a remarkable book on cardiac disease',
#  'He classified heart disease by anatomic structure muscle  valves  endocardium  etc   used the term organic lesion  and distinguished between hypertrophy and dilation Major',
#  "His fame and ability were such that he became Napoleon Bonaparte's physician",
#  "Corvisart recognized the value of Auenbrugger's work and set about testing it on the wards",
#  'His technique differed from Auenbrugger  he used the palmar surfaces of the closely approximated and extended fingers',
#  "After twenty years' experience with percussion  he published his findings in   together with an unabridged translation of Inventum Novum",
#  'Corvisart chose as the motto of his translation Resonvere Cavae Cavernae  the hollow cavities resounded Buck',
#  "This comes from the second book of Virgil's Aeneid  where Laocoon threw his spear at the wooden horse  with the result as described",
#  'The great prestige of Corvisart immediately established percussion as an important physical diagnosis tool',
#  "His revival of Auenbrugger's discovery and the latter's resulting fame occurred just a year before Auenbrugger's death",
#  'The next name in percussion is that of Pierre Adolphe Piorry    who invented the pleximeter',
#  'He was born in Poitiers and received his medical degree in Paris in   studying under Corvisart',
#  'Piorry worshipped Laennec and desired to contribute something equally important to medicine',
#  'The idea of the pleximeter is said to have come to him once when  scratching himself due to pruritus  he noted the sound made by the scratching',
#  'He scratched over a coin  and noted the louder sound thereby produced',
#  'He went on to design a small plate  which he placed between the percussing finger and the skin',
#  'He called this plate a pleximeter from the Greek words to strike and to measure',
#  'He felt this had the advantages of diminishing the pain to the patient as well as improving the quality of sound',
#  'His plate was ivory   cm in diameter',
#  'Piorry used his fingers to strike the pleximeter',
#  'English and American visitors started using the fingers of the left hand as the pleximeter  and Wintrich later introduced the percussion hammer Bedford',
#  'The hammer was later adopted for use as the reflex hammer see below',
#  'The technique introduced by Piorry is known as mediate percussionthat is  something is between the finger and the skin',
#  "A familiar and characteristic sight at his clinical demonstrations at the Piti\xc3\xa9 was Piorry sitting on a high stool  which was moved from bed to bed  and by careful pleximetry he mapped out the patient's organs on the skin  using coloured crayons  so that the patient's torso ended up looking like a geographical map Gueniot",
#  'He tried to convince observers that every organ had a special percussion sound  and he played on his pleximeter like a virtuoso on a musical instrument',
#  'He came to be known as the medical Paganini Ebstein',
#  'There were many anecdotes  no doubt fictitious  related about him  such as that he paid a visit to the Royal Palace in the Tuilleries and demanded to see the King  but was told that the monarch was not in his reception room',
#  'Piorry then decided to percuss the closed door with his pleximeter  detected a certain dull sound and diagnosed the presence of the King in his chamber',
#  'Monpart   Sakula    p',
#  'The significance of the development of the stethoscope was not merely that the sounds of the heart could be heard clearly for the first time',
#  'Laennec did more than discover auscultation  much more',
#  'It was he who first sought and found the confirmation of the clinical diagnosis at the autopsy table and united pathological anatomy and clinical medicine by an inseparable bond',
#  'Morgagni had raised the question  what changes are produced by the disease',
#  'Laennec went further and asked by what symptoms or signs are these changes to be recognized during life',
#  'In answering this question Laennec created local diagnosis Naunyn',
#  'Pratt',
#  'p',
#  'Laennec not only united pathological anatomy and clinical medicine by an inseparable bond  but he singlehandedly created a new discipline in medicine',
#  'Laennec had a mind that had been prepared for the discovery of mediate auscultation immediate auscultation is the listening to the body directly  mediate is listening to the body through another object  such as the stethoscope',
#  "Laennec's De l'auscultation m\xc3\xa9diate was the product of three years of the most intensive work with his new stethoscope and  also  of more than  years of close study of problems in pathology and clinical medicine",
#  'It is far more than a manual for the stethoscope',
#  'It is  also  a treatise on diseases of the lung and of the heart  a mine of information on the clinical aspects of pulmonary and cardiac disease  with an accurate description of the pathological anatomy of these conditions',
#  'Laennec heard with his stethoscope sounds never before heard or described and for which no terms existed in medical literature',
#  'He was the creator of a large number of words now currently employed in physical diagnosis  such as rales  bronchophony  pectoriloquy and egophony',
#  "His book  unlike Auenbrugger's Inventum Novum  did not wait  years for recognition",
#  'It was immediately accepted as an epoch making work  and auscultation was soon used in medical clinics throughout the world',
#  'Major    p',
#  'He was born at Quimper  France  in',
#  'On the death of his mother  Laennec at age eight went to live with an uncle who was a physician in Nantes',
#  'He began studying medicine under this uncle at age',
#  'In  he went to Paris and continued studying medicine under Corvisart  receiving his degree in',
#  'He was fascinated by pathology',
#  'Laennec and his friend Bayle became assistants to Dupuytren  who was working on pathologic anatomy',
#  'Laennec gained a reputation as an excellent pathologist as well as being an excellent clinician',
#  'This interest led to the writing of several papers on pathology',
#  'He invented the stethoscope in',
#  'His friend Lejumeau de Kergaradec wrote of the discovery',
#  'The author told me himself  the great discovery which has immortalized his name was due to chance',
#  'One day walking in the court of the Louvre  he saw some children  who  with their ears glued to the two ends of some long pieces of wood which transmitted the sound of the little blows of the pins  struck at the opposite end',
#  'He conceived instantly the thought of applying this to the study of diseases of the heart',
#  'On the morrow  at his clinic at the Necker Hospital  he took a sheet of paper  rolled it up  tied it with a string  making a central canal which he then placed on a diseased heart',
#  'This was the first stethoscope',
#  'Major    pp',
#  'He apparently first used it on a fat young lady in whom direct auscultation yielded no useful information',
#  'Laennec had used direct auscultation for some years previously  Bayle was the first whom I saw employ it  when we followed the service of Corvisart together',
#  'Another comment about direct auscultation  As inconvenient for the physician as for the patient  distaste alone renders it almost impracticable in the hospital  it cannot even be proposed to most women and in most of them the volume of the breast is a physical obstacle to its use Laennec as quoted by McKusick    pp',
#  'Laennec made his discovery in',
#  'The next three years were years of intense work  as he perfected his technique at the Necker Hospital',
#  "In  he published De l'auscultation m\xc3\xa9diate On Mediate Auscultation",
#  'He named the stethoscope for the Greek words meaning to explore the chest',
#  'The book contains the symptoms  signs  clinical course  and pathologic findings of a variety of diseases  pulmonary edema  pneumonia  tuberculosis  emphysema  pneumothorax  pleural effusion',
#  'The descriptions are compellingfor example  the sound he called egophony',
#  'It appears as if a kind of silvery voice  of a sharper and shriller tone than that of a patient  was vibrating on the surface of the lungs  sounding more like the echo of the voice than the voice itself',
#  "It has  moreover  another character  so constant as to lead me to derive from it the appellation of the phenomenonI mean a trembling or bleating sound like the voice of a goat  a character which is the more striking because the key or tone of it approaches that of this animal's voice",
#  'Further egophony is likened to the nasal intonations of the juggler speaking in the character of Punch',
#  'Middleton    p',
#  'Laennec experimented with various stethoscope designs  turning them all on the lathe himself',
#  'He finally settled on one  cm long   cm in diameter  with a plug that fitted into it when listening to the heart',
#  'The instrument was made more portable by fashioning it in two pieces',
#  'Each purchaser of his book was presented with a stethoscope',
#  "Thayer maintained that at the time of Laennec's death from tuberculosis in  every stethoscope then in existence had been made by him",
#  'Students from all over the world flocked to study under Laennec and to learn how to auscultate  returning to their countries with stethoscopes',
#  'Laennec obviously had tuberculosis during this period  but worked indefatigably',
#  'A good account of his work is given by C J B',
#  'Williams  who visited Paris in',
#  'Laennec demonstrated the signs obtained by auscultation in the wards from  a m',
#  'to noon  always speaking in Latin at the bedside  after which he either gave a lecture in French or attended a postmortem examination to correlate the anatomical findings with the signs which had been elicited by auscultation',
#  'Williams took notes of the lectures and made sketches of Laennec whom he described as a frail looking man of small stature who often became exhausted by his hospital duties',
#  "Laennec's own account of his life in Paris was given in a letter to a colleague which was published by Thayer",
#  'Rising at   a m   he gave consultations while dressing  then visited the Necker Hospital  and rarely had time to return home for lunch before setting out on his visits which lasted until   p m   after which he took an early dinner and then set out on another round of visits until  p m   eventually retiring to bed at  p m',
#  'Bedford   p',
#  'Public acceptance of the stethoscope was such that within a decade physicians felt they must use the stethoscope or else jeopardize their reputation',
#  'Changes in the design of the stethoscope appeared gradually',
#  'The first stethoscope that was not rigid was built by Nicholas Comins  an Edinburgh physician  in',
#  'Monaural instruments that were completely flexible appeared in the s',
#  'The first satisfactory binaural stethoscopes appeared in the s',
#  'The fully flexible binaural stethoscope became generally used in the s',
#  'The diaphragm was added in the early s',
#  'Paris was the mecca of the medical world from  to',
#  'Modern medicine began to emerge in France during this fifty year period',
#  'The leading clinicians of Paris were individuals such as Corvisart and Laennec',
#  "The list of luminaries included the surgeon Dupuytren    the great pathologist Bichat    who succeeded to Morgagni's mantle  the pioneering psychiatrist Pinel    the gastroenterologist Broussais    Pierre Louis  and others",
#  'The Parisian medical community was the shining light that attracted physicians from all over the world  just as they were to go to Germany starting in the s',
#  'In the decade from  alone   American physicians visited Paris for further study Jones',
#  'Medicine in the United States was influenced profoundly by what has come to be known as the French School',
#  'The remarkable accomplishments of the French physicians did not come about by accident',
#  'For one thing  the physicians and medicine did not exist in isolation',
#  'Paris was a center of great activity from  to  in mathematics  physics  chemistry  and biology',
#  'Progress in the physical sciences carried over into other areas  such as medicine',
#  'Another vital development was the rise of the hospital  this did not occur until the nineteenth century',
#  'Greek physicians focused upon the individual sickbed',
#  'Libraries were the focus of medicine during the Middle Ages',
#  'The bedside was the center of attention during the seventeenth century  as Boerhaave taught in his  bed ward at Leyden',
#  'The nineteenth century was the century of the hospital',
#  'The tens of thousands of peasants who streamed into the capitals of Europe with the coming of the Industrial Revolution became sick with a host of acute infectious and chronic diseases',
#  'Tuberculosis and typhoid fever were especially prevalent  and attracted the interest of physicians and lay people alike during this period',
#  'The \xc3\xa9migr\xc3\xa9s from the farms to the cities were without urban roots or families  and consequently  when they became ill  the hospital was the only place to go',
#  'The wards of the overcrowded hospitals provided clinical material in unprecedented quantity to the physicians of the period',
#  'Physicians could apply for the type of cases they wanted to see',
#  "Whereas Boerhaave's clinic had  beds  Bouillaud boasted of having seen   cases in  years Ackerknecht",
#  'In  Paris had  hospitals containing   patients',
#  'The H\xc3\xb4tel Dieu alone had  beds',
#  'There were  medical students',
#  'The political climate was favorable  Napoleon liked and encouraged physicians',
#  "Corvisart  the most influential physician of the period  was Napoleon's personal physician",
#  'Pierre Charles Alexandre Louis   epitomized the best of French medicine during this period',
#  'Louis was an inspiring teacher and masterful clinician',
#  'He was the favorite of the American students who visited Paris during this time  and exerted an extraordinary influence upon medicine along the Eastern seaboard in the United States',
#  'Oliver Wendell Holmes  Sr   who studied under him  He is the object of our reverence  I might almost say idolatry',
#  'He was born in Aix  and received his medical degree in Paris in   at the age of',
#  'He went to Russia with a family friend and settled in Odessa to practice medicine',
#  'William Osier describes what happened next',
#  'In the last year of his stay in Odessa he was very much disturbed by the high rate of mortality in children with diphtheria  and this appears to have determined him to abandon for a time the practice of medicine and to devote himself to study',
#  "With this object in view he returned to Paris and for six months attended the practice at the Children's Hospital",
#  'Among the younger physicians in Paris he found an old fellow pupil  Chomel  physician to La Charit\xc3\xa9  who offered him opportunities for work in his wards',
#  'Louis at this time was thirty four years of age',
#  'Here for six years uninterruptedly he set himself to work to study disease in the wards and in the post mortem room',
#  'At first he appears to have occupied the position simply as a voluntary assistant and friend of Chomel  but subsequently he became his chef declinique  and during this period he occupied a room in the entresol of the hospital',
#  'He was a voluminous note taker and collected in this time an enormous number of important facts',
#  "This remarkable feature in Louis' life has scarcely been dwelt upon sufficiently",
#  'I know of no other parallel instance in the history of medicine',
#  'It is worth reading the brief extract from Dr',
#  "Cowan's introduction to his translation of the work on Phthisis",
#  'He entered the hospital of La Charit\xc3\xa9 as a clinical clerk  under his friend',
#  'Professor Chomel',
#  'For nearly seven years  including the flower of his bodily and mental powers from the age of thirty three to forty  he consecrated the whole of his time and talents to rigorous  impartial observation',
#  'All private practice was relinquished  and he allowed no considerations of personal emolument to interfere with the resolution he had formed',
#  'From this moment may be dated the presence of that strong impression of the necessity of exact observation by which the school of Paris has been since so distinguished',
#  'Osler    p',
#  'Louis can be called the first full time clinical investigator  based on the five methods of approach that he employed Harvey',
#  'Every effort was made to discover the previous state of health of a patient  his age  occupation  residence  family history  manner of living',
#  'The present illness was sought in detail  its initial and subsequent symptoms  the chronological order of occurrence  other symptoms',
#  "The manifestations of the disease were sought in the patient's statements and in the physician's examination",
#  'A careful record was made of the clinical manifestations during the course of the illness',
#  'If the patient died  an autopsy was obtained and a meticulous record was made of the findings',
#  'Louis established the systematic approach to the clinical case that is in use today',
#  "This approach is given in detail below  when Martinet's contributions are described",
#  'Louis was one of the first to apply statistics to the study of medicine',
#  'His early concern for cures  based on his experiences in Odessa  caused him to turn his attention to therapeutics',
#  'It occurred to him to list each case in numerical order  and to compare the group receiving a certain therapy against the group that did not',
#  'He used this method to demonstrate that blood letting  which was quite popular in France at that time  was of uncertain value in treating pneumonia',
#  'There were any number of critics of this numerical method',
#  "Louis' reply was that in the difference between exactitude and vagueness  lies the difference between truth and error",
#  'By the s the preeminence of French medicine began to decline',
#  'A basic reason for this appears to be that the French did not investigate the causes of disease',
#  'Their strength was observation  they distrusted experimental laboratory investigation Ludmerer',
#  'Hospital medicine  with its complete dependence upon two techniquesclinical observation and the autopsyhad achieved its maximum potential',
#  'In order for clinical diagnosis to progress further  the causes and mechanisms of diseases had to be investigated',
#  'These investigations depended upon progress in the fundamental medical and biological sciences  biochemistry  pathology  physiology  experimental pathology  bacteriology  pharmacology',
#  'The mainstream development of modern medicine shifted to Germany  where the focus was upon the use of experimental methods to unravel the mysteries of medicine',
# ...
#  'The acute and chronic forms of disease require a plan of examination and narration altogether different',
#  'Everything connected with the previous history should be known  and stated fully in chronic cases  it is the only means of throwing any light on the obscurity which so generally surrounds them',
#  'But in acute cases this is far less necessary',
#  "Martinet  from Quain's translation",
#  "Martinet's history begins with taking the full history as applicable to all diseases  he then uses special methods for the three great cavities of the bodythe brain  chest  and abdomen Keele",
#  'After the history comes the physical examination',
#  'The stethoscope is used before percussion on the chest',
#  'Inspection  percussion  palpation  and auscultation are used systematically for the chest  head  and abdomen',
#  'Rectal examination is performed to detect prostatic enlargement',
#  'The skin  muscles  nerves  mucous and synovial membranes  lymphatics  and veins are noted specifically',
#  "Martinet's remarks could fit with ease into a modern physical diagnosis book",
#  'His scheme illustrates the clinical method as developed by the great clinicians of the French School',
#  "An interesting contrast to Martinet's methods are those of Peter Latham at St",
#  "Bartholomew's Hospital",
#  'He writes  in   The patient being placed before me  I ask him no question until I have learned everything worthy of remark which my own eyes can inform me of',
#  'from Keele    p',
#  'Comments in the literature about history taking are quite sparse for the next century',
#  'G',
#  'L',
#  'Engel has this to say about the meagerness of the historical record',
#  'I am not particularly bothered that the record is as sparse as it is',
#  'Eliciting historical accounts of the experiences of others as a means of gaining knowledge is  of course  as old as man',
#  'It is also quintessentially human and is after all one of the ways we learn from early childhood on  that is  from the stories that others have to tell about that which is not known or is unfamiliar to us',
#  'It is for this reason  I suspect  that the process of history taking has not until very recently been thought of as anything that needed to be taught or even studied  much less as a scientific method',
#  "Yet  if science  and being scientific  represent man's most persistent effort to extend and organize knowledge by reasoned efforts that ultimately depend on evidence that can be consensually validated  as Charles Odegaard has said  then history taking or interviewing does qualify as a scientific method",
#  'Even Rufus of Ephesus appeared to know that intuitively',
#  'Thus  he recommends asking questions in order that physicians know more exactly some of the things that concern the disease  a suitable manner of patient response is with a faithful memory  he recommends verification by questioning relatives and friends  advises that the physician find out precisely',
#  'Therein is captured the essence of science in the human realm of history taking  a perspective disregarded in this era dominated by the biomedical model',
#  'Engel  personal communication',
#  'Stoeckle and Billings have surveyed the history of the medical interview in the United States since the beginning of the twentieth century',
#  'Inferences about the history can be obtained from hospital records',
#  "Examples from Richard Cabot's Case Teaching in Medicine  illustrate detailed histories  with one or two lines regarding the patient's social circumstances Stoeckle and Billings",
#  'From  to the s in the United States  as well as elsewhere  there were no instructional texts on history taking',
#  'Teaching was by senior physicians acting as role models at the bedside',
#  'With rare exceptions  there were no verbatim accounts of the history  and students themselves were rarely if ever actually observed or critiqued doing a history',
#  'Didactic material on what to ask was found  albeit sparsely  in physical diagnosis texts and manuals on the physical examination',
#  'Questions given as examples were highly specific  Have you ever had tuberculosis',
#  'There was circumscribed attention to social circumstances',
#  'After Martinet  the next real advance in history taking came with the publication of The Clinical Interview by Felix Deutsch and William Murphy in',
#  'The book was based in part upon reviewing transcribed tapes of psychiatric resident interviews of patients over a period of  years',
#  'The process of the interview received detailed attention',
#  'If the examiner allows the patient to talk without asking leading questions or answering his questions  the patient will usually give a detailed account of his complaints and ideas about his illness',
#  'Having exhausted his ideas and recollections regarding his organic disturbances  he will stop and wait to be asked a question',
#  "The examiner waits until he feels that the patient will not continue spontaneously  and he then repeats one of the points in the patient's last sentence in an interrogative form",
#  'Usually the therapist repeats one of the somatic complaints last mentioned  being careful to use the same wording as the patient',
#  'The patient then as a rule gives new information centering around his symptoms and is stimulated to further associations',
#  'P',
#  'Deutsch and Murphy termed this method associative anamnesis  or associative exploration',
#  'Medical students began to be taught this method  notably beginning with the course in Clinical Methods designed and used at the University of Rochester by Morgan and Engel',
#  'Their text introduced the method to other medical schools see Morgan and Engel',
#  'The Rochester course and text represent a landmark in history taking and in the approach to the patient',
#  'The book is the first text on clinical skills that approaches the history and interviewing differently from what had been so long a tradition of neglect',
#  'The biopsychosocial concept  as articulated by Engel   has now become the standard approach to the history',
#  'The spread and refinement of the history and physical examination in the United States followed the development of medical education',
#  'This development has been the subject of a recent book by Ludmerer',
#  'The outline below follows his excellent account',
#  'The Civil War pointed up with brutal clarity the deficiencies of American physicians',
#  'One estimate is that   Union soldiers died from wounds and   from disease    Confederate soldiers died from wounds and   from disease',
#  'Percussion was performed by only a small portion of physicians',
#  'Very few used the thermometer',
#  'Stethoscopes were rarely used',
#  'Large doses of laxatives and emetics were given for therapy',
#  'The U S',
#  'government finally required that each physician entering the army or navy pass a compulsory examination  barely  passed',
#  'The U S',
#  'physician of this time was a product of the medical education system of several dozen proprietary and a few university schools',
#  'Admission requirements consisted of one question  Can the applicant pay the fees',
#  'Instruction was almost totally didactic  anatomy was taught without benefit of dissection',
#  'The faculty of a typical proprietary school was composed of six to eight professors',
#  'The pervasive spirit was commercialism  with the teachers sharing the spoils of what was left of student tuition after expenses were paid',
#  'There were some bright spots',
#  'Alternatives and supplements available included apprenticeship  being a house pupil in a hospital  additional work during the summer by extramural non degree granting schools  and by going to Europeespecially Franceas has been described above',
#  'There was a profound skepticism toward medical science and experimentation among American physicians from  until the last half of the century',
#  'This reflected the influence of the French School',
#  'The laboratory sciences were distrusted',
#  'In  American physicians who had studied in France founded the Society for Medical Observation',
#  'By way of contrast  American physicians influenced by study in Germany founded in  the American Society for Clinical Investigation',
#  'This attitude against research profoundly influenced medical education until beyond the Civil War',
#  "It is illustrated by the fact that at no medical school in the s did research constitute a part of a faculty member's responsibilities Ludmerer",
#  "The faculty lectured and administrated on the school's time  and saw private patients on their own time",
#  'An extraordinary change occurred between  and   American physicians journeyed to Germany for their postgraduate education',
#  'As noted earlier    went between  and',
#  'The physicians who went to Germany had to have significant means  a spartan living cost $ a year',
#  'Consequently they were young  male  from the East Coast  and the upper strata of society Ludmerer',
#  'They took one of two paths',
#  'They gained practical experience in the newly developing specialties of ophthalmology  dermatology  laryngology  obstetrics  and surgery  and then came home to go into private practice',
#  'This groupestimated to be some   of the number cited abovemostly went to Vienna  where the New Vienna School provided exceptional clinical opportunities',
#  'A smaller group went to study the fundamental medical sciences',
#  'These people came back to America and became the leaders in American medicine until well in the s  William Welch  Franklin Mall  Henry Bowditch  etc',
#  'When these individuals returned  they were frustrated beyond measure because America simply had nothing comparable to the German university',
#  'A development that fortunately paralleled the return from Germany of these individuals was the emergence of the American university between  and',
#  'After the Civil War  the old fashioned college evolved into the modern university',
#  'At the root of this transformation was the astounding growth of information that occurred in all scholarly fields Ludmerer',
#  'Professional schools  including medicine  moved into the universities',
#  'The presidents of these universities  for a variety of reasons  vigorously promoted the welfare of their medical schools',
#  'To university leaders  research and teaching in medicine carried a special imperative  for such work offered the hope of better diagnosis and treatment of disease Ludmerer',
#  'Between  and  these two forces  the German trained physicians and ascendance of the university  acted to produce a profound change in American medical education at four universities  Harvard  Pennsylvania  Michigan  and Johns Hopkins',
#  'At Harvard  Charles Eliot became president in',
#  'He was a chemist who had worked in the laboratory and spent time abroad in Germany',
#  'He felt deeply the need to teach science with laboratories',
#  'He had a poor view of medical education  The ignorance and general incompetency of the average graduate of American Medical Schools  at the time he receives the degree which turns him loose upon the community  is something horrible to contemplate',
#  'His strong views on the need to reform medical education met with resistance and hostility on the part of the older faculty',
#  'In November   Eliot took the unprecedented step of assuming the chair at a meeting of the medical faculty  a seat he did not relinquish for the next forty years',
#  'No other event more dramatically symbolized the desire of the modern university to take charge of medical education',
#  'With the support of his faculty allies  Eliot tried to push through his ideas of reforming the medical school',
#  'For a year  as the two factions locked horns  the faculty was torn with strife',
#  'This was no conflict between elite and ordinary physicians but a civil war within the ranks of the elite',
#  'A deep chasm divided those with French from those with German views of medical science  providing a microcosm of the conflict besetting the elite medical community throughout America',
#  'Ludmerer    p',
#  "Eliot pushed through his ideas successfully  and in  appointed Henry Bowditch  just back from Ludwig's laboratory in Germany  as the faculty member in physiology",
#  'Bowditch was the first medical professor in America to be full time in teaching and research',
#  'The laboratory became the seat for teaching a greatly expanded basic science curriculum',
#  "This focus upon the laboratory fostered a new educational philosophy  the primary goal of medical education  in the eyes of the Harvard faculty  was not to provide students an encyclopedic knowledge of facts but to foster the student's ability to think critically  to solve problems  to acquire new information  to keep up with the changing times",
#  'This could best be done in the laboratory rather than in the lecture hall Ludmerer    p',
#  'The University of Pennsylvania medical school underwent similar reforms in   followed closely by the University of Michigan',
#  'The reforms in these three schools set the stage for the most extraordinary development of all  the opening of the Johns Hopkins Medical School in',
#  'This new medical school embodied astonishing innovations from its inception  strict admission requirements for students  two years of rigorous basic science training with plentiful laboratory experience  two years of clinical experience at the hospital bedside  a faculty chosen solely for their teaching and research ability  a view that research was one of its high priorities',
#  'The acquisition of William Osler as professor and head of medicine at the Johns Hopkins Medical School was of the highest importance in the development of medical education and the foundation of clinical work as a science in the United States',
#  'In this one man there was a confluence of all the forces described earlier in this chapter  an appreciation of the importance of the laboratory and research  a reverence for the clinical greats who had laid the foundations of physical diagnosisAuenbrugger  Laennec  Louis  a solid foundation in pathology',
#  'His training and historical interest had given him the knowledge and perspective to incorporate in one medical educational setting all that the heritage of medicine had slowly and painfully evolved up to that time Harvey',
#  'The medical clinic instructional model that Osler put into effect revolutionized medical teaching in the art and science of diagnosis and patient care',
#  'There were three aspects to the clinic',
#  "There was a live in resident staff with graded experience  from the new graduate to more senior residents of several years' experience",
#  'Instruction in methods of history taking and physical diagnosis was emphasized to a degree not seen since Louis',
#  'Medical students became actual members of the patient care team  taking histories  doing physicals  doing the laboratory work  and making rounds with the residents and faculty',
#  'Thus evolved the medical clerkship  which was extended to surgery  obstetrics and gynecology',
#  'This clerkship did for the clinical students what laboratory work did for the scientists',
#  'From the proprietary schools of the Civil War to the Johns Hopkins Medical School of   the teaching of medicine had changed dramatically Ludmerer',
#  'Three basic changes had occurred  the curriculum was more rigorous  many new subjects were added  the student became an active participant rather than a passive observer',
#  'The biographical vignettes beginning each section of this book take up where this chapter leaves off',
#  'These vignettes present individuals who have made seminal contributions to clinical diagnosis in the United States',
#  'They are listed in Table',
#  'This chapter has traced the stages in the knowledge and forces that have shaped the modern history and physical examination',
#  'As stated in the beginning  this has been a story of scholarship largely achieved by physicians going about the daily work of delivering patient care',
#  'They serve to stimulate us to rise above the routines of the daily ward round']

# %% [markdown]
# Then, have a look at the boundaries.

# %%
sents_dict['000.ref'][1]
# Out:
# [36, 90, 149, 213, 286, 355, 420, 463, 523, 559, 593, 623, 719, 798, 801]

# %% [markdown]
# ## Task 2 Tokenize each sentence in each document
#
# In this task, you are going to tokenize all the sentences for each clinical report. The tokenization function is provided as follows:

# %%
def tokenize_sent(sent):
    """
    The function tokenizes a sentence, and return a list of words that only contain alphabet 
    letters.
    """
    return [word for word in nltk.word_tokenize(sent.lower()) if word.isalpha()]

# %% [markdown]
# The above function uses the nltk's  built-in tokenizer to tokenize a given sentence. All the words are converted to lower cases and must only contain alphabet letters. Note that for simplification, we did the case normalization and just keep words with only alphabetic letters. However, for some tasks, like sentence segmentation and named entity recognition, it is good to keep the original form of the words.
#
# Now, you should write your code to tokenize all the sentences stored in <font color="orange">sents_dict</font>

# %%
tokenized_sents = {} #The key is the document name, the value is a list of tokenized sentences
#########please write the missing code below#######
for key, value in sents_dict.iteritems():
    tokenized_sents[key] = [tokenize_sent(sent) for sent in value[0]]

# %% [markdown]
# Similarly, you should check the out put of your code. Here, we print the first three tokenized sentences of "000.ref", and compare them with the original sentences in "000.ref".

# %%
print tokenized_sents['000.ref'][0]
print tokenized_sents['000.ref'][1]
print tokenized_sents['000.ref'][2]
# Out:
# ['physical', 'diagnosis', 'had', 'its', 'origins', 'in', 'grecian', 'medicine']
# ['clinical', 'medicine', 'flourished', 'before', 'the', 'greeks', 'especially', 'in', 'egypt', 'crete', 'and', 'babylonia', 'and', 'undoubtedly', 'the', 'greeks', 'were', 'influenced', 'by', 'these', 'earlier', 'physicians']
# ['but', 'writings', 'from', 'these', 'countries', 'did', 'not', 'become', 'part', 'of', 'the', 'mainstream', 'of', 'western', 'civilization', 'as', 'did', 'those', 'of', 'the', 'greeks']

# %% [markdown]
# ## Task 3 remove stop words
#
# As we discussed in the lecture, stop words do not contribute much to the lexical content. In most text analysis tasks (e.g., IR, text classification, topic modeling), we choose to remove all the stop words. Here, we start with counting the frequency of each unique word in the 16 reports in order to demonstrate that stop-words actually dominate the text. The NLTK package that we are going to use is the <b><a ref="http://www.nltk.org/api/nltk.html#nltk.probability.FreqDist">FreqDist</a></b> in the <font color="blue">nltk.probability</font>. To use <b>FreqDist</b>, we need to concatenate words in all the sentences of all the reports, and form a long list of tokens. The function for concatenating all the words is provides as follows:

# %%
from nltk.probability import *

def word_concat(dsd):
    """
    concatenate all the words stored in the values of a given dictionary. Each value is a list
    of tokenized sentences.
    """
    all_words = []
    for value in dsd.values():
        for sent in value:
            all_words += sent
    print "tokens:", len(all_words)
    print "types:", len(set(all_words))
    return all_words

# %% [markdown]
# Now, write your code the find the 20 most_common words in the code cell below.

# %%
#########please write the missing code below#######
freq_dist = FreqDist(word_concat(tokenized_sents))
freq_dist.most_common(20)
# Out:
# tokens: 61412
# types: 6925
# [('the', 4497),
#  ('of', 2590),
#  ('and', 1674),
#  ('a', 1436),
#  ('to', 1416),
#  ('in', 1397),
#  ('is', 1023),
#  ('with', 637),
#  ('or', 636),
#  ('be', 631),
#  ('that', 535),
#  ('patient', 529),
#  ('for', 491),
#  ('as', 479),
#  ('by', 450),
#  ('may', 361),
#  ('are', 348),
#  ('this', 335),
#  ('disease', 325),
#  ('it', 303)]

# %% [markdown]
# You should find that nearly all the words are functional words in those top 20 most-common words, except for "patient" and "disease". However, the two words actually appear in every clinical report. We should also consider removing this type of words in the preprocessing. Here your task is to remove all the stop words in the following list:

# %%
stopwords = []
with open('./stopwords_en.txt') as f:
    stopwords = f.read().splitlines()
stopwords = set(stopwords)

# %%
def remove_words(words, stops):
    """
    This function excludes all the words appearing in a given list.
    Here the list is named "stops"
    """
    #########please write the missing code below#######
    return [word for word in words if word not in stops]

# %% [markdown]
# Write your code below. Your code should use the above the <font color="blue">remove_words</font> function defined above.

# %%
tokenized_sents_stop = {}
#########please write the missing code below#######
for key, value in tokenized_sents.items():
    tokenized_sents_stop[key] = [remove_words(sent, stopwords) for sent in value]

# %% [markdown]
# After removing the stop words, you can find the difference of the most common words between before and after removing stopwords.

# %%
#########please write the missing code below#######
freq_dist = FreqDist(word_concat(tokenized_sents_stop))
freq_dist.most_common(20)
# Out:
# tokens: 30395
# types: 6506
# [('patient', 529),
#  ('disease', 325),
#  ('patients', 255),
#  ('pain', 225),
#  ('history', 208),
#  ('test', 202),
#  ('symptoms', 155),
#  ('physician', 141),
#  ('heart', 141),
#  ('pressure', 126),
#  ('physical', 126),
#  ('chest', 124),
#  ('syncope', 124),
#  ('clinical', 121),
#  ('blood', 118),
#  ('cardiac', 113),
#  ('examination', 113),
#  ('diagnostic', 111),
#  ('medical', 110),
#  ('exercise', 106)]

# %% [markdown]
# ## Task 4 Generate TF-IDF vector for each sentence
# Now assume that we are also interested in computing the similarity between any two sentences in a vector space. Instead of using counts, we consider the use of TF-IDF vectors. In this task, you are going to use the <a ref="http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html#sklearn.feature_extraction.text.TfidfVectorizer">TfidfVectorizer</a> in the <a ref="http://scikit-learn.org/stable/modules/classes.html#module-sklearn.feature_extraction.text">sklearn.feature_extraction.text </a> package. It is also necessary to read the <a ref="http://scikit-learn.org/stable/modules/feature_extraction.html"> Feature Extraction</a> tutorial on the sklearn website.

# %%
sents_ids = []
sents_words =[]
for key, value in tokenized_sents_stop.items():
    i = 0
    for sent in value:
        #print key
        sents_ids.append("{0},{1}".format(key, i))
        txt = ' '.join(sent)
        sents_words.append(txt)
        i = i + 1
sents_words
# Out:
# ['clinicians rate patient medical history greater diagnostic physical examination results laboratory investigations rich',
#  'clinical adage thirds diagnoses made basis history retained validity technological advances modern hospital',
#  'accurate history focus physical examination making productive time efficient',
#  'clinical hypotheses generated interview provide basis cost effective utilization clinical laboratory diagnostic modalities',
#  'diagnostic utility interview complemented therapeutic power',
#  'medium positive relationship established doctor patient empathic patient centered interview bolster patient sense esteem lessen feelings helplessness accompany episode illness',
#  'therapeutic alliance forged clinical encounter foundation ongoing patient care education',
#  'student medical interview differs conversations special skills required',
#  'sense direction distinguishes medical interview casual conversations social encounters',
#  'fundamentally medical interview purposeful conversation undertaken set goals priorities maintained physician mind',
#  'direction reflects respective participantspatient physician',
#  'patient enters interview seeking relief discomforts uncertainties illness physician actively conducts interview order clarify patient problems derive diagnostic therapeutic plans patient benefit',
#  'interview patient story heard suffering understood balanced physician understand patient problems engel',
#  'physicians difficult aspect interviewing patients maintaining balance patient physician agenda actively directing encounter facilitating patient spontaneous report history',
#  'interview dialogue people driven common goal',
#  'medical interviews basic types problem oriented health promotion interviews levinson',
#  'goals problem oriented interview reflect patient request specific problems',
#  'health promotion interview establishes data baseline patient current past health problems assesses current health risk factors smoking diet alcohol consumption heritable diseases family detect early evidence disease change bowel habits weight loss chest discomfort patient severe warrant problem specific visit doctor',
#  'reality medical encounters combine problem oriented health promotion approaches',
#  'issues health promotion important patients patients doctor routine check hidden concerns specific symptoms',
#  'fact careful questioning patient schedules routine check uncovers significant health concerns',
#  'medical interview categories information unavailable source patient illness',
#  'patient tells physician factual content medical history',
#  'factual content physician edits records written recordthe medical history',
#  'include comprehensive chronological report patient illness information positive negative accurate inclusive diagnostic reasoning etiologies patient problems',
#  'process interview physician patient encounter',
#  'observation process verbal nonverbal important information patient person',
#  'patient behavior interview facial expressions posture gestures communicates emotional concerns reactions illness style relating',
#  'sudden shifts topic avoidance issues flow spontaneous associations point concerns expressed directly',
#  'physician communication style behavior interview critical element interviewing process',
#  'distinction content process highlights dual skills required medical interviewanalytical interpersonal',
#  'skills discussed separately practiced',
#  'clarity validity information gathered interview content critically determined quality relationship develops patient physician process',
#  'candid disclosure patient concerns context nonjudgmental interviewing style',
#  'final comment process content helpful beginning student',
#  'content organization written medical history confused process clinician collects information interview',
#  'written medical history journalistic endeavor clinician edits organizes patient spontaneous report formal organized presentation',
#  'final product medical chart bear resemblance work clinician performs bedside',
#  'patients rarely report symptoms organized logical fashion comparable descriptions disease medical texts',
#  'fact patients complain illness sickness stating problems terms pathophysiologic categories disease',
#  'students expect patient present classic symptom complexes organized fashion experience considerable frustration rapidly disillusioned clinical medicine',
#  'complaint patient poor historian reflect unrealistic expectations interviewer part',
#  'clinical practice interview collaborative effort physician patient',
#  'reiser states physician matter skilled simply extract history patient',
#  'patient matter articulate give history final form guidance physician',
#  'history patient implies story illness extracted patient shaking coin piggy bank',
#  'erroneous conception medical interview leads frustrated attempts shaking history patient willfully keeping valuable coin hidden',
#  'helping relationship cornerstone medical care rogers',
#  'practice medicine medical interview important avenue establishing helping relationship built trust commitment',
#  'occur magically',
#  'physician actively employs interviewing techniques promote relationship',
#  'nonjudgmental interest patient problems active listening empathy communicating patient accurate assessment emotional state concern patient unique person important tools physician interpersonal repertoire',
#  'techniques strengthen therapeutic bond improve interview diagnostic power providing patient attentive receptive audience',
#  'visits physician excluding catastrophic illness motivated request interpretation symptoms patient finds confusing barsky',
#  'helping patient describe sort experiences physician provide explanations meaning events feelings perplexing threatening',
#  'patient sense control established realistic fashion feelings helplessness hopelessness addressed context helping relationship',
#  'problems reframed prioritized patient develop solutions',
#  'goals medical interview common psychotherapy',
#  'patients sense story feel encouraged active participants medical care',
#  'patient compliance cooperation future diagnostic therapeutic plans hinge physician skill developing negotiating management plan encourages patient involvement initiative',
#  'method physician establish rapport differs interview',
#  'encounter unique',
#  'patient respond reassuring touch timed interpretation emotional concerns moment shared silence',
#  'observation patient responses serve physician guide techniques employ feedback change',
#  'patients demonstrate remarkable variety responses medical interview reflecting range human personality types responses illness',
#  'anger anxiety denial vagueness detail emotional embellishment unreasonable expectations demands difficult common challenges medical interview',
#  'minutes interview physician actively sets stage effective interaction',
#  'interview begins meeting strangersthe physician patientclear introductions important',
#  'communicate physician respect patient unique individual',
#  'feelings anxiety common initial moments encounter intense beginning student uncertain role',
#  'simple statement good start',
#  'mrs',
#  'parish john simmons',
#  'year medical student school',
#  'interviewing minutes learn kinds problems affected',
#  '',
#  '',
#  'introduction establishes names roles purpose including interest patient response illness time limits interview',
#  'important knock entering patient room begin interview',
#  'courtesy neglected hospital rounds',
#  'assessing patient comfort step',
#  'iv oxygen mask facial expressions distress emesis basin bedside provide nonverbal clues alert clinician',
#  'bringing cup water raising head bed helping patient bathroom greatly appreciated',
#  'provide natural opportunity caring touch',
#  'questions feeling',
#  'comfortable',
#  'feel talk helpful',
#  'conduct interview quiet private environment',
#  'impossible busy hospital',
#  'televisions turned doors closed curtains pulled',
#  'bedrail lowered remove physical barrier communication',
#  'patient feels chair',
#  'difference interviewing patient lying flat bed sitting chair striking',
#  'simple act emphasize patient autonomy active involvement interview',
#  'family members visitors patient room physician introduce present explain purpose interview',
#  'allowed stay interviewer inform family patient opportunity speak excessive interruptions editorial comments',
#  'family comply problem addressed directly',
#  'minutes give observant physician valuable information patient communication style behavior providing tentative list problems',
#  'patients considerable prompting discuss current problems limits set rambling history',
#  'patient vocabulary clarity expression assessed early encounter',
#  'emotional reactions anxiety defensiveness hostility evident',
#  'elements important determining patient reliability historian',
#  'minutes give interviewed time calibrate hisher techniques individual patient engel',
#  'recognizing patient emotions responding supportive manner clinician conduct effective patient centered interview',
#  'examples interviewer expect confused patient give confused history emotionally reactive patient embellish exaggerate symptoms reactions depressed patient withdrawn require considerable support',
#  'introductions completed patient comfort assessed physician decide initiate questioning',
#  'physicians patient social personal background including residence employment family',
#  'technique works patients find distracting',
#  'expect direct inquiry health current problems',
#  'frequently opening questions include problems brought hospital office today',
#  'kind problems recently',
#  'kind problems share',
#  'open ended nondirective questions encourage patient report problems',
#  'point interview important patient talk spontaneously restricting directing flow information multiple questions',
#  'patient talk freely minutes initiating detailed inquiry',
#  'beckman observations internal medicine residents appears physicians frequently interrupt patients seconds interview',
#  'patients prevented expressing major concerns',
#  'unexpressed concerns part hidden agenda patient hiding physician hasnt patient chance talk',
#  'patient patient important complaint',
#  'premature selection direction detailed questioning report generalized fatigue confuse distract patient reporting significant problems chest pains fear heart problems',
#  'beginning directive closed questions early interview communicates patient remain silent asked specific question',
#  'patient feel good reason major complaint',
#  'physician turn feel frustrated direct questions lead dead ends',
#  'physician task arduous heshe question patient response',
#  'situations describing patient poor historian obscures fact major problem stems physician premature selection line inquiry full scope patient concerns defined physician overuse closed question answer interactional technique',
#  'obtain accurate unbiased information exert control interview needed',
#  'physician task patient talking illness productive fashion',
#  'facilitation techniques employed encourage guide patient spontaneous report',
#  'include posture gesture words interviewer interested patient',
#  'techniques reassure patient speaking provide time patient respond',
#  'shared silence helps flow interview interviewer maintains eye contact interested manner',
#  'question moment patient falls silent',
#  'silences patient reexperience emotions provide time needed reflection',
#  'interviewers judge patient actively thinking silence started',
#  'prompt patient continue spontaneous report repeating patient phrase questioning tone',
#  'felt short breath',
#  'make observational statement stopped talking moments ago telling weight loss',
#  'thinking',
#  'occasional nods head patient response',
#  '',
#  'huh huh',
#  'questioning tone patient talking',
#  'selecting focus questioning',
#  'problems',
#  'list extensive time limit interview problems concerns bothers',
#  'problems hope today',
#  'physician ranks problems order importance listens patterns suggest disease processes',
#  'problems related chief complaint',
#  'unrelated relevance',
#  'evident patient troubled problems physician considers lower priority urgent',
#  'patient concerned finances physician learn chest pain palpitations',
#  'general clinician briefly communicate concern patient major concerns medically significant',
#  '',
#  'mentioned problems time clarify',
#  'worried finances',
#  'concerns attention',
#  'work',
#  'find chest pain fainting spell mentioned',
#  'physician assume patient concerns raised early interview',
#  'patients talk embarrassing confidential problems rapport trust deepened',
#  'infrequently patient brings important issues end encounter stating doctor',
#  'clinician explores fully patient major problems leads obtained discussion chief complaint',
#  'history present illness hpi includes patient history recent remote pertinent understanding current illness',
#  'completing hpi physician collect pertinent information patient past history history hypertension patient stroke patient family history family history breast cancer patient breast lump social history domestic discord patient insomnia fatigue',
#  'piece information assessed reliability completeness relevance patient problem',
#  'physician repeatedly scan information gathered symptom complexes diagnostic patterns',
#  'physician interviewing year woman fever back pain urinary frequency immediately possibility urinary tract infection',
#  'increasing knowledge clinical syndromes clinician ability form complex diagnostic hypotheses improves',
#  'hypothesis tested validity specific questions bladder kidney infection',
#  'kidney stones',
#  'sexually active',
#  'process speculations tested objective reality accurate hypotheses generated',
#  'begin line inquiry open ended question proceed specific questions fill gaps',
#  'encourage patient provide primary data words symptoms provide diagnostic labels hearsay doctors family members secondary tertiary information',
#  'patient coaching information physician seeks',
#  'patient complains esophagitis asked describe symptoms physician accepts diagnostic label',
#  'questions worded patient difficulty understanding asked',
#  'avoid technical terms diagnostic labels',
#  'interviewer questions type information requested answer expected',
#  'difference stomach problems',
#  'youre hurting stomach',
#  'obvious easy fall pattern leading questions',
#  'effective questions simple',
#  'avoid double barreled questions stomach pains bladder problems',
#  'engel describes dimensions characterize bodily emotional aspects symptom chronology bodily location quality quantity setting aggravating alleviating factors manifestations',
#  'general clinician gather information clarifying dimensions area major concern',
#  'directive statement needed direct coach patient information needed',
#  'detailed description symptoms',
#  'start beginning',
#  'chronologic description framework characterizing illness',
#  'interviewer obtain chronologic report problem started facilitate continuing flow information questions happened',
#  '',
#  '',
#  'dating onset illness difficult patients general estimate made',
#  'questions feel',
#  'feel christmastime',
#  'time onset illness',
#  'specifically patient similar symptoms past',
#  'chronology includes duration symptomatic episode minutes chest pain angina days chest pain rib fractures periodicity pain early small bowel obstruction versus constant pain peritonitis symptom worse time',
#  'bodily location pain discomfort defined accurately',
#  'patient encouraged location radiation pain hand gestures large area involved',
#  'remember patient pain multiple pains multiple disease processes',
#  'patient characterize differentiate',
#  'patients analogies describe quality sensation',
#  'pain myocardial infarction similar vise tightening chest standing chest',
#  'patient exact words important tightness assumed pain',
#  'patient vocabulary',
#  'patients highly descriptive emotion laden terms felt stabbing knife',
#  'important clues patient emotional state reactivity',
#  'patients interviewer find descriptive language',
#  'providing patient choice descriptions pain sharp dull',
#  'clinician realize limiting patient response alternatives bias history',
#  'intensity pain estimated scale compared pain patient experienced',
#  'scalar method helpful intensity symptoms time',
#  'examples quantity include volume quantity sputum expectorated day number number times patient lost consciousness degree impairment patient suffers',
#  'impairment disability characterized terms patient usual daily activities dyspnea climbing stairs home chest pain sweeping floor',
#  'patients minimize amplify quantity intensity symptomsimportant indicators emotional responses communication styles',
#  'setting symptoms occur critical developing clear description illness',
#  'felt ill',
#  '',
#  '',
#  'excellent questions early interview',
#  'hypotheses etiology symptoms frequently evolve understanding accompanying physical social emotional events surround episode illness',
#  'initial data makes symptom worse makes flows patient spontaneous account',
#  'chest tightness brought exertion shortness breath night relieved sitting points specific pathologic processes effort angina paroxysmal nocturnal dyspnea',
#  'knowledge clinical syndromes sharpens physician ear clues basis directed line inquiry',
#  'physician patient reports sudden onset shortness breath chest pain days fractured tibia pain pleuriticworsened deep breath cougha symptom pulmonary embolus',
#  'clinician collects data kinds patient sought symptom types treatments including prescribed counter medications',
#  'symptoms rarely occur singly',
#  'clinician listen groups related symptoms provide diagnostic clues pathologic processes involved organs',
#  'physician joint pains notice',
#  'patient response positive asked describe symptoms open ended questions',
#  'clarification obtained specific questions',
#  'patient reports symptoms physician decide directed questions support reject diagnostic possibility',
#  'patient complains joint pains physician fevers',
#  'night sweats',
#  'rash',
#  'sensitivity sun',
#  'irritation eyes',
#  'negative answers termed pertinent negatives important positives defining nature severity illness',
#  'rule rule specific diagnoses',
#  'dimensions pursued comprehensive interview including patient emotional reactions illness patient means coping discomfort disability',
#  'patient reactions events important events',
#  'addition patient thoughts fantasies caused illness important understanding patient decided seek care',
#  'majority illness episodes treated physician office',
#  'problem oriented health promotion interviews interesting patient decided seek care',
#  'patients specific unrealistic fantasies physician',
#  'interviewer identify',
#  'patient explanatory model illness differing patient cultural group significantly determine individual behavior illness affect compliance medical therapy',
#  'negotiation bring doctor patient closer kleinman al',
#  'interviewer clinical discretion determining history present illness defined',
#  'summarizing history concluding section interview',
#  'understand history',
#  'march noticed',
#  'summary patient chance check accuracy history physician chance review history gaps lack clarity',
#  'hpi completed physician collected great deal data remaining segments medical history past medical history family history social historypatient profile review systems',
#  'information time',
#  'remainder interview physician directs patient fill blanks completing rest history',
#  'proceeding section make clear transitional statement',
#  'ive pretty good idea major problems developed',
#  'questions past health',
#  'transitional statements prepare patient coming',
#  'review past medical problems treatments directly pertinent hpi completes past medical history',
#  'prior diagnosis diabetes mellitus patient gangrenous toe belongs hpi remote appendectomy',
#  'past medical history defines data base future reference',
#  'major elements past medical history include childhood adult illnesses operations trauma allergies drug sensitivities characterized detail immunizations health maintenance ppd status patient performs breast examination routine pap smears sigmoidoscopies',
#  'medical problems family members reviewed special attention heritable disorders',
#  'patient reaction illness family influence response personal medical problems',
#  'family history hypertension myocardial infarction included hpi patient onset chest pain',
#  'time limitations preclude detailed inquiry health family member',
#  'discretion family large elderly patients remember major purpose family history assess risk factors patient current future health',
#  'physician collects personal data patient complete patient profile',
#  'information emerged patient describes story present illness gaps apparent',
#  'social history portion interview physician gather data patient education occupation usual daily activities functional status relationships friends family social supports stresses financial statusinsurance coverage habits cigarettes alcohol health consequences',
#  'relevance patient health life adaptation guide interviewer deciding information gather',
#  'concluding interview physician complete symptom checklist assure important areas patient physical psychologic health considered',
#  'clinicians prefer complete review systems examining patient distracting beginning student',
#  'begin review systems open ended question problems havent discussed',
#  'patient mentions problem symptoms characterized',
#  'transitional statement prepares patient line questioning',
#  'move physical examination series questions specific health problems',
#  'stop problems find',
#  'interviewer inquire system orderly fashion',
#  'questions headaches',
#  'unwanted effect inspiring overly complete patient response',
#  'providing direction limits',
#  'recent health problems',
#  'severe headaches recently',
#  'entire review systems minutes physician begins open ended request information proceeding',
#  'patients positive review systemsproblems area',
#  'emotional problems patient amplify symptoms gain attention emotional support',
#  'closing interview patient discuss questions',
#  'clinician proceeds physical examination',
#  'interestingly patients talkative examination',
#  'reassured physician touch feel ease sitting face face interview',
#  'examination specific body region system remind patient previously forgotten details considerable diagnostic importance',
#  'alert physician stethoscope ears long hear patient',
#  'communication techniques critical importance physician reports findings history physical examination',
#  'diagnostic prognostic discussions effective tailored patient individual cognitive communication style',
#  'special emotional concerns discovered interview guide sensitive approach sharing news preparing future',
#  'physician knowledge patient person foundation patient education',
#  'real sense interview continues clinical encounter',
#  'skilled clinician encounter problems interviewing patients',
#  'interview back track clinician recognize problem find solution',
#  'interviewing problems roughly divided categories',
#  'problems patient intense emotional reactions altered mental status unrealistic fantasies doctor',
#  'problems interviewer overly judgmental attitude directive approach questioning failure listen patient',
#  'problems physician patient relationship language barrier failure negotiate shared goal encounter',
#  'complexities interviewing process problems category found encounter',
#  'step solving problems recognize interview',
#  'recognition facilitated clinician assesses interview reference major functions data gathering establishing supportive therapeutic relationship',
#  'minutes interview clinician asks himherself questions',
#  'established rapport patient',
#  'helping patient provide accurate unbiased report illness',
#  'collected data make accurate diagnostic hypotheses patient problems',
#  'clinician monitors reactions interview',
#  'frustration anger boredom signal troubled interview',
#  'problem recognized interviewer clinical reasoning establish nature problem produced',
#  'effort diagnose problems interview parallels process diagnosing patient presenting problems chief complaint',
#  'diagnostic processes defining problem based observations patient patient',
#  'clinician step back mentally form hypotheses wrong communication process',
#  'interviewer notice patient appears depressed withdrawn confused',
#  'evident interviewer feels negatively patient disapproves behavior distracted personal thoughts',
#  'problem recognized hypotheses generated etiology clinician solutions interview progresses',
#  'complete mental status examination needed confused patient decision interview patient family check reliability history',
#  'interpreter needed language barrier',
#  'directive interview style required patient problems identified',
#  'limiting technique employed patient rambles',
#  'clarifying highly directed questions needed history vague',
#  'cultural differences detected shared approach negotiated',
#  'physician limitations defined patient makes unreasonable requests quill',
#  'frequently problems interview result patient emotional reactions illness medical encounter',
#  'patients experience considerable anxiety illness visiting doctor',
#  'patients feelings anger helplessness',
#  'responses vary severity illness past experiences personality current stresses supports',
#  'patient appears reticent talk emotional support',
#  'active judgmental listening demonstrates physician interest concern encourages patient talking',
#  'reassurance provided interview proceeds attempt reduce patient anxiety',
#  'statements upset didnt caused pain waiting biopsy results pretty tough patients increase patient esteem share experiences physician',
#  'avoid false reassurance unrealistic promise happy outcome',
#  'obtain accurate information emotion laden issues physician roll carpet inviting patient honest answers',
#  'patients respond defensively questions drink',
#  'minimizing quantity interviewer',
#  'rephrasing question accusatory tone reassurance atmosphere acceptance',
#  'people stress find drink',
#  'experienced',
#  'sexual history patient respond candidly statement patients heart problems find difficulties sexual function',
#  'problem',
#  'sex life',
#  'empathy closely related reassurance',
#  'empathic statements communicate physician recognition patient feelings provide feedback interviewer understands',
#  'empathy begins interviewer identifying patient emotional state',
#  'statement communicates physician recognition acceptance patient feelings encourages exploration sad talk son',
#  '',
#  'pointing patient emotion form gentle confrontation',
#  'focuses attention aspect patient feelings communicated statements behaviors',
#  'physician point emotion patient unaware defensive timing critical',
#  'interviewer prepared hostile response denial',
#  'nature response depends patient personality depth rapport established',
#  'patients cry medical interview',
#  'interviewer rush stop tears',
#  'storm pass providing time emotional release crying',
#  'interview resume gentle questioning',
#  'general good avoid questions feel angry sad',
#  'rephrasing question angry',
#  '',
#  'tears',
#  'gentle confrontation needed address communication problems physician patient',
#  'patient reticent talk issues important pointed',
#  'reluctant talk problems',
#  'uncertain trust',
#  'problems',
#  'proceed',
#  'statements identify problem confrontation suggest problem distrust establish physician invite patient participation deciding interview',
#  'principle sharing problems interview patient seldom practiced frequently effective',
#  'clinicians feel rushed complete interview move activities',
#  'time limitations reality clinical medicine complete data collection single encounter',
#  'settings physician opportunity back patient clarify history',
#  'patients encouraged reflect memories clarify visit',
#  'patients unaware physician time restraints',
#  'patient claim monopoly physician efforts addressed',
#  'dependent patient express time doctor follow visits reporting worrisome symptoms rectal bleeding exertional chest pain night sweats end appointment',
#  'recurrent behavior angers frustrates physicians jeopardize physician patient relationship',
#  'gentle confrontation helpful modifying situation',
#  'visits told worrisome symptoms end appointment',
#  'real problem doesnt give chance discuss problems fully',
#  'id decide problems hear coming visit',
#  'ill list beginning appointment',
#  'length appointments decide problems cover wait',
#  'statement establishes physician limits encourages patient active participation deciding utilize scheduled time',
#  'confusing traditional rigid order written medical history actual process information emerges medical interview',
#  'relying heavily directed closed questions',
#  'style discourages patient associations spontaneous report symptoms',
#  'ignoring patient emotional responses concerns interview process',
#  'narrowing scope inquiry early interview',
#  'failure clarify dimensions symptom patient words',
#  'insisting interview accomplished session',
#  'experienced clinicians return patient clarify history',
#  'limiting list diagnostic hypotheses adequate data collected',
#  'questions leading complex double barreled unclear',
#  'failure follow basic courtesies interview lack clear introductions ignoring patient comfort failure establish atmosphere trust confidentiality',
#  'failure elicit patient ideas problem patient fantasies doctor',
#  'note taking interrupts flow interview',
#  'selected references follow elaborate extend concepts discussed',
#  'student remember clinicians learn conduct interviews interviewing patients supervision critical element educational process',
#  'engel compared learning interview patients learning play musical instrument',
#  'tasks require practice critical supportive assessment things',
#  'review audio video recordings student observe understand interviewing process',
#  'practice medicine awareness important',
#  'learning process extends years',
#  'finest clinicians find reasons excitement humility patient encounterwith challenge interview',
#  'good hear patient ive finally found doctor listens problems',
#  'technologic wizardry modern hospital difficult diagnostic puzzles unraveled carefully conducted patient centered interview',
#  'physical examination process evaluating objective anatomic findings observation palpation percussion auscultation',
#  'information obtained thoughtfully integrated patient history pathophysiology',
#  'unique situation patient physician understand interaction intended diagnostic therapeutic',
#  'physical examination thoughtfully performed yield data patient diagnosis management',
#  'exception medical history patient time physical examination',
#  'rarely history recordings acute events',
#  'information pertinent physical examination learned observation speech gestures habits gait manipulation features extremities',
#  'interactions relatives staff revealing',
#  'pigmentary cyanosis jaundice pallor noted',
#  'diaphoresis blanching flushing provide clues vasomotor tone related mood physiologic abnormalities',
#  'aspects patient habits interests relationships ascertained pictures books magazines personal objects bedside',
#  'hospital room office physical examination occur variety settings difficult establish privacy quiet',
#  'resource physician set stage physical examination communicate respect genuine interest patient welfare',
#  'patient addressed politely asked perform required maneuvers examination technique preferable imperative language',
#  'patients prepared unpleasant portions examination',
#  'explanations reassurance maintain continuous conversation patient examination',
#  'avoid embarrassing patient',
#  'draping material appropriately personal areas subjected undue exposure',
#  'examination ends abruptly diminish doctor patient relationship destroy therapeutic content',
#  'patient benefit summary relevant findings require reassurance found',
#  'single device optimal performance physical examination inquisitive sensitive mind',
#  'mastery techniques observation palpation percussion auscultation',
#  'important tools required examination table',
#  'environment affects quality physical examination wise arrange quiet privacy darkening room parts examination comfort patient examiner',
#  'complete examination proceed orderly fashion minimum required position shifts patient table',
#  'hand physician ascertain integrity organ systems regional examinations',
#  'instance examination head neck physician identify vascular neurologic lymphatic skeletal integumentary components relate complements body regions',
#  'tedious contrast examine vascular system entirety complete neurologic examination organ systems turn',
#  'examining anatomic region observer alert appearance abnormality question time morphologic aspects abnormality clinical significance',
#  'general physical examination forms depending circumstances',
#  'examiner evaluates body regions general abnormalities',
#  'clues derived history signal precise detailed examination system',
#  'physical examination includes sequence presented table',
#  'clinically significant physical examination flexible entity vary patient',
#  'periodic examinations health assessment comprehensive hospital admission examinations',
#  'contrast cost effective undertake complete physical examination patients presenting symptoms upper respiratory tract infection urinary tract infection',
#  'physical examination key part continuum extends history present illness therapeutic outcome',
#  'history physical examination linked properly physician reasoning capabilities laboratory tests large measure confirmatory',
#  'physical examination weak link chain performed perfunctory superficial manner',
#  'understanding pathophysiologic mechanism physical abnormality essential correct diagnosis management',
#  'instance failure discriminate origin carotid bruits transmitted sounds valvular origin critical significance',
#  'knowledge disease techniques physical examination augmented',
#  'astute physician constantly reviews adds repertoire techniques physical examination',
#  'evaluation physical examination terms sensitivity specificity difficult',
#  'interpretation isolated physical findings influenced presence absence historical information coexisting physical findings',
#  'instance assessment clubbing fingers present absent significant interobserver variability demonstrated influenced clinical appearance patient',
#  'number studies attempted validity physical exam diagnostic tool',
#  'concept interobserver intraobserver variability introduced specific isolated findings',
#  'judging presence absence agreed observers repeated exams single blinded observer graded intensity breath sounds',
#  'presence absence ascites patients liver disease shown difficult determine physical exam techniques',
#  'bedside measurement forced expiratory time auscultation shown small interobserver variability trained observers clinical degree airway obstruction',
#  'large degree variability observing physical signs recommendations made reporting interpreting physical findings',
#  'emphasis dichotomous variables presence absence graded variables intensity breath sounds',
#  'physical signs clubbing fingers represent continuum normal abnormal',
#  'emphasis findings represent extremes borderline cases',
#  'recognition physical findings high degree interobserver variability important',
#  'good examples include detection moderate small amounts ascitic fluid detection diaphragmatic movement percussion',
#  'findings deemphasized favor reproducibility',
#  'beneficial body symmetry advantage',
#  'differences auscultated breath sounds similar area left lung clinically important decrease breath sounds',
#  'points mind physical exam fill proper role care patient',
#  'adjunct history physician interact physically patient',
#  'exercise capacity maximum amount physical exertion patient sustain',
#  'accurate assessment exercise capacity requires maximal exertion sufficiently prolonged stable steady state effect circulation pattern patient response consistent exertion repeated',
#  'assessment exercise capacity essential feature patient evaluation',
#  'complete accurate history cornerstone assessment',
#  'history reflect detailed quantitative information intensity duration maximal effort specifics nature limiting symptoms',
#  'information clarify extent impact exertionally related problems valuable diagnostic prognostic implications',
#  'logical guide evaluation therapy',
#  'exercise capacity evaluated interview direct laboratory measurement',
#  'approaches important complementary',
#  'information patient history immediately inexpensive',
#  'significantly information defines exercise capacity context patient symptoms lifestyle preferred mode activity',
#  'historical information contaminated unsuitable forms exercise patient anxiety occur exercise laboratory',
#  'practice complete historical information patient activity planning exercise laboratory testing',
#  'interview patients encouraged specific describing observations relation recent periods physical activity',
#  'kinds information elicited',
#  'maximal effort defined terms intensity duration exertion',
#  'quantification intensity implies estimation rate performing physical work',
#  'flight stairs climbed run steady walk leisurely pace possibly interrupted frequent stops',
#  'exercise performance fully characterized total work output flights blocks rate brisk walk normal pace duration effort minutes',
#  'incidental information important precipitation exertionally related symptoms',
#  'ambient temperature recent meals medications emotional state exert crucial influence circulatory response exercise alter likelihood intensity effort challenge cardiovascular reserves',
#  'important item historical information related effort character time exercise induced symptoms symptoms patient stop',
#  'specific symptoms discussed detail section',
#  'general presence pattern effort limiting dyspnea chest discomfort light headedness generalized specific weakness palpitations leg cramping major distinctive implications patient management',
#  'exertional symptoms occur crescendo fashion threshold exercise intensity exceeded symptoms resolve minutes rest',
#  'noteworthy exception walk angina',
#  'patients unusual condition angina fades exercise persists initially excessive circulatory response exercise partially reverses continuing steady mild effort',
#  'symptoms postexertional period',
#  'symptoms reflect greater awareness somatic sensation exercise ceases rapid shifts hemodynamic autonomic function recovery period',
#  'response exercise induced symptoms therapy prevention symptoms effort clinical utility',
#  'detailed accurate account exercise induced symptoms reward interviewer remarkably precise indications relevant pathophysiology possibilities effective therapeutic intervention',
#  'ingenuity imagination needed arrive reliable meaningful information exercise performance ordinarily sedentary patients',
#  'specific detailed inquiry made physically demanding common domestic activities carrying laundry groceries chasing wayward children pets yard work bed making floor washing job related tasks lifting stair climbing operating machinery sexual intercourse travel hauling luggage sports',
#  'question elicit vivid accounts experiences effort mentioned',
#  'order bracket maximal exercise capability define patient flight blocks normal pace flights blocks',
#  'activity sustained minute yield reliable information circulation begin approach steady state time period',
#  'sustained activity severely symptomatic patients',
#  'consistency performance important defining exercise capacity',
#  'consistency sought kinds activities',
#  'extent patient limitation equally evident contexts',
#  'patients fluctuations inconsistencies exercise capacity',
#  'degree explained differences incidental conditioning factors mentioned previously differences character exertion arm work versus leg work untrained versus trained muscle groups isometric versus isotonic effort',
#  'discrepancies resolved compelled define range exercise capacity characterizes patient good days bad days',
#  'consistent shifts exercise capacity important sought patient exercise related problems',
#  'clear cut deterioration exercise capacitybest defined symptom induced inability perform activity performed regularly symptoms earlier dateis convincing evidence clinically meaningful disease progression',
#  'exercise capacity defined terms maximal effort tolerance clinical context delineated evaluating patient expectations demands respect physical activity',
#  'exercise capacity subjectively satisfactory sedentary apartment dweller severely debilitating patient physically demanding occupation avocation',
#  'important consideration expressed commonly means classifying cardiovascular symptoms table',
#  'practice objective subjective measures symptomatic limitation figure clinical decisions',
#  'newer canadian cardiovascular society classification stipulates inability perform specific task walking blocks level climbing flight ordinary stairs normal pace normal conditions objective index marked limitation anginal patients',
#  'function body systems circulation respiratory systems adequately tested exercise',
#  'system reserve capacity excess needed sustain normal asymptomatic body functioning rest modest activity',
#  'disease processes affecting circulation respiration progressive loss physiologic function',
#  'diseases manifest initially reduction cardiac pulmonary reserve',
#  'reserve capacities tested exercise early potentially remediable stages diseases sort produce symptoms strenuous effort',
#  'assessing maximum capability patients perform exercise examining physician evaluates qualitative terms reserve capacity organ systems contributing exercise response',
#  'impairment exercise capacity alert physician potential specific precise studies organ function',
#  'exercise performance reflects coordinated response cardiovascular pulmonary neural function action exercising muscles',
#  'exercise induces graded increases heart rate arterial pressure cardiac output myocardial contractility rate depth respiration',
#  'rapid reversible shifts occur distribution blood flow blood composition',
#  'orchestrated central nervous system responding direct cortical input neural humoral feedback exercising muscles',
#  'neural control cardiovascular function exerted part characteristic increases sympathetic stimulation reciprocal decreases para sympathetic stimulation',
#  'steady effort cardiovascular pulmonary parameters begin stabilize minutes rapid change levels specific intensity exercise patient',
#  'steady state levels characterize patient performance',
#  'autonomic shifts trigger pathologic physiologic responses exercise induced arrhythmias asthma',
#  'reduced exercise capacity dysfunction portion complex exercise response',
#  'nonspecific symptom generalized weakness reflect endocrine metabolic hematologic neuromuscular psychological problems cardiovascular pulmonary disorders',
#  'generalized weakness nonspecific underlying identified clinical manifestations',
#  'exercise capacity instances measured objectively testing patient exercise laboratory',
#  'limitations testing great selected patients',
#  'maximum exercise performance characterized respect intensity duration effort values limiting symptom compared estimates obtained history',
#  'performance index matched prior performance patient order quantify occurring time therapy',
#  'matched performance patients order assess comparability patient groups',
#  'information physician patient historical information unreliable ambiguous',
#  'infrequently case patients fail push meaningful limits',
#  'exercise intensity measured external work watts total body oxygen consumption ml okgmin',
#  'exercise performed generally accepted protocol workload escalation fixed intervals stage exercise termination provide summary estimate exercise capacity',
#  'general exercise testing historical inquiry seeks define functional reserve measuring maximal symptom limited exercise capacity',
#  'exercise testing utilize specific physiological end point age related target heart rate full deployment functional reserve',
#  'addition objective quantification exercise capacity definition limiting symptoms laboratory testing demonstrate important concomitant physiological parameters heart rate blood pressure cardiac output left ventricular ejection fraction arterial blood gas content ventilatory characteristics',
#  'reveal characterize electrocardiographic evidence myocardial ischemia arrhythmia',
#  'coincidence exercise induced symptoms specific physiologic derangements long identifying origin possibly remedy patient problem',
#  'history limited exercise capacity important characterizing quantifying clinically significant problem',
#  'decreased exercise capacity stimulate search specific guided symptoms signs',
#  'control exercise induced symptoms major goal treatment cardiovascular pulmonary disorders',
#  'complete accurate assessment extent limitation relation patient pattern activity essential intelligent selection evaluation treatment program',
#  'quantifying exercise limitation impact lifestyle accurate estimate exercise capacity establishing diagnosis prognosis',
#  'presence stable consistent limitation exercise implies static defect anatomy physiology',
#  'circumstances measurement cardiac pulmonary function onset symptoms reveal characteristic',
#  'contrast dyspnea ischemic type chest pain occurring unpredictably impaired exercise capacity suggests evanescent abnormality paroxysmal arrhythmia bronchospasm coronary spasm',
#  'prognostic implications reduced exercise capacity significant',
#  'aortic valve disease aortic stenosis heart related exercise limitation identifies patients high risk cardiac death',
#  'lack interference lifestyle favorable symptomatic response medical therapy patients generally considered candidates operative intervention prevent cardiac death',
#  'analogous situation exists subgroups patients coronary artery disease',
#  'selected individuals marked impairment exercise capacity canadian cardiovascular society class iii iv suggests high mortality improve coronary artery bypass procedure exercise capacity lower mortality lesser likelihood improved prognosis operation',
#  'assessment exercise capacity patients aortic valve disease coronary artery disease offers important clues long term outlook optimal management',
#  'noteworthy exercise capacity reliable guide prognosis cardiac patients',
#  'individuals dilated cardiomyopathy left ventricular ejection fraction reliable predictor mortality',
#  'patients markedly reduced ejection fractions preserved exercise capacity approximately equal risk early cardiac death patients similar ejection fractions impaired exercise capacity',
#  'detailed searching sympathetic discussion patient yield information patient exercise capacity',
#  'interviewer aware limitations approach',
#  'patient anxiety depression potent motivating factors lead unconscious denial distortion exaggeration exercise related symptoms',
#  'patients symptoms present character defined confidence',
#  'patients perform tasks reveal meaningful information exercise capacity reasons directly linked disordered physiology',
#  'wise clinician seek corroborative data objective exercise testing',
#  'laboratory conditions patient practice symptoms appearing vague inconsistent atypical history revealed distinct consistent typical reproduced testing',
#  'correlative physical findings electrocardiographic findings hemo dynamic parameters clarify origin character obscure problems',
#  'exercise laboratory viewed occasionally indispensable supplement interview assessment exercise capacity',
#  'patients unsuited exercise testing',
#  'testing inappropriate information emerge clinical situation fully defined findings exercise performance impaired extraneous factors',
# ...
#  'similarly improving exercise tolerance strong evidence treatment regimen effective',
#  'pain caused exertion severity clue etiology',
#  'pain caused coronary disease require patients stop usual activities',
#  'frequency duration pain defined data helpful distinguishing attacks',
#  'episodes pain caused coronary disease hour',
#  'coronary disease rarely episodes lasting hours electrocardiographic acute myocardial infarction',
#  'symptoms accompanying chest pain provide diagnostic clues',
#  'cough dyspnea suggests pulmonary disorders',
#  'diaphoresis frequently occurs acute myocardial infarction',
#  'dysphagia nausea vomiting suggest gastrointestinal etiology',
#  'patient asked describe temporal relationship pain symptoms',
#  'accompanying symptoms helpful diagnostically occur close proximity episodes pain',
#  'surprisingly patients history myocardial infarction found coronary disease recurrent episodes pain',
#  'conditions asked include valvular rheumatic heart disease hypertension peptic disorders esophageal disorders achalasia rheumatologic disease chronic lung disease hyperventilation syndrome anxiety states',
#  'pain originate structures chest including skin ribs intercostal muscles pleura esophagus heart aorta diaphragm thoracic vertebrae',
#  'pain transmitted intercostal sympathetic vagus phrenic nerves',
#  'innervations deep structures thorax follow common pathways central nervous system making difficult localize source pain',
#  'pursuing chest pain probabilistic approach diagnosis aid making decisions patients',
#  'chapter clinician estimate probability diagnosis patient',
#  'studies coronary arteriography patients referred evaluation recurrent chest pain quantified prevalance coronary artery disease chest pain syndromes',
#  'studies found patients typical exertional angina significant anatomic coronary disease',
#  'patients atypical angina prevalence coronary disease prevalence patients nonanginal pain',
#  'prevalence figures interpreted caution',
#  'arteriography studies consistently shown women lower prevalance coronary disease men',
#  'coronary artery surgery study men typical angina pectoris prevalance significant coronary disease women typical angina prevalence',
#  'prevalence coronary artery disease strongly influenced age',
#  'men risk coronary disease increases steadily ages increase age',
#  'women risk rises gradually age increases rapidly ages',
#  'arteriography studies reported disease prevalances patients evaluated referral centers selected populations higher prevalance coronary disease general population',
#  'study reported sox al',
#  'patients met specific criteria nonischemic chest pain determine pain',
#  'patents walk clinic evidence ischemic heart disease follow',
#  'clinicians attempt estimate underlying rates disease clinical settings interpreting patient disease risk',
#  'studies provided data estimating risk coronary artery disease investigation prevalance disease patients chest pain',
#  'patients recurrent chest pain caused coronary artery disease approximately half reflux esophagitis esophageal contraction abnormalities',
#  'etiologies include chest wall disorders hyperventilation pulmonary disease common populations',
#  'schemes classify etiologies chest pain distinguish acute chronic patterns pain',
#  'patients acute pain include episodes recent onset recent increase intensity frequency recurrent pain',
#  'patients chronic pain include recurrent episodes pain occurring stable pattern',
#  'leading diagnostic consideration patients chronic chest pain coronary artery disease',
#  'commonest clinical presentation coronary artery disease recurrent angina pectoris',
#  'helpful diagnostic feature coronary artery disease pain improves specific medications',
#  'relief anginal pain minutes taking sublingual nitroglycerin strong evidence coronary disease caused pain',
#  'decreased frequency attacks starting beta blocker calcium channel blocker long acting nitrate preparation suggests coronary artery disease',
#  'esophageal disease common recurrent chest pain',
#  'esophagitis secondary acid reflux stomach frequently esophageal pain',
#  'acid chemical damage inflammation mucosa resulting pain burning quality',
#  'clues presence reflux esophagitis include history acid peptic disease symptoms reflux regurgitation acid taste mouth',
#  'chest pain caused esophageal reflux occur meals related body position',
#  'episodes pain induced bending waist',
#  'occur night recumbent posture enhances reflux acid esophagus',
#  'relief pain antacids topical lidocaine specific maneuvers reduce reflux suggests diagnosis',
#  'esophageal motor disorders commonly chest pain',
#  'reflux esophagitis pain irritation esophageal mucosa motor disorders pain contraction spasm muscular wall esophagus',
#  'esophageal spasm occurs secondary manifestation reflux esophagitis',
#  'mucosal irritation inflammation severe stimulation local nerves leads muscular spasm',
#  'patients report pattern pain similar reflux esophagitis occurring meals aggravated body position',
#  'patients report varying qualities pain',
#  'episodes simple mucosal irritation pain reported heartburn pain reported severe heavy quality episodes muscular spasm',
#  'esophageal motor disorders independent acid reflux disease patients achalasia diffuse esophageal spasm',
#  'patients show pattern episodes occurs patients acid reflux',
#  'pain unrelated body position occur eating meals',
#  'dysphagia frequently prominent symptom patients primary motor disorders',
#  'esophageal motor disorders relieved nitrates calcium channel blockers relaxation smooth muscle wall esophagus',
#  'agents relieve chest pain caused coronary artery disease clinician difficulty medication response clue undiagnosed chest pain',
#  'clinician carefully interpret results therapeutic trial rapidity response',
#  'relief pain minutes sublingual dose nitroglycerin consistent coronary artery disease esophageal motor disorders',
#  'relief occurs minutes esophageal disease',
#  'nitrates calcium channel blockers relax lower esophogeal sphincter aggravate esophageal reflux increasing symptoms reflux esophagitis',
#  'myocardial ischemia occurs absence fixed obstructions coronary arteries resulting recurrent chest pain',
#  'obstructive disease intramural small vessels ischemia',
#  'lesions occur frequently diabetics small vessel disease infrequent chest pain',
#  'considered etiologies excluded',
#  'valvular aortic stenosis hypertrophic cardiomyopathy thyrotoxicosis myocardial ischemia',
#  'quality pattern pain conditions similar coronary artery disease',
#  'entities accompanied physical examination findings typical underlying disease detection difficult',
#  'coronary vasospasm myocardial ischemia absence obstructive coronary disease',
#  'pain quality similar pain obstructive coronary disease occur unpredictable pattern',
#  'pain typically induced exertion awaken patient sleep',
#  'patients report emotional stress trigger',
#  'pain frequently responds sublingual nitroglycerin frequency episodes decreases therapy calcium channel blockers long acting nitrates',
#  'approximately patients coronary vasospasm ecg episodes pain',
#  'absence electrocardiographic pain makes coronary vasospasm',
#  'mitral valve prolapse mvp controversial etiology chronic chest pain',
#  'clinical echocardiographic studies demonstrated mvp common finding healthy adults',
#  'population studies found incidence chest pain higher individuals mitral valve prolapse disorder',
#  'numerous clinical reports patients mitral valve prolapse identifiable etiology recurrent chest pain',
#  'patients studies pain qualities patterns typical chest pain syndrome mvp',
#  'considered recurrent chest pain excluded specific treatment disorder',
#  'major diagnosing mitral valve prolapse identify patients risk endocarditis arrhythmias',
#  'prospective studies shown patients develop complications late systolic murmur abnormal electrocardiogram conjunction midsystolic click',
#  'unnecessary obtain echocardiography exclude mitral valve prolapse patient findings physical examination andor electrocardiogram suggest risk complications',
#  'chest wall recurrent chest pain clinical diagnosis chest wall syndromes',
#  'quality location chest wall pain vary greatly precipitating factors diagnosis',
#  'chest wall pain pleuritic aggravated moving arms torso',
#  'patients pain reproduced palpation manipulation chest wall',
#  'clinician make management decisions patients onset chest pain increase frequency severity recurrent chest pain',
#  'disorders life threatening decided admit patient',
#  'option assess response therapeutic interventions patients',
#  'systematic approach management essential',
#  'leading diagnostic consideration acute chest pain myocardial infarction life threatening condition requiring medical management',
#  'pain myocardial infarction similar quality location angina pectoris intense severe longer lasting',
#  'pain occurs rest relieved nitroglycerin',
#  'accompanied diaphoresis dyspnea nausea',
#  'initial electrocardiogram shows waves st segment elevations patients absence findings exclude infarction',
#  'patients suspected myocardial infarction require hospital admission',
#  'syndrome unstable angina pectoris includes diverse group patients chest pain due coronary artery disease',
#  'patients unstable angina short term risk myocardial infarction therapeutic interventions shown reduce risk',
#  'syndrome includes patients onset angina pectoris',
#  'patients exertional pain relieved rest sublingual nitroglycerin',
#  'syndrome includes patients stable exertional pain changing pain pattern',
#  'patients report pain occurring lower level exertion rest',
#  'nitroglycerin longer provide relief',
#  'pathophysiologic mechanisms responsible unstable angina',
#  'common mechanism progression severity atherosclerotic disease',
#  'vasospasm aggravating atherosclerotic disease unstable angina pectoris',
#  'important unstable angina patients prior stable angina alteration patient medication',
#  'patient misunderstand physician prescribed regimen patient compliant regimen',
#  'nitroglycerin outdated ineffective',
#  'careful review patient medications provide clues',
#  'difficult differentiate unstable angina acute myocardial infarction',
#  'hospitalization required clarify diagnosis facilitate treatment interventions',
#  'serial electrocardiograms cardiac enzymes confirm exclude myocardial infarction',
#  'infarction excluded patient response medications carefully evaluated',
#  'pain episodes improve substantially cardiac medications patient refractory coronary artery disease preinfarction angina pain',
#  'diagnostic evaluation imaging studies coronary arteriography',
#  'dissection thoracic aorta potentially catastrophic acute chest pain',
#  'dissection requires specific treatment clinician exclude diagnosis early',
#  'primary types dissection clinical presentations',
#  'proximal dissections arise ascending aorta extend aortic arch',
#  'patients proximal dissection pain anterior chest approximately half report radiation posterior chest',
#  'approximately thirds evidence previous hypertension',
#  'pulse deficits murmur aortic regurgitation neurologic deficits physical examination important diagnosis',
#  'distal dissection thoracic aorta arises descending aorta great vessels',
#  'occurs predominantly men older age history hypertension group risk acute myocardial infarction',
#  'patients acute myocardial infarction anterior chest pain majority patients distal dissection posterior chest pain',
#  'pain distal dissection tearing ripping improve nitroglycerin',
#  'physical findings frequent distal proximal dissection diagnosis distal dissection subtle considered patients histories hypertension hypertensive time pain atypical pain',
#  'radiographic studies aorta exclude diagnosis',
#  'pericarditis moderately common disorder chest pain frequent symptom',
#  'pericarditis',
#  'pain retrosternal radiate left arm suggesting ischemic etiology',
#  'pain pleuritic affected body position aggravated lying relieved sitting',
#  'pericardial friction rub suggests diagnosis rub absent',
#  'electrocardiogram show st elevations multiple leads finding confused acute myocardial infarction',
#  'patients pericarditis ecg uremic pericarditis notable absence ecg findings',
#  'chest rays show normal cardiac silhouette',
#  'diverse presentation pericarditis difficult exclude routine clinical examination diagnosis suspected patient pain clinical evidence precipitating',
#  'pneumonia pneumothorax acute chest pain disorders easy diagnose',
#  'pain characteristically unilaterial pleuritic',
#  'chest ray establish diagnosis',
#  'difficult diagnostic problem hyperventilation',
#  'hyperventilation pain atypical angina pectoris',
#  'vary location pleuritic',
#  'clue pain brought anxiety emotions',
#  'tool confirming hyperventilation demonstrate pain reproduced rapid breathing',
#  'ms',
#  'jones single year associate editor large publishing house treated dr',
#  'burns mild hypertension',
#  'visit ms',
#  'jones experiencing episodes burning pressure type chest pain times week lasting minutes relieved maalox',
#  'episodes occurred work generally hour lunch',
#  'ascribed tension related job concerned week occurred aerobics class',
#  'time pain occurred minutes class rest minutes',
#  'ms',
#  'jones admits symptoms sign heart trouble causing problem good shape physically smoked family history heart disease',
#  'fact participated class yesterday experience discomfort',
#  'hearing dr',
#  'burns ms',
#  'jones concerned possibility heart disease symptoms fearful discovering wrong',
#  'complete description chest pain radiation location quality duration description episodes directed physical examination dr',
#  'burns decide optimal action ms',
#  'jones make recommendation',
#  'coronary artery disease cad major health problem united states chest pain common medical complaint encountered internists physicians provide care adults',
#  'dr',
#  'burns devoted special emphasis subject time reading continuing education activities',
#  'number workers collected data patients chest pain angina pectoris classically chest pain due myocardial ischemia occurring consistent basis physical activity relieved rest categorized pattern pain subsets correlate probability finding coronary artery disease coronary arteriography',
#  'dr',
#  'burns considers subsets typical classic angina pain occurs consistently exercise relieved rest minutes atypical chest pain pain features angina consistent relationship activity relief rest noncardiac chest pain pain features resembling angina',
#  'data derived clinical databases historical information collected large number patients typically hundred thousand',
#  'arrive plausible estimate ms',
#  'jones likelihood coronary artery disease basis history results physical examination dr',
#  'burns refers article drs',
#  'diamond forrester entitled analysis probability aid clinical diagnosis coronary artery disease',
#  'diamond forrester related probability person complaint chest pain coronary artery disease age sex pain pattern',
#  'modification tabular data appeared article reproduced table',
#  'dr',
#  'burns interprets ms',
#  'jones pain pattern atypical angina inconsistent relationship physical activity',
#  'extrapolating table notes reasonable estimate likelihood woman ms',
#  'jones age atypical angina significant coronary artery disease',
#  'arrive specific estimate ms',
#  'jones decides revise figure downward younger end age interval lacks risk factors mild hypertension',
#  'dr',
#  'burns recognizes uncertainty estimate considers likelihood lie range guess ms',
#  'jones likelihood cad',
#  'dr',
#  'burns decide recommend noninvasive test ecg treadmill stress test invasive procedure coronary arteriography simply',
#  'exercise tests stress thallium test dr',
#  'burns considers treadmill test simplest perform preferred noninvasive test ms',
#  'jones',
#  'coronary arteriogram considered definitive test determining presence severity cad provide information anatomic state ms',
#  'jones coronary arteries',
#  'served gold standard accuracy diagnostic tests cad measured',
#  ...]

# %%
sents_ids
# Out:
# ['002.ref,0',
#  '002.ref,1',
#  '002.ref,2',
#  '002.ref,3',
#  '002.ref,4',
#  '002.ref,5',
#  '002.ref,6',
#  '002.ref,7',
#  '002.ref,8',
#  '002.ref,9',
#  '002.ref,10',
#  '002.ref,11',
#  '002.ref,12',
#  '002.ref,13',
#  '002.ref,14',
#  '002.ref,15',
#  '002.ref,16',
#  '002.ref,17',
#  '002.ref,18',
#  '002.ref,19',
#  '002.ref,20',
#  '002.ref,21',
#  '002.ref,22',
#  '002.ref,23',
#  '002.ref,24',
#  '002.ref,25',
#  '002.ref,26',
#  '002.ref,27',
#  '002.ref,28',
#  '002.ref,29',
#  '002.ref,30',
#  '002.ref,31',
#  '002.ref,32',
#  '002.ref,33',
#  '002.ref,34',
#  '002.ref,35',
#  '002.ref,36',
#  '002.ref,37',
#  '002.ref,38',
#  '002.ref,39',
#  '002.ref,40',
#  '002.ref,41',
#  '002.ref,42',
#  '002.ref,43',
#  '002.ref,44',
#  '002.ref,45',
#  '002.ref,46',
#  '002.ref,47',
#  '002.ref,48',
#  '002.ref,49',
#  '002.ref,50',
#  '002.ref,51',
#  '002.ref,52',
#  '002.ref,53',
#  '002.ref,54',
#  '002.ref,55',
#  '002.ref,56',
#  '002.ref,57',
#  '002.ref,58',
#  '002.ref,59',
#  '002.ref,60',
#  '002.ref,61',
#  '002.ref,62',
#  '002.ref,63',
#  '002.ref,64',
#  '002.ref,65',
#  '002.ref,66',
#  '002.ref,67',
#  '002.ref,68',
#  '002.ref,69',
#  '002.ref,70',
#  '002.ref,71',
#  '002.ref,72',
#  '002.ref,73',
#  '002.ref,74',
#  '002.ref,75',
#  '002.ref,76',
#  '002.ref,77',
#  '002.ref,78',
#  '002.ref,79',
#  '002.ref,80',
#  '002.ref,81',
#  '002.ref,82',
#  '002.ref,83',
#  '002.ref,84',
#  '002.ref,85',
#  '002.ref,86',
#  '002.ref,87',
#  '002.ref,88',
#  '002.ref,89',
#  '002.ref,90',
#  '002.ref,91',
#  '002.ref,92',
#  '002.ref,93',
#  '002.ref,94',
#  '002.ref,95',
#  '002.ref,96',
#  '002.ref,97',
#  '002.ref,98',
#  '002.ref,99',
#  '002.ref,100',
#  '002.ref,101',
#  '002.ref,102',
#  '002.ref,103',
#  '002.ref,104',
#  '002.ref,105',
#  '002.ref,106',
#  '002.ref,107',
#  '002.ref,108',
#  '002.ref,109',
#  '002.ref,110',
#  '002.ref,111',
#  '002.ref,112',
#  '002.ref,113',
#  '002.ref,114',
#  '002.ref,115',
#  '002.ref,116',
#  '002.ref,117',
#  '002.ref,118',
#  '002.ref,119',
#  '002.ref,120',
#  '002.ref,121',
#  '002.ref,122',
#  '002.ref,123',
#  '002.ref,124',
#  '002.ref,125',
#  '002.ref,126',
#  '002.ref,127',
#  '002.ref,128',
#  '002.ref,129',
#  '002.ref,130',
#  '002.ref,131',
#  '002.ref,132',
#  '002.ref,133',
#  '002.ref,134',
#  '002.ref,135',
#  '002.ref,136',
#  '002.ref,137',
#  '002.ref,138',
#  '002.ref,139',
#  '002.ref,140',
#  '002.ref,141',
#  '002.ref,142',
#  '002.ref,143',
#  '002.ref,144',
#  '002.ref,145',
#  '002.ref,146',
#  '002.ref,147',
#  '002.ref,148',
#  '002.ref,149',
#  '002.ref,150',
#  '002.ref,151',
#  '002.ref,152',
#  '002.ref,153',
#  '002.ref,154',
#  '002.ref,155',
#  '002.ref,156',
#  '002.ref,157',
#  '002.ref,158',
#  '002.ref,159',
#  '002.ref,160',
#  '002.ref,161',
#  '002.ref,162',
#  '002.ref,163',
#  '002.ref,164',
#  '002.ref,165',
#  '002.ref,166',
#  '002.ref,167',
#  '002.ref,168',
#  '002.ref,169',
#  '002.ref,170',
#  '002.ref,171',
#  '002.ref,172',
#  '002.ref,173',
#  '002.ref,174',
#  '002.ref,175',
#  '002.ref,176',
#  '002.ref,177',
#  '002.ref,178',
#  '002.ref,179',
#  '002.ref,180',
#  '002.ref,181',
#  '002.ref,182',
#  '002.ref,183',
#  '002.ref,184',
#  '002.ref,185',
#  '002.ref,186',
#  '002.ref,187',
#  '002.ref,188',
#  '002.ref,189',
#  '002.ref,190',
#  '002.ref,191',
#  '002.ref,192',
#  '002.ref,193',
#  '002.ref,194',
#  '002.ref,195',
#  '002.ref,196',
#  '002.ref,197',
#  '002.ref,198',
#  '002.ref,199',
#  '002.ref,200',
#  '002.ref,201',
#  '002.ref,202',
#  '002.ref,203',
#  '002.ref,204',
#  '002.ref,205',
#  '002.ref,206',
#  '002.ref,207',
#  '002.ref,208',
#  '002.ref,209',
#  '002.ref,210',
#  '002.ref,211',
#  '002.ref,212',
#  '002.ref,213',
#  '002.ref,214',
#  '002.ref,215',
#  '002.ref,216',
#  '002.ref,217',
#  '002.ref,218',
#  '002.ref,219',
#  '002.ref,220',
#  '002.ref,221',
#  '002.ref,222',
#  '002.ref,223',
#  '002.ref,224',
#  '002.ref,225',
#  '002.ref,226',
#  '002.ref,227',
#  '002.ref,228',
#  '002.ref,229',
#  '002.ref,230',
#  '002.ref,231',
#  '002.ref,232',
#  '002.ref,233',
#  '002.ref,234',
#  '002.ref,235',
#  '002.ref,236',
#  '002.ref,237',
#  '002.ref,238',
#  '002.ref,239',
#  '002.ref,240',
#  '002.ref,241',
#  '002.ref,242',
#  '002.ref,243',
#  '002.ref,244',
#  '002.ref,245',
#  '002.ref,246',
#  '002.ref,247',
#  '002.ref,248',
#  '002.ref,249',
#  '002.ref,250',
#  '002.ref,251',
#  '002.ref,252',
#  '002.ref,253',
#  '002.ref,254',
#  '002.ref,255',
#  '002.ref,256',
#  '002.ref,257',
#  '002.ref,258',
#  '002.ref,259',
#  '002.ref,260',
#  '002.ref,261',
#  '002.ref,262',
#  '002.ref,263',
#  '002.ref,264',
#  '002.ref,265',
#  '002.ref,266',
#  '002.ref,267',
#  '002.ref,268',
#  '002.ref,269',
#  '002.ref,270',
#  '002.ref,271',
#  '002.ref,272',
#  '002.ref,273',
#  '002.ref,274',
#  '002.ref,275',
#  '002.ref,276',
#  '002.ref,277',
#  '002.ref,278',
#  '002.ref,279',
#  '002.ref,280',
#  '002.ref,281',
#  '002.ref,282',
#  '002.ref,283',
#  '002.ref,284',
#  '002.ref,285',
#  '002.ref,286',
#  '002.ref,287',
#  '002.ref,288',
#  '002.ref,289',
#  '002.ref,290',
#  '002.ref,291',
#  '002.ref,292',
#  '002.ref,293',
#  '002.ref,294',
#  '002.ref,295',
#  '002.ref,296',
#  '002.ref,297',
#  '002.ref,298',
#  '002.ref,299',
#  '002.ref,300',
#  '002.ref,301',
#  '002.ref,302',
#  '002.ref,303',
#  '002.ref,304',
#  '002.ref,305',
#  '002.ref,306',
#  '002.ref,307',
#  '002.ref,308',
#  '002.ref,309',
#  '002.ref,310',
#  '002.ref,311',
#  '002.ref,312',
#  '002.ref,313',
#  '002.ref,314',
#  '002.ref,315',
#  '002.ref,316',
#  '002.ref,317',
#  '002.ref,318',
#  '002.ref,319',
#  '002.ref,320',
#  '002.ref,321',
#  '002.ref,322',
#  '002.ref,323',
#  '002.ref,324',
#  '002.ref,325',
#  '002.ref,326',
#  '002.ref,327',
#  '002.ref,328',
#  '002.ref,329',
#  '002.ref,330',
#  '002.ref,331',
#  '002.ref,332',
#  '002.ref,333',
#  '002.ref,334',
#  '002.ref,335',
#  '002.ref,336',
#  '002.ref,337',
#  '002.ref,338',
#  '002.ref,339',
#  '002.ref,340',
#  '002.ref,341',
#  '002.ref,342',
#  '002.ref,343',
#  '002.ref,344',
#  '002.ref,345',
#  '002.ref,346',
#  '002.ref,347',
#  '002.ref,348',
#  '002.ref,349',
#  '002.ref,350',
#  '002.ref,351',
#  '002.ref,352',
#  '002.ref,353',
#  '002.ref,354',
#  '002.ref,355',
#  '002.ref,356',
#  '002.ref,357',
#  '002.ref,358',
#  '002.ref,359',
#  '002.ref,360',
#  '002.ref,361',
#  '002.ref,362',
#  '002.ref,363',
#  '002.ref,364',
#  '002.ref,365',
#  '002.ref,366',
#  '002.ref,367',
#  '002.ref,368',
#  '002.ref,369',
#  '002.ref,370',
#  '002.ref,371',
#  '002.ref,372',
#  '002.ref,373',
#  '002.ref,374',
#  '002.ref,375',
#  '002.ref,376',
#  '002.ref,377',
#  '002.ref,378',
#  '002.ref,379',
#  '002.ref,380',
#  '002.ref,381',
#  '002.ref,382',
#  '002.ref,383',
#  '002.ref,384',
#  '002.ref,385',
#  '002.ref,386',
#  '002.ref,387',
#  '002.ref,388',
#  '002.ref,389',
#  '002.ref,390',
#  '002.ref,391',
#  '002.ref,392',
#  '002.ref,393',
#  '002.ref,394',
#  '002.ref,395',
#  '002.ref,396',
#  '002.ref,397',
#  '002.ref,398',
#  '002.ref,399',
#  '002.ref,400',
#  '002.ref,401',
#  '002.ref,402',
#  '002.ref,403',
#  '002.ref,404',
#  '002.ref,405',
#  '002.ref,406',
#  '002.ref,407',
#  '002.ref,408',
#  '002.ref,409',
#  '002.ref,410',
#  '002.ref,411',
#  '002.ref,412',
#  '003.ref,0',
#  '003.ref,1',
#  '003.ref,2',
#  '003.ref,3',
#  '003.ref,4',
#  '003.ref,5',
#  '003.ref,6',
#  '003.ref,7',
#  '003.ref,8',
#  '003.ref,9',
#  '003.ref,10',
#  '003.ref,11',
#  '003.ref,12',
#  '003.ref,13',
#  '003.ref,14',
#  '003.ref,15',
#  '003.ref,16',
#  '003.ref,17',
#  '003.ref,18',
#  '003.ref,19',
#  '003.ref,20',
#  '003.ref,21',
#  '003.ref,22',
#  '003.ref,23',
#  '003.ref,24',
#  '003.ref,25',
#  '003.ref,26',
#  '003.ref,27',
#  '003.ref,28',
#  '003.ref,29',
#  '003.ref,30',
#  '003.ref,31',
#  '003.ref,32',
#  '003.ref,33',
#  '003.ref,34',
#  '003.ref,35',
#  '003.ref,36',
#  '003.ref,37',
#  '003.ref,38',
#  '003.ref,39',
#  '003.ref,40',
#  '003.ref,41',
#  '003.ref,42',
#  '003.ref,43',
#  '003.ref,44',
#  '003.ref,45',
#  '003.ref,46',
#  '003.ref,47',
#  '003.ref,48',
#  '003.ref,49',
#  '003.ref,50',
#  '003.ref,51',
#  '003.ref,52',
#  '003.ref,53',
#  '003.ref,54',
#  '003.ref,55',
#  '003.ref,56',
#  '003.ref,57',
#  '003.ref,58',
#  '003.ref,59',
#  '003.ref,60',
#  '003.ref,61',
#  '007.ref,0',
#  '007.ref,1',
#  '007.ref,2',
#  '007.ref,3',
#  '007.ref,4',
#  '007.ref,5',
#  '007.ref,6',
#  '007.ref,7',
#  '007.ref,8',
#  '007.ref,9',
#  '007.ref,10',
#  '007.ref,11',
#  '007.ref,12',
#  '007.ref,13',
#  '007.ref,14',
#  '007.ref,15',
#  '007.ref,16',
#  '007.ref,17',
#  '007.ref,18',
#  '007.ref,19',
#  '007.ref,20',
#  '007.ref,21',
#  '007.ref,22',
#  '007.ref,23',
#  '007.ref,24',
#  '007.ref,25',
#  '007.ref,26',
#  '007.ref,27',
#  '007.ref,28',
#  '007.ref,29',
#  '007.ref,30',
#  '007.ref,31',
#  '007.ref,32',
#  '007.ref,33',
#  '007.ref,34',
#  '007.ref,35',
#  '007.ref,36',
#  '007.ref,37',
#  '007.ref,38',
#  '007.ref,39',
#  '007.ref,40',
#  '007.ref,41',
#  '007.ref,42',
#  '007.ref,43',
#  '007.ref,44',
#  '007.ref,45',
#  '007.ref,46',
#  '007.ref,47',
#  '007.ref,48',
#  '007.ref,49',
#  '007.ref,50',
#  '007.ref,51',
#  '007.ref,52',
#  '007.ref,53',
#  '007.ref,54',
#  '007.ref,55',
#  '007.ref,56',
#  '007.ref,57',
#  '007.ref,58',
#  '007.ref,59',
#  '007.ref,60',
#  '007.ref,61',
#  '007.ref,62',
#  '007.ref,63',
#  '007.ref,64',
#  '007.ref,65',
#  '007.ref,66',
#  '007.ref,67',
#  '007.ref,68',
#  '007.ref,69',
#  '007.ref,70',
#  '007.ref,71',
#  '007.ref,72',
#  '007.ref,73',
#  '007.ref,74',
#  '007.ref,75',
#  '007.ref,76',
#  '007.ref,77',
#  '007.ref,78',
#  '007.ref,79',
#  '007.ref,80',
#  '007.ref,81',
#  '007.ref,82',
#  '007.ref,83',
#  '007.ref,84',
#  '007.ref,85',
#  '007.ref,86',
#  '007.ref,87',
#  '007.ref,88',
#  '007.ref,89',
#  '007.ref,90',
#  '007.ref,91',
#  '007.ref,92',
#  '007.ref,93',
#  '007.ref,94',
#  '007.ref,95',
#  '007.ref,96',
#  '007.ref,97',
#  '007.ref,98',
#  '007.ref,99',
#  '007.ref,100',
#  '007.ref,101',
#  '007.ref,102',
#  '007.ref,103',
#  '007.ref,104',
#  '007.ref,105',
#  '007.ref,106',
#  '007.ref,107',
#  '007.ref,108',
#  '007.ref,109',
#  '007.ref,110',
#  '013.ref,0',
#  '013.ref,1',
#  '013.ref,2',
#  '013.ref,3',
#  '013.ref,4',
#  '013.ref,5',
#  '013.ref,6',
#  '013.ref,7',
#  '013.ref,8',
#  '013.ref,9',
#  '013.ref,10',
#  '013.ref,11',
#  '013.ref,12',
#  '013.ref,13',
#  '013.ref,14',
#  '013.ref,15',
#  '013.ref,16',
#  '013.ref,17',
#  '013.ref,18',
#  '013.ref,19',
#  '013.ref,20',
#  '013.ref,21',
#  '013.ref,22',
#  '013.ref,23',
#  '013.ref,24',
#  '013.ref,25',
#  '013.ref,26',
#  '013.ref,27',
#  '013.ref,28',
#  '013.ref,29',
#  '013.ref,30',
#  '013.ref,31',
#  '013.ref,32',
#  '013.ref,33',
#  '013.ref,34',
#  '013.ref,35',
#  '013.ref,36',
#  '013.ref,37',
#  '013.ref,38',
#  '013.ref,39',
#  '013.ref,40',
#  '013.ref,41',
#  '013.ref,42',
#  '013.ref,43',
#  '013.ref,44',
#  '013.ref,45',
#  '013.ref,46',
#  '013.ref,47',
#  '013.ref,48',
#  '013.ref,49',
#  '013.ref,50',
#  '013.ref,51',
#  '013.ref,52',
#  '013.ref,53',
#  '013.ref,54',
#  '013.ref,55',
#  '013.ref,56',
#  '013.ref,57',
#  '013.ref,58',
#  '013.ref,59',
#  '013.ref,60',
#  '013.ref,61',
#  '013.ref,62',
#  '013.ref,63',
#  '013.ref,64',
#  '013.ref,65',
#  '013.ref,66',
#  '013.ref,67',
#  '013.ref,68',
#  '013.ref,69',
#  '013.ref,70',
#  '013.ref,71',
#  '013.ref,72',
#  '013.ref,73',
#  '013.ref,74',
#  '013.ref,75',
#  '013.ref,76',
#  '013.ref,77',
#  '013.ref,78',
#  '013.ref,79',
#  '013.ref,80',
#  '013.ref,81',
#  '013.ref,82',
#  '013.ref,83',
#  '013.ref,84',
#  '013.ref,85',
#  '013.ref,86',
#  '013.ref,87',
#  '013.ref,88',
#  '013.ref,89',
#  '013.ref,90',
#  '013.ref,91',
#  '013.ref,92',
#  '013.ref,93',
#  '013.ref,94',
#  '013.ref,95',
#  '013.ref,96',
#  '013.ref,97',
#  '013.ref,98',
#  '013.ref,99',
#  '013.ref,100',
#  '013.ref,101',
#  '013.ref,102',
#  '013.ref,103',
#  '010.ref,0',
#  '010.ref,1',
#  '010.ref,2',
#  '010.ref,3',
#  '010.ref,4',
#  '010.ref,5',
#  '010.ref,6',
#  '010.ref,7',
#  '010.ref,8',
#  '010.ref,9',
#  '010.ref,10',
#  '010.ref,11',
#  '010.ref,12',
#  '010.ref,13',
#  '010.ref,14',
#  '010.ref,15',
#  '010.ref,16',
#  '010.ref,17',
#  '010.ref,18',
#  '010.ref,19',
#  '010.ref,20',
#  '010.ref,21',
#  '010.ref,22',
#  '010.ref,23',
#  '010.ref,24',
#  '010.ref,25',
#  '010.ref,26',
#  '010.ref,27',
#  '010.ref,28',
#  '010.ref,29',
#  '010.ref,30',
#  '010.ref,31',
#  '010.ref,32',
#  '010.ref,33',
#  '010.ref,34',
#  '010.ref,35',
#  '010.ref,36',
#  '010.ref,37',
#  '010.ref,38',
#  '010.ref,39',
#  '010.ref,40',
#  '010.ref,41',
#  '010.ref,42',
#  '010.ref,43',
#  '010.ref,44',
#  '010.ref,45',
#  '010.ref,46',
#  '010.ref,47',
#  '010.ref,48',
#  '010.ref,49',
#  '010.ref,50',
#  '010.ref,51',
#  '010.ref,52',
#  '010.ref,53',
#  '010.ref,54',
#  '010.ref,55',
#  '010.ref,56',
#  '010.ref,57',
#  '010.ref,58',
#  '010.ref,59',
#  '010.ref,60',
#  '010.ref,61',
#  '010.ref,62',
#  '010.ref,63',
#  '010.ref,64',
#  '010.ref,65',
#  '010.ref,66',
#  '010.ref,67',
#  '010.ref,68',
#  '010.ref,69',
#  '010.ref,70',
#  '010.ref,71',
#  '010.ref,72',
#  '010.ref,73',
#  '010.ref,74',
#  '010.ref,75',
#  '010.ref,76',
#  '010.ref,77',
#  '010.ref,78',
#  '010.ref,79',
#  '010.ref,80',
#  '010.ref,81',
#  '010.ref,82',
#  '008.ref,0',
#  '008.ref,1',
#  '008.ref,2',
#  '008.ref,3',
#  '008.ref,4',
#  '008.ref,5',
#  '008.ref,6',
#  '008.ref,7',
#  '008.ref,8',
#  '008.ref,9',
#  '008.ref,10',
#  '008.ref,11',
#  '008.ref,12',
#  '008.ref,13',
#  '008.ref,14',
#  '008.ref,15',
#  '008.ref,16',
#  '008.ref,17',
#  '008.ref,18',
#  '008.ref,19',
#  '008.ref,20',
#  '008.ref,21',
#  '008.ref,22',
#  '008.ref,23',
#  '008.ref,24',
#  '008.ref,25',
#  '008.ref,26',
#  '008.ref,27',
#  '008.ref,28',
#  '008.ref,29',
#  '008.ref,30',
#  '008.ref,31',
#  '008.ref,32',
#  '008.ref,33',
#  '008.ref,34',
#  '008.ref,35',
#  '008.ref,36',
#  '008.ref,37',
#  '008.ref,38',
#  '008.ref,39',
#  '008.ref,40',
#  '008.ref,41',
#  '008.ref,42',
#  '008.ref,43',
#  '008.ref,44',
#  '008.ref,45',
#  '008.ref,46',
#  '008.ref,47',
#  '008.ref,48',
#  '008.ref,49',
#  '008.ref,50',
#  '008.ref,51',
#  '008.ref,52',
#  '008.ref,53',
#  '008.ref,54',
#  '008.ref,55',
#  '008.ref,56',
#  '008.ref,57',
#  '008.ref,58',
#  '008.ref,59',
#  '008.ref,60',
#  '008.ref,61',
#  '008.ref,62',
#  '008.ref,63',
#  '008.ref,64',
#  '008.ref,65',
#  '008.ref,66',
#  '008.ref,67',
#  '008.ref,68',
#  '008.ref,69',
#  '008.ref,70',
#  '008.ref,71',
#  '008.ref,72',
#  '008.ref,73',
#  '008.ref,74',
#  '008.ref,75',
#  '008.ref,76',
#  '008.ref,77',
#  '008.ref,78',
#  '008.ref,79',
#  '008.ref,80',
#  '008.ref,81',
#  '008.ref,82',
#  '008.ref,83',
#  '008.ref,84',
#  '008.ref,85',
#  '008.ref,86',
#  '008.ref,87',
#  '008.ref,88',
#  '008.ref,89',
#  '008.ref,90',
#  '008.ref,91',
#  '008.ref,92',
#  '008.ref,93',
#  '008.ref,94',
#  '008.ref,95',
#  '008.ref,96',
#  '008.ref,97',
#  '008.ref,98',
#  '008.ref,99',
#  '008.ref,100',
#  '008.ref,101',
#  '008.ref,102',
#  '008.ref,103',
#  '008.ref,104',
#  '008.ref,105',
#  '008.ref,106',
#  '008.ref,107',
#  '008.ref,108',
#  '008.ref,109',
#  '008.ref,110',
#  '008.ref,111',
#  '008.ref,112',
#  '008.ref,113',
#  '008.ref,114',
#  '008.ref,115',
#  '008.ref,116',
#  '008.ref,117',
#  '008.ref,118',
#  '008.ref,119',
#  '008.ref,120',
#  '008.ref,121',
#  '008.ref,122',
#  '008.ref,123',
#  '008.ref,124',
#  '008.ref,125',
#  '008.ref,126',
#  '008.ref,127',
#  '008.ref,128',
#  '008.ref,129',
#  '008.ref,130',
#  '008.ref,131',
#  '008.ref,132',
#  '008.ref,133',
#  '008.ref,134',
#  '008.ref,135',
#  '008.ref,136',
#  '008.ref,137',
#  '008.ref,138',
#  '008.ref,139',
#  '008.ref,140',
#  '008.ref,141',
#  '008.ref,142',
#  '008.ref,143',
#  '008.ref,144',
#  '008.ref,145',
#  '008.ref,146',
#  '008.ref,147',
#  '008.ref,148',
#  '008.ref,149',
#  '008.ref,150',
#  '008.ref,151',
#  '008.ref,152',
#  '008.ref,153',
#  '008.ref,154',
#  '008.ref,155',
#  '008.ref,156',
#  '008.ref,157',
#  '008.ref,158',
#  '008.ref,159',
#  '008.ref,160',
#  '008.ref,161',
#  '008.ref,162',
#  '008.ref,163',
#  '008.ref,164',
#  '008.ref,165',
#  '008.ref,166',
#  '008.ref,167',
#  '008.ref,168',
#  '008.ref,169',
#  '008.ref,170',
#  '008.ref,171',
#  '008.ref,172',
#  '008.ref,173',
#  '008.ref,174',
#  '008.ref,175',
#  '008.ref,176',
#  '008.ref,177',
#  '008.ref,178',
#  '005.ref,0',
#  '005.ref,1',
#  '005.ref,2',
#  '005.ref,3',
#  '005.ref,4',
#  '005.ref,5',
#  '005.ref,6',
#  '005.ref,7',
#  '005.ref,8',
#  '005.ref,9',
#  '005.ref,10',
#  '005.ref,11',
#  '005.ref,12',
#  '005.ref,13',
#  '005.ref,14',
#  '005.ref,15',
#  '005.ref,16',
#  '005.ref,17',
#  '005.ref,18',
#  '005.ref,19',
#  '005.ref,20',
#  '005.ref,21',
#  '005.ref,22',
#  '005.ref,23',
#  '005.ref,24',
#  '005.ref,25',
#  '005.ref,26',
#  '005.ref,27',
#  '005.ref,28',
#  '005.ref,29',
#  '005.ref,30',
#  '005.ref,31',
#  '005.ref,32',
#  '005.ref,33',
#  '005.ref,34',
#  '005.ref,35',
#  '005.ref,36',
#  '005.ref,37',
#  '005.ref,38',
#  '005.ref,39',
#  '005.ref,40',
#  '005.ref,41',
#  '005.ref,42',
#  '005.ref,43',
#  '005.ref,44',
#  '005.ref,45',
#  '005.ref,46',
#  '005.ref,47',
#  ...]

# %% [markdown]
# Write your code below to generate TF-IDF vector.

# %%
#########please write the missing code below#######
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf_vectorizer = TfidfVectorizer(input = 'content', analyzer = 'word')
tfidf_vectors = tfidf_vectorizer.fit_transform(sents_words)
tfidf_vectors.shape
# Out:
# (3281, 6506)

# %% [markdown]
# Now you should think about how to save the TF-IDF vector for each sentences in each report. Let's print out the sparse vector for the first sentence in "002.ref".

# %%
vocab = tfidf_vectorizer.get_feature_names()
for word, weight in zip(vocab, tfidf_vectors.toarray()[0]):
    if weight > 0:
        print word, ":", weight
# Out:
# clinicians : 0.316406000789
# diagnostic : 0.225621475546
# examination : 0.225160186953
# greater : 0.33592441701
# history : 0.196377281577
# investigations : 0.375692150284
# laboratory : 0.250824965944
# medical : 0.229468751274
# patient : 0.150956882278
# physical : 0.220341630219
# rate : 0.282126767625
# results : 0.264622676996
# rich : 0.411343020291

# %% [markdown]
# ## Task 5 Save the processed text
# In this task, we need to save the TF-IDF vectors in a sparse format. There are difference ways of generating the sparse format. For example, you can consider the data format used by <font color="red">tfidf_vectors</a>

# %%
import itertools
save_file = open("clinical.txt", 'w')
#########please write the missing code below#######
cx = tfidf_vectors.tocoo() # return the coordinate representation of a sparse matrix
for i,j,v in itertools.izip(cx.row, cx.col, cx.data):
    save_file.write(sents_ids[i] + ':' + str(j) + ',' + str(v) + '\n')
save_file.close()

# %% [markdown]
# ## Task 6 Save the final vocabulary
# In this task, you should save the final vocabulary in a file.

# %%
v_writer = open("clinical_voc.txt", "w")
for type in vocab:
    v_writer.write(type+"\n")
v_writer.close()
