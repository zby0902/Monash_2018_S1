# %% [markdown]
# #### Parsing XML Files
#
# [XML](https://www.w3.org/XML/), Extensible Markup Lanuage, is a markup language much like HTML.
# It is a simple and flexible data format that defines a set of rules for encoding documents in a way that
# is both human and machine readable.
# As a self-descriptive markup language, XML plays an important role in many information systems.
# It stores data in plain text format, which provides a platform-independent way of storing, transporting,
# and sharing data.
# In this chapter you are going to learn how to parse and extract data from XML files with Python.
#
#
# First and foremost, you will need to have some basic understanding about XML.
# There are a lot of good introductory materials freely available online.
# We suggest the following two sections of Chapter 12 in "**Dive Into Python 3**":
# * [12.2 A 5-Minute Crash Course in XML](http://www.diveintopython3.net/xml.html#xml-intro) 📖
# * [12.3 The Structure Of An Atom Feed](http://www.diveintopython3.net/xml.html#xml-structure) 📖
#
# If you are quite familiar with XML, you can skip the above materials and jump
# directly into the parsing sections.
#
# XML files are not as easy as the CSV or JSON files to preview and understand.
# Luckily for us, the data we are going to parse is the same as the one used in previous sections.
# Please download the XML version for the "Melbourne bike share" dataset from
# [data.gov.au](https://data.melbourne.vic.gov.au/Transport-Movement/Melbourne-bike-share/tdvh-n9dv),
# and save it in the same directory as this IPython notebook.
#
# As we did in the previous chapter, let's first open the file in your favourite editor to preview it.
# If you scroll through the opened file, you will find that the same data used in the CSV/JSON examples has
# been encompassed in XML syntax, using things called tags. The following figure shows a snippet of the data.
#
# ![](./xml_example.png)
#
# After eyeballing the file, you should find that
# data values can be stored in two places in an XML file, which are:
# * in between two tags, for example,
#     ```html
#         <featurename>Harbour Town - Docklands Dve - Docklands</featurename>
#     ```
#     where the value is "Harbour Town - Docklands Dve - Docklands" for the <featurename> tag.
# * as an attribute of a tag, for example
#     ```html
#         <coordinates human_address="{&quot;address&quot;:&quot;&quot;,&quot;city&quot;:&quot;&quot;
#         ,&quot;state&quot;:&quot;&quot;,&quot;zip&quot;:&quot;&quot;}"
#         latitude="-37.814022" longitude="144.939521" needs_recoding="false"/>
#     ```
#     where the value of latitude is -37.814022 and longitude is 144.939521.
#
# The attributes in XML store rich information about a specific tag.
# Comparing XML with JSON, you will find that the XML tags and attributes hold data in
# a similar way to the JSON keys.
# The advantage of XML is that each tag in XML can hold more than one attribute, and
# more values can be stored in one node. See the "coordinate" tag above.
#
# Now, how can we extract data stored either in between tags or as an attribute?
# In the following sections, we will demonstrate the process of loading and exploring a XML file, extracting
# data from the XML file and storing the data in Pandas DataFrame.
# * * *

# %% [markdown]
# ## 1. Loading and Exploring an XML file
#
# Python can parse XML files in many ways.
# You can find several Python libraries for parsing xml from
# [" XML Processing Modules"](https://docs.python.org/2/library/xml.html).
# Here we will show you how to use the following Python libraries
# to parse our XML file.
# * ElementTree
# * lxml
# * beautifulsoup
#
# There are a couple of good materials worth reading
# * The office ElementTree [API](https://docs.python.org/2/library/xml.etree.elementtree.html#module-xml.etree.ElementTree) documentation, which provides not only the API reference but also a short tutorial on using ElementTree. 📖
# * [Parsing XML](http://www.diveintopython3.net/xml.html#xml-parse), Section 12.4 in Chapter 12 of "**Dive into Python**" does a good job on elaborating the process of parsing an example XML file with ElementsTree. 📖
#
# If you are a visual learner, we suggest the following YouTube video
# * [Parsing XML files in Python](https://www.youtube.com/watch?v=c2qlCZhkwtE)
#
# We strongly suggest that you read these materials, although we are going to reproduce some of their content
# along with our own XML file.
#
# Let's start with ElementTree.
# There are several ways to import the data, which depends on how the data is stored.
# Here we will read the file from disk.

# %%
import xml.etree.ElementTree as etree    
tree = etree.parse("./Melbourne_bike_share.xml")

# %% [markdown]
# In the ElementTree API, an element object is designed to store data in a hierarchical structure according to the XML tag structure.
# Each element has a number of properties associated with it, for example, a tag, a text string,
# a set of attributes and a set of child elements.
# The `parse()` function is one of the entry points of the ElementTree library.
# It parses the entire XML document at once into an ElementTree object that contains a hierarchy of Element objects.
# see ["How ElementTree represents XML"](http://infohost.nmt.edu/tcc/help/pubs/pylxml/web/etree-view.html). 📖
#
# The first element in every XML document is called the root element,
# and an XML document can only have one root.
# However, the returning ElementTree object is not the root element.
# Instead, it represents the entire document.
# To get a reference to the root element, call `getroot()` method.

# %%
root = tree.getroot()     
root.tag
# Out:
# 'response'

# %% [markdown]
# As expected, the root element is the 'response' element. See the original XML file.
# You can also check the number of children of the root element by typing
# ```python
#     len(root)
# ```
# It will give you one. To get the only child, one can use the `getchildren()` method.
# But it will result in a warning message
# that looks like
# ```python
#     /Users/land/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:2: DeprecationWarning: This method
#     will be removed in future versions.  Use 'list(elem)' or iteration over elem instead.
#     from ipykernel import kernelapp as app.
# ```
# This is because the method has already been deprecated in Python 2.7.
# Indeed, an element acts like a list in the ElementTree API.
# The items of the list are the element’s children.

# %%
for child in root:           
   print child
# Out:
# <Element 'row' at 0x103dba950>

# %% [markdown]
# The `root` list only contains its direct children elements. The children elements of each entry in the list are not included.
#
# Each element can also have its own set of attributes. The `attrib` property of an element is a mutable
# Python dictionary.
# Does the root have attributes? Let's check it out.

# %%
root.attrib
# Out:
# {}

# %% [markdown]
# It returns a empty dictionary.
# So far, the element tree seems to be empty.
# Now you need to either examine the original xml to discover the structure,
# or further traverse the element hierarchy by iteratively printing out all the elements and
# data contained therein.
# The `root` element has only one child.
# It can be accessed by index, for example:
# ```python
#     root[0]
# ```
# A FOR loop can be used to print out all the children of `root[0]`.

# %%
for child in root[0]:
    print child
# Out:
# <Element 'row' at 0x103dba990>
# <Element 'row' at 0x103dbab90>
# <Element 'row' at 0x103dbad90>
# <Element 'row' at 0x103dbaf90>
# <Element 'row' at 0x103dc71d0>
# <Element 'row' at 0x103dc73d0>
# <Element 'row' at 0x103dc75d0>
# <Element 'row' at 0x103dc77d0>
# <Element 'row' at 0x103dc79d0>
# <Element 'row' at 0x103dc7bd0>
# <Element 'row' at 0x103dc7dd0>
# <Element 'row' at 0x103dc7fd0>
# <Element 'row' at 0x103dd1210>
# <Element 'row' at 0x103dd1410>
# <Element 'row' at 0x103dd1610>
# <Element 'row' at 0x103dd1810>
# <Element 'row' at 0x103dd1a10>
# <Element 'row' at 0x103dd1c10>
# <Element 'row' at 0x103dd1e10>
# <Element 'row' at 0x103dde050>
# <Element 'row' at 0x103dde250>
# <Element 'row' at 0x103dde490>
# <Element 'row' at 0x103dde690>
# <Element 'row' at 0x103dde890>
# <Element 'row' at 0x103ddea90>
# <Element 'row' at 0x103ddec90>
# <Element 'row' at 0x103ddee90>
# <Element 'row' at 0x103dec0d0>
# <Element 'row' at 0x103dec2d0>
# <Element 'row' at 0x103dec4d0>
# <Element 'row' at 0x103dec6d0>
# <Element 'row' at 0x103dec8d0>
# <Element 'row' at 0x103decad0>
# <Element 'row' at 0x103deccd0>
# <Element 'row' at 0x103deced0>
# <Element 'row' at 0x103df9110>
# <Element 'row' at 0x103df9310>
# <Element 'row' at 0x103df9510>
# <Element 'row' at 0x103df9710>
# <Element 'row' at 0x103df9910>
# <Element 'row' at 0x103df9b10>
# <Element 'row' at 0x103df9d10>
# <Element 'row' at 0x103df9f10>
# <Element 'row' at 0x103e05150>
# <Element 'row' at 0x103e05410>
# <Element 'row' at 0x103e05650>
# <Element 'row' at 0x103e05850>
# <Element 'row' at 0x103e05a50>
# <Element 'row' at 0x103e05c50>
# <Element 'row' at 0x103e05e50>

# %% [markdown]
# The tag of each child is the same, called 'row'.
# The total number of children is 50, which is exactly the same as the number of records
# extracted from the CSV file.
# Thus, we can guess that these rows might correspond to those records in the CSV file.
# Let us keep on retrieving the children of these rows. Instead of doing that for
# all the rows, we retrieve the children of `root[0][0]` and that should correspond to the first record.

# %%
for child in  root[0][0]:
    print child
# Out:
# <Element 'id' at 0x103dba9d0>
# <Element 'featurename' at 0x103dbaa10>
# <Element 'terminalname' at 0x103dbaa50>
# <Element 'nbbikes' at 0x103dbaa90>
# <Element 'nbemptydoc' at 0x103dbaad0>
# <Element 'uploaddate' at 0x103dbab10>
# <Element 'coordinates' at 0x103dbab50>

# %% [markdown]
# Fortunately, the tags of the retrieved child elements correspond to the column heads of the CSV file.
# Thus, all the tags storing the data we want have been found.
# To confirm it you can inspect the original XML file
# or simply look at the figure shown in Section 1.
# Another way of exploring the element hierarchy is to use the iteration function of ElementTree, `iter()`.
# The iterator loops over all elements in the tree, in section order.
# Each element is represented as a Python tuple, where the first entry is a tag,
# the second is the text, and the last is a dictionary of attributes.

# %%
for elem in tree.iter():
   print (elem.tag, elem.text, elem.attrib)
# Out:
# ('response', None, {})
# ('row', None, {})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/2', '_id': '155', '_uuid': '7C09387D-9E6C-4B42-9041-9A98B88F54BB', '_position': '155'})
# ('id', '2', {})
# ('featurename', 'Harbour Town - Docklands Dve - Docklands', {})
# ('terminalname', '60000', {})
# ('nbbikes', '9', {})
# ('nbemptydoc', '14', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.814022', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.939521'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/4', '_id': '156', '_uuid': '52739A59-E034-436B-A613-E7A5F62448C0', '_position': '156'})
# ('id', '4', {})
# ('featurename', 'Federation Square - Flinders St / Swanston St - City', {})
# ('terminalname', '60001', {})
# ('nbbikes', '15', {})
# ('nbemptydoc', '7', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.817523', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.967814'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/5', '_id': '157', '_uuid': '7EFB5219-2764-47CE-A497-B6D872823BBE', '_position': '157'})
# ('id', '5', {})
# ('featurename', 'Plum Garland Reserve - Beaconsfield Pde - Albert Park', {})
# ('terminalname', '60002', {})
# ('nbbikes', '16', {})
# ('nbemptydoc', '1', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.84782', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.948196'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/6', '_id': '158', '_uuid': '4B09D743-FFEE-4185-B968-A7866E45FE0B', '_position': '158'})
# ('id', '6', {})
# ('featurename', 'State Library - Swanston St / Little Lonsdale St - City', {})
# ('terminalname', '60003', {})
# ('nbbikes', '9', {})
# ('nbemptydoc', '2', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.810702', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.964417'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/7', '_id': '159', '_uuid': 'C5493850-5714-40E2-9A67-DA443A4F64F8', '_position': '159'})
# ('id', '7', {})
# ('featurename', 'Bourke Street Mall - 205 Bourke St - City', {})
# ('terminalname', '60004', {})
# ('nbbikes', '10', {})
# ('nbemptydoc', '1', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.813088', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.967437'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/8', '_id': '160', '_uuid': '1130BB85-AE44-4706-89AD-91B3B6AF15CF', '_position': '160'})
# ('id', '8', {})
# ('featurename', 'Melbourne Uni - Tin Alley - Carlton', {})
# ('terminalname', '60005', {})
# ('nbbikes', '2', {})
# ('nbemptydoc', '17', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.79625', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.960858'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/9', '_id': '161', '_uuid': '37EE6B9B-D06F-493E-9263-F9708FCFDB33', '_position': '161'})
# ('id', '9', {})
# ('featurename', 'RMIT - Swanston St / Franklin St - City', {})
# ('terminalname', '60006', {})
# ('nbbikes', '11', {})
# ('nbemptydoc', '0', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.807699', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.963095'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/10', '_id': '162', '_uuid': 'EBE9EF80-BF46-4553-968D-DF94EB556268', '_position': '162'})
# ('id', '10', {})
# ('featurename', "St Paul's Cathedral - Swanston St / Flinders St - City", {})
# ('terminalname', '60007', {})
# ('nbbikes', '4', {})
# ('nbemptydoc', '7', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.817189', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.967409'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/11', '_id': '163', '_uuid': '635C91D4-127F-4C5E-AAFD-967D04900027', '_position': '163'})
# ('id', '11', {})
# ('featurename', 'MSAC - Aughtie Dve - Albert Park', {})
# ('terminalname', '60008', {})
# ('nbbikes', '9', {})
# ('nbemptydoc', '18', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.842395', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.961868'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/12', '_id': '164', '_uuid': 'AA5B6285-EEDD-4102-A5B5-0AD25BB7FB8D', '_position': '164'})
# ('id', '12', {})
# ('featurename', 'Fitzroy Town Hall - Moor St - Fitzroy', {})
# ('terminalname', '60009', {})
# ('nbbikes', '3', {})
# ('nbemptydoc', '4', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.801813', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.979209'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/15', '_id': '165', '_uuid': '4E10C43A-8DE3-4FE0-96B5-17BEF69EB2DA', '_position': '165'})
# ('id', '15', {})
# ('featurename', 'Coventry St / St Kilda Rd - Southbank', {})
# ('terminalname', '60017', {})
# ('nbbikes', '5', {})
# ('nbemptydoc', '6', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.828887', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.970822'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/16', '_id': '166', '_uuid': '59632E91-08BE-40D4-A863-51A28D7CB5F3', '_position': '166'})
# ('id', '16', {})
# ('featurename', 'NAB - Harbour Esp / Bourke St - Docklands', {})
# ('terminalname', '60011', {})
# ('nbbikes', '13', {})
# ('nbemptydoc', '20', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.818306', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.945923'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/17', '_id': '167', '_uuid': 'EAF2E40E-3E0C-4FDE-AD1E-7667A77411D7', '_position': '167'})
# ('id', '17', {})
# ('featurename', "Yarra's Point - Lorimer St / Yarra River - Docklands", {})
# ('terminalname', '60024', {})
# ('nbbikes', '5', {})
# ('nbemptydoc', '9', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.823805', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.943051'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/18', '_id': '168', '_uuid': '8A211E44-3AC2-48FB-832E-47B4E5B2DA9E', '_position': '168'})
# ('id', '18', {})
# ('featurename', 'Argyle Square - Lygon St - Carlton', {})
# ('terminalname', '60021', {})
# ('nbbikes', '0', {})
# ('nbemptydoc', '11', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.802129', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.96677'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/20', '_id': '170', '_uuid': 'E50ADBDC-8B95-456F-A92B-91FB44A11FEB', '_position': '170'})
# ('id', '20', {})
# ('featurename', 'Parliament Station - Nicholson St / Albert St - City', {})
# ('terminalname', '60025', {})
# ('nbbikes', '8', {})
# ('nbemptydoc', '7', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.809072', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.972762'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/21', '_id': '171', '_uuid': 'F83F8106-F883-4E8A-92F1-95850DAA0E36', '_position': '171'})
# ('id', '21', {})
# ('featurename', 'Bridport St / Montague St - Albert Park', {})
# ('terminalname', '60014', {})
# ('nbbikes', '6', {})
# ('nbemptydoc', '17', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.840885', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.955303'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/22', '_id': '172', '_uuid': 'C59C7CA0-A02E-40D3-9667-39DC9EB3B03D', '_position': '172'})
# ('id', '22', {})
# ('featurename', 'Pickles St / Ingles St - Port Melbourne', {})
# ('terminalname', '60027', {})
# ('nbbikes', '12', {})
# ('nbemptydoc', '11', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.835803', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.94852'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/23', '_id': '173', '_uuid': '5BD9B795-6F53-46E8-8A96-A10321D2BB65', '_position': '173'})
# ('id', '23', {})
# ('featurename', "Yarra's Edge - River Esp / Yarra River - Docklands", {})
# ('terminalname', '60015', {})
# ('nbbikes', '10', {})
# ('nbemptydoc', '1', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.824468', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.946033'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/24', '_id': '174', '_uuid': '33D0B004-3202-47A2-91F2-AD89B0666CD2', '_position': '174'})
# ('id', '24', {})
# ('featurename', 'North Melbourne Station - Adderley St - North Melbourne', {})
# ('terminalname', '60038', {})
# ('nbbikes', '7', {})
# ('nbemptydoc', '8', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.807021', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.941854'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/25', '_id': '175', '_uuid': '589A56B0-E7A8-4D88-ADAA-A9804D6F106F', '_position': '175'})
# ('id', '25', {})
# ('featurename', 'Sandridge Bridge - Southbank', {})
# ('terminalname', '60026', {})
# ('nbbikes', '1', {})
# ('nbemptydoc', '26', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.820836', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.962266'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/26', '_id': '176', '_uuid': '6EDC4391-3FED-4FA2-B744-F3FD14CB7005', '_position': '176'})
# ('id', '26', {})
# ('featurename', 'Beach St - Port Melbourne', {})
# ('terminalname', '60029', {})
# ('nbbikes', '17', {})
# ('nbemptydoc', '22', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.841954', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.935296'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/27', '_id': '177', '_uuid': '084EA824-DB3F-4D4D-A32B-1D56DECC42A6', '_position': '177'})
# ('id', '27', {})
# ('featurename', 'New Quay Prom / Harbour Esp - Docklands', {})
# ('terminalname', '60028', {})
# ('nbbikes', '4', {})
# ('nbemptydoc', '23', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.814117', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.944081'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/28', '_id': '178', '_uuid': '0ADD1AA0-18C5-4651-92D2-E2857C30CDA7', '_position': '178'})
# ('id', '28', {})
# ('featurename', 'Queensbridge St / Yarra River - Southbank', {})
# ('terminalname', '60035', {})
# ('nbbikes', '0', {})
# ('nbemptydoc', '15', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.821071', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.961113'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/29', '_id': '179', '_uuid': 'CE0A1000-AD4E-4522-9AFF-03CCFAB4B6C7', '_position': '179'})
# ('id', '29', {})
# ('featurename', 'Southern Cross Station - Spencer St - City', {})
# ('terminalname', '60034', {})
# ('nbbikes', '0', {})
# ('nbemptydoc', '26', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.818124', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.953581'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/30', '_id': '180', '_uuid': '325ED8D1-B7B3-4D8B-8322-AAAEEE91F501', '_position': '180'})
# ('id', '30', {})
# ('featurename', 'Gasworks Arts Park - Pickles St - Albert Park', {})
# ('terminalname', '60023', {})
# ('nbbikes', '6', {})
# ('nbemptydoc', '5', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.842174', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.946051'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/31', '_id': '181', '_uuid': 'D03B2082-EFCE-4197-A761-47F5953F8F3C', '_position': '181'})
# ('id', '31', {})
# ('featurename', 'Cleve Gardens - Fitzroy St - St Kilda', {})
# ('terminalname', '60032', {})
# ('nbbikes', '10', {})
# ('nbemptydoc', '5', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.861984', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.97341'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/32', '_id': '182', '_uuid': '550A5A60-CF0E-4615-B5FE-E391D6D82105', '_position': '182'})
# ('id', '32', {})
# ('featurename', 'West Beach Pavilion - Beaconsfield Pde - St Kilda West', {})
# ('terminalname', '60030', {})
# ('nbbikes', '8', {})
# ('nbemptydoc', '7', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.858553', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.969101'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/33', '_id': '183', '_uuid': '4D352150-8BE5-491D-A468-69FB41A50353', '_position': '183'})
# ('id', '33', {})
# ('featurename', 'Siddeley St / Seafarers Bridge - Docklands', {})
# ('terminalname', '60031', {})
# ('nbbikes', '22', {})
# ('nbemptydoc', '1', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.823124', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.951918'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/34', '_id': '184', '_uuid': 'E03921EE-0B31-43F0-920E-5E1E02098437', '_position': '184'})
# ('id', '34', {})
# ('featurename', 'RACV - Bourke St / New Chancery Ln - City', {})
# ('terminalname', '60013', {})
# ('nbbikes', '8', {})
# ('nbemptydoc', '3', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.815505', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.959278'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/35', '_id': '185', '_uuid': '8A0F1BC0-5386-4BED-97BF-B57D0F0152A3', '_position': '185'})
# ('id', '35', {})
# ('featurename', 'Yorkshire Brewery - Wellington St - Collingwood', {})
# ('terminalname', '60033', {})
# ('nbbikes', '3', {})
# ('nbemptydoc', '4', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.805997', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.986953'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/36', '_id': '186', '_uuid': 'F8475211-428F-4DCB-96C6-08207FDAAF74', '_position': '186'})
# ('id', '36', {})
# ('featurename', 'Napier St / Victoria Pde - Fitzroy', {})
# ('terminalname', '60022', {})
# ('nbbikes', '7', {})
# ('nbemptydoc', '4', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.808266', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.979005'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/37', '_id': '187', '_uuid': '609E776E-AB71-47AD-8A50-CB925EC7EF37', '_position': '187'})
# ('id', '37', {})
# ('featurename', 'University Square - Grattan St - Carlton', {})
# ('terminalname', '60045', {})
# ('nbbikes', '4', {})
# ('nbemptydoc', '11', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.800214', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.960313'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/38', '_id': '188', '_uuid': '61B9BAE6-0E20-41BA-B3E5-8B0F050EB42C', '_position': '188'})
# ('id', '38', {})
# ('featurename', 'Aquarium - Kings Way / Flinders St - City', {})
# ('terminalname', '60046', {})
# ('nbbikes', '5', {})
# ('nbemptydoc', '6', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.821324', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.958318'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/39', '_id': '189', '_uuid': 'A098BBA8-C74E-4CDE-95F7-2915BBCB4D8B', '_position': '189'})
# ('id', '39', {})
# ('featurename', 'Richmond Station - Brunton Ave - East Melbourne', {})
# ('terminalname', '60020', {})
# ('nbbikes', '12', {})
# ('nbemptydoc', '7', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.822962', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.988507'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/40', '_id': '190', '_uuid': 'C839809C-AD68-4FB6-9A3D-93C4A84632E8', '_position': '190'})
# ('id', '40', {})
# ('featurename', 'Rod Laver Arena - Batman Ave / Swan St - City', {})
# ('terminalname', '60047', {})
# ('nbbikes', '14', {})
# ('nbemptydoc', '8', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.822987', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.978459'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/41', '_id': '191', '_uuid': '686B6908-C48E-4626-8E86-FCA3D45175C4', '_position': '191'})
# ('id', '41', {})
# ('featurename', 'Domain Interchange - Park St / St Kilda Rd - Melbourne', {})
# ('terminalname', '60016', {})
# ('nbbikes', '12', {})
# ('nbemptydoc', '3', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.832396', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.971678'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/42', '_id': '192', '_uuid': 'D5B41F96-AB9D-4CCA-9862-9FD410E7DF2F', '_position': '192'})
# ('id', '42', {})
# ('featurename', 'Kings Way / St Kilda Rd - Melbourne', {})
# ('terminalname', '60018', {})
# ('nbbikes', '18', {})
# ('nbemptydoc', '8', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.836323', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.975162'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/43', '_id': '193', '_uuid': '45E235B6-993C-4927-8741-EE2651101735', '_position': '193'})
# ('id', '43', {})
# ('featurename', 'Spring St / Collins St - City', {})
# ('terminalname', '60019', {})
# ('nbbikes', '9', {})
# ('nbemptydoc', '2', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.813774', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.974054'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/44', '_id': '194', '_uuid': '08F09E48-9FB6-4E8F-A3FF-5D57CDB5D700', '_position': '194'})
# ('id', '44', {})
# ('featurename', 'Queens Rd / Bowen Cres - Melbourne', {})
# ('terminalname', '60036', {})
# ('nbbikes', '10', {})
# ('nbemptydoc', '5', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.835383', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.973699'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/45', '_id': '195', '_uuid': 'E0DCF7FB-3562-48A2-9637-23241D1A5A71', '_position': '195'})
# ('id', '45', {})
# ('featurename', 'Luna Park - Lower Esp - St Kilda', {})
# ('terminalname', '60037', {})
# ('nbbikes', '23', {})
# ('nbemptydoc', '16', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.867068', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.976428'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/46', '_id': '196', '_uuid': '7F84D0CB-B469-4D64-8980-40165B502EA2', '_position': '196'})
# ('id', '46', {})
# ('featurename', 'South Melbourne Market - York St / Cecil St - South Melbourne', {})
# ('terminalname', '60039', {})
# ('nbbikes', '9', {})
# ('nbemptydoc', '6', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.831475', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.957511'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/47', '_id': '197', '_uuid': '6882C51B-0A33-4596-A62C-5F2F79AC7D92', '_position': '197'})
# ('id', '47', {})
# ('featurename', 'VCAM - St Kilda Rd / Southbank Blvd - Southbank', {})
# ('terminalname', '60040', {})
# ('nbbikes', '6', {})
# ('nbemptydoc', '5', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.824088', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.970085'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/48', '_id': '198', '_uuid': '2BC742C3-CDD4-43C5-94F9-674D78EDCFB3', '_position': '198'})
# ('id', '48', {})
# ('featurename', 'Museum - Rathdowne St - Carlton', {})
# ('terminalname', '60041', {})
# ('nbbikes', '4', {})
# ('nbemptydoc', '11', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.803868', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.969609'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/49', '_id': '199', '_uuid': '8EF503F8-ADF0-4BAA-8C7F-ED39AE5E8196', '_position': '199'})
# ('id', '49', {})
# ('featurename', 'Jolimont Station - Wellington Pde South - East Melbourne', {})
# ('terminalname', '60042', {})
# ('nbbikes', '3', {})
# ('nbemptydoc', '8', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.816731', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.982006'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/50', '_id': '200', '_uuid': '3F1BF86C-DC07-4395-9CD3-0A8D729C23AF', '_position': '200'})
# ('id', '50', {})
# ('featurename', 'ACCA - Sturt St - Southbank', {})
# ('terminalname', '60043', {})
# ('nbbikes', '15', {})
# ('nbemptydoc', '8', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.826578', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.966542'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/51', '_id': '201', '_uuid': 'FE678EF7-468B-4594-AF13-57858D566267', '_position': '201'})
# ('id', '51', {})
# ('featurename', 'ANZ - Collins St - Docklands', {})
# ('terminalname', '60044', {})
# ('nbbikes', '9', {})
# ('nbemptydoc', '10', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.821568', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.944488'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/52', '_id': '202', '_uuid': 'A5EFB6BA-5E93-4171-978B-8981B324B0A2', '_position': '202'})
# ('id', '52', {})
# ('featurename', 'Flagstaff Gardens - Peel St - West Melbourne', {})
# ('terminalname', '60048', {})
# ('nbbikes', '6', {})
# ('nbemptydoc', '5', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.809216', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.955223'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/53', '_id': '203', '_uuid': 'D531339E-DBBC-42B8-8937-8A2D8433C792', '_position': '203'})
# ('id', '53', {})
# ('featurename', 'Victoria Market - Elizabeth St / Victoria St - City', {})
# ('terminalname', '60049', {})
# ('nbbikes', '15', {})
# ('nbemptydoc', '10', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.806091', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.959017'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/55', '_id': '204', '_uuid': '75FC6E82-0B5C-45DD-800E-3FFD5AD0B359', '_position': '204'})
# ('id', '55', {})
# ('featurename', 'Coventry St / Clarendon St - South Melbourne', {})
# ('terminalname', '60050', {})
# ('nbbikes', '8', {})
# ('nbemptydoc', '3', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.831776', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.960818'})
# ('row', None, {'_address': 'http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/57', '_id': '205', '_uuid': '223A0CB0-60DD-4166-82F0-C2D181086C8E', '_position': '205'})
# ('id', '57', {})
# ('featurename', 'Fitzroy Street - St Kilda', {})
# ('terminalname', '60052', {})
# ('nbbikes', '18', {})
# ('nbemptydoc', '13', {})
# ('uploaddate', '1453986006', {})
# ('coordinates', None, {'latitude': '-37.858655', 'needs_recoding': 'false', 'human_address': '{"address":"","city":"","state":"","zip":""}', 'longitude': '144.978818'})

# %% [markdown]
# Besides ElementTree, there are other Python libraries that can be used to parse XML files.
# Here we show two of them, which are **`lxml`** and **`BeautifulSoup`**.
#
# [**`lxml`**](http://lxml.de) is an open source third-party library that builds on top of two C libraries
# libxml2 and libxslt.
# It is mostly compatible but superior to the well-known ElementTree API.
# To study **`lxml`** in detail, you should refer to:
# * [the lxml.etree tutorial](http://lxml.de/tutorial.html), a tutorial on XML processing with lxml.etree. 📖
# * and [Going Further With lxml](http://www.diveintopython3.net/xml.html#xml-lxml), Section 12.6 in Chapter 12 of "**Dive into Python 3**". 📖
#
# Here we are going to briefly show you how to extract the text content of an element tree
# using **XPath**.
# **XPath** allows you to extract the separate text chunks into a list:

# %%
from lxml import etree
ltree = etree.parse("./Melbourne_bike_share.xml")
for el in ltree.xpath('descendant-or-self::text()'):
    print (el)
# Out:
# 2
# Harbour Town - Docklands Dve - Docklands
# 60000
# 9
# 14
# 1453986006
# 4
# Federation Square - Flinders St / Swanston St - City
# 60001
# 15
# 7
# 1453986006
# 5
# Plum Garland Reserve - Beaconsfield Pde - Albert Park
# 60002
# 16
# 1
# 1453986006
# 6
# State Library - Swanston St / Little Lonsdale St - City
# 60003
# 9
# 2
# 1453986006
# 7
# Bourke Street Mall - 205 Bourke St - City
# 60004
# 10
# 1
# 1453986006
# 8
# Melbourne Uni - Tin Alley - Carlton
# 60005
# 2
# 17
# 1453986006
# 9
# RMIT - Swanston St / Franklin St - City
# 60006
# 11
# 0
# 1453986006
# 10
# St Paul's Cathedral - Swanston St / Flinders St - City
# 60007
# 4
# 7
# 1453986006
# 11
# MSAC - Aughtie Dve - Albert Park
# 60008
# 9
# 18
# 1453986006
# 12
# Fitzroy Town Hall - Moor St - Fitzroy
# 60009
# 3
# 4
# 1453986006
# 15
# Coventry St / St Kilda Rd - Southbank
# 60017
# 5
# 6
# 1453986006
# 16
# NAB - Harbour Esp / Bourke St - Docklands
# 60011
# 13
# 20
# 1453986006
# 17
# Yarra's Point - Lorimer St / Yarra River - Docklands
# 60024
# 5
# 9
# 1453986006
# 18
# Argyle Square - Lygon St - Carlton
# 60021
# 0
# 11
# 1453986006
# 20
# Parliament Station - Nicholson St / Albert St - City
# 60025
# 8
# 7
# 1453986006
# 21
# Bridport St / Montague St - Albert Park
# 60014
# 6
# 17
# 1453986006
# 22
# Pickles St / Ingles St - Port Melbourne
# 60027
# 12
# 11
# 1453986006
# 23
# Yarra's Edge - River Esp / Yarra River - Docklands
# 60015
# 10
# 1
# 1453986006
# 24
# North Melbourne Station - Adderley St - North Melbourne
# 60038
# 7
# 8
# 1453986006
# 25
# Sandridge Bridge - Southbank
# 60026
# 1
# 26
# 1453986006
# 26
# Beach St - Port Melbourne
# 60029
# 17
# 22
# 1453986006
# 27
# New Quay Prom / Harbour Esp - Docklands
# 60028
# 4
# 23
# 1453986006
# 28
# Queensbridge St / Yarra River - Southbank
# 60035
# 0
# 15
# 1453986006
# 29
# Southern Cross Station - Spencer St - City
# 60034
# 0
# 26
# 1453986006
# 30
# Gasworks Arts Park - Pickles St - Albert Park
# 60023
# 6
# 5
# 1453986006
# 31
# Cleve Gardens - Fitzroy St - St Kilda
# 60032
# 10
# 5
# 1453986006
# 32
# West Beach Pavilion - Beaconsfield Pde - St Kilda West
# 60030
# 8
# 7
# 1453986006
# 33
# Siddeley St / Seafarers Bridge - Docklands
# 60031
# 22
# 1
# 1453986006
# 34
# RACV - Bourke St / New Chancery Ln - City
# 60013
# 8
# 3
# 1453986006
# 35
# Yorkshire Brewery - Wellington St - Collingwood
# 60033
# 3
# 4
# 1453986006
# 36
# Napier St / Victoria Pde - Fitzroy
# 60022
# 7
# 4
# 1453986006
# 37
# University Square - Grattan St - Carlton
# 60045
# 4
# 11
# 1453986006
# 38
# Aquarium - Kings Way / Flinders St - City
# 60046
# 5
# 6
# 1453986006
# 39
# Richmond Station - Brunton Ave - East Melbourne
# 60020
# 12
# 7
# 1453986006
# 40
# Rod Laver Arena - Batman Ave / Swan St - City
# 60047
# 14
# 8
# 1453986006
# 41
# Domain Interchange - Park St / St Kilda Rd - Melbourne
# 60016
# 12
# 3
# 1453986006
# 42
# Kings Way / St Kilda Rd - Melbourne
# 60018
# 18
# 8
# 1453986006
# 43
# Spring St / Collins St - City
# 60019
# 9
# 2
# 1453986006
# 44
# Queens Rd / Bowen Cres - Melbourne
# 60036
# 10
# 5
# 1453986006
# 45
# Luna Park - Lower Esp - St Kilda
# 60037
# 23
# 16
# 1453986006
# 46
# South Melbourne Market - York St / Cecil St - South Melbourne
# 60039
# 9
# 6
# 1453986006
# 47
# VCAM - St Kilda Rd / Southbank Blvd - Southbank
# 60040
# 6
# 5
# 1453986006
# 48
# Museum - Rathdowne St - Carlton
# 60041
# 4
# 11
# 1453986006
# 49
# Jolimont Station - Wellington Pde South - East Melbourne
# 60042
# 3
# 8
# 1453986006
# 50
# ACCA - Sturt St - Southbank
# 60043
# 15
# 8
# 1453986006
# 51
# ANZ - Collins St - Docklands
# 60044
# 9
# 10
# 1453986006
# 52
# Flagstaff Gardens - Peel St - West Melbourne
# 60048
# 6
# 5
# 1453986006
# 53
# Victoria Market - Elizabeth St / Victoria St - City
# 60049
# 15
# 10
# 1453986006
# 55
# Coventry St / Clarendon St - South Melbourne
# 60050
# 8
# 3
# 1453986006
# 57
# Fitzroy Street - St Kilda
# 60052
# 18
# 13
# 1453986006

# %% [markdown]
# In the `xpath()` function,
# the `descendant-or-self::` is an axis selector that limits the search to the context node, its children, their children, and so on out to the leaves of the tree. The `text()` function selects only text nodes, discarding any elements, comments, and other non-textual content. The return value is a list of strings.
# Read [XPath processing](http://infohost.nmt.edu/tcc/help/pubs/pylxml/web/xpath.html) 📖 for a short introduction
# to `xpath` and [W3C's website on Xpath](http://www.w3.org/TR/xpath/) for a detailed introduction to XPath.
# Note that `lxml` is significantly faster than the built-in ElementTree library on parsing large xml documents.
# If your XML files are very large, you should consider using `lxml`.
#
# [Beautiful Soup](http://www.crummy.com/software/BeautifulSoup/) is an another Python library for pulling data out of HTML and XML files. It provides Pythonic idioms for iterating, searching, and modifying the parsed tree.
# We begin by reading in our XML file and creating a Beautiful Soup object with the BeautifulSoup function.

# %%
from bs4 import BeautifulSoup
btree = BeautifulSoup(open("./Melbourne_bike_share.xml"),"lxml-xml")

# %% [markdown]
# There are two different ways of passing an XML document into the BeautifulSoup constructor.
# One is to pass in a string, another is to parse an open filehandle. (the above example follows this way.)
# The second argument is the parser to be used to parse the document.
# Beautiful Soup presents the same interface to a number of different parsers, but each parser is different. Different parsers will create different parsed trees from the same document.

# %%
print(btree.prettify())
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <response>
#  <row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/2" _id="155" _position="155" _uuid="7C09387D-9E6C-4B42-9041-9A98B88F54BB">
#    <id>
#     2
#    </id>
#    <featurename>
#     Harbour Town - Docklands Dve - Docklands
#    </featurename>
#    <terminalname>
#     60000
#    </terminalname>
#    <nbbikes>
#     9
#    </nbbikes>
#    <nbemptydoc>
#     14
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.814022" longitude="144.939521" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/4" _id="156" _position="156" _uuid="52739A59-E034-436B-A613-E7A5F62448C0">
#    <id>
#     4
#    </id>
#    <featurename>
#     Federation Square - Flinders St / Swanston St - City
#    </featurename>
#    <terminalname>
#     60001
#    </terminalname>
#    <nbbikes>
#     15
#    </nbbikes>
#    <nbemptydoc>
#     7
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.817523" longitude="144.967814" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/5" _id="157" _position="157" _uuid="7EFB5219-2764-47CE-A497-B6D872823BBE">
#    <id>
#     5
#    </id>
#    <featurename>
#     Plum Garland Reserve - Beaconsfield Pde - Albert Park
#    </featurename>
#    <terminalname>
#     60002
#    </terminalname>
#    <nbbikes>
#     16
#    </nbbikes>
#    <nbemptydoc>
#     1
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.84782" longitude="144.948196" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/6" _id="158" _position="158" _uuid="4B09D743-FFEE-4185-B968-A7866E45FE0B">
#    <id>
#     6
#    </id>
#    <featurename>
#     State Library - Swanston St / Little Lonsdale St - City
#    </featurename>
#    <terminalname>
#     60003
#    </terminalname>
#    <nbbikes>
#     9
#    </nbbikes>
#    <nbemptydoc>
#     2
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.810702" longitude="144.964417" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/7" _id="159" _position="159" _uuid="C5493850-5714-40E2-9A67-DA443A4F64F8">
#    <id>
#     7
#    </id>
#    <featurename>
#     Bourke Street Mall - 205 Bourke St - City
#    </featurename>
#    <terminalname>
#     60004
#    </terminalname>
#    <nbbikes>
#     10
#    </nbbikes>
#    <nbemptydoc>
#     1
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.813088" longitude="144.967437" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/8" _id="160" _position="160" _uuid="1130BB85-AE44-4706-89AD-91B3B6AF15CF">
#    <id>
#     8
#    </id>
#    <featurename>
#     Melbourne Uni - Tin Alley - Carlton
#    </featurename>
#    <terminalname>
#     60005
#    </terminalname>
#    <nbbikes>
#     2
#    </nbbikes>
#    <nbemptydoc>
#     17
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.79625" longitude="144.960858" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/9" _id="161" _position="161" _uuid="37EE6B9B-D06F-493E-9263-F9708FCFDB33">
#    <id>
#     9
#    </id>
#    <featurename>
#     RMIT - Swanston St / Franklin St - City
#    </featurename>
#    <terminalname>
#     60006
#    </terminalname>
#    <nbbikes>
#     11
#    </nbbikes>
#    <nbemptydoc>
#     0
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.807699" longitude="144.963095" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/10" _id="162" _position="162" _uuid="EBE9EF80-BF46-4553-968D-DF94EB556268">
#    <id>
#     10
#    </id>
#    <featurename>
#     St Paul's Cathedral - Swanston St / Flinders St - City
#    </featurename>
#    <terminalname>
#     60007
#    </terminalname>
#    <nbbikes>
#     4
#    </nbbikes>
#    <nbemptydoc>
#     7
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.817189" longitude="144.967409" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/11" _id="163" _position="163" _uuid="635C91D4-127F-4C5E-AAFD-967D04900027">
#    <id>
#     11
#    </id>
#    <featurename>
#     MSAC - Aughtie Dve - Albert Park
#    </featurename>
#    <terminalname>
#     60008
#    </terminalname>
#    <nbbikes>
#     9
#    </nbbikes>
#    <nbemptydoc>
#     18
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.842395" longitude="144.961868" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/12" _id="164" _position="164" _uuid="AA5B6285-EEDD-4102-A5B5-0AD25BB7FB8D">
#    <id>
#     12
#    </id>
#    <featurename>
#     Fitzroy Town Hall - Moor St - Fitzroy
#    </featurename>
#    <terminalname>
#     60009
#    </terminalname>
#    <nbbikes>
#     3
#    </nbbikes>
#    <nbemptydoc>
#     4
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.801813" longitude="144.979209" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/15" _id="165" _position="165" _uuid="4E10C43A-8DE3-4FE0-96B5-17BEF69EB2DA">
#    <id>
#     15
#    </id>
#    <featurename>
#     Coventry St / St Kilda Rd - Southbank
#    </featurename>
#    <terminalname>
#     60017
#    </terminalname>
#    <nbbikes>
#     5
#    </nbbikes>
#    <nbemptydoc>
#     6
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.828887" longitude="144.970822" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/16" _id="166" _position="166" _uuid="59632E91-08BE-40D4-A863-51A28D7CB5F3">
#    <id>
#     16
#    </id>
#    <featurename>
#     NAB - Harbour Esp / Bourke St - Docklands
#    </featurename>
#    <terminalname>
#     60011
#    </terminalname>
#    <nbbikes>
#     13
#    </nbbikes>
#    <nbemptydoc>
#     20
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.818306" longitude="144.945923" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/17" _id="167" _position="167" _uuid="EAF2E40E-3E0C-4FDE-AD1E-7667A77411D7">
#    <id>
#     17
#    </id>
#    <featurename>
#     Yarra's Point - Lorimer St / Yarra River - Docklands
#    </featurename>
#    <terminalname>
#     60024
#    </terminalname>
#    <nbbikes>
#     5
#    </nbbikes>
#    <nbemptydoc>
#     9
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.823805" longitude="144.943051" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/18" _id="168" _position="168" _uuid="8A211E44-3AC2-48FB-832E-47B4E5B2DA9E">
#    <id>
#     18
#    </id>
#    <featurename>
#     Argyle Square - Lygon St - Carlton
#    </featurename>
#    <terminalname>
#     60021
#    </terminalname>
#    <nbbikes>
#     0
#    </nbbikes>
#    <nbemptydoc>
#     11
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.802129" longitude="144.96677" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/20" _id="170" _position="170" _uuid="E50ADBDC-8B95-456F-A92B-91FB44A11FEB">
#    <id>
#     20
#    </id>
#    <featurename>
#     Parliament Station - Nicholson St / Albert St - City
#    </featurename>
#    <terminalname>
#     60025
#    </terminalname>
#    <nbbikes>
#     8
#    </nbbikes>
#    <nbemptydoc>
#     7
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.809072" longitude="144.972762" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/21" _id="171" _position="171" _uuid="F83F8106-F883-4E8A-92F1-95850DAA0E36">
#    <id>
#     21
#    </id>
#    <featurename>
#     Bridport St / Montague St - Albert Park
#    </featurename>
#    <terminalname>
#     60014
#    </terminalname>
#    <nbbikes>
#     6
#    </nbbikes>
#    <nbemptydoc>
#     17
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.840885" longitude="144.955303" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/22" _id="172" _position="172" _uuid="C59C7CA0-A02E-40D3-9667-39DC9EB3B03D">
#    <id>
#     22
#    </id>
#    <featurename>
#     Pickles St / Ingles St - Port Melbourne
#    </featurename>
#    <terminalname>
#     60027
#    </terminalname>
#    <nbbikes>
#     12
#    </nbbikes>
#    <nbemptydoc>
#     11
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.835803" longitude="144.94852" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/23" _id="173" _position="173" _uuid="5BD9B795-6F53-46E8-8A96-A10321D2BB65">
#    <id>
#     23
#    </id>
#    <featurename>
#     Yarra's Edge - River Esp / Yarra River - Docklands
#    </featurename>
#    <terminalname>
#     60015
#    </terminalname>
#    <nbbikes>
#     10
#    </nbbikes>
#    <nbemptydoc>
#     1
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.824468" longitude="144.946033" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/24" _id="174" _position="174" _uuid="33D0B004-3202-47A2-91F2-AD89B0666CD2">
#    <id>
#     24
#    </id>
#    <featurename>
#     North Melbourne Station - Adderley St - North Melbourne
#    </featurename>
#    <terminalname>
#     60038
#    </terminalname>
#    <nbbikes>
#     7
#    </nbbikes>
#    <nbemptydoc>
#     8
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.807021" longitude="144.941854" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/25" _id="175" _position="175" _uuid="589A56B0-E7A8-4D88-ADAA-A9804D6F106F">
#    <id>
#     25
#    </id>
#    <featurename>
#     Sandridge Bridge - Southbank
#    </featurename>
#    <terminalname>
#     60026
#    </terminalname>
#    <nbbikes>
#     1
#    </nbbikes>
#    <nbemptydoc>
#     26
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.820836" longitude="144.962266" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/26" _id="176" _position="176" _uuid="6EDC4391-3FED-4FA2-B744-F3FD14CB7005">
#    <id>
#     26
#    </id>
#    <featurename>
#     Beach St - Port Melbourne
#    </featurename>
#    <terminalname>
#     60029
#    </terminalname>
#    <nbbikes>
#     17
#    </nbbikes>
#    <nbemptydoc>
#     22
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.841954" longitude="144.935296" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/27" _id="177" _position="177" _uuid="084EA824-DB3F-4D4D-A32B-1D56DECC42A6">
#    <id>
#     27
#    </id>
#    <featurename>
#     New Quay Prom / Harbour Esp - Docklands
#    </featurename>
#    <terminalname>
#     60028
#    </terminalname>
#    <nbbikes>
#     4
#    </nbbikes>
#    <nbemptydoc>
#     23
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.814117" longitude="144.944081" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/28" _id="178" _position="178" _uuid="0ADD1AA0-18C5-4651-92D2-E2857C30CDA7">
#    <id>
#     28
#    </id>
#    <featurename>
#     Queensbridge St / Yarra River - Southbank
#    </featurename>
#    <terminalname>
#     60035
#    </terminalname>
#    <nbbikes>
#     0
#    </nbbikes>
#    <nbemptydoc>
#     15
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.821071" longitude="144.961113" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/29" _id="179" _position="179" _uuid="CE0A1000-AD4E-4522-9AFF-03CCFAB4B6C7">
#    <id>
#     29
#    </id>
#    <featurename>
#     Southern Cross Station - Spencer St - City
#    </featurename>
#    <terminalname>
#     60034
#    </terminalname>
#    <nbbikes>
#     0
#    </nbbikes>
#    <nbemptydoc>
#     26
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.818124" longitude="144.953581" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/30" _id="180" _position="180" _uuid="325ED8D1-B7B3-4D8B-8322-AAAEEE91F501">
#    <id>
#     30
#    </id>
#    <featurename>
#     Gasworks Arts Park - Pickles St - Albert Park
#    </featurename>
#    <terminalname>
#     60023
#    </terminalname>
#    <nbbikes>
#     6
#    </nbbikes>
#    <nbemptydoc>
#     5
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.842174" longitude="144.946051" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/31" _id="181" _position="181" _uuid="D03B2082-EFCE-4197-A761-47F5953F8F3C">
#    <id>
#     31
#    </id>
#    <featurename>
#     Cleve Gardens - Fitzroy St - St Kilda
#    </featurename>
#    <terminalname>
#     60032
#    </terminalname>
#    <nbbikes>
#     10
#    </nbbikes>
#    <nbemptydoc>
#     5
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.861984" longitude="144.97341" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/32" _id="182" _position="182" _uuid="550A5A60-CF0E-4615-B5FE-E391D6D82105">
#    <id>
#     32
#    </id>
#    <featurename>
#     West Beach Pavilion - Beaconsfield Pde - St Kilda West
#    </featurename>
#    <terminalname>
#     60030
#    </terminalname>
#    <nbbikes>
#     8
#    </nbbikes>
#    <nbemptydoc>
#     7
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.858553" longitude="144.969101" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/33" _id="183" _position="183" _uuid="4D352150-8BE5-491D-A468-69FB41A50353">
#    <id>
#     33
#    </id>
#    <featurename>
#     Siddeley St / Seafarers Bridge - Docklands
#    </featurename>
#    <terminalname>
#     60031
#    </terminalname>
#    <nbbikes>
#     22
#    </nbbikes>
#    <nbemptydoc>
#     1
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.823124" longitude="144.951918" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/34" _id="184" _position="184" _uuid="E03921EE-0B31-43F0-920E-5E1E02098437">
#    <id>
#     34
#    </id>
#    <featurename>
#     RACV - Bourke St / New Chancery Ln - City
#    </featurename>
#    <terminalname>
#     60013
#    </terminalname>
#    <nbbikes>
#     8
#    </nbbikes>
#    <nbemptydoc>
#     3
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.815505" longitude="144.959278" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/35" _id="185" _position="185" _uuid="8A0F1BC0-5386-4BED-97BF-B57D0F0152A3">
#    <id>
#     35
#    </id>
#    <featurename>
#     Yorkshire Brewery - Wellington St - Collingwood
#    </featurename>
#    <terminalname>
#     60033
#    </terminalname>
#    <nbbikes>
#     3
#    </nbbikes>
#    <nbemptydoc>
#     4
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.805997" longitude="144.986953" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/36" _id="186" _position="186" _uuid="F8475211-428F-4DCB-96C6-08207FDAAF74">
#    <id>
#     36
#    </id>
#    <featurename>
#     Napier St / Victoria Pde - Fitzroy
#    </featurename>
#    <terminalname>
#     60022
#    </terminalname>
#    <nbbikes>
#     7
#    </nbbikes>
#    <nbemptydoc>
#     4
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.808266" longitude="144.979005" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/37" _id="187" _position="187" _uuid="609E776E-AB71-47AD-8A50-CB925EC7EF37">
#    <id>
#     37
#    </id>
#    <featurename>
#     University Square - Grattan St - Carlton
#    </featurename>
#    <terminalname>
#     60045
#    </terminalname>
#    <nbbikes>
#     4
#    </nbbikes>
#    <nbemptydoc>
#     11
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.800214" longitude="144.960313" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/38" _id="188" _position="188" _uuid="61B9BAE6-0E20-41BA-B3E5-8B0F050EB42C">
#    <id>
#     38
#    </id>
#    <featurename>
#     Aquarium - Kings Way / Flinders St - City
#    </featurename>
#    <terminalname>
#     60046
#    </terminalname>
#    <nbbikes>
#     5
#    </nbbikes>
#    <nbemptydoc>
#     6
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.821324" longitude="144.958318" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/39" _id="189" _position="189" _uuid="A098BBA8-C74E-4CDE-95F7-2915BBCB4D8B">
#    <id>
#     39
#    </id>
#    <featurename>
#     Richmond Station - Brunton Ave - East Melbourne
#    </featurename>
#    <terminalname>
#     60020
#    </terminalname>
#    <nbbikes>
#     12
#    </nbbikes>
#    <nbemptydoc>
#     7
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.822962" longitude="144.988507" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/40" _id="190" _position="190" _uuid="C839809C-AD68-4FB6-9A3D-93C4A84632E8">
#    <id>
#     40
#    </id>
#    <featurename>
#     Rod Laver Arena - Batman Ave / Swan St - City
#    </featurename>
#    <terminalname>
#     60047
#    </terminalname>
#    <nbbikes>
#     14
#    </nbbikes>
#    <nbemptydoc>
#     8
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.822987" longitude="144.978459" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/41" _id="191" _position="191" _uuid="686B6908-C48E-4626-8E86-FCA3D45175C4">
#    <id>
#     41
#    </id>
#    <featurename>
#     Domain Interchange - Park St / St Kilda Rd - Melbourne
#    </featurename>
#    <terminalname>
#     60016
#    </terminalname>
#    <nbbikes>
#     12
#    </nbbikes>
#    <nbemptydoc>
#     3
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.832396" longitude="144.971678" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/42" _id="192" _position="192" _uuid="D5B41F96-AB9D-4CCA-9862-9FD410E7DF2F">
#    <id>
#     42
#    </id>
#    <featurename>
#     Kings Way / St Kilda Rd - Melbourne
#    </featurename>
#    <terminalname>
#     60018
#    </terminalname>
#    <nbbikes>
#     18
#    </nbbikes>
#    <nbemptydoc>
#     8
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.836323" longitude="144.975162" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/43" _id="193" _position="193" _uuid="45E235B6-993C-4927-8741-EE2651101735">
#    <id>
#     43
#    </id>
#    <featurename>
#     Spring St / Collins St - City
#    </featurename>
#    <terminalname>
#     60019
#    </terminalname>
#    <nbbikes>
#     9
#    </nbbikes>
#    <nbemptydoc>
#     2
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.813774" longitude="144.974054" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/44" _id="194" _position="194" _uuid="08F09E48-9FB6-4E8F-A3FF-5D57CDB5D700">
#    <id>
#     44
#    </id>
#    <featurename>
#     Queens Rd / Bowen Cres - Melbourne
#    </featurename>
#    <terminalname>
#     60036
#    </terminalname>
#    <nbbikes>
#     10
#    </nbbikes>
#    <nbemptydoc>
#     5
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.835383" longitude="144.973699" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/45" _id="195" _position="195" _uuid="E0DCF7FB-3562-48A2-9637-23241D1A5A71">
#    <id>
#     45
#    </id>
#    <featurename>
#     Luna Park - Lower Esp - St Kilda
#    </featurename>
#    <terminalname>
#     60037
#    </terminalname>
#    <nbbikes>
#     23
#    </nbbikes>
#    <nbemptydoc>
#     16
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.867068" longitude="144.976428" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/46" _id="196" _position="196" _uuid="7F84D0CB-B469-4D64-8980-40165B502EA2">
#    <id>
#     46
#    </id>
#    <featurename>
#     South Melbourne Market - York St / Cecil St - South Melbourne
#    </featurename>
#    <terminalname>
#     60039
#    </terminalname>
#    <nbbikes>
#     9
#    </nbbikes>
#    <nbemptydoc>
#     6
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.831475" longitude="144.957511" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/47" _id="197" _position="197" _uuid="6882C51B-0A33-4596-A62C-5F2F79AC7D92">
#    <id>
#     47
#    </id>
#    <featurename>
#     VCAM - St Kilda Rd / Southbank Blvd - Southbank
#    </featurename>
#    <terminalname>
#     60040
#    </terminalname>
#    <nbbikes>
#     6
#    </nbbikes>
#    <nbemptydoc>
#     5
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.824088" longitude="144.970085" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/48" _id="198" _position="198" _uuid="2BC742C3-CDD4-43C5-94F9-674D78EDCFB3">
#    <id>
#     48
#    </id>
#    <featurename>
#     Museum - Rathdowne St - Carlton
#    </featurename>
#    <terminalname>
#     60041
#    </terminalname>
#    <nbbikes>
#     4
#    </nbbikes>
#    <nbemptydoc>
#     11
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.803868" longitude="144.969609" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/49" _id="199" _position="199" _uuid="8EF503F8-ADF0-4BAA-8C7F-ED39AE5E8196">
#    <id>
#     49
#    </id>
#    <featurename>
#     Jolimont Station - Wellington Pde South - East Melbourne
#    </featurename>
#    <terminalname>
#     60042
#    </terminalname>
#    <nbbikes>
#     3
#    </nbbikes>
#    <nbemptydoc>
#     8
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.816731" longitude="144.982006" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/50" _id="200" _position="200" _uuid="3F1BF86C-DC07-4395-9CD3-0A8D729C23AF">
#    <id>
#     50
#    </id>
#    <featurename>
#     ACCA - Sturt St - Southbank
#    </featurename>
#    <terminalname>
#     60043
#    </terminalname>
#    <nbbikes>
#     15
#    </nbbikes>
#    <nbemptydoc>
#     8
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.826578" longitude="144.966542" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/51" _id="201" _position="201" _uuid="FE678EF7-468B-4594-AF13-57858D566267">
#    <id>
#     51
#    </id>
#    <featurename>
#     ANZ - Collins St - Docklands
#    </featurename>
#    <terminalname>
#     60044
#    </terminalname>
#    <nbbikes>
#     9
#    </nbbikes>
#    <nbemptydoc>
#     10
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.821568" longitude="144.944488" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/52" _id="202" _position="202" _uuid="A5EFB6BA-5E93-4171-978B-8981B324B0A2">
#    <id>
#     52
#    </id>
#    <featurename>
#     Flagstaff Gardens - Peel St - West Melbourne
#    </featurename>
#    <terminalname>
#     60048
#    </terminalname>
#    <nbbikes>
#     6
#    </nbbikes>
#    <nbemptydoc>
#     5
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.809216" longitude="144.955223" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/53" _id="203" _position="203" _uuid="D531339E-DBBC-42B8-8937-8A2D8433C792">
#    <id>
#     53
#    </id>
#    <featurename>
#     Victoria Market - Elizabeth St / Victoria St - City
#    </featurename>
#    <terminalname>
#     60049
#    </terminalname>
#    <nbbikes>
#     15
#    </nbbikes>
#    <nbemptydoc>
#     10
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.806091" longitude="144.959017" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/55" _id="204" _position="204" _uuid="75FC6E82-0B5C-45DD-800E-3FFD5AD0B359">
#    <id>
#     55
#    </id>
#    <featurename>
#     Coventry St / Clarendon St - South Melbourne
#    </featurename>
#    <terminalname>
#     60050
#    </terminalname>
#    <nbbikes>
#     8
#    </nbbikes>
#    <nbemptydoc>
#     3
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.831776" longitude="144.960818" needs_recoding="false"/>
#   </row>
#   <row _address="http://data.melbourne.vic.gov.au/resource/tdvh-n9dv/57" _id="205" _position="205" _uuid="223A0CB0-60DD-4166-82F0-C2D181086C8E">
#    <id>
#     57
#    </id>
#    <featurename>
#     Fitzroy Street - St Kilda
#    </featurename>
#    <terminalname>
#     60052
#    </terminalname>
#    <nbbikes>
#     18
#    </nbbikes>
#    <nbemptydoc>
#     13
#    </nbemptydoc>
#    <uploaddate>
#     1453986006
#    </uploaddate>
#    <coordinates human_address='{"address":"","city":"","state":"","zip":""}' latitude="-37.858655" longitude="144.978818" needs_recoding="false"/>
#   </row>
#  </row>
# </response>

# %% [markdown]
# The soup object contains all of the XML content in the original document.
# The XML tags contained in the angled brackets provide structural information (and sometimes formatting).
# If you were to take a moment to print out the parsed tree, you would find Beautiful Soup did a good job.
# It provides a structural representation of the original XML document.
# Now it is easy for you to eyeball the document and the tags or attributes containing the data we want.
# We will stop here and leave the extraction of the data with Beautiful Soup as a simple exercise for you.
# A tutorial on how to use Beautiful Soup can be found [here](https://www.crummy.com/software/BeautifulSoup/bs4/doc/).
#
# * * *

# %% [markdown]
# ## 2. Extracting XML data into DataFrame
# So far we have loaded XML into an element tree and have also found all the tags that contain the data we want.
# We have worked with our XML file in a top-down fashion, starting with the root element,
# then getting its child elements, and so on.
# We have also gained a brief idea of **lxml** and **beautiful soup**.
# This section will show you how to extract the data from all the tags and put it into Pandas DataFrame, a common
# and standard storage structure we used in the previous chapter.
# This structure will also be used in the following chapters.
# Before we walk through the extracting process, please read:
# * [Searching For Nodes Within An XML Document](http://www.diveintopython3.net/xml.html#xml-find) Section 12.5 in Chapter 12 of "**Dive into Python 3**". 📖
#
# Let's first just look at one tag, i.e., '*featurename*'.
# Since we don't know where it is, the code should loop over all the elements in the tree.
# To produce a simple list of the featurenames, the logic could be simplified using
# `findall()` to look for all the elements with tag name '*featurename*'.
# Both the ElementTree and the Element classes implement `findall(match)` function.
# The one implemented by the ElementTree class finds all the matched subelements starting from root.
# The other implemented by the Element finds those sub-elements starting from a given Element in the tree.
# All the matched elements returned by the function are stored in a list.
# The `match` argument should take values on either tag names or paths to specific tags.
# Try
# ```python
#     tree.findall('featurename')
# ```
# and
# ```python
#     tree.findall('row/featurename')
# ```
# What did you get?
#
# The '*featurename*' tag is not the child or grandchild of the root element.
# In order to get all the '*featurename*',
# we should first figure out the path from the root to the '*featurename*' tag.
# By looking at the original file or basing on what we learnt from the previous section, we know the path is
# ```html
#     row/row/featurename
# ```
# Thus,

# %%
elements = tree.findall('row/row/featurename')
elements
# Out:
# [<Element 'featurename' at 0x103dbaa10>,
#  <Element 'featurename' at 0x103dbac10>,
#  <Element 'featurename' at 0x103dbae10>,
#  <Element 'featurename' at 0x103dc7050>,
#  <Element 'featurename' at 0x103dc7250>,
#  <Element 'featurename' at 0x103dc7450>,
#  <Element 'featurename' at 0x103dc7650>,
#  <Element 'featurename' at 0x103dc7850>,
#  <Element 'featurename' at 0x103dc7a50>,
#  <Element 'featurename' at 0x103dc7c50>,
#  <Element 'featurename' at 0x103dc7e50>,
#  <Element 'featurename' at 0x103dd1090>,
#  <Element 'featurename' at 0x103dd1290>,
#  <Element 'featurename' at 0x103dd1490>,
#  <Element 'featurename' at 0x103dd1690>,
#  <Element 'featurename' at 0x103dd1890>,
#  <Element 'featurename' at 0x103dd1a90>,
#  <Element 'featurename' at 0x103dd1c90>,
#  <Element 'featurename' at 0x103dd1e90>,
#  <Element 'featurename' at 0x103dde0d0>,
#  <Element 'featurename' at 0x103dde2d0>,
#  <Element 'featurename' at 0x103dde510>,
#  <Element 'featurename' at 0x103dde710>,
#  <Element 'featurename' at 0x103dde910>,
#  <Element 'featurename' at 0x103ddeb10>,
#  <Element 'featurename' at 0x103dded10>,
#  <Element 'featurename' at 0x103ddef10>,
#  <Element 'featurename' at 0x103dec150>,
#  <Element 'featurename' at 0x103dec350>,
#  <Element 'featurename' at 0x103dec550>,
#  <Element 'featurename' at 0x103dec750>,
#  <Element 'featurename' at 0x103dec950>,
#  <Element 'featurename' at 0x103decb50>,
#  <Element 'featurename' at 0x103decd50>,
#  <Element 'featurename' at 0x103decf50>,
#  <Element 'featurename' at 0x103df9190>,
#  <Element 'featurename' at 0x103df9390>,
#  <Element 'featurename' at 0x103df9590>,
#  <Element 'featurename' at 0x103df9790>,
#  <Element 'featurename' at 0x103df9990>,
#  <Element 'featurename' at 0x103df9b90>,
#  <Element 'featurename' at 0x103df9d90>,
#  <Element 'featurename' at 0x103df9f90>,
#  <Element 'featurename' at 0x103e051d0>,
#  <Element 'featurename' at 0x103e05490>,
#  <Element 'featurename' at 0x103e056d0>,
#  <Element 'featurename' at 0x103e058d0>,
#  <Element 'featurename' at 0x103e05ad0>,
#  <Element 'featurename' at 0x103e05cd0>,
#  <Element 'featurename' at 0x103e05ed0>]

# %% [markdown]
# The above list should contain 50 Elements corresponding to '*featurename*'.
# As you may notice, the items returned by `findall()` are Element objects, each representing a node in the
# XML parse tree.
# What we want is the data stored in those objects.
# To pull out the data, we can access the element properpties: tag, attrib and text.

# %%
featurename = [elem.text for elem in elements]
featurename
# Out:
# ['Harbour Town - Docklands Dve - Docklands',
#  'Federation Square - Flinders St / Swanston St - City',
#  'Plum Garland Reserve - Beaconsfield Pde - Albert Park',
#  'State Library - Swanston St / Little Lonsdale St - City',
#  'Bourke Street Mall - 205 Bourke St - City',
#  'Melbourne Uni - Tin Alley - Carlton',
#  'RMIT - Swanston St / Franklin St - City',
#  "St Paul's Cathedral - Swanston St / Flinders St - City",
#  'MSAC - Aughtie Dve - Albert Park',
#  'Fitzroy Town Hall - Moor St - Fitzroy',
#  'Coventry St / St Kilda Rd - Southbank',
#  'NAB - Harbour Esp / Bourke St - Docklands',
#  "Yarra's Point - Lorimer St / Yarra River - Docklands",
#  'Argyle Square - Lygon St - Carlton',
#  'Parliament Station - Nicholson St / Albert St - City',
#  'Bridport St / Montague St - Albert Park',
#  'Pickles St / Ingles St - Port Melbourne',
#  "Yarra's Edge - River Esp / Yarra River - Docklands",
#  'North Melbourne Station - Adderley St - North Melbourne',
#  'Sandridge Bridge - Southbank',
#  'Beach St - Port Melbourne',
#  'New Quay Prom / Harbour Esp - Docklands',
#  'Queensbridge St / Yarra River - Southbank',
#  'Southern Cross Station - Spencer St - City',
#  'Gasworks Arts Park - Pickles St - Albert Park',
#  'Cleve Gardens - Fitzroy St - St Kilda',
#  'West Beach Pavilion - Beaconsfield Pde - St Kilda West',
#  'Siddeley St / Seafarers Bridge - Docklands',
#  'RACV - Bourke St / New Chancery Ln - City',
#  'Yorkshire Brewery - Wellington St - Collingwood',
#  'Napier St / Victoria Pde - Fitzroy',
#  'University Square - Grattan St - Carlton',
#  'Aquarium - Kings Way / Flinders St - City',
#  'Richmond Station - Brunton Ave - East Melbourne',
#  'Rod Laver Arena - Batman Ave / Swan St - City',
#  'Domain Interchange - Park St / St Kilda Rd - Melbourne',
#  'Kings Way / St Kilda Rd - Melbourne',
#  'Spring St / Collins St - City',
#  'Queens Rd / Bowen Cres - Melbourne',
#  'Luna Park - Lower Esp - St Kilda',
#  'South Melbourne Market - York St / Cecil St - South Melbourne',
#  'VCAM - St Kilda Rd / Southbank Blvd - Southbank',
#  'Museum - Rathdowne St - Carlton',
#  'Jolimont Station - Wellington Pde South - East Melbourne',
#  'ACCA - Sturt St - Southbank',
#  'ANZ - Collins St - Docklands',
#  'Flagstaff Gardens - Peel St - West Melbourne',
#  'Victoria Market - Elizabeth St / Victoria St - City',
#  'Coventry St / Clarendon St - South Melbourne',
#  'Fitzroy Street - St Kilda']

# %% [markdown]
# You might wonder whether there is another way to extract the text stored in the '*featurename*' tag.
# It might be possible that the structure of an XML file is quite complex (more complex that our example XML file)
# and it is not easy to figure out the path.
# There are other ways to search for descendant elements, i.e., children, grandchildrens,
# and any element at any nesting level.
# Using the same function, `findall()`, we can construct an XPath argument to look for all
# '*featurename*' elements.

# %%
tree.findall('.//featurename')
# Out:
# [<Element 'featurename' at 0x103dbaa10>,
#  <Element 'featurename' at 0x103dbac10>,
#  <Element 'featurename' at 0x103dbae10>,
#  <Element 'featurename' at 0x103dc7050>,
#  <Element 'featurename' at 0x103dc7250>,
#  <Element 'featurename' at 0x103dc7450>,
#  <Element 'featurename' at 0x103dc7650>,
#  <Element 'featurename' at 0x103dc7850>,
#  <Element 'featurename' at 0x103dc7a50>,
#  <Element 'featurename' at 0x103dc7c50>,
#  <Element 'featurename' at 0x103dc7e50>,
#  <Element 'featurename' at 0x103dd1090>,
#  <Element 'featurename' at 0x103dd1290>,
#  <Element 'featurename' at 0x103dd1490>,
#  <Element 'featurename' at 0x103dd1690>,
#  <Element 'featurename' at 0x103dd1890>,
#  <Element 'featurename' at 0x103dd1a90>,
#  <Element 'featurename' at 0x103dd1c90>,
#  <Element 'featurename' at 0x103dd1e90>,
#  <Element 'featurename' at 0x103dde0d0>,
#  <Element 'featurename' at 0x103dde2d0>,
#  <Element 'featurename' at 0x103dde510>,
#  <Element 'featurename' at 0x103dde710>,
#  <Element 'featurename' at 0x103dde910>,
#  <Element 'featurename' at 0x103ddeb10>,
#  <Element 'featurename' at 0x103dded10>,
#  <Element 'featurename' at 0x103ddef10>,
#  <Element 'featurename' at 0x103dec150>,
#  <Element 'featurename' at 0x103dec350>,
#  <Element 'featurename' at 0x103dec550>,
#  <Element 'featurename' at 0x103dec750>,
#  <Element 'featurename' at 0x103dec950>,
#  <Element 'featurename' at 0x103decb50>,
#  <Element 'featurename' at 0x103decd50>,
#  <Element 'featurename' at 0x103decf50>,
#  <Element 'featurename' at 0x103df9190>,
#  <Element 'featurename' at 0x103df9390>,
#  <Element 'featurename' at 0x103df9590>,
#  <Element 'featurename' at 0x103df9790>,
#  <Element 'featurename' at 0x103df9990>,
#  <Element 'featurename' at 0x103df9b90>,
#  <Element 'featurename' at 0x103df9d90>,
#  <Element 'featurename' at 0x103df9f90>,
#  <Element 'featurename' at 0x103e051d0>,
#  <Element 'featurename' at 0x103e05490>,
#  <Element 'featurename' at 0x103e056d0>,
#  <Element 'featurename' at 0x103e058d0>,
#  <Element 'featurename' at 0x103e05ad0>,
#  <Element 'featurename' at 0x103e05cd0>,
#  <Element 'featurename' at 0x103e05ed0>]

# %% [markdown]
# It is very similar to the previous example, except for the two slashes at the beginning of the query.
# The two slashes is short for '/descendant-or-self::node()/'.
# Here './/featurename' selects any 'featurename' element in the XML document.
# Similarly, we can extract the text with `Element.text`.
#
# Remember that to visit the elements in the XML document in order,
# you can use `iter()` to create an iterator that iterates over all the ElementTree instances in a tree.
# We have shown you how to explore the element hierarchy with this iteration fucntion.
# Here you are going to learn how to find specifc elements.
# [ElementTree's API](https://docs.python.org/2/library/xml.etree.elementtree.html#xml.etree.ElementTree.Element.findall)
# shows that `iter()` function can take an argument `tag`.
# If the tag is specified, the iterator loops over all elements in the tree and returns
# a list of elements having the specified tag.

# %%
featurename = [] 
for elem in tree.iter(tag = 'featurename'):
   featurename.append(elem.text) 
featurename
# Out:
# ['Harbour Town - Docklands Dve - Docklands',
#  'Federation Square - Flinders St / Swanston St - City',
#  'Plum Garland Reserve - Beaconsfield Pde - Albert Park',
#  'State Library - Swanston St / Little Lonsdale St - City',
#  'Bourke Street Mall - 205 Bourke St - City',
#  'Melbourne Uni - Tin Alley - Carlton',
#  'RMIT - Swanston St / Franklin St - City',
#  "St Paul's Cathedral - Swanston St / Flinders St - City",
#  'MSAC - Aughtie Dve - Albert Park',
#  'Fitzroy Town Hall - Moor St - Fitzroy',
#  'Coventry St / St Kilda Rd - Southbank',
#  'NAB - Harbour Esp / Bourke St - Docklands',
#  "Yarra's Point - Lorimer St / Yarra River - Docklands",
#  'Argyle Square - Lygon St - Carlton',
#  'Parliament Station - Nicholson St / Albert St - City',
#  'Bridport St / Montague St - Albert Park',
#  'Pickles St / Ingles St - Port Melbourne',
#  "Yarra's Edge - River Esp / Yarra River - Docklands",
#  'North Melbourne Station - Adderley St - North Melbourne',
#  'Sandridge Bridge - Southbank',
#  'Beach St - Port Melbourne',
#  'New Quay Prom / Harbour Esp - Docklands',
#  'Queensbridge St / Yarra River - Southbank',
#  'Southern Cross Station - Spencer St - City',
#  'Gasworks Arts Park - Pickles St - Albert Park',
#  'Cleve Gardens - Fitzroy St - St Kilda',
#  'West Beach Pavilion - Beaconsfield Pde - St Kilda West',
#  'Siddeley St / Seafarers Bridge - Docklands',
#  'RACV - Bourke St / New Chancery Ln - City',
#  'Yorkshire Brewery - Wellington St - Collingwood',
#  'Napier St / Victoria Pde - Fitzroy',
#  'University Square - Grattan St - Carlton',
#  'Aquarium - Kings Way / Flinders St - City',
#  'Richmond Station - Brunton Ave - East Melbourne',
#  'Rod Laver Arena - Batman Ave / Swan St - City',
#  'Domain Interchange - Park St / St Kilda Rd - Melbourne',
#  'Kings Way / St Kilda Rd - Melbourne',
#  'Spring St / Collins St - City',
#  'Queens Rd / Bowen Cres - Melbourne',
#  'Luna Park - Lower Esp - St Kilda',
#  'South Melbourne Market - York St / Cecil St - South Melbourne',
#  'VCAM - St Kilda Rd / Southbank Blvd - Southbank',
#  'Museum - Rathdowne St - Carlton',
#  'Jolimont Station - Wellington Pde South - East Melbourne',
#  'ACCA - Sturt St - Southbank',
#  'ANZ - Collins St - Docklands',
#  'Flagstaff Gardens - Peel St - West Melbourne',
#  'Victoria Market - Elizabeth St / Victoria St - City',
#  'Coventry St / Clarendon St - South Melbourne',
#  'Fitzroy Street - St Kilda']

# %% [markdown]
# The code pulls out data from all elements with a tag equal to '*featurename*', and stores the text in a list.
# Similarly, you can retrieve data from elements having the following tags: 'id', 'terminalname', 'nbbikes',
# 'nbemptydoc', and 'uploaddate' as follows. Note that we only print out the first 10 records of the retrieved data.

# %%
id = [] 
for elem in tree.iter(tag='id'):
       id.append(elem.text) 
id[:10]
# Out:
# ['2', '4', '5', '6', '7', '8', '9', '10', '11', '12']

# %%
terminalname = []
for elem in tree.iter(tag='terminalname'):
       terminalname.append(elem.text) 
terminalname[:10]
# Out:
# ['60000',
#  '60001',
#  '60002',
#  '60003',
#  '60004',
#  '60005',
#  '60006',
#  '60007',
#  '60008',
#  '60009']

# %%
nbbikes = []
for elem in tree.iter(tag='nbbikes'):
       nbbikes.append(elem.text)  
nbbikes[:10]
# Out:
# ['9', '15', '16', '9', '10', '2', '11', '4', '9', '3']

# %%
nbemptydoc  = []
for elem in tree.iter(tag='nbemptydoc'):
       nbemptydoc.append(elem.text) 
nbemptydoc[:10]
# Out:
# ['14', '7', '1', '2', '1', '17', '0', '7', '18', '4']

# %%
uploaddate = []
for elem in tree.iter(tag='uploaddate'):
       uploaddate.append(elem.text)  
uploaddate[:10]
# Out:
# ['1453986006',
#  '1453986006',
#  '1453986006',
#  '1453986006',
#  '1453986006',
#  '1453986006',
#  '1453986006',
#  '1453986006',
#  '1453986006',
#  '1453986006']

# %% [markdown]
# As mentioned in the introduction section, latitudes and longitudes
# are stored as attributes in 'coordinates' elements.
# Extracting them needs to access specific attributes that corresponds
# to latitude and longitude.
# Recall that attributes are dictionaries.
# To extract a specific attribute value, you can use the
# square brackets along with the attribute name as the key to obtain
# its value.
# Let's first extract all the latitudes and longitudes and store them in two lists,
# "lat" and "lon" respectively.

# %%
lat = []
lon = []
for elem in tree.iter(tag='coordinates'):
       lat.append(elem.attrib['latitude'])
       lon.append(elem.attrib['longitude'])
print lat[0:10]
print lon[0:10]
# Out:
# ['-37.814022', '-37.817523', '-37.84782', '-37.810702', '-37.813088', '-37.79625', '-37.807699', '-37.817189', '-37.842395', '-37.801813']
# ['144.939521', '144.967814', '144.948196', '144.964417', '144.967437', '144.960858', '144.963095', '144.967409', '144.961868', '144.979209']

# %% [markdown]
# The last step is to store the extracted data into Pandas DataFrame.
# There are multiple ways of constructing a DataFrame object.
# Here you are going to generate a DataFrame by passing a Python dictionary to DataFrame's constructor
# and setting the index to IDs.

# %%
import pandas as pd 
dataDict = {}
dataDict['Featurename'] = featurename
dataDict['TerminalName'] = terminalname
dataDict['NBBikes'] = nbbikes
dataDict['NBEmptydoc'] = nbemptydoc
dataDict['UploadDate'] = uploaddate
dataDict['lat'] = lat
dataDict['lon'] = lon
df = pd.DataFrame(dataDict, index = id)
df.index.name = 'ID'
df.head()
# Out:
#                                           Featurename NBBikes NBEmptydoc  \
# ID
# 2            Harbour Town - Docklands Dve - Docklands       9         14
# 4   Federation Square - Flinders St / Swanston St ...      15          7
# 5   Plum Garland Reserve - Beaconsfield Pde - Albe...      16          1
# 6   State Library - Swanston St / Little Lonsdale ...       9          2
# 7           Bourke Street Mall - 205 Bourke St - City      10          1
#
#    TerminalName  UploadDate         lat         lon
# ID
# 2         60000  1453986006  -37.814022  144.939521
# 4         60001  1453986006  -37.817523  144.967814
# 5         60002  1453986006   -37.84782  144.948196
# 6         60003  1453986006  -37.810702  144.964417
# 7         60004  1453986006  -37.813088  144.967437

# %% [markdown]
# Pandas DataFrame has automatically sorted the columns according the alphabetic order of column names.
# You can change the order and make the dataframe look exactly the same as the one you got in Chapter 2. It can be easily done by specifying the value of the `columns` argument in the DataFrame constructor.
# As a simple exercise, you are going to tidy up the dates, as we have done in Chapter 2.
# * * *

# %% [markdown]
# ## 3. Summary
# In this chapter we have shown you the process of extracting data from XML files with Python built-in libraries and briefly introduced two open source third-party libraries, i.e., lxml and Beautiful Soup. Together with the previous
# chapter, you have learnt how to extract data from CSV, JSON and XML files,
# the three common machine-readable formats.
# Being able to handle these formats with Python and related libraries is one of the must-have skills for a
# data wrangler.
# * * *
# ## 4. Exercises
#
# 1. We have shown you how to use ElementTree in Python step-by-step. Now try to extract the same data out from our XML file with Beautiful Soup.
# 2. Compare various data formats, CSV, JSON, XML, what are the pros & cons?
